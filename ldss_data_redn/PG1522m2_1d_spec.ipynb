# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/1D_Extractions_updated/PG1522m2/'

# %%
def load_spec_1d(rootdir, slit_num):
    
    spec_1d = fits.open(rootdir + '{}_1dspec.fits'.format(slit_num))
    
    wav0 = spec_1d[0].header['CRVAL1']
    delta_wav = spec_1d[0].header['CDELT1']
    
    flux = spec_1d[0].data[4,:]
    err = spec_1d[0].data[5,:]
    
    wav = np.arange(wav0, wav0+len(flux)*delta_wav, delta_wav)
    
    return spec_1d, wav, flux, err

# %%
def plot_spec(ax, rootdir, slit_num):
    
    spec_1d, wav, flux, err = load_spec_1d(rootdir, slit_num)
    ax.step(wav, flux, where='mid', color='black')
    ax.step(wav, err, where='mid', color='cyan')
    ax.set_title('SLIT {}'.format(slit_num))
    ax.set_xlabel('Wavelength (Å)')
    ax.set_ylabel('Relative Counts')

# %%
spec_1d, wav, flux, err = load_spec_1d(rootdir, 394)

# %%
spec_1d[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4310
# NAXIS2  =                    6
# BUNIT   = 'DU/PIXEL'
# ORIGIN  = 'PG1522m22/ccd1062c_394c1sfo.fits'
# OBSERVER= 'Eng'                        / observer name
# TELESCOP= 'Clay'                       / telescope
# SITENAME= 'LCO'
# SITEALT =                 2405         / meters
# SITELAT =            -29.01423
# SITELONG=            -70.69242
# TIMEZONE=                    4
# DATE-OBS= '2023-03-29T04:12:56'        / (start)
# UT-DATE = '2023-03-29'                 / UT date (start)
# UT-TIME = '04:12:56'                   / UT time (start) 15175 seconds
# TIME-OBS= '04:12:56'                   / UT time (start) 15175 seconds
# UT-END  = '04:42:56'                   / UT time (end) 16976 seconds
# LC-TIME = '01:12:56'                   / local time (start) 4376 seconds
# ...

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 394)
ax.set_ylim(-1000,6000)
# Out:
# (-1000.0, 6000.0)

# %%
spec_1d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_36092/4258909429.py in <module>
# ----> 1 spec_1d
#
# NameError: name 'spec_1d' is not defined

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 383)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 404)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 473)
ax.set_ylim(-1000,7000)
# Out:
# (-1000.0, 7000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 691)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 455)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 536)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 830)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 22)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 309)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 328)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))
plot_spec(ax, rootdir, 18)
ax.set_ylim(-1000,3000)
# Out:
# (-1000.0, 3000.0)
