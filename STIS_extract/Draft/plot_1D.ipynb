# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd
from astropy import constants, units
from astropy.io import fits
from stis_extract import *

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/'

# %% [markdown]
# # J011035

# %% [markdown]
# ## Alignment of individual exposures

# %%
exp_list = ['of8g05010', 'of8g05020', 'of8g05030', 'of8g08010', 'of8g08020']

spec_dict = {}
wav_dict = {}
flux_dict = {}
err_dict = {}

for exp_name in exp_list:

    wav_dict[exp_name],flux_dict[exp_name],err_dict[exp_name] = load_spec1d_fits(rootdir+'J011035/{}/'.format(exp_name),
                                                                                 'J011035_{}_es=4'.format(exp_name))

# %% [markdown]
# ### OF8G05010

# %%
fig, ax = plt.subplots(1, figsize=(15,4))
ax.step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black')
ax.step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')

ax.set_title('J011035 (of8g05010, extrsize=4)')
ax.axhline(0, linestyle='--')
#ax.set_xlim(2580,2610)
#ax.set_ylim(-3e-15, 10e-15)

# %%
fig, ax = plt.subplots(1, figsize=(15,4))
ax.step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black')
ax.step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')

ax.set_title('J011035 (of8g05010, extrsize=4)')
ax.axhline(0, linestyle='--')
ax.set_xlim(2580,2610)
ax.set_ylim(-3e-15, 10e-15)
# Out:
# (-3e-15, 1e-14)

# %% [markdown]
# ### OF8G05020

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g05020'], flux_dict['of8g05020'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g05020')
axes[0].step(wav_dict['of8g05020'], err_dict['of8g05020'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-3e-15, 10e-15)

axes[0].axhline(0, linestyle='--')

axes[0].set_title('J011035 (of8g05020)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g05020'], (flux_dict['of8g05020']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g05020']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g05020'], flux_dict['of8g05020'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g05020')
axes[0].step(wav_dict['of8g05020'], err_dict['of8g05020'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-3e-15, 10e-15)

axes[0].axhline(0, linestyle='--')

axes[0].set_title('J011035 (of8g05020)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g05020'], (flux_dict['of8g05020']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g05020']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %% [markdown]
# ### OF8G05030

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g05030'], flux_dict['of8g05030'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g05030')
axes[0].step(wav_dict['of8g05030'], err_dict['of8g05030'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

axes[0].axhline(0, linestyle='--')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-3e-15, 10e-15)

axes[0].set_title('J011035 (of8g05030)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g05030'], (flux_dict['of8g05030']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g05030']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g05030'], flux_dict['of8g05030'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g05030')
axes[0].step(wav_dict['of8g05030'], err_dict['of8g05030'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

axes[0].axhline(0, linestyle='--')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-3e-15, 10e-15)

axes[0].set_title('J011035 (of8g05030)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g05030'], (flux_dict['of8g05030']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g05030']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %% [markdown]
# ### OF8G08010

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g08010'], flux_dict['of8g08010'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g08010')
axes[0].step(wav_dict['of8g08010'], err_dict['of8g08010'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-3e-15, 10e-15)

axes[0].axhline(0, linestyle='--')

axes[0].set_title('J011035 (of8g08010)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g08010'], (flux_dict['of8g08010']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g08010']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g08010'], flux_dict['of8g08010'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g08010')
axes[0].step(wav_dict['of8g08010'], err_dict['of8g08010'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-3e-15, 10e-15)

axes[0].axhline(0, linestyle='--')

axes[0].set_title('J011035 (of8g08010)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g08010'], (flux_dict['of8g08010']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g08010']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %% [markdown]
# ### OF8G08020

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g08020'], flux_dict['of8g08020'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g08020')
axes[0].step(wav_dict['of8g08020'], err_dict['of8g08020'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

axes[0].axhline(0, linestyle='--')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-3e-15, 10e-15)

axes[0].set_title('J011035 (of8g08020)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g08020'], (flux_dict['of8g08020']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g08020']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_dict['of8g05010'], flux_dict['of8g05010'], where='mid', color='black', label='of8g05010')
axes[0].step(wav_dict['of8g05010'], err_dict['of8g05010'], where='mid', color='cyan')

axes[0].step(wav_dict['of8g08020'], flux_dict['of8g08020'], where='mid', linestyle='--', alpha=.5,
             color='black', label='of8g08020')
axes[0].step(wav_dict['of8g08020'], err_dict['of8g08020'], where='mid', linestyle='--', alpha=.5,
             color='cyan')

axes[0].axhline(0, linestyle='--')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-3e-15, 10e-15)

axes[0].set_title('J011035 (of8g08020)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_dict['of8g08020'], (flux_dict['of8g08020']-flux_dict['of8g05010'])/np.sqrt(err_dict['of8g08020']**2+err_dict['of8g05010']**2), 
             where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %% [markdown]
# ## Effect of extraction box size

# %%
spec_def = np.loadtxt(rootdir+'J011035/J011035_x1d.dat')
spec_cust_1 = np.loadtxt(rootdir+'J011035/J011035_x1d_es=3.dat')
spec_cust_2 = np.loadtxt(rootdir+'J011035/J011035_x1d_es=4.dat')
spec_cust_3 = np.loadtxt(rootdir+'J011035/J011035_x1d_es=5.dat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_80541/1399281941.py in <module>
# ----> 1 spec_def = np.loadtxt(rootdir+'J011035/J011035_x1d.dat')
#       2 spec_cust_1 = np.loadtxt(rootdir+'J011035/J011035_x1d_es=3.dat')
#       3 spec_cust_2 = np.loadtxt(rootdir+'J011035/J011035_x1d_es=4.dat')
#       4 spec_cust_3 = np.loadtxt(rootdir+'J011035/J011035_x1d_es=5.dat')
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1371         delimiter = delimiter.decode('latin1')
#    1372
# -> 1373     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374                 converters=converters, skiplines=skiprows, usecols=usecols,
# ...

# %%
wav_def, flux_def, err_def = spec_def[:,0], spec_def[:,1], spec_def[:,2]
wav_cust_1, flux_cust_1, err_cust_1 = spec_cust_1[:,0], spec_cust_1[:,1], spec_cust_1[:,2]
wav_cust_2, flux_cust_2, err_cust_2 = spec_cust_2[:,0], spec_cust_2[:,1], spec_cust_2[:,2]
wav_cust_3, flux_cust_3, err_cust_3 = spec_cust_3[:,0], spec_cust_3[:,1], spec_cust_3[:,2]

# %% [markdown]
# ### extrsize=7

# %%
fig, ax = plt.subplots(1, figsize=(15,4))
ax.step(wav_def, flux_def, where='mid', color='black')
ax.step(wav_def, err_def, where='mid', color='cyan')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')

ax.set_title('J011035 (default, extrsize=7)')

# %%
fig, ax = plt.subplots(1, figsize=(15,4))
ax.step(wav_def, flux_def, where='mid', color='black')
ax.step(wav_def, err_def, where='mid', color='cyan')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')

ax.set_title('J011035 (default, extrsize=7)')
ax.axhline(0, linestyle='--')
ax.set_xlim(2580,2610)
ax.set_ylim(-1.5e-15, 7e-15)

# %% [markdown]
# ### extrsize=3

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_cust_1, flux_cust_1, where='mid', color='black', label='extrsize=3')
axes[0].step(wav_cust_1, err_cust_1, where='mid', color='cyan')

axes[0].step(wav_def, flux_def, where='mid', color='black', alpha=.5, linestyle='--', label='extrsize=7')
axes[0].step(wav_def, err_def, where='mid', color='cyan', alpha=.5, linestyle='--')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-1.5e-15, 7e-15)

axes[0].set_title('J011035 (extrsize=3)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_cust_1, (flux_cust_1-flux_def)/np.sqrt(err_cust_1**2+err_def**2), where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_cust_1, flux_cust_1, where='mid', color='black', label='extrsize=3')
axes[0].step(wav_cust_1, err_cust_1, where='mid', color='cyan')

axes[0].step(wav_def, flux_def, where='mid', color='black', alpha=.5, linestyle='--', label='extrsize=7')
axes[0].step(wav_def, err_def, where='mid', color='cyan', alpha=.5, linestyle='--')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-1.5e-15, 7e-15)

axes[0].set_title('J011035 (extrsize=3)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_cust_1, (flux_cust_1-flux_def)/np.sqrt(err_cust_1**2+err_def**2), where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %% [markdown]
# ### extrsize=4

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_cust_2, flux_cust_2, where='mid', color='black', label='extrsize=4')
axes[0].step(wav_cust_2, err_cust_2, where='mid', color='cyan')

axes[0].step(wav_def, flux_def, where='mid', color='black', alpha=.5, linestyle='--', label='extrsize=7')
axes[0].step(wav_def, err_def, where='mid', color='cyan', alpha=.5, linestyle='--')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-1.5e-15, 7e-15)

axes[0].set_title('J011035 (extrsize=4)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_cust_2, (flux_cust_2-flux_def)/np.sqrt(err_cust_2**2+err_def**2), where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_cust_2, flux_cust_2, where='mid', color='black', label='extrsize=4')
axes[0].step(wav_cust_2, err_cust_2, where='mid', color='cyan')

axes[0].step(wav_def, flux_def, where='mid', color='black', alpha=.5, linestyle='--', label='extrsize=7')
axes[0].step(wav_def, err_def, where='mid', color='cyan', alpha=.5, linestyle='--')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-1.5e-15, 7e-15)

axes[0].set_title('J011035 (extrsize=4)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_cust_2, (flux_cust_2-flux_def)/np.sqrt(err_cust_2**2+err_def**2), where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %% [markdown]
# ### extrsize=5

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_cust_3, flux_cust_3, where='mid', color='black', label='extrsize=5')
axes[0].step(wav_cust_3, err_cust_3, where='mid', color='cyan')

axes[0].step(wav_def, flux_def, where='mid', color='black', alpha=.5, linestyle='--', label='extrsize=7')
axes[0].step(wav_def, err_def, where='mid', color='cyan', alpha=.5, linestyle='--')

#axes[0].set_xlim(2580,2610)
#axes[0].set_ylim(-1.5e-15, 7e-15)

axes[0].set_title('J011035 (extrsize=5)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_cust_3, (flux_cust_3-flux_def)/np.sqrt(err_cust_3**2+err_def**2), where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5.), gridspec_kw={'height_ratios': [2.8, 1]}, sharex=True)

axes[0].step(wav_cust_3, flux_cust_3, where='mid', color='black', label='extrsize=5')
axes[0].step(wav_cust_3, err_cust_3, where='mid', color='cyan')

axes[0].step(wav_def, flux_def, where='mid', color='black', alpha=.5, linestyle='--', label='extrsize=7')
axes[0].step(wav_def, err_def, where='mid', color='cyan', alpha=.5, linestyle='--')

axes[0].set_xlim(2580,2610)
axes[0].set_ylim(-1.5e-15, 7e-15)

axes[0].set_title('J011035 (extrsize=5)')
axes[0].set_ylabel(r'Flux (erg/s/cm${}^2$/Å)')
axes[0].legend()

axes[1].step(wav_cust_3, (flux_cust_3-flux_def)/np.sqrt(err_cust_3**2+err_def**2), where='mid', 
             color='black')

axes[1].set_ylabel(r'$\Delta f / \sigma_f$')
axes[1].set_xlabel('Wavelength (Å)')
# Out:
# Text(0.5, 0, 'Wavelength (Å)')
