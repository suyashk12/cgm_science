# %%
import stistools
import os
import glob
from pathlib import Path
# Out:
# /opt/anaconda3/envs/stenv/lib/python3.12/site-packages/stsci/tools/nmpfit.py:8: UserWarning: NMPFIT is deprecated - stsci.tools v 3.5 is the last version to contain it.
#   warnings.warn("NMPFIT is deprecated - stsci.tools v 3.5 is the last version to contain it.")
# /opt/anaconda3/envs/stenv/lib/python3.12/site-packages/stsci/tools/gfit.py:18: UserWarning: GFIT is deprecated - stsci.tools v 3.4.12 is the last version to contain it.Use astropy.modeling instead.
#   warnings.warn("GFIT is deprecated - stsci.tools v 3.4.12 is the last version to contain it."
# The following tasks in the stistools package can be run with TEAL:
#    basic2d      calstis     ocrreject     wavecal        x1d          x2d

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/'

# %%
def extract_1D(qso_name, extrsize=None):

    # Reference directory for finding calibration files
    os.environ['oref'] = rootdir+'{}/2D/'.format(qso_name)

    # Route to 2D files downloaded from MAST
    dir_list = glob.glob(rootdir+'{}/2D/*flt*'.format(qso_name))

    for f in dir_list:
        # Get exposure name
        exp_name = f.split('/')[-1].split('.')[0][:-4]

        # Create path
        if extrsize==None:
            es_str = ''
        else:
            es_str = '_es={}'.format(extrsize)

        # Make path available
        Path(rootdir+'{}/unstitched{}'.format(qso_name, es_str)).mkdir(parents=True, exist_ok=True)
        
        # Stitch and save 1D files
        stistools.x1d.x1d(f, 
                          output=rootdir+'{}/unstitched{}/{}_x1d'.format(qso_name, es_str, exp_name),
                          extrsize=extrsize)

# %% [markdown]
# # J011035

# %%
# Default extraction size
extract_1D('J011035')

# Try different extraction sizes
extract_1D('J011035', 3)
extract_1D('J011035', 4)
extract_1D('J011035', 5)
extract_1D('J011035', 6)
extract_1D('J011035', 7)
extract_1D('J011035', 8)
extract_1D('J011035', 14)
# Out:
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:24:59 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:24:59 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:24:59 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:24:59 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:24:59 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:24:59 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05020_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=3/of8g05020_x1d.fits
# Rootname of8g05020
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 19:24:59 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 19:25:00 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 21.9725
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# APDESTAB oref$16j16005o_apd.fits
# APDESTAB PEDIGREE=INFLIGHT 01/03/1997 01/03/1997
# APDESTAB DESCRIP =Aligned long-slit bar positions for single-bar cases.--------------
# APDESTAB DESCRIP =Microscope Meas./Hartig Post-launch Offsets
# INANGTAB oref$l3m1437ro_iac.fits
# INANGTAB PEDIGREE=GROUND
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler and Models
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# PHOTTAB  oref$77o18278o_pht.fits
# PHOTTAB  PEDIGREE=INFLIGHT 05/08/2009 25/10/2021
# PHOTTAB  DESCRIP =Updated sensitivity curves for E230H
# PHOTTAB  DESCRIP =2022 Recalibration
# APERTAB  oref$y2r1559to_apt.fits
# APERTAB  PEDIGREE=MODEL
# APERTAB  DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# APERTAB  DESCRIP =Bohlin/Hartig TIM Models Nov. 1998
# PCTAB    oref$y2r16003o_pct.fits
# PCTAB    PEDIGREE=INFLIGHT 18/05/1997 19/12/1998
# PCTAB    DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# TDSTAB   oref$8712049go_tds.fits
# TDSTAB   PEDIGREE=INFLIGHT 01/04/1997 16/03/2024
# TDSTAB   DESCRIP =Updated time sensitivities for MIRNUV and L, M, and H modes.
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 1 written to disk.
# Order 73 End 19:25:00 CDT
#
# Order 74 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 68.2706
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 2 written to disk.
# Order 74 End 19:25:00 CDT
#
# Order 75 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 113.385
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 3 written to disk.
# Order 75 End 19:25:00 CDT
#
# Order 76 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 157.377
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 4 written to disk.
# Order 76 End 19:25:00 CDT
#
# Order 77 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 200.376
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 5 written to disk.
# Order 77 End 19:25:00 CDT
#
# Order 78 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 242.243
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 6 written to disk.
# Order 78 End 19:25:00 CDT
#
# Order 79 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 283.131
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 7 written to disk.
# Order 79 End 19:25:00 CDT
#
# Order 80 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 323
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 19:25:00 CDT
#
# Order 81 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 361.904
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 19:25:00 CDT
#
# Order 82 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 399.951
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 19:25:00 CDT
#
# Order 83 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 436.954
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 19:25:00 CDT
#
# Order 84 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 473.179
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 19:25:00 CDT
#
# Order 85 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 508.552
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 19:25:00 CDT
#
# Order 86 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 543.058
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 19:25:00 CDT
#
# Order 87 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 576.783
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 19:25:00 CDT
#
# Order 88 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 609.737
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 19:25:00 CDT
#
# Order 89 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 641.969
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 19:25:00 CDT
#
# Order 90 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 673.436
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 19:25:00 CDT
#
# Order 91 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 704.238
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 19:25:00 CDT
#
# Order 92 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 734.395
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 19:25:00 CDT
#
# Order 93 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 763.866
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 19:25:00 CDT
#
# Order 94 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 792.702
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 19:25:00 CDT
#
# Order 95 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 820.993
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 19:25:00 CDT
#
# Order 96 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 848.69
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 19:25:00 CDT
#
# Order 97 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 875.844
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 19:25:00 CDT
#
# Order 98 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 902.335
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 19:25:00 CDT
#
# Order 99 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.803757 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 928.472
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 19:25:00 CDT
#
# Order100 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.81788 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 954.078
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 19:25:00 CDT
#
# Order101 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -1.03572 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 979.219
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 19:25:00 CDT
#
# Order102 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1003.98
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2084 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 19:25:00 CDT
#
# Order103 Begin 19:25:00 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 19:25:00 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      28-Jul-2024 19:25:00 CDT
#
# *** CALSTIS-6 complete ***
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:00 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08010_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=3/of8g08010_x1d.fits
# Rootname of8g08010
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 19:25:00 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 19:25:00 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: 0.603883 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 23.2233
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# APDESTAB oref$16j16005o_apd.fits
# APDESTAB PEDIGREE=INFLIGHT 01/03/1997 01/03/1997
# APDESTAB DESCRIP =Aligned long-slit bar positions for single-bar cases.--------------
# APDESTAB DESCRIP =Microscope Meas./Hartig Post-launch Offsets
# INANGTAB oref$l3m1437ro_iac.fits
# INANGTAB PEDIGREE=GROUND
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler and Models
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# PHOTTAB  oref$77o18278o_pht.fits
# PHOTTAB  PEDIGREE=INFLIGHT 05/08/2009 25/10/2021
# PHOTTAB  DESCRIP =Updated sensitivity curves for E230H
# PHOTTAB  DESCRIP =2022 Recalibration
# APERTAB  oref$y2r1559to_apt.fits
# APERTAB  PEDIGREE=MODEL
# APERTAB  DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# APERTAB  DESCRIP =Bohlin/Hartig TIM Models Nov. 1998
# PCTAB    oref$y2r16003o_pct.fits
# PCTAB    PEDIGREE=INFLIGHT 18/05/1997 19/12/1998
# PCTAB    DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# TDSTAB   oref$8712049go_tds.fits
# TDSTAB   PEDIGREE=INFLIGHT 01/04/1997 16/03/2024
# TDSTAB   DESCRIP =Updated time sensitivities for MIRNUV and L, M, and H modes.
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 1 written to disk.
# Order 73 End 19:25:00 CDT
#
# Order 74 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 69.4535
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 2 written to disk.
# Order 74 End 19:25:00 CDT
#
# Order 75 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 114.671
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 3 written to disk.
# Order 75 End 19:25:00 CDT
#
# Order 76 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 158.715
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 4 written to disk.
# Order 76 End 19:25:00 CDT
#
# Order 77 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 201.659
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 5 written to disk.
# Order 77 End 19:25:00 CDT
#
# Order 78 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 243.502
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 6 written to disk.
# Order 78 End 19:25:00 CDT
#
# Order 79 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 284.397
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 7 written to disk.
# Order 79 End 19:25:00 CDT
#
# Order 80 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 324.251
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 19:25:00 CDT
#
# Order 81 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 363.225
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 19:25:00 CDT
#
# Order 82 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 401.212
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 19:25:00 CDT
#
# Order 83 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 438.251
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 19:25:00 CDT
#
# Order 84 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 474.466
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 19:25:00 CDT
#
# Order 85 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 509.802
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 19:25:00 CDT
#
# Order 86 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 544.335
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 19:25:00 CDT
#
# Order 87 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 578.024
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 19:25:00 CDT
#
# Order 88 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 611.018
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 19:25:00 CDT
#
# Order 89 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 643.251
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 19:25:00 CDT
#
# Order 90 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 674.632
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 19:25:00 CDT
#
# Order 91 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 705.413
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 19:25:00 CDT
#
# Order 92 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 735.554
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 19:25:00 CDT
#
# Order 93 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 765.061
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 19:25:00 CDT
#
# Order 94 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 793.924
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 19:25:00 CDT
#
# Order 95 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 822.2
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 19:25:00 CDT
#
# Order 96 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 849.845
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 19:25:00 CDT
#
# Order 97 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 877.017
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 19:25:00 CDT
#
# Order 98 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: 0.62366 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 903.621
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 19:25:00 CDT
#
# Order 99 Begin 19:25:00 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 929.658
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 19:25:01 CDT
#
# Order100 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: 0.665706 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 955.32
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 19:25:01 CDT
#
# Order101 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: 0.621902 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 980.46
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 19:25:01 CDT
#
# Order102 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1005.17
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9441 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 19:25:01 CDT
#
# Order103 Begin 19:25:01 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 19:25:01 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      28-Jul-2024 19:25:01 CDT
#
# *** CALSTIS-6 complete ***
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:01 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05030_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=3/of8g05030_x1d.fits
# Rootname of8g05030
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 19:25:01 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 19:25:01 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 21.8946
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# APDESTAB oref$16j16005o_apd.fits
# APDESTAB PEDIGREE=INFLIGHT 01/03/1997 01/03/1997
# APDESTAB DESCRIP =Aligned long-slit bar positions for single-bar cases.--------------
# APDESTAB DESCRIP =Microscope Meas./Hartig Post-launch Offsets
# INANGTAB oref$l3m1437ro_iac.fits
# INANGTAB PEDIGREE=GROUND
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler and Models
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# PHOTTAB  oref$77o18278o_pht.fits
# PHOTTAB  PEDIGREE=INFLIGHT 05/08/2009 25/10/2021
# PHOTTAB  DESCRIP =Updated sensitivity curves for E230H
# PHOTTAB  DESCRIP =2022 Recalibration
# APERTAB  oref$y2r1559to_apt.fits
# APERTAB  PEDIGREE=MODEL
# APERTAB  DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# APERTAB  DESCRIP =Bohlin/Hartig TIM Models Nov. 1998
# PCTAB    oref$y2r16003o_pct.fits
# PCTAB    PEDIGREE=INFLIGHT 18/05/1997 19/12/1998
# PCTAB    DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# TDSTAB   oref$8712049go_tds.fits
# TDSTAB   PEDIGREE=INFLIGHT 01/04/1997 16/03/2024
# TDSTAB   DESCRIP =Updated time sensitivities for MIRNUV and L, M, and H modes.
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 1 written to disk.
# Order 73 End 19:25:01 CDT
#
# Order 74 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 68.193
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 2 written to disk.
# Order 74 End 19:25:01 CDT
#
# Order 75 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 113.288
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 3 written to disk.
# Order 75 End 19:25:01 CDT
#
# Order 76 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 157.306
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 4 written to disk.
# Order 76 End 19:25:01 CDT
#
# Order 77 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 200.281
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 5 written to disk.
# Order 77 End 19:25:01 CDT
#
# Order 78 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 242.146
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 6 written to disk.
# Order 78 End 19:25:01 CDT
#
# Order 79 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 282.994
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 7 written to disk.
# Order 79 End 19:25:01 CDT
#
# Order 80 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 322.927
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 19:25:01 CDT
#
# Order 81 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 361.882
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 19:25:01 CDT
#
# Order 82 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 399.845
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 19:25:01 CDT
#
# Order 83 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 436.9
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 19:25:01 CDT
#
# Order 84 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 473.071
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 19:25:01 CDT
#
# Order 85 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 508.47
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 19:25:01 CDT
#
# Order 86 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 542.935
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 19:25:01 CDT
#
# Order 87 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 576.686
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 19:25:01 CDT
#
# Order 88 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 609.665
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 19:25:01 CDT
#
# Order 89 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 641.906
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 19:25:01 CDT
#
# Order 90 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 673.342
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 19:25:01 CDT
#
# Order 91 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 704.214
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 19:25:01 CDT
#
# Order 92 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 734.281
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 19:25:01 CDT
#
# Order 93 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 763.827
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 19:25:01 CDT
#
# Order 94 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 792.664
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 19:25:01 CDT
#
# Order 95 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 820.932
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 19:25:01 CDT
#
# Order 96 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 848.561
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 19:25:01 CDT
#
# Order 97 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 875.671
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 19:25:01 CDT
#
# Order 98 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 902.344
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 19:25:01 CDT
#
# Order 99 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 928.359
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 19:25:01 CDT
#
# Order100 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 954.003
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 19:25:01 CDT
#
# Order101 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.94313 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 979.134
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 19:25:01 CDT
#
# Order102 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.681214 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1003.83
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 12.2234 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 19:25:01 CDT
#
# Order103 Begin 19:25:01 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 19:25:01 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      28-Jul-2024 19:25:01 CDT
#
# *** CALSTIS-6 complete ***
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:01 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08020_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=3/of8g08020_x1d.fits
# Rootname of8g08020
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 19:25:01 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 19:25:01 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 19:25:01 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: 0.665933 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 23.1576
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# ...
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 324.661
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 19:25:05 CDT
#
# Order 81 Begin 19:25:05 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 363.493
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 19:25:06 CDT
#
# Order 82 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 401.444
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 19:25:06 CDT
#
# Order 83 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 438.645
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 19:25:06 CDT
#
# Order 84 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 474.73
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 19:25:06 CDT
#
# Order 85 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 510.099
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 19:25:06 CDT
#
# Order 86 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 544.571
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 19:25:06 CDT
#
# Order 87 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 578.271
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 19:25:06 CDT
#
# Order 88 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 611.361
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 19:25:06 CDT
#
# Order 89 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 643.543
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 19:25:06 CDT
#
# Order 90 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 675.064
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 19:25:06 CDT
#
# Order 91 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 705.813
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 19:25:06 CDT
#
# Order 92 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 735.949
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 19:25:06 CDT
#
# Order 93 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 765.452
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 19:25:06 CDT
#
# Order 94 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 794.278
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 19:25:06 CDT
#
# Order 95 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 822.541
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 19:25:06 CDT
#
# Order 96 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 850.334
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 19:25:06 CDT
#
# Order 97 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 877.292
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 19:25:06 CDT
#
# Order 98 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 904.018
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 19:25:06 CDT
#
# Order 99 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 930.085
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 19:25:06 CDT
#
# Order100 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 955.75
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 19:25:06 CDT
#
# Order101 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: 0.325626 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 980.802
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 19:25:06 CDT
#
# Order102 Begin 19:25:06 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1005.56
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
#          Blaze shift of 11.9172 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 19:25:06 CDT
#
# Order103 Begin 19:25:06 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 19:25:06 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      28-Jul-2024 19:25:06 CDT
#
# *** CALSTIS-6 complete ***
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=6/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=6/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=6/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=6/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=6/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=7/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=7/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=7/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=7/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=7/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=8/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=8/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=8/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=8/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=8/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=14/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=14/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=14/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=14/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    28-Jul-2024 19:25:06 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/unstitched_es=14/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J011035/2D/of8g05010_flt.fits.
