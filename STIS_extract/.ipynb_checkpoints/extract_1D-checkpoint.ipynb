# %%
import stistools
import os
import glob
from pathlib import Path
# Out:
# /opt/anaconda3/envs/stenv/lib/python3.12/site-packages/stsci/tools/nmpfit.py:8: UserWarning: NMPFIT is deprecated - stsci.tools v 3.5 is the last version to contain it.
#   warnings.warn("NMPFIT is deprecated - stsci.tools v 3.5 is the last version to contain it.")
# /opt/anaconda3/envs/stenv/lib/python3.12/site-packages/stsci/tools/gfit.py:18: UserWarning: GFIT is deprecated - stsci.tools v 3.4.12 is the last version to contain it.Use astropy.modeling instead.
#   warnings.warn("GFIT is deprecated - stsci.tools v 3.4.12 is the last version to contain it."
# The following tasks in the stistools package can be run with TEAL:
#    basic2d      calstis     ocrreject     wavecal        x1d          x2d

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/'

# %%
def extract_1D(qso_name, extrsize=None):

    # Reference directory for finding calibration files
    os.environ['oref'] = rootdir+'{}/2D/'.format(qso_name)

    # Route to 2D files downloaded from MAST
    dir_list = glob.glob(rootdir+'{}/2D/*flt*'.format(qso_name))

    for f in dir_list:
        # Get exposure name
        exp_name = f.split('/')[-1].split('.')[0][:-4]

        # Create path
        if extrsize==None:
            es_str = ''
        else:
            es_str = '_es={}'.format(extrsize)

        # Make path available
        Path(rootdir+'{}/unstitched{}'.format(qso_name, es_str)).mkdir(parents=True, exist_ok=True)
        
        # Stitch and save 1D files
        stistools.x1d.x1d(f, 
                          output=rootdir+'{}/unstitched{}/{}_x1d'.format(qso_name, es_str, exp_name),
                          extrsize=extrsize)

# %% [markdown]
# # J011035

# %%
# Default extraction size
extract_1D('J011035')

# Try different extraction sizes
extract_1D('J011035', 3)
extract_1D('J011035', 4)
extract_1D('J011035', 5)
extract_1D('J011035', 6)
extract_1D('J011035', 7)
extract_1D('J011035', 8)
extract_1D('J011035', 14)
# Out:
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=3/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=4/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:02 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=5/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=6/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=7/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=8/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g05020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g06030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g08010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g05030_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05030_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g06020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g08020_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g08020_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g06010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g06010_flt.fits.
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:03 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/unstitched_es=14/of8g05010_x1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J011035/2D/of8g05010_flt.fits.

# %% [markdown]
# # J045415

# %%
extract_1D('J045415', 4)
# Out:
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:33 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J045415/2D/of8g38030_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J045415/unstitched_es=4/of8g38030_x1d.fits
# Rootname of8g38030
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 14:00:33 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 14:00:34 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.445882 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 22.001
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# APDESTAB oref$16j16005o_apd.fits
# APDESTAB PEDIGREE=INFLIGHT 01/03/1997 01/03/1997
# APDESTAB DESCRIP =Aligned long-slit bar positions for single-bar cases.--------------
# APDESTAB DESCRIP =Microscope Meas./Hartig Post-launch Offsets
# INANGTAB oref$l3m1437ro_iac.fits
# INANGTAB PEDIGREE=GROUND
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler and Models
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# PHOTTAB  oref$77o18278o_pht.fits
# PHOTTAB  PEDIGREE=INFLIGHT 05/08/2009 25/10/2021
# PHOTTAB  DESCRIP =Updated sensitivity curves for E230H
# PHOTTAB  DESCRIP =2022 Recalibration
# APERTAB  oref$y2r1559to_apt.fits
# APERTAB  PEDIGREE=MODEL
# APERTAB  DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# APERTAB  DESCRIP =Bohlin/Hartig TIM Models Nov. 1998
# PCTAB    oref$y2r16003o_pct.fits
# PCTAB    PEDIGREE=INFLIGHT 18/05/1997 19/12/1998
# PCTAB    DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# TDSTAB   oref$8712049go_tds.fits
# TDSTAB   PEDIGREE=INFLIGHT 01/04/1997 16/03/2024
# TDSTAB   DESCRIP =Updated time sensitivities for MIRNUV and L, M, and H modes.
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 1 written to disk.
# Order 73 End 14:00:34 CDT
#
# Order 74 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 68.2411
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 2 written to disk.
# Order 74 End 14:00:34 CDT
#
# Order 75 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 113.507
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 3 written to disk.
# Order 75 End 14:00:34 CDT
#
# Order 76 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 157.465
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 4 written to disk.
# Order 76 End 14:00:34 CDT
#
# Order 77 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 200.426
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 5 written to disk.
# Order 77 End 14:00:34 CDT
#
# Order 78 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 242.288
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 6 written to disk.
# Order 78 End 14:00:34 CDT
#
# Order 79 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 283.158
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 7 written to disk.
# Order 79 End 14:00:34 CDT
#
# Order 80 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 323.077
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 14:00:34 CDT
#
# Order 81 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 362.013
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 14:00:34 CDT
#
# Order 82 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 400.01
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 14:00:34 CDT
#
# Order 83 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 437.067
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 14:00:34 CDT
#
# Order 84 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 473.206
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 14:00:34 CDT
#
# Order 85 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 508.617
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 14:00:34 CDT
#
# Order 86 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 543.073
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 14:00:34 CDT
#
# Order 87 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 576.817
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 14:00:34 CDT
#
# Order 88 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 609.734
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 14:00:34 CDT
#
# Order 89 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 641.982
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 14:00:34 CDT
#
# Order 90 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 673.399
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 14:00:34 CDT
#
# Order 91 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 704.224
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 14:00:34 CDT
#
# Order 92 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 734.328
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 14:00:34 CDT
#
# Order 93 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 763.85
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 14:00:34 CDT
#
# Order 94 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 792.682
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 14:00:34 CDT
#
# Order 95 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 820.913
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 14:00:34 CDT
#
# Order 96 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 848.632
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 14:00:34 CDT
#
# Order 97 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 875.8
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 14:00:34 CDT
#
# Order 98 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 902.414
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 14:00:34 CDT
#
# Order 99 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 928.512
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 14:00:34 CDT
#
# Order100 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.432694 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 954.097
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 14:00:34 CDT
#
# Order101 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 979.194
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 14:00:34 CDT
#
# Order102 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.430434 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1003.93
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.3242 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 14:00:34 CDT
#
# Order103 Begin 14:00:34 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 14:00:34 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      14-Aug-2024 14:00:34 CDT
#
# *** CALSTIS-6 complete ***
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:34 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J045415/2D/of8g38020_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J045415/unstitched_es=4/of8g38020_x1d.fits
# Rootname of8g38020
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 14:00:34 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 14:00:34 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.390722 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 22.1574
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# APDESTAB oref$16j16005o_apd.fits
# APDESTAB PEDIGREE=INFLIGHT 01/03/1997 01/03/1997
# APDESTAB DESCRIP =Aligned long-slit bar positions for single-bar cases.--------------
# APDESTAB DESCRIP =Microscope Meas./Hartig Post-launch Offsets
# INANGTAB oref$l3m1437ro_iac.fits
# INANGTAB PEDIGREE=GROUND
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler and Models
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# PHOTTAB  oref$77o18278o_pht.fits
# PHOTTAB  PEDIGREE=INFLIGHT 05/08/2009 25/10/2021
# PHOTTAB  DESCRIP =Updated sensitivity curves for E230H
# PHOTTAB  DESCRIP =2022 Recalibration
# APERTAB  oref$y2r1559to_apt.fits
# APERTAB  PEDIGREE=MODEL
# APERTAB  DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# APERTAB  DESCRIP =Bohlin/Hartig TIM Models Nov. 1998
# PCTAB    oref$y2r16003o_pct.fits
# PCTAB    PEDIGREE=INFLIGHT 18/05/1997 19/12/1998
# PCTAB    DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# TDSTAB   oref$8712049go_tds.fits
# TDSTAB   PEDIGREE=INFLIGHT 01/04/1997 16/03/2024
# TDSTAB   DESCRIP =Updated time sensitivities for MIRNUV and L, M, and H modes.
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 1 written to disk.
# Order 73 End 14:00:34 CDT
#
# Order 74 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 68.4305
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 2 written to disk.
# Order 74 End 14:00:34 CDT
#
# Order 75 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 113.616
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 3 written to disk.
# Order 75 End 14:00:34 CDT
#
# Order 76 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 157.626
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 4 written to disk.
# Order 76 End 14:00:34 CDT
#
# Order 77 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 200.579
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 5 written to disk.
# Order 77 End 14:00:34 CDT
#
# Order 78 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 242.485
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 6 written to disk.
# Order 78 End 14:00:34 CDT
#
# Order 79 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 283.289
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 7 written to disk.
# Order 79 End 14:00:34 CDT
#
# Order 80 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 323.205
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 14:00:34 CDT
#
# Order 81 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 362.175
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 14:00:34 CDT
#
# Order 82 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 400.149
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 14:00:34 CDT
#
# Order 83 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 437.174
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 14:00:34 CDT
#
# Order 84 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 473.407
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 14:00:34 CDT
#
# Order 85 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 508.732
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 14:00:34 CDT
#
# Order 86 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 543.208
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 14:00:34 CDT
#
# Order 87 Begin 14:00:34 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 577.003
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 14:00:34 CDT
#
# Order 88 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 609.921
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 14:00:35 CDT
#
# Order 89 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 642.135
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 14:00:35 CDT
#
# Order 90 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 673.596
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 14:00:35 CDT
#
# Order 91 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 704.396
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 14:00:35 CDT
#
# Order 92 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 734.526
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 14:00:35 CDT
#
# Order 93 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 764.005
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 14:00:35 CDT
#
# Order 94 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 792.866
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 14:00:35 CDT
#
# Order 95 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 821.151
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 14:00:35 CDT
#
# Order 96 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 848.809
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 14:00:35 CDT
#
# Order 97 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 875.891
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 14:00:35 CDT
#
# Order 98 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.504441 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 902.555
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 14:00:35 CDT
#
# Order 99 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 928.565
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 14:00:35 CDT
#
# Order100 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 954.341
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 14:00:35 CDT
#
# Order101 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 979.365
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 14:00:35 CDT
#
# Order102 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1004
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 14:00:35 CDT
#
# Order103 Begin 14:00:35 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 14:00:35 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      14-Aug-2024 14:00:35 CDT
#
# *** CALSTIS-6 complete ***
#
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    14-Aug-2024 14:00:35 CDT
#
# Warning  Grating-aperture throughput correction table (GACTAB) was not found,
#          and no gac corrections will be applied
# Input    /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J045415/2D/of8g38010_flt.fits
# Output   /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/STIS/J045415/unstitched_es=4/of8g38010_x1d.fits
# Rootname of8g38010
# OBSMODE  TIME-TAG
# APERTURE 0.2X0.2
# OPT_ELEM E230M
# DETECTOR NUV-MAMA
#
# XTRACTAB oref$l3m1437to_1dx.fits
# XTRACTAB PEDIGREE=GROUND
# XTRACTAB DESCRIP =Analysis from prop. 7064 and ground data
# XTRACTAB DESCRIP =Prelaunch Values
# SPTRCTAB oref$77o1827jo_1dt.fits
# SPTRCTAB PEDIGREE=INFLIGHT 27/02/1997 06/01/2010
# SPTRCTAB DESCRIP =New traces for select echelle secondary modes
#
# Imset 1  Begin 14:00:35 CDT
#          Input read into memory.
#          Begin offset analysis.
#          End offset analysis.
# Order 72 Begin 14:00:35 CDT
# Warning  Extraction position outside data array. Skipping order.
# Order 73 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.449316 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 22.1499
#
# DISPCORR PERFORM
# DISPTAB  oref$m7p16111o_dsp.fits
# DISPTAB  PEDIGREE=GROUND
# DISPTAB  DESCRIP =Dispersion coefficients reference table
# DISPTAB  DESCRIP =Prelaunch Calibration/Lindler
# APDESTAB oref$16j16005o_apd.fits
# APDESTAB PEDIGREE=INFLIGHT 01/03/1997 01/03/1997
# APDESTAB DESCRIP =Aligned long-slit bar positions for single-bar cases.--------------
# APDESTAB DESCRIP =Microscope Meas./Hartig Post-launch Offsets
# INANGTAB oref$l3m1437ro_iac.fits
# INANGTAB PEDIGREE=GROUND
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler and Models
# INANGTAB DESCRIP =Prelaunch Calibration/Lindler
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# PHOTTAB  oref$77o18278o_pht.fits
# PHOTTAB  PEDIGREE=INFLIGHT 05/08/2009 25/10/2021
# PHOTTAB  DESCRIP =Updated sensitivity curves for E230H
# PHOTTAB  DESCRIP =2022 Recalibration
# APERTAB  oref$y2r1559to_apt.fits
# APERTAB  PEDIGREE=MODEL
# APERTAB  DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# APERTAB  DESCRIP =Bohlin/Hartig TIM Models Nov. 1998
# PCTAB    oref$y2r16003o_pct.fits
# PCTAB    PEDIGREE=INFLIGHT 18/05/1997 19/12/1998
# PCTAB    DESCRIP =Added/updated values for 31X0.05NDA,31X0.05NDB,31X0.05NDC apertures
# TDSTAB   oref$8712049go_tds.fits
# TDSTAB   PEDIGREE=INFLIGHT 01/04/1997 16/03/2024
# TDSTAB   DESCRIP =Updated time sensitivities for MIRNUV and L, M, and H modes.
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 1 written to disk.
# Order 73 End 14:00:35 CDT
#
# Order 74 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 68.429
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 2 written to disk.
# Order 74 End 14:00:35 CDT
#
# Order 75 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 113.596
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 3 written to disk.
# Order 75 End 14:00:35 CDT
#
# Order 76 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 157.632
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 4 written to disk.
# Order 76 End 14:00:35 CDT
#
# Order 77 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 200.58
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 5 written to disk.
# Order 77 End 14:00:35 CDT
#
# Order 78 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 242.449
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 6 written to disk.
# Order 78 End 14:00:35 CDT
#
# Order 79 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 283.31
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 7 written to disk.
# Order 79 End 14:00:35 CDT
#
# Order 80 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 323.198
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 8 written to disk.
# Order 80 End 14:00:35 CDT
#
# Order 81 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 362.166
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 9 written to disk.
# Order 81 End 14:00:35 CDT
#
# Order 82 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 400.157
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 10 written to disk.
# Order 82 End 14:00:35 CDT
#
# Order 83 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 437.155
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 11 written to disk.
# Order 83 End 14:00:35 CDT
#
# Order 84 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 473.33
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 12 written to disk.
# Order 84 End 14:00:35 CDT
#
# Order 85 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 508.728
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 13 written to disk.
# Order 85 End 14:00:35 CDT
#
# Order 86 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 543.264
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 14 written to disk.
# Order 86 End 14:00:35 CDT
#
# Order 87 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 576.978
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 15 written to disk.
# Order 87 End 14:00:35 CDT
#
# Order 88 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 609.88
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 16 written to disk.
# Order 88 End 14:00:35 CDT
#
# Order 89 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 642.099
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 17 written to disk.
# Order 89 End 14:00:35 CDT
#
# Order 90 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 673.597
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 18 written to disk.
# Order 90 End 14:00:35 CDT
#
# Order 91 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 704.404
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 19 written to disk.
# Order 91 End 14:00:35 CDT
#
# Order 92 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 734.508
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 20 written to disk.
# Order 92 End 14:00:35 CDT
#
# Order 93 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 763.989
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 21 written to disk.
# Order 93 End 14:00:35 CDT
#
# Order 94 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 792.813
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 22 written to disk.
# Order 94 End 14:00:35 CDT
#
# Order 95 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 821.091
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 23 written to disk.
# Order 95 End 14:00:35 CDT
#
# Order 96 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 848.773
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 24 written to disk.
# Order 96 End 14:00:35 CDT
#
# Order 97 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.479289 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 875.947
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 25 written to disk.
# Order 97 End 14:00:35 CDT
#
# Order 98 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 902.443
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 26 written to disk.
# Order 98 End 14:00:35 CDT
#
# Order 99 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 928.643
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 27 written to disk.
# Order 99 End 14:00:35 CDT
#
# Order100 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.545548 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 954.246
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 28 written to disk.
# Order100 End 14:00:35 CDT
#
# Order101 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# Warning  Cross correlation to locate spectrum failed.
# Warning  The offset found was: -0.561102 pixels
# Warning  Using global offset instead.
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 979.387
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 29 written to disk.
# Order101 End 14:00:35 CDT
#
# Order102 Begin 14:00:35 CDT
# X1DCORR  PERFORM
# BACKCORR PERFORM
# BACKCORR COMPLETE
# X1DCORR  COMPLETE
#          Spectrum extracted at y position = 1004.18
#
# DISPCORR PERFORM
# DISPCORR COMPLETE
#
# HELCORR  PERFORM
# HELCORR  COMPLETE
#
# FLUXCORR PERFORM
# Warning  No exact extraction box height match in PCTAB.
# Warning  Using entry for height 3
#          Blaze shift of 12.2505 pixels applied to sensitivity curve.
# FLUXCORR COMPLETE
# SGEOCORR OMIT
#
#          Row 30 written to disk.
# Order102 End 14:00:35 CDT
#
# Order103 Begin 14:00:35 CDT
# Warning  Extraction position outside data array. Skipping order.
# Imset 1  End 14:00:35 CDT
#
# Warning  Keyword `XTRACALG' is being added to header.
# End      14-Aug-2024 14:00:35 CDT
#
# *** CALSTIS-6 complete ***
