# %%
import stistools
import os

# %%
os.environ["oref"] = "/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J224500/exp1/"

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/'

# %%
stistools.x1d.x1d(rootdir+'J224500/exp1/of8g42010_flt.fits', 
                  output=rootdir+'J224500/exp1/of8g42010_flt_1d')
# Out:
# *** CALSTIS-6 -- Version 3.4.2 (19-Jan-2018) ***
# Begin    23-Jul-2024 20:11:12 CDT
#
# ERROR    Output file `/Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J224500/exp1/of8g42010_flt_1d.fits' already exists.
# Error processing /Users/thepoetoftwilight/Documents/CUBS/Data/CONTACT/J224500/exp1/of8g42010_flt.fits.
# 1
