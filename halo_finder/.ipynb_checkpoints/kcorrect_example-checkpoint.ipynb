# %%
import numpy as np
import matplotlib.pyplot as plt
import kcorrect
from astropy.table import Table
import pandas as pd
from scipy.interpolate import interp1d
from astropy.cosmology import FlatLambdaCDM
import scipy.optimize as opt
import scipy.stats as st
#from dustmaps.sfd import SFDQuery

# %%
#kcorrect?

# %%
#import healpy

# %%
from dustmaps.config import config
config.reset()

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

# %% [markdown]
# # Custom bandpasses

# %% [markdown]
# ## F140W (JH gap) reprocess

# %%
F140W_rep = False

if F140W_rep == True:
    
    # Read bandpass
    bp_F140W = np.loadtxt('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/HST_images/wfcam_JH.dat')
    wav_F140W = np.round(bp_F140W[:,0],1)
    resp_F140W = bp_F140W[:,1]    
    
    # Make table
    t = Table([wav_F140W,resp_F140W],
               names=('lambda', 'pass'))
    
    # Save in fixed width format
    t.write('/opt/anaconda3/lib/python3.9/site-packages/kcorrect/data/responses/wfcam_JH.dat', 
            format='ascii.fixed_width', overwrite=True)

# %% [markdown]
# ## MUSE write

# %%
wav0_MUSE = 4751.284541786687 # In Å
dwav_MUSE = 1.25
N_pix_MUSE = 3681

wav_MUSE = np.arange(wav0_MUSE, wav0_MUSE+N_pix_MUSE*dwav_MUSE, dwav_MUSE)

# %%
# Define this for automation later
bandpasses_MUSE = {'pseudo_g': [4800,5800], 'pseudo_r': [6000,7500], 'pseudo_i': [7500,9000]}

# %%
MUSE_write = False

if MUSE_write == True:
    for k in list(bandpasses_MUSE.keys()):

        # Get wavelength limits
        wav_lims = bandpasses_MUSE[k]

        # Read in MUSE response
        df = pd.read_csv('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/MUSE/MUSE_bp.csv')
        df.columns = ['lambda','pass']
        # Edge effects
        wav_arr = 10*np.array([485,490] + list(df['lambda']) + [900,905]) # To Å
        pass_arr = np.array([0,29.808658] + list(df['pass']) + [25.065098,0])/100 # To fraction

        # Fix negatives
        pass_arr[pass_arr<=0] = 0
        
        # Interpolate along uniform wavelength array
        pass_interp = interp1d(wav_arr, pass_arr, fill_value=0, bounds_error=False)(wav_MUSE)

        # Isolate relevant wavelengths
        wav_idx = (wav_MUSE<wav_lims[0])|(wav_MUSE>wav_lims[1])
        # Create bandpass
        pass_interp[wav_idx] = 0 # Set bandpass not in filter


        # Save bandpass
        # Make table
        wav_idx_save = (wav_MUSE>=wav_lims[0]-15*dwav_MUSE)&(wav_MUSE<=wav_lims[1]+15*dwav_MUSE)
        t = Table([wav_MUSE[wav_idx_save],pass_interp[wav_idx_save]],
                   names=('lambda', 'pass'))

        plt.plot(wav_MUSE[wav_idx_save], pass_interp[wav_idx_save])

        # Save in fixed width format
        t.write('/opt/anaconda3/lib/python3.9/site-packages/kcorrect/data/responses/muse_{}.dat'.format(k), 
                format='ascii.fixed_width', overwrite=True)

# %% [markdown]
# # Utilities

# %% [markdown]
# Some definitions for HST

# %%
# Calibration and pivot wavelength for F814W
PHOTPLAM_F814W = 8045.5352
PHOTFLAM_F814W = 7.092805575e-20
# F_nu sensitivity calculation using pivot wavelength and F_lam sensitivity
# Formula presumably converts F_lam in erg/s/Å to F_nu in Jy
PHOTFNU_814W = 3.34e+4*PHOTPLAM_F814W**2*PHOTFLAM_F814W
t_exp_F814W = 546.0

# Calibration for F140W
PHOTFNU_F140W = 9.5432426E-08
t_exp_F140W = 555.875916

# Calibration for F160W 
PHOTFNU_F160W = 1.5308434e-07
t_exp_F160W = 227.93692 # seconds


# Make global dictionaries
PHOTFNU_dict = {'F814W':PHOTFNU_814W, 'F140W':PHOTFNU_F140W, 'F160W':PHOTFNU_F160W}
t_exp_dict = {'F814W':t_exp_F814W, 'F140W':t_exp_F140W, 'F160W':t_exp_F160W}

# %%
# Magnitude -> Janskys -> e/s -> e -> sqrt(e) -> err/s -> d(Jansky) -> dm = -(2.5/ln(10))*d(Jansky)/Jansky

# %% [markdown]
# Function to compute HST photometric error

# %%
# Poisson distribution
def poisson(n, lam):
    
    '''
    Returns the Poisson discrete PDF
    '''

    return lam**n*np.exp(-lam)/np.math.factorial(n)

# Equation for upper bound
def lam_u_eqn(lam_u, n, C):
    
    '''
    Equation whose roots return upper bound for n observations at a 
    confidence interval C (accounting for small number statistics). 
    Taken from Gehrels 1986.
    '''

    # Generate array of x values
    x_arr = np.arange(0,n+1)
    
    poisson_x = np.array([poisson(x, lam_u) for x in x_arr])
    
    return np.sum(poisson_x)-(1-C)

# Equation for lower bound
def lam_l_eqn(lam_l, n, C):
    
    '''
    Equation whose roots return lower bound for n observations at a 
    confidence interval C (accounting for small number statistics). 
    Taken from Gehrels 1986.    
    '''

    # Generate array of x values
    x_arr = np.arange(0,n)
    
    poisson_x = np.array([poisson(x, lam_l) for x in x_arr])
    
    return np.sum(poisson_x)-C

# Approximate solutions for seeding
def lam_u_approx(n, C):
    
    '''
    Approximate solution to upper bound equation, used for seeding exact solution.
    Taken from Gehrels 1986.
    '''

    # First compute number of Gaussian sigma
    S = st.norm.ppf(C)
    
    # Now use the formula
    return n + S*np.sqrt(n+1) + ((S**2+2)/3)

def lam_l_approx(n, C):
    
    '''
    Approximate solution to lower bound equation, used for seeding exact solution.
    Taken from Gehrels 1986.
    '''

    if(n==0):
        return 0
    
    # First compute number of Gaussian sigma
    S = st.norm.ppf(C)
    
    # Now use the formula
    return n - S*np.sqrt(n) + ((S**2-1)/3)

# Solve upper bound
def lam_u_eqn_solve(n, C):

    '''
    Root of the upper bound equation, found numerically with approximate solution
    as seed.
    '''
    
    lam_u = opt.fsolve(lam_u_eqn, x0=lam_u_approx(n, C), args=(n, C))[0]
        
    return lam_u

# Solve lower bound
def lam_l_eqn_solve(n, C):
    
    '''
    Root of the lower bound equation, found numerically with approximate solution
    as seed.
    '''

    if(n==0):
        return 0
    
    lam_l = opt.fsolve(lam_l_eqn, x0=lam_l_approx(n, C), args=(n, C))[0]
    
    return lam_l

# Pre-compute errors and interpolate for non-integer counts
n_arr = np.arange(0, 100)
lam_u_exact_arr = np.array([lam_u_eqn_solve(n, 0.8413) for n in n_arr])
lam_l_exact_arr = np.array([lam_l_eqn_solve(n, 0.8413) for n in n_arr])
lam_l_interp = interp1d(n_arr, lam_l_exact_arr, fill_value='extrapolate')
lam_u_interp = interp1d(n_arr, lam_u_exact_arr, fill_value='extrapolate')
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_6561/3072316160.py:8: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return lam**n*np.exp(-lam)/np.math.factorial(n)

# %%
def compute_phot_err(mags):
    
    '''
    mags: list of AB magnitudes in order of increasing wavelength
    '''
    
    F_nu_Jy_arr = 3631*10**(-0.4*mags) # In Jy
    
    dmags = np.zeros(len(mags))

    for i in range(len(PHOTFNU_dict)):
        
        filt = list(PHOTFNU_dict.keys())[i]
        F_nu_Jy = F_nu_Jy_arr[i]

        count_rate = F_nu_Jy/PHOTFNU_dict[filt] # Divide by sensitivity
        counts = count_rate*t_exp_dict[filt] # Get counts
        
        if counts<100:
            counts_err_hi = lam_u_interp(counts)-counts
            counts_err_lo = counts-lam_l_interp(counts)
            counts_err = .5*(counts_err_hi+counts_err_lo) # Get count error assuming Poisson counting
        else:
            counts_err = np.sqrt(counts)
            
        count_rate_err = counts_err/t_exp_dict[filt] # Divide counts by exposure time
        dF_nu_Jy = count_rate_err*PHOTFNU_dict[filt] # Get error in F_nu

        # Compute error in magnitude using propagation of error
        dmags[i] = np.abs((-2.5/np.log(10))*(dF_nu_Jy/F_nu_Jy))    
    
    return np.round(dmags,3)

# %% [markdown]
# All bandpasses

# %%
wavs_pass_min = np.array([4800,6000,7500,6800,11370,14210])
wavs_pass_max = np.array([5800,7500,9000,10000,16450,19240])

wavs_pass_cen = .5*(wavs_pass_max+wavs_pass_min)
dwavs_pass = .5*(wavs_pass_max-wavs_pass_min)

# %% [markdown]
# Extinction scaled to E(B-V)=1

# %%
ext_scale = np.array([3.255, 2.446, 1.758, 1.743, 0.754, 0.556])

# %% [markdown]
# Functions for maggies and ivar

# %%
def get_maggies(m):
    # Maggies
    mu = 10**(-0.4*m)
    return mu

# %%
def get_ivar_maggies(mu, dm):
    dmu = np.abs(-0.4*np.log(10)*dm*mu)
    # Inverse variance for maggies
    return dmu**-2

# %% [markdown]
# Functions for Mstar

# %%
def get_Mstar_15(Mr, Mg):
    
    if Mg-Mr<0.15:
        ML = -0.6
    else:
        ML = -1.01 + 2.95*(Mg-Mr) - 1.67*(Mg-Mr)**2
    
    return 1.872 - 0.4*Mr + ML

# %%
def get_Mstar_24(MB, ug):
    
    if ug<0.9:
        return -0.36*MB + 2.17*ug + 1.1
    else:
        return -0.36*MB + 0.72*ug + 2.4

# %% [markdown]
# ## z=0.0966

# %%
redshift = 0.0966
ebv = 0.0397

# %%
MUSE_mags = np.array([24.65, 24.18, 24.15])
dMUSE_mags = np.array([0.02, 0.02, 0.04])

HST_mags = np.array([23.803,22.883,22.655])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %%
dmags
# Out:
# array([0.02 , 0.02 , 0.04 , 0.017, 0.009, 0.016])

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g

# %%
responses_out = ['sdss_r0', 'sdss_g0',]
responses_map = ['muse_pseudo_r', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 7.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-14.07, -13.55, 7.6)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_g

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-13.42, 0.65, 7.4)

# %% [markdown]
# ## z=0.1203

# %%
redshift = 0.1203
ebv = 0.0397

# %%
MUSE_mags = np.array([18.8587, 18.1284, 17.6973])
dMUSE_mags = np.array([0.0003, 0.0002, 0.0003])

HST_mags = np.array([18.03,16.898,16.789])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.4

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.65, -19.81, 10.4)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_g

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.48, 1.72, 10.6)

# %% [markdown]
# ## z=0.1204

# %%
redshift = 0.1204
ebv = 0.0397

# %%
MUSE_mags = np.array([20.0668, 19.5231, 19.2059])
dMUSE_mags = np.array([0.0006, 0.0004, 0.0008])

HST_mags = np.array([19.784,18.48,18.369])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.7

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.25, -18.63, 9.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_g

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.43, 1.19, 9.9)

# %% [markdown]
# ## z=0.1264

# %%
redshift = 0.1264
ebv = 0.0397

# %%
MUSE_mags = np.array([26.7, 26.3, 25.5])
dMUSE_mags = np.array([0.1, 0.1, 0.1])

HST_mags = np.array([25.431,23.78,23.555])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 7.4

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-12.65, -12.12, 7.0)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_g

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-11.69, 2.36, 8.3)

# %% [markdown]
# ## z=0.1335

# %%
redshift = 0.1335
ebv = 0.0404

# %%
MUSE_mags = np.array([28.7, 27.8, 26.7])
dMUSE_mags = np.array([0.5, 0.2, 0.2])

HST_mags = np.array([26.456, 24.939, 24.807])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 7.0

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-11.3, -10.28, 6.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_g

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-9.85, 2.36, 7.6)

# %% [markdown]
# ## z=0.1393

# %%
redshift = 0.1393
ebv = 0.0397

# %%
MUSE_mags = np.array([24.13, 23.89, 23.58])
dMUSE_mags = np.array([0.02, 0.02, 0.04])

HST_mags = np.array([23.797,22.784,22.655])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 7.9

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-15.24, -14.92, 7.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_g

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_g']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-14.88, 0.22, 6.9)

# %% [markdown]
# ## z=0.2791

# %%
redshift = 0.2791
ebv = 0.0404

# %%
MUSE_mags = np.array([25.70, 25.25, 25.11])
dMUSE_mags = np.array([0.05, 0.04, 0.09])

HST_mags = np.array([25.358, 23.432, 23.282])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 8.4

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-15.24, -15.12, 7.4)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-15.04, 0.41, 7.4)

# %% [markdown]
# ## z=0.2915

# %%
redshift = 0.2915
ebv = 0.0404

# %%
MUSE_mags = np.array([26.49, 26.15, 25.50])
dMUSE_mags = np.array([0.07, 0.06, 0.08])

HST_mags = np.array([25.617, 23.838, 23.676])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 8.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-15.1, -14.26, 8.2)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-14.42, 0.34, 7.0)

# %% [markdown]
# ## z=0.3198

# %%
redshift = 0.3198
ebv = 0.0404

# %%
MUSE_mags = np.array([24.01, 23.43, 23.13])
dMUSE_mags = np.array([0.02, 0.01, 0.02])

HST_mags = np.array([23.027,21.89,21.746])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-17.76, -17.31, 9.0)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-17.15, 0.65, 8.7)

# %% [markdown]
# ## z=0.3286

# %%
redshift = 0.3286
ebv = 0.0404

# %%
MUSE_mags = np.array([22.21, 21.0403, 20.485])
dMUSE_mags = np.array([0.002, 0.0007, 0.001])

HST_mags = np.array([20.638, 19.609, 19.494])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.47, -19.66, 10.3)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_g
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_g', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.36, 1.65, 10.6)

# %% [markdown]
# ## z=0.3752

# %%
redshift = 0.3752
ebv = 0.0404

# %%
MUSE_mags = np.array([24.90, 24.15, 23.98])
dMUSE_mags = np.array([0.02, 0.01, 0.03])

HST_mags = np.array([24.418, 22.834, 22.624])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 8.9

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-17.44, -17.06, 8.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-16.94, 0.9, 9.1)

# %% [markdown]
# ## z=0.3759

# %%
redshift = 0.3759
ebv = 0.0397

# %%
MUSE_mags = np.array([26.92, 25.78, 25.46])
dMUSE_mags = np.array([0.09, 0.04, 0.07])

HST_mags = np.array([25.077,23.472,23.441])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 8.7

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-15.93, -15.33, 8.4)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-15.0, 1.37, 8.8)

# %% [markdown]
# ## z=0.4395

# %%
redshift = 0.4395
ebv = 0.0404

# %%
MUSE_mags = np.array([25.48, 24.21, 23.70])
dMUSE_mags = np.array([0.04, 0.01, 0.02])

HST_mags = np.array([23.55, 22.146, 22.313])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-18.13, -17.42, 9.4)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-17.09, 1.39, 9.6)

# %% [markdown]
# ## z=0.4581

# %%
redshift = 0.4581
ebv = 0.0404

# %%
MUSE_mags = np.array([23.125, 22.453, 22.341])
dMUSE_mags = np.array([0.006, 0.004, 0.008])

HST_mags = np.array([22.217,21.346,21.363])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.8

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.59, -19.28, 9.5)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.14, 0.7, 9.5)

# %% [markdown]
# ## z=0.4784

# %%
redshift = 0.4784
ebv = 0.0397

# %%
MUSE_mags = np.array([23.96, 23.17, 22.58])
dMUSE_mags = np.array([0.03, 0.02, 0.02])

HST_mags = np.array([23.194,21.987,21.776])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.43, -18.68, 9.9)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.57, 0.82, 9.6)

# %% [markdown]
# ## z=0.5191

# %%
redshift = 0.5191
ebv = 0.0404

# %%
MUSE_mags = np.array([25.30, 23.81, 23.28])
dMUSE_mags = np.array([0.03, 0.01, 0.01])

HST_mags = np.array([23.149,21.69,21.535])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.8

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.13, -18.4, 9.8)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.1, 1.58, 10.1)

# %% [markdown]
# ## z=0.5205

# %%
redshift = 0.5205
ebv = 0.0404

# %%
MUSE_mags = np.array([23.89, 22.791, 22.334])
dMUSE_mags = np.array([0.01, 0.005, 0.009])

HST_mags = np.array([22.342,21.384,21.272])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.1

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.92, -19.38, 9.9)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.14, 1.18, 10.1)

# %% [markdown]
# ## z=0.5257

# %%
redshift = 0.5257
ebv = 0.0397

# %%
MUSE_mags = np.array([28.0, 27.2, 26.6])
dMUSE_mags = np.array([0.4, 0.2, 0.3])

HST_mags = np.array([26.789, 24.939, 24.801])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 8.6

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-15.89, -15.1, 8.5)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-14.76, 0.96, 8.4)

# %% [markdown]
# ## z=0.5356

# %%
redshift = 0.5356
ebv = 0.0404

# %%
MUSE_mags = np.array([22.910, 21.621, 21.055])
dMUSE_mags = np.array([0.008, 0.003, 0.004])

HST_mags = np.array([21.132, 20.225, 20.069])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.3, -20.65, 10.6)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# muse_pseudo_r

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'muse_pseudo_r']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.41, 1.34, 10.7)

# %% [markdown]
# ## z=0.5723

# %%
redshift = 0.5723
ebv = 0.0397

# %%
MUSE_mags = np.array([23.86, 22.26, 21.536])
dMUSE_mags = np.array([0.02, 0.004, 0.006])

HST_mags = np.array([21.719, 20.567, 20.415])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.05, -20.24, 10.6)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.04, 1.6, 10.8)

# %% [markdown]
# ## z=0.6164

# %%
redshift = 0.6164
ebv = 0.0394

# %%
HST_mags = np.array([23.3,22.469,22.305])
dHST_mags = compute_phot_err(HST_mags)

mags = HST_mags
dmags = dHST_mags

mags -= ebv*ext_scale[3:]

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# wfpc2_f814w

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[3:], 1e9*3631*maggies, 
            xerr=dwavs_pass[3:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.8

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.45, -18.95, 9.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# wfpc2_f814w
# wfpc2_f814w

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'wfpc2_f814w', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[3:], 1e9*3631*maggies, 
            xerr=dwavs_pass[3:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.78, 1.04, 9.9)

# %% [markdown]
# ## z=0.6174

# %%
redshift = 0.6174
ebv = 0.0404

# %%
MUSE_mags = np.array([26.5, 25.62, 25.15])
dMUSE_mags = np.array([0.1,  0.04, 0.08])

HST_mags = np.array([25.294, 23.433, 23.254])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-17.85, -16.93, 9.3)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-16.94, 0.83, 9.0)

# %% [markdown]
# ## z=0.6178

# %%
redshift = 0.6178
ebv = 0.0404

# %%
MUSE_mags = np.array([23.85, 23.027, 22.79])
dMUSE_mags = np.array([0.01, 0.006, 0.01])

HST_mags = np.array([22.839,22.519,22.357])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.2

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.8, -19.5, 9.5)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.45, 0.72, 9.7)

# %% [markdown]
# ## z=0.6183

# %%
redshift = 0.6183
ebv = 0.0404

# %%
MUSE_mags = np.array([24.42, 23.835, 23.14])
dMUSE_mags = np.array([0.02, 0.009, 0.01])

HST_mags = np.array([23.222, 22.613, 22.531])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.7

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.55, -19.07, 9.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.69, 0.89, 9.8)

# %% [markdown]
# ## z=0.6469

# %%
redshift = 0.6469
ebv = 0.0397

# %%
MUSE_mags = np.array([26.6, 25.62, 25.11])
dMUSE_mags = np.array([0.1, 0.04, 0.08])

HST_mags = np.array([25.688, 23.091, 22.944])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-18.24, -16.66, 8.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-17.21, 0.51, 8.4)

# %% [markdown]
# ## z=0.6478

# %%
redshift = 0.6478
ebv = 0.0404

# %%
MUSE_mags = np.array([26.69,25.71,25.42])
dMUSE_mags = np.array([0.07, 0.03, 0.07])

HST_mags = np.array([25.258, 23.13, 22.991])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-17.86, -17.11, 9.3)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-17.08, 1.07, 9.3)

# %% [markdown]
# ## z=0.6518

# %%
redshift = 0.6518
ebv = 0.0404

# %%
HST_mags = np.array([22.175,21.234,21.109])
dHST_mags = compute_phot_err(HST_mags)

mags = HST_mags
dmags = dHST_mags

mags -= ebv*ext_scale[3:]

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# wfpc2_f814w

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[3:], 1e9*3631*maggies, 
            xerr=dwavs_pass[3:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.78, -20.25, 10.3)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# wfpc2_f814w
# wfpc2_f814w

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'wfpc2_f814w', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
HST_mags = np.array([22.232,21.234,21.109])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((np.array([22.17]),HST_mags))
dmags =  np.concatenate((np.array([0.02]), dHST_mags))

mags -= ebv*ext_scale[2:]

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[2:], 1e9*3631*maggies, 
            xerr=dwavs_pass[2:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.05, 1.1, 10.4)

# %% [markdown]
# ## z=0.6531

# %%
redshift = 0.6531
ebv = 0.0397

# %%
MUSE_mags = np.array([25.16, 24.29, 24.05])
dMUSE_mags = np.array([0.03, 0.02, 0.04])

HST_mags = np.array([24.187, 22.697, 22.483])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.6

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-18.95, -18.25, 9.7)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_r
# muse_pseudo_g
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_r', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.41, 0.7, 9.3)

# %% [markdown]
# ## z=0.6780

# %%
redshift = 0.6780
ebv = 0.0404

# %%
MUSE_mags = np.array([25.63, 24.15, 23.81])
dMUSE_mags = np.array([0.06, 0.02, 0.03])

HST_mags = np.array([23.634,22.512,22.415])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 9.9

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.26, -18.91, 9.4)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# muse_pseudo_g
# wfpc2_f814w

# %%
dresp_lams
# Out:
# array([[ 2251.   ,   801.   ,   699.   ,   589.   ,  6449.   ,  8449.   ],
#        [  645.154,   804.846,  2304.846,  2194.846,  8054.846, 10054.846],
#        [ 2704.06 ,  1254.06 ,   245.94 ,   135.94 ,  5995.94 ,  7995.94 ]])

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'muse_pseudo_g', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.68, 1.51, 10.2)

# %% [markdown]
# ## z=0.7010

# %%
redshift = 0.7010
ebv = 0.0397

# %%
MUSE_mags = np.array([24.89, 23.98, 23.33])
dMUSE_mags = np.array([0.04, 0.02, 0.02])

HST_mags = np.array([23.335, 21.244, 21.078])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.4

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.26, -19.33, 10.3)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# muse_pseudo_r
# wfpc2_f814w

# %%
dresp_lams
# Out:
# array([[2354.5  ,  904.5  ,  595.5  ,  485.5  , 6345.5  , 8345.5  ],
#        [ 726.643,  723.357, 2223.357, 2113.357, 7973.357, 9973.357],
#        [2813.77 , 1363.77 ,  136.23 ,   26.23 , 5886.23 , 7886.23 ]])

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'muse_pseudo_r', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.02, 1.25, 10.1)

# %% [markdown]
# ## z=0.7293

# %%
redshift = 0.7293
ebv = 0.0397

# %%
MUSE_mags = np.array([23.75, 22.872, 22.426])
dMUSE_mags = np.array([0.01, 0.005, 0.008])

HST_mags = np.array([22.33, 21.577, 21.419])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.0

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.72, -20.28, 10.1)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# muse_pseudo_r
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.3, 0.86, 10.3)

# %% [markdown]
# ## z=0.8217

# %%
redshift = 0.8217
ebv = 0.0404

# %%
MUSE_mags = np.array([25.05, 24.08, 23.3])
dMUSE_mags = np.array([0.04, 0.02, 0.03])

HST_mags = np.array([23.215, 22.064, 21.953])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.6, -19.8, 10.4)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.58, 1.09, 10.2)

# %% [markdown]
# ## z=0.8404

# %%
redshift = 0.8404
ebv = 0.0404

# %%
HST_mags = np.array([23.367, 21.864, 21.706])
dHST_mags = compute_phot_err(HST_mags)

mags = HST_mags
dmags = dHST_mags

mags -= ebv*ext_scale[3:]

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# wfpc2_f814w

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[3:], 1e9*3631*maggies, 
            xerr=dwavs_pass[3:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.4

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.81, -20.05, 10.5)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([8140,14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfpc2_f814w
# wfpc2_f814w
# wfpc2_f814w

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfpc2_f814w', 'wfpc2_f814w', 'wfpc2_f814w']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[3:], 1e9*3631*maggies, 
            xerr=dwavs_pass[3:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.76, 1.6, 10.7)

# %% [markdown]
# ## z=0.8458

# %%
redshift = 0.8458
ebv = 0.0404

# %%
MUSE_mags = np.array([24.367, 23.229, 22.311])
dMUSE_mags = np.array([0.002, 0.001, 0.001])

HST_mags = np.array([22.388, 21.283, 21.115])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i', 'wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.4

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.47, -20.85, 10.6)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r
# muse_pseudo_i

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.68, 1.21, 10.7)

# %% [markdown]
# ## z=0.9576

# %%
redshift = 0.9576
ebv = 0.0404

# %%
MUSE_mags = np.array([24.338, 23.442, 22.511])
dMUSE_mags = np.array([0.003, 0.001, 0.001])

HST_mags = np.array([22.363, 21.06, 20.925])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.9

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-22.0, -21.3, 10.9)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-21.03, 1.29, 10.9)

# %% [markdown]
# ## z=1.0959

# %%
redshift = 1.0959
ebv = 0.0397

# %%
MUSE_mags = np.array([26.44, 26.23, 25.76])
dMUSE_mags = np.array([0.01, 0.01, 0.02])

HST_mags = np.array([25.533,23.742,23.388])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.0

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-19.64, -18.65, 10.0)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.37, 1.05, 9.8)

# %% [markdown]
# ## z=1.1932

# %%
redshift = 1.1932
ebv = 0.0397

# %%
MUSE_mags = np.array([27.31, 26.62, 26.02])
dMUSE_mags = np.array([0.03, 0.01, 0.02])

HST_mags = np.array([25.776, 23.678, 23.51])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.1

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.02, -19.0, 10.1)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-18.69, 1.15, 10.0)

# %% [markdown]
# ## z=1.1935

# %%
redshift = 1.1935
ebv = 0.0397

# %%
MUSE_mags = np.array([24.704, 24.261, 23.799])
dMUSE_mags = np.array([0.002, 0.002, 0.003])

HST_mags = np.array([23.519, 22.328, 22.202])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.6

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.4, -20.81, 10.6)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.61, 0.65, 9.9)

# %% [markdown]
# ## z=1.2256

# %%
redshift = 1.2256
ebv = 0.0397

# %%
MUSE_mags = np.array([25.879, 25.234, 24.655])
dMUSE_mags = np.array([0.007, 0.004, 0.006])

HST_mags = np.array([24.765, 23.365, 23.254])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.0

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-20.46, -20.03, 10.0)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-19.88, 1.03, 10.3)

# %% [markdown]
# ## z=1.2787

# %%
redshift = 1.2787
ebv = 0.0404

# %%
MUSE_mags = np.array([26.45, 25.299, 24.26])
dMUSE_mags = np.array([0.01, 0.005, 0.005])

HST_mags = np.array([24.031,22.043,22.006])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.8

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.89, -21.15, 10.9)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# wfpc2_f814w
# muse_pseudo_i

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'wfpc2_f814w', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.88, 1.24, 10.8)

# %% [markdown]
# ## z=1.2988

# %%
redshift = 1.2988
ebv = 0.0404

# %%
# Make global dictionaries
PHOTFNU_dict_IR = {'F140W':PHOTFNU_F140W, 'F160W':PHOTFNU_F160W}
t_exp_dict_IR = {'F140W':t_exp_F140W, 'F160W':t_exp_F160W}

# %%
def compute_phot_err_IR(mags):
    
    '''
    mags: list of AB magnitudes
    '''
    
    F_nu_Jy_arr = 3631*10**(-0.4*mags) # In Jy
    
    dmags = np.zeros(len(mags))

    for i in range(len(PHOTFNU_dict_IR)):
        
        filt = list(PHOTFNU_dict_IR.keys())[i]
        F_nu_Jy = F_nu_Jy_arr[i]

        count_rate = F_nu_Jy/PHOTFNU_dict_IR[filt] # Divide by sensitivity
        counts = count_rate*t_exp_dict_IR[filt] # Get counts

        counts_err = np.sqrt(counts) # Get count error assuming Poisson counting
        count_rate_err = counts_err/t_exp_dict_IR[filt] # Divide counts by exposure time
        dF_nu_Jy = count_rate_err*PHOTFNU_dict_IR[filt] # Get error in F_nu

        # Compute error in magnitude using propagation of error
        dmags[i] = np.abs((-2.5/np.log(10))*(dF_nu_Jy/F_nu_Jy))    
    
    return np.round(dmags,3)

# %%
HST_mags = np.array([22.141,21.962])
dHST_mags = compute_phot_err_IR(HST_mags)

mags = HST_mags
dmags = dHST_mags

mags -= ebv*ext_scale[4:]

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([14000,16000])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# wfcam_JH

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'wfcam_JH']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[4:], 1e9*3631*maggies, 
            xerr=dwavs_pass[4:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.3

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.81, -21.52, 10.3)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([14000,16000])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# wfcam_JH
# wfcam_JH

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['wfcam_JH', 'wfcam_JH', 'wfcam_JH']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[4:], 1e9*3631*maggies, 
            xerr=dwavs_pass[4:], yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-21.43, 0.73, 10.4)

# %% [markdown]
# ## z=1.0426

# %%
redshift = 1.0426
ebv = 0.0397

# %%
MUSE_mags = np.array([28.8, 25.46, 24.05])
dMUSE_mags = np.array([0.6, 0.03, 0.02])

HST_mags = np.array([23.913, 22.271, 22.012])
dHST_mags = compute_phot_err(HST_mags)

mags = np.concatenate((MUSE_mags,HST_mags))
dmags = np.concatenate((dMUSE_mags,dHST_mags))

mags -= ebv*ext_scale

maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %% [markdown]
# ### J15

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[6231,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# wfcam_JH
# muse_pseudo_i

# %%
responses_out = ['sdss_r0', 'sdss_g0']
responses_map = ['wfcam_JH', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
derived = kc.derived(redshift=redshift, coeffs=coeffs)
Mstar_KC = np.log10(derived['mremain'])

# %%
np.round(Mstar_KC,1)
# Out:
# 10.5

# %%
Mr = absmag[0]
Mg = absmag[1]
Mstar = get_Mstar_15(Mr, Mg)

# %%
np.round(Mr,2), np.round(Mg,2), np.round(Mstar,1)
# Out:
# (-21.03, -20.32, 10.5)

# %% [markdown]
# ### Q24

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
dresp_lams = np.abs(responses_out_lams.T*(1+redshift)-responses_lams)
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']

for i in range(dresp_lams.shape[0]):
    print(responses[np.argmin(dresp_lams[i,:])])
# Out:
# muse_pseudo_i
# muse_pseudo_r
# muse_pseudo_i

# %%
responses_out = ['bessell_B', 'sdss_u0', 'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %%
fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift))
spec = np.array(coeffs.dot(kc.templates.restframe_flux) / (1. + redshift))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies, 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
# Out:
# (4500.0, 17000.0)

# %%
MB = absmag[0]
ug = absmag[1]-absmag[2]
Mstar = get_Mstar_24(MB, ug)

# %%
np.round(MB,2), np.round(ug,2), np.round(Mstar,1)
# Out:
# (-20.01, 1.88, 11.0)

# %% [markdown]
# # DRAFT

# %%
def compute_phot_err(mag, filt):
    
    '''
    mags: list of AB magnitudes
    '''
    
    F_nu_Jy = 3631*10**(-0.4*mag) # In Jy

    count_rate = F_nu_Jy/PHOTFNU_dict[filt] # Divide by sensitivity
    counts = count_rate*t_exp_dict[filt] # Get counts

    counts_err = np.sqrt(counts) # Get count error assuming Poisson counting
    count_rate_err = counts_err/t_exp_dict[filt] # Divide counts by exposure time
    dF_nu_Jy = count_rate_err*PHOTFNU_dict[filt] # Get error in F_nu

    # Compute error in magnitude using propagation of error
    dmag = np.abs((-2.5/np.log(10))*(dF_nu_Jy/F_nu_Jy))    

    return np.round(dmag,3)

# %%
pg_mags = np.array([25.683,26.415,25.945,26.446])
#pg_mags -= np.array([0.131,0.129,0.129,0.131])
dpg_mags = np.array([0.006,0.011,0.008,0.012])

pr_mags = np.array([24.147,26.204,25.405,25.299])
#pr_mags -= np.array([0.099,0.097,0.097,0.099])
dpr_mags = np.array([0.002,0.010,0.005,0.005])

pi_mags = np.array([23.800,25.714,24.852,24.260])
#pi_mags -= np.array([0.071,0.070,0.070,0.071])
dpi_mags = np.array([0.003,0.017,0.008,0.005])

# %%
pg_mags[0], dpg_mags[0]

# %%
pr_mags[0], dpr_mags[0]

# %%
pi_mags[0], dpi_mags[0]

# %%
F814W_mags = np.array([23.634,25.533,24.765,24.031])
#F814W_mags -= np.array([0.070,0.069,0.069,0.070])
dF814W_mags = [compute_phot_err(mag,'F814W') for mag in F814W_mags]

F140W_mags = np.array([22.137,23.341,22.894,22.134])
#F140W_mags -= np.array([0.030,0.030,0.030,0.030])
dF140W_mags = [compute_phot_err(mag,'F140W') for mag in F140W_mags]

F160W_mags = np.array([21.989,23.178,22.693,22.049])
#F160W_mags -= np.array([0.022,0.022,0.022,0.022])
dF160W_mags = [compute_phot_err(mag,'F160W') for mag in F160W_mags]

# %%
dF140W_mags, dF160W_mags, dF814W_mags

# %%
redshift = np.array([0.6780, 1.0959, 1.2256, 1.2787])

mags = np.zeros((4,6))
dmags = np.zeros((4,6))

mags[:,0] = pg_mags
dmags[:,0] = dpg_mags

mags[:,1] = pr_mags
dmags[:,1] = dpr_mags

mags[:,2] = pi_mags
dmags[:,2] = dpi_mags

mags[:,3] = F814W_mags
dmags[:,3] = dF814W_mags

mags[:,4] = F140W_mags
dmags[:,4] = dF140W_mags

mags[:,5] = F160W_mags
dmags[:,5] = dF160W_mags

# %%
mags

# %%
#dmags = 0.6*np.ones((4,3))

# %%
dmags

# %%
df = pd.DataFrame()

# %%
df['z'] = redshift

# %%
df['pseudo-g'] = pg_mags
df['pseudo-r'] = pr_mags
df['pseudo-i'] = pi_mags
df['F814W'] = F814W_mags
df['F140W'] = F140W_mags
df['F160W'] = F160W_mags

# %%
df

# %% [markdown]
# # Bandpass filter wavelengths

# %%
#wavs_pass_min = np.array([11370.0,14210.0,6800.0,4800,6000,7500])
#wavs_pass_max = np.array([16450.0,19240.0,10000.0,5800,7500,9000])

wavs_pass_min = np.array([4800,6000,7500,6800,11370,14210])
wavs_pass_max = np.array([5800,7500,9000,10000,16450,19240])

wavs_pass_cen = .5*(wavs_pass_max+wavs_pass_min)
dwavs_pass = .5*(wavs_pass_max-wavs_pass_min)

# %%
wavs_pass_cen

# %% [markdown]
# # Fit

# %%
def get_maggies(m):
    # Maggies
    mu = 10**(-0.4*m)
    return mu

# %%
def get_ivar_maggies(mu, dm):
    dmu = np.abs(-0.4*np.log(10)*dm*mu)
    # Inverse variance for maggies
    return dmu**-2

# %%
maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %%
maggies

# %%
ivar

# %%
responses_lams = np.array([5300,6750,8250,8140,14000,16000,])
responses_out_lams = np.array([[4500,3543,4770]])

# %%
responses_out_lams*(1+1)

# %%
np.abs(responses_out_lams.T*(1+1)-responses_lams)

# %%
responses = ['muse_pseudo_g', 'muse_pseudo_r', 'muse_pseudo_i','wfpc2_f814w','wfcam_JH','wfcam_H']
responses_out = ['bessell_B', 'sdss_u0',  'sdss_g0']
responses_map = ['muse_pseudo_i', 'muse_pseudo_r', 'muse_pseudo_i']

kc = kcorrect.kcorrect.Kcorrect(responses=responses, responses_out=responses_out, responses_map=responses_map,
                               cosmo=cosmo)

# "coeffs" is a [4,6]-array coefficients multiplying each template
coeffs = kc.fit_coeffs(redshift=redshift, maggies=maggies, ivar=ivar)

# "k" is a [3]-array with the K-corrections in magnitude units,
# from iri to Bug
k = kc.kcorrect(redshift=redshift, coeffs=coeffs)

# "absmag" is also a [3]-array resuling from applying K-corrections
# and the distance modulus
absmag = kc.absmag(redshift=redshift, maggies=maggies, ivar=ivar, coeffs=coeffs)

# %% [markdown]
# # Stellar mass estimates

# %%
MB = absmag[:,0]
ug = absmag[:,1]-absmag[:,2]

# %%
np.round(MB,2), np.round(ug,2)

# %%
def get_Mstar(MB, ug):
    
    logM_star_blue = -0.36*MB + 2.17*ug + 1.1
    logM_star_red = -0.36*MB + 0.72*ug + 2.4
    
    idx = ug>=0.9
    
    logM_star = logM_star_blue.copy()
    
    logM_star[idx] = logM_star_red[idx]
    
    return logM_star

# %%
np.round(get_Mstar(MB, ug), 1)

# %% [markdown]
# # Assess fit

# %%
n = 0

fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift[n]))
spec = np.array(coeffs.dot(kc.templates.restframe_flux)[n,:] / (1. + redshift[n]))

idx = (wave>=4500)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies[n,:], 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar[n,:]**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,17000)
ax.set_title(r'$z_\mathrm{gal}=0.6780, \ \log M_*/M_\odot = 7.9$', fontsize=14)

# %%
n = 1

fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift[n]))
spec = np.array(coeffs.dot(kc.templates.restframe_flux)[n,:] / (1. + redshift[n]))

idx = (wave>=4800)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies[n,:], 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar[n,:]**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4800,17000)
ax.set_title(r'$z_\mathrm{gal}=1.0959, \ \log M_*/M_\odot = 8.1$', fontsize=14)

# %%
n = 2

fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift[n]))
spec = np.array(coeffs.dot(kc.templates.restframe_flux)[n,:] / (1. + redshift[n]))

idx = (wave>=4800)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies[n,:], 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar[n,:]**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4800,17000)
ax.set_title(r'$z_\mathrm{gal}=1.2256, \ \log M_*/M_\odot = 8.5$', fontsize=14)

# %%
n = 3

fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift[n]))
spec = np.array(coeffs.dot(kc.templates.restframe_flux)[n,:] / (1. + redshift[n]))

idx = (wave>=4800)&(wave<=17000)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen, 1e9*3631*maggies[n,:], 
            xerr=dwavs_pass, yerr=1e9*3631*np.sqrt(ivar[n,:]**-1),
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4800,17000)
ax.set_title(r'$z_\mathrm{gal}=1.2787, \ \log M_*/M_\odot = 8.7$', fontsize=14)

# %% [markdown]
# # Select galaxies

# %%
redshift = np.array([#0.6780, 
                     #1.0959, 
                     #1.2256, 
                     1.2787,
                    ])

        # pseudo-g psuedo-r pseudo-i F814W F140W F160W
mags = np.array([
       #[25.8905696, 24.673364 , 24.4225636], #23.5323008, 20.6465592, 20.7507296], # z=0.67
       #[26.2763076, 26.100659 , 25.6345591,], #25.4552748, 22.5160102, 22.7950176], # z=1.09
       #[25.8070028, 25.302177 , 24.7729573,],# 24.6876644, 21.5651906, 21.5981328], # z=1.22
       [26.3055696, 25.194364 , 24.1795636,], #23.9523008, 20.7265592, 20.9007296], # z=1.27
        ])

dmags = np.array([
       #[0.008, 0.003, 0.006]#, 0.015, 0.003, 0.007],
       #[0.011, 0.01 , 0.017,],# 0.037, 0.008, 0.017],
       #[0.008, 0.005, 0.008,],# 0.026, 0.005, 0.010],
       [0.012, 0.005, 0.005,], # 0.019, 0.003, 0.007],
        ])

# %%
mags = np.zeros((4,6))
dmags = np.zeros((4,6))

mags[:,0] = pg_mags
dmags[:,0] = dpg_mags

mags[:,1] = pr_mags
dmags[:,1] = dpr_mags

mags[:,2] = pi_mags
dmags[:,2] = dpi_mags

mags[:,3] = F814W_mags
dmags[:,3] = dF814W_mags

mags[:,4] = F140W_mags
dmags[:,4] = dF140W_mags

mags[:,5] = F160W_mags
dmags[:,5] = dF160W_mags

# %%
maggies = get_maggies(mags)
ivar = get_ivar_maggies(maggies, dmags)

# %%
#wavs_pass_min = np.array([11370.0,14210.0,6800.0,4800,6000,7500])
#wavs_pass_max = np.array([16450.0,19240.0,10000.0,5800,7500,9000])

wavs_pass_min = np.array([4800,6000,7500,6800,11370,14210])
wavs_pass_max = np.array([5800,7500,9000,10000,16450,19240])

wavs_pass_cen = .5*(wavs_pass_max+wavs_pass_min)
dwavs_pass = .5*(wavs_pass_max-wavs_pass_min)

# %%
n = 0

fig, ax = plt.subplots(1, figsize=(6,3))

wave = np.array(kc.templates.restframe_wave * (1. + redshift[n]))
spec = np.array(coeffs.dot(kc.templates.restframe_flux)[n,:] / (1. + redshift[n]))

idx = (wave>=4500)&(wave<=9300)

wave_slice = wave[idx]
spec_slice = spec[idx]

ax.plot(wave_slice,1e9*3.34*10**4*wave_slice**2*spec_slice)
ax.errorbar(wavs_pass_cen[0:3], 1e9*3631*maggies[n,:][0:3], 
            xerr=dwavs_pass[0:3], yerr=1e9*3631*np.sqrt(ivar[n,:]**-1)[0:3],
           linestyle='none', capsize=4, marker='o',
           color='orangered')

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel('Flux (nJy)')
ax.set_xlim(4500,9300)
ax.set_title(r'$z_\mathrm{gal}=1.2256$', fontsize=14)
