# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import voigt_profile
from scipy import integrate, interpolate
from lmfit import minimize, Parameters
import emcee
import corner
import pandas as pd

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %% [markdown]
# Specify atomic parameters for LyA

# %%
wav0_rest = 1215.6701
f = 0.416400
gamma_nu = 6.265E8

# %% [markdown]
# Convert $\Gamma_\nu$ to $\Gamma_v$ (must be done in the rest frame)

# %%
# First convert wavelength to meters, then velocity to km/s
gamma_v = (gamma_nu*(wav0_rest*1e-10))*1e-3

# %% [markdown]
# Thomson scattering cross-section

# %%
sigma_0 = 2.654E-2 # In cm^-2

# %% [markdown]
# Specify the redshift, wavelength range of observation, and velocity pixel size

# %%
z_test = 0.1
wav0_obs_min = 1250
wav0_obs_max = 1450
delta_v_pix = 2.3

# %% [markdown]
# Use this information to generate the velocity array

# %%
wav0_obs = wav0_rest*(1+z_test) # Observed wavelength of transition
v_min = 3e+5*(wav0_obs_min-wav0_obs)/wav0_obs
v_max = 3e+5*(wav0_obs_max-wav0_obs)/wav0_obs
v = np.arange(v_min, v_max+delta_v_pix, delta_v_pix)

# %% [markdown]
# Generate the Ly$\alpha$ lines

# %%
N = 1e+12 # cm^-2
b = 12.9
sigma_v = b/np.sqrt(2)

# %%
def vp(v, N, ctn):
    
    tau = N*sigma_0*f*voigt_profile(v, sigma_v, gamma_v/(4*np.pi))*wav0_rest*1e-13
    flux = np.exp(-tau)+(1-ctn)
    
    return flux

# %%
flux = vp(v, N, 1)

# %%
fig, ax = plt.subplots(1, figsize=(7,4))
ax.step(v, flux, where='mid')

ax.axhline(0, linestyle=':', color='red')
ax.axhline(1, linestyle=':', color='green')
ax.axvline(0, linestyle=':', color='brown')


ax.set_xlim(-100,100)
ax.set_ylim(-0.05,1.5)

ax.set_xlabel('Relative velocity (km/s)')
ax.set_ylabel('Continuum normalized flux')
# Out:
# Text(0, 0.5, 'Continuum normalized flux')

# %% [markdown]
# Create the noisy data

# %%
err_std = 0.15
# Draw samples from a Gaussian of mean zero and above std dev
np.random.seed(45)
pert = np.random.normal(loc=0, scale=err_std, size=len(v))
flux_pert = flux+pert
err_pert = np.ones(len(v))*err_std

# %%
fig, ax = plt.subplots(1, figsize=(7,4))
ax.step(v, flux_pert, where='mid')
ax.step(v, err_pert, color='cyan', where='mid')

ax.axhline(0, linestyle=':', color='red')
ax.axhline(1, linestyle=':', color='green')
ax.axvline(0, linestyle=':', color='brown')


ax.set_xlim(-100,100)
ax.set_ylim(-0.05,1.5)

ax.set_xlabel('Relative velocity (km/s)')
ax.set_ylabel('Continuum normalized flux')
# Out:
# Text(0, 0.5, 'Continuum normalized flux')

# %% [markdown]
# Calculate EW within a window equal to twice of the FWHM

# %%
fwhm = 2*np.sqrt(2*np.log(2))*sigma_v

# %%
idx_ew = (v>-fwhm)&(v<fwhm)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,4), sharex=True, sharey=True)

axes[0].step(v, flux, where='mid')
axes[0].axvspan(xmin=-fwhm, xmax=fwhm, color='yellow', alpha=.1)
axes[0].axhline(0, linestyle=':', color='red')
axes[0].axhline(1, linestyle=':', color='green')
axes[0].axvline(0, linestyle=':', color='brown')
axes[0].text(x=-100, y=1.4, s='Signal')

axes[0].set_xlim(-110,110)

axes[1].step(v, flux_pert, where='mid')
axes[1].step(v, err_pert, where='mid', color='cyan')
axes[1].axvspan(xmin=-fwhm, xmax=fwhm, color='yellow', alpha=.1)
axes[1].axhline(0, linestyle=':', color='red')
axes[1].axhline(1, linestyle=':', color='green')
axes[1].axvline(0, linestyle=':', color='brown')
axes[1].text(x=-100, y=1.4, s='Perturbed')

plt.subplots_adjust(wspace=0, hspace=0)

ax_label = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_xlabel('Velocity (km/s)') # Use argument `labelpad` to move label downwards.
ax_label.set_ylabel('Flux (continuum normalized)')
# Out:
# Text(0, 0.5, 'Flux (continuum normalized)')

# %%
# Calculate EW of the unperturbed and perturbed feature in mÅ

EW = np.sum(1-flux[idx_ew][:-1])*(delta_v_pix*wav0_rest/3e+5)*1e+3
EW_pert = np.sum(1-flux_pert[idx_ew][:-1])*(delta_v_pix*wav0_rest/3e+5)*1e+3
sig_EW_pert = np.sqrt(np.sum(err_pert[idx_ew][:-1]**2))*(delta_v_pix*wav0_rest/3e+5)*1e+3

# %%
EW, EW_pert, sig_EW_pert
# Out:
# (5.196993346713397, 4.847827924730622, 5.931299142630524)

# %%
EW_pert/sig_EW_pert
# Out:
# 0.8173298645295803

# %%
3*sig_EW_pert
# Out:
# 17.793897427891572

# %%
# Column density estimate from linear regime of curve of growth
logN_EW_UL = np.log10((3*sig_EW_pert*1e-3/wav0_rest)*(3e+8/(wav0_rest*1e-10))*(2.654e-2*f)**-1)

# %%
logN_EW_UL
# Out:
# 12.514349227833831

# %% [markdown]
# Fit a Voigt profile using LMFIT

# %%
def residual(param, v, flux, err):
    
    model = vp(v, 10**param['logN'].value, param['ctn'])
    
    return (flux-model)/err

# %%
params = Parameters()
params.add('logN', value=13)
params.add('ctn', value=1)

# %%
idx_fit = (v>-110)&(v<110)

# %%
result = minimize(residual, params, args=(v[idx_fit], flux_pert[idx_fit], err_pert[idx_fit]))

# %%
result
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>16</td><td></td></tr><tr><td># data points</td><td>105</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 124.895168</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.21257444</td><td></td></tr><tr><td>Akaike info crit.</td><td> 22.2190096</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 27.5269303</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> logN </td><td>  12.1447984 </td><td>  0.37961377 </td><td> (3.13%) </td><td> 13 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> ctn </td><td>  0.98224353 </td><td>  0.01734590 </td><td> (1.77%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>logN</td><td>ctn</td><td>-0.3693</td></tr></table>

# %%
linear_mean = 10**result.params['logN'].value
linear_std = linear_mean*(1-10**(-result.params['logN'].stderr))
print(linear_mean/linear_std, np.log10(3*linear_std))
# Out:
# 1.7159730935846782 12.387409202345848

# %% [markdown]
# Refine using MCMC

# %%
def log_likelihood(params, v, flux, err):
    
    logN, ctn = params
    
    model = vp(v, 10**logN, ctn)
    return -0.5*np.sum(((flux-model)/err)**2)

# %%
def log_prior(params):
    
    logN, ctn = params
    
    if logN>0 and logN<18.5 and ctn>0.4 and ctn<1.6:
        return 0
    else:
        return -np.inf

# %%
def log_probability(params, v, flux, err):
    
    logN, ctn = params
    
    lp = log_prior(params)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(params, v, flux, err)

# %%
pos = np.array(list(result.params.valuesdict().values())) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(v[idx_fit], flux_pert[idx_fit], err_pert[idx_fit])
)

# %%
sampler.run_mcmc(pos, 6000, progress=True)
# Out:
# 100%|██████████████████████████████████████| 6000/6000 [00:25<00:00, 239.20it/s]
# State([[ 7.46201025  1.00107172]
#  [ 7.38076533  0.99371099]
#  [12.13028694  0.97658573]
#  [11.58572663  1.0186717 ]
#  [10.11391713  1.00932825]
#  [ 4.01196635  0.96752757]
#  [10.62283127  1.01273894]
#  [ 2.13132875  0.99749281]
#  [ 1.61023107  0.98361499]
#  [ 3.20046626  0.98139759]
#  [12.07315681  0.97732721]
#  [ 6.8901466   0.9717002 ]
#  [ 4.38027802  0.98339706]
#  [ 4.53917459  0.98937264]
#  [ 7.21056187  0.99729444]
#  [10.10768667  0.97358934]
#  [ 7.18748909  1.01934313]
#  [10.30290643  0.99708581]
#  [11.19169226  1.00338707]
#  [ 7.61591685  0.99835473]
#  [ 4.74175431  0.98665398]
#  [12.16515382  0.95782913]
#  [ 2.89048831  1.00207039]
#  [ 7.56650451  0.9543989 ]
#  [ 2.05191081  0.98874319]
#  [ 7.14495477  0.99148901]
#  [ 8.84643629  1.00368329]
#  [ 2.3730696   0.96844759]
#  [ 1.11742438  0.9779001 ]
#  [ 7.72300253  0.964649  ]
#  [ 5.63315839  1.00804843]
#  [ 2.41829814  0.98936478]
#  [ 5.40243958  0.98542992]
#  [ 5.86818431  0.98383596]
#  [ 0.95275354  0.95968251]
#  [ 3.33322103  0.99694719]
#  [ 8.80357183  0.99250111]
#  [ 3.04046664  0.98094165]
#  [12.14727429  0.98744888]
#  [ 9.32564337  1.03267263]
#  [ 5.88640542  1.00736397]
#  [ 8.01423777  1.01336255]
#  [ 6.08664155  0.97682467]
#  [10.7909999   0.99768799]
#  [10.38111096  1.00661725]
#  [12.24981428  0.97632119]
#  [ 3.90413105  1.01208199]
#  [ 0.35038725  1.0116233 ]
#  [ 5.3985111   0.97648928]
#  [ 7.93177558  0.98816122]
#  [12.03454577  0.97393234]
#  [ 2.48307266  0.97409537]
#  [ 0.05660117  0.99813303]
#  [11.87909052  0.98672973]
#  [ 6.39041092  0.97079649]
#  [ 2.59101908  0.9997582 ]
#  [ 4.00008864  0.97276637]
#  [ 9.80360535  1.00515054]
#  [ 8.42692667  0.98992944]
#  [ 9.57279504  1.00761529]
#  [10.16947977  0.9976638 ]
#  [ 0.59472641  0.98878635]
#  [ 8.64125829  0.97463124]
#  [ 7.32971235  1.00764504]
#  [ 0.17206693  0.97554049]
#  [12.0338527   0.96774787]
#  [ 0.15158798  0.98446505]
#  [ 9.93753443  1.00247893]
#  [ 8.51085471  0.98733843]
#  [ 0.87824494  0.98401532]
#  [ 8.9634874   0.97798101]
#        2287372414, 3604297051,  949272626, 1717257986, 1763327722,
#         233345730, 3757871526, 4220399832, 2846246095, 1484287055,
#         461425299, 2900934170,  137561153, 1866562250, 1458130436,
#        3196983835, 3956835710, 4097412739, 3637133773, 3651270217,
#         527969297, 1263350705, 3381136079, 1669420782,  690639738,
#        3731936399, 3861056636,  542215842,  900512088, 1909334901,
#        3447853926,  725941841,  482675322, 2526978045, 1374523631,
#        4032481234, 1267005446, 2432522155, 3815621273, 1161682882,
#         756340631, 2370293742, 3781809907, 2258469132, 2944839896,
#         229115946,  879968853, 1641564668, 2168555457, 4032005324,
#          78307949, 3003650767, 3156826343, 3091982322, 4267771446,
#         328561346,  383914979, 2873399357, 3007850856, 3753824672,
#         799325487, 2213312488, 3434001011, 2906139608, 3668279048,
#        2628409953, 2093902036, 3048652943, 2857890720,  126100283,
#        2912518384, 3129668840,  239796008, 2693936604, 2789706436,
#        1815389662, 2340806031, 1175633041, 3275780577,  526165041,
#         509707503, 2978091537, 1376943405, 3575177562, 4116084973,
#         582311103,   14318177, 3517816963, 1734430134, 1588602037,
#        4294219630,  378421822, 2076198985,  514170073, 1806194158,
#        1565925110, 1790730274, 2644534755, 2784101772, 2673689982,
#        2447928294,  887466249, 2510185445, 2199346216, 2403839808,
#        2619748110, 1705952196,  984266338, 3862223489, 1072433466,
#         648069502,  694712421,  143402792,  415781336, 3914715217,
#        1019268480, 2079793321, 1317079161, 2270349150, 1322550073,
#        2993530120, 3163555333, 2269958495, 2263268318, 3914906527,
#        1500044889,  309942469, 3725599189,  997815133, 3739442669,
#        2525543796, 3251362538,   33448508, 1335368721, 3085931223,
#        3948209834,  319653021,  771001575, 1100097511, 1926935148,
#        1619469284,  182315161, 3837177015, 1752514894, 3561726288,
#        3874539412, 1560288148,  273994921,  490000684, 3997382731,
#        2702105275,  709651833, 3230753206,  409021913, 1178176252,
#        2713835339, 2605412220, 4140636684,   66712423, 3082248386,
#         643012978,  855118113, 1245580598, 4055458750,  540089856,
#        3409233268,  594484985,  548313714, 2992455001, 1214015812,
#         830246016, 4099369498,  278204769, 2415861451, 1747841215,
#        2310878286, 2320714242, 2308301828,  340588720, 2221184570,
#        1924435208, 2498091685, 1988915657, 2870697364], dtype=uint32), 579, 0, 0.0))

# %%
flat_samples = sampler.get_chain(discard=100, flat=True)
np.save('flat_samples_1200', flat_samples)

# %%
fig = corner.corner(
    flat_samples, labels=['logN', 'ctn']
)

# %%
#flat_samples = np.load('flat_samples_1200.npy')

# %%
pdf, bin_edges = np.histogram(flat_samples[:,0], bins=400, density=True)
X = 10**(.5*(bin_edges[1:]+bin_edges[:-1]))
pdf = pdf/np.max(pdf)

# %%
X_peak = X[np.argmax(pdf)]
X_peak_1sig = X[np.argmin(np.abs(pdf-np.exp(-0.5)))]

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.plot(X, pdf)
ax.axvline(X_peak, linestyle=':')
ax.axvline(X_peak_1sig, linestyle=':')

ax.set_xlabel(r'$N$')
ax.set_ylabel('PDF')
#ax.set_xscale('log')
# Out:
# Text(0, 0.5, 'PDF')

# %%
X_3sig = 3*np.abs(X_peak_1sig-X_peak)

# %%
np.log10(X_3sig)
# Out:
# 12.459922471932298
