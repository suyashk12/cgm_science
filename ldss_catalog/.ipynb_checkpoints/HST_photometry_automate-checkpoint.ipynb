# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import constants, units
from astropy.coordinates import Angle
from scipy.optimize import curve_fit
import pandas as pd
import os
from scipy.signal import medfilt
from astropy.wcs import WCS
import scipy.integrate as integrate
from astropy.coordinates import SkyCoord
import dustmaps
import extinction

# %%
#dustmaps?

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/HST_images/'

# %% [markdown]
# Define utility functions to compute photometry for an HST image based on its FITS file and the segmentation map/ catalog

# %%
def hst_photometry_compute(img_fits, seg_fits, cat_file):
    
    # Create a WCS coordinate system for the image header
    wcs = WCS(header=img_fits[0].header)
    
    # Get the segmentation map
    seg_map = seg_fits[0].data
    
    # Get coordinates for each identified galaxy in the segmentation map
    gal_ids_arr = np.int_(cat_file[:,0])

    gal_ids_coords = {}
    
    for i in range(len(gal_ids_arr)):

        # Isolate the galaxy ID
        gal_id = gal_ids_arr[i]

        # Get x, y coordinates of the galaxy
        # Once again, remember the transposition
        seg_map_gal_y, seg_map_gal_x = np.where(seg_map==gal_id)

        # Counts for each pixel
        counts_gal = np.zeros(len(seg_map_gal_x))

        gal_ids_coords[gal_id] = []

        for j in range(len(seg_map_gal_x)):

            # Get the x and y coordinates
            x = seg_map_gal_x[j]
            y = seg_map_gal_y[j] 

            # Append the galactic coordinates
            counts_gal[j] = img_fits[0].data[y,x]

        # These are some bolometric flux cuts to include/ exclude pixels when stacking the spectra
        min_count_gal = np.nanpercentile(counts_gal, 75)
        max_count_gal = np.nanpercentile(counts_gal, 100)

        idx_bright = (counts_gal>=min_count_gal) & (counts_gal<=max_count_gal)

        gal_ids_coords[gal_id] = np.array([seg_map_gal_y[idx_bright],seg_map_gal_x[idx_bright]]).T
        
    # Add up fluxes for all galaxies and compute apparent magnitude
    
    flux_map = img_fits[0].data*img_fits[0].header['PHOTFNU']
    
    gal_ids_flux = np.zeros(len(gal_ids_arr))
    
    for i in range(len(gal_ids_arr)):

        # Get coordinates for the current galaxy
        gal_coords = gal_ids_coords[gal_ids_arr[i]]

        for j in range(gal_coords.shape[0]):

            # Add up fluxes for each coordinate
            coords = gal_coords[j]
            gal_ids_flux[i] += flux_map[coords[0], coords[1]]
            
    gal_ids_mag = -2.5*np.log10(gal_ids_flux/3631)
    
    return gal_ids_mag

# %%
def hst_photometry_compute_814w(img_fits, seg_fits, cat_file):
    
    # Get the segmentation map
    seg_map = seg_fits[0].data
    
    # Get coordinates for each identified galaxy in the segmentation map
    gal_ids_arr = np.int_(cat_file[:, 0])

    gal_ids_coords = {}
    
    N_gals = len(gal_ids_arr)
    
    for i in range(len(gal_ids_arr)):

        # Isolate the galaxy ID
        gal_id = gal_ids_arr[i]

        # Get x, y coordinates of the galaxy
        # Once again, remember the transposition
        seg_map_gal_y, seg_map_gal_x = np.where(seg_map==gal_id)

        # Counts for each pixel
        counts_gal = np.zeros(len(seg_map_gal_x))

        gal_ids_coords[gal_id] = []

        for j in range(len(seg_map_gal_x)):

            # Get the x and y coordinates
            x = seg_map_gal_x[j]
            y = seg_map_gal_y[j] 

            # Append the galactic coordinates
            counts_gal[j] = img_fits[0].data[y,x]

        # These are some bolometric flux cuts to include/ exclude pixels when stacking the spectra
        min_count_gal = np.nanpercentile(counts_gal, 75)
        max_count_gal = np.nanpercentile(counts_gal, 100)

        idx_bright = (counts_gal>=min_count_gal) & (counts_gal<=max_count_gal)

        gal_ids_coords[gal_id] = np.array([seg_map_gal_y[idx_bright],seg_map_gal_x[idx_bright]]).T
        
    # Add up fluxes for all galaxies and compute apparent magnitude
    
    flux_map = img_fits[0].data*(3.34e+4*img_fits[0].header['PHOTPLAM']**2*img_fits[0].header['PHOTFLAM'])
    
    gal_ids_flux = np.zeros(len(gal_ids_arr))
    
    for i in range(len(gal_ids_arr)):
        
        # Get coordinates for the current galaxy
        gal_coords = gal_ids_coords[gal_ids_arr[i]]

        for j in range(gal_coords.shape[0]):

            # Add up fluxes for each coordinate
            coords = gal_coords[j]
            gal_ids_flux[i] += flux_map[coords[0], coords[1]]
            
    gal_ids_mag = -2.5*np.log10(gal_ids_flux/3631)
    
    return gal_ids_mag

# %% [markdown]
# Load in the image, segmentation map, and catalog file for F160W

# %%
img_fits_160w = fits.open(rootdir+'f160w_comb.fits')
seg_fits_160w = fits.open(rootdir+'f160w_seg.fits')
cat_file_160w = np.loadtxt(rootdir + 'f160w.cat')

# %%
img_fits_140w = fits.open(rootdir+'f140w_comb.fits')
seg_fits_140w = fits.open(rootdir+'f140w_seg.fits')
cat_file_140w = np.loadtxt(rootdir + 'f140w.cat')

# %%
img_fits_814w = fits.open(rootdir+'f814wdrc.fits')
seg_fits_814w = fits.open(rootdir+'f814w_seg.fits')
cat_file_814w = np.loadtxt(rootdir + 'f814w.cat')

# %%
gal_ids_mag_160w = hst_photometry_compute(img_fits_160w, seg_fits_160w, cat_file_160w)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57925.000000 from DATE-OBS'. [astropy.wcs.wcs]
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_94660/49810420.py:62: RuntimeWarning: invalid value encountered in log10
#   gal_ids_mag = -2.5*np.log10(gal_ids_flux/3631)

# %%
np.nanmax(gal_ids_mag_160w)
# Out:
# 26.840366296367755

# %%
plt.hist(gal_ids_mag_160w)
# Out:
# (array([  2.,   1.,   5.,  11.,  41., 126., 263., 384., 230.,  17.]),
#  array([15.67881188, 16.79496732, 17.91112277, 19.02727821, 20.14343365,
#         21.25958909, 22.37574453, 23.49189997, 24.60805541, 25.72421085,
#         26.8403663 ]),
#  <BarContainer object of 10 artists>)

# %%
gal_ids_mag_140w = hst_photometry_compute(img_fits_140w, seg_fits_140w, cat_file_140w)

# %%
gal_ids_mag_814w = hst_photometry_compute_814w(img_fits_814w, seg_fits_814w, cat_file_814w)

# %% [markdown]
# Write up a catalog for each image

# %%
def write_catalog(cat_file, gal_ids_mag, fname, mag_col_name):
    
    # Galaxy IDs (can help extract the spectra)
    gal_ids_arr = cat_file[:,0]
    
    # Galaxy coordinates, first load in degrees
    gal_ra_arr_deg = cat_file[:,1]
    gal_dec_arr_deg = cat_file[:,2]
    
    gal_x_arr = cat_file[:,3]
    gal_y_arr = cat_file[:,4]

    gal_ra_arr_hms = [Angle(ra, units.degree).hms for ra in gal_ra_arr_deg]
    gal_dec_arr_dms = [Angle(dec, units.degree).dms for dec in gal_dec_arr_deg]

    gal_ra_arr_hms_str = np.array([str(int(ra[0])) + 'h' + str(int(ra[1])) + 'm' + str(np.round(ra[2],2)) + 's' 
                     for ra in gal_ra_arr_hms])

    gal_dec_arr_dms_str = np.array([str(int(dec[0])) + 'd' + str(int(dec[1])) + 'm' + str(np.round(dec[2],2)) + 's' 
                     for dec in gal_dec_arr_dms])
    
    # Save the file name
    
    with open(fname, 'w') as f:
        
        f.write('ID,RA,Dec,x,y,'+mag_col_name)      

        # Write out the catalog
        for i in range(len(gal_ids_arr)):

            f.write('\n'+str(int(gal_ids_arr[i])) + ',' + 
                  str(gal_ra_arr_deg[i]) + ',' + 
                  str(gal_dec_arr_deg[i]) + ',' + 
                  str(gal_x_arr[i]) + ',' + 
                  str(gal_y_arr[i]) + ',' + 
                  str('%.4f'%np.round(gal_ids_mag[i],4)))

# %%
write_catalog(cat_file_160w, gal_ids_mag_160w, rootdir+'f160w_photometry.dat', 'f160w_mag')

# %%
write_catalog(cat_file_140w, gal_ids_mag_140w, rootdir+'f140w_photometry.dat', 'f140w_mag')

# %%
write_catalog(cat_file_814w, gal_ids_mag_814w, rootdir+'f814w_photometry.dat', 'f814w_mag')

# %% [markdown]
# # DRAFT

# %% [markdown]
# Isolate galaxies with CIV detections

# %%
np.int_(cat_file_814w[:,0]), np.int_(cat_file_140w[:,0]), np.int_(cat_file_160w[:,0])
# Out:
# (array([   1,    2,    3, ..., 8046, 8047, 8048]),
#  array([   1,    2,    3, ..., 1112, 1113, 1114]),
#  array([   1,    2,    3, ..., 1080, 1081, 1082]))

# %%
len(gal_ids_mag_814w), len(gal_ids_mag_140w), len(gal_ids_mag_160w)
# Out:
# (8048, 1114, 1082)

# %%
[np.where(np.round(gal_ids_mag_814w,4)==24.3255)[0][0]+1, 
 np.where(np.round(gal_ids_mag_814w,4)==26.0512)[0][0]+1,
 np.where(np.round(gal_ids_mag_814w,4)==25.3929)[0][0]+1,
 np.where(np.round(gal_ids_mag_814w,4)==24.4112)[0][0]+1]
# Out:
# [7247, 5066, 5633, 7389]

# %%
[np.where(np.round(gal_ids_mag_140w,4)==21.9529)[0][0]+1, 
 np.where(np.round(gal_ids_mag_140w,4)==23.8175)[0][0]+1,
 np.where(np.round(gal_ids_mag_140w,4)==22.9237)[0][0]+1,
 np.where(np.round(gal_ids_mag_140w,4)==21.7996)[0][0]+1]
# Out:
# [681, 281, 452, 563]

# %%
[np.where(np.round(gal_ids_mag_160w,4)==22.0527)[0][0]+1, 
 np.where(np.round(gal_ids_mag_160w,4)==24.1001)[0][0]+1,
 np.where(np.round(gal_ids_mag_160w,4)==22.9471)[0][0]+1,
 np.where(np.round(gal_ids_mag_160w,4)==21.8910)[0][0]+1]
# Out:
# [642, 301, 465, 570]

# %% [markdown]
# # Compute photometry for specific galaxies

# %% [markdown]
# ## F814W

# %%
seg_map_gal_y_814w_z067, seg_map_gal_x_814w_z067 = np.where(seg_fits_814w[0].data==7247)
x_814w_z067, y_814w_z067 = np.mean(seg_map_gal_x_814w_z067), np.mean(seg_map_gal_y_814w_z067)

seg_map_gal_y_814w_z109, seg_map_gal_x_814w_z109 = np.where(seg_fits_814w[0].data==5066)
x_814w_z109, y_814w_z109 = np.mean(seg_map_gal_x_814w_z109), np.mean(seg_map_gal_y_814w_z109)

seg_map_gal_y_814w_z122, seg_map_gal_x_814w_z122 = np.where(seg_fits_814w[0].data==5633)
x_814w_z122, y_814w_z122 = np.mean(seg_map_gal_x_814w_z122), np.mean(seg_map_gal_y_814w_z122)

seg_map_gal_y_814w_z127, seg_map_gal_x_814w_z127 = np.where(seg_fits_814w[0].data==7389)
x_814w_z127, y_814w_z127 = np.mean(seg_map_gal_x_814w_z127), np.mean(seg_map_gal_y_814w_z127)

# %%
[np.nanmin(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM'])),
np.nanmax(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']))]
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2298880298.py:1: RuntimeWarning: divide by zero encountered in log10
#   [np.nanmin(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM'])),
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2298880298.py:1: RuntimeWarning: invalid value encountered in log10
#   [np.nanmin(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM'])),
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2298880298.py:2: RuntimeWarning: divide by zero encountered in log10
#   np.nanmax(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']))]
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2298880298.py:2: RuntimeWarning: invalid value encountered in log10
#   np.nanmax(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']))]
# [-inf, -16.912327]

# %%
fig, ax = plt.subplots(1, figsize=(10,10))


# img[0].header['PHOTFLAM'] is the flux calibration
# We plot in log-scale to see features distinctly
# Notice also that the coordinate system is rotated
plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-17, cmap='gray')

ax.scatter(seg_map_gal_x_814w_z067, seg_map_gal_y_814w_z067,  color='red', s=10, alpha=.05)
ax.scatter(seg_map_gal_x_814w_z109, seg_map_gal_y_814w_z109,  color='yellow', s=10, alpha=.05)
ax.scatter(seg_map_gal_x_814w_z122, seg_map_gal_y_814w_z122,  color='green', s=10, alpha=.05)
ax.scatter(seg_map_gal_x_814w_z127, seg_map_gal_y_814w_z127,  color='blue', s=10, alpha=.05)

ax.set_xlim(1400,2500)
ax.set_ylim(2500,3700)
ax.invert_yaxis()
ax.invert_xaxis()
# Projection utilizes the WCS object created earlier
#plt.subplot(projection=wcs)

#plt.grid(color='white', ls='solid')
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/711059425.py:7: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/711059425.py:7: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',

# %% [markdown]
# ### z=0.67

# %%
idx_814w_z067=np.where((seg_map_gal_x_814w_z067-x_814w_z067)**2+(seg_map_gal_y_814w_z067-y_814w_z067)**2<20**2)

counts_814w_z067 = np.zeros(len(seg_map_gal_x_814w_z067))

for i in range(len(seg_map_gal_x_814w_z067)):
    x = seg_map_gal_x_814w_z067[i]
    y = seg_map_gal_y_814w_z067[i]
    counts_814w_z067[i] = img_fits_814w[0].data[y,x]
    
min_count_814w_z067 = np.nanpercentile(counts_814w_z067, 75)
max_count_814w_z067 = np.nanpercentile(counts_814w_z067, 100)
        
idx_bright_814w_z067 = (counts_814w_z067>=min_count_814w_z067)&(counts_814w_z067<=max_count_814w_z067)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))


# img[0].header['PHOTFLAM'] is the flux calibration
# We plot in log-scale to see features distinctly
# Notice also that the coordinate system is rotated
plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-17, cmap='gray')

ax.scatter(seg_map_gal_x_814w_z067[idx_814w_z067], seg_map_gal_y_814w_z067[idx_814w_z067],  
           color='red', s=10, alpha=.1)

#ax.scatter(seg_map_gal_x_814w_z067[idx_bright_814w_z067], seg_map_gal_y_814w_z067[idx_bright_814w_z067],  
#           color='yellow', s=10, alpha=.5)

ax.set_xlim(x_814w_z067-150,x_814w_z067+150)
ax.set_ylim(y_814w_z067-150,y_814w_z067+150)
ax.invert_yaxis()
ax.invert_xaxis()
# Projection utilizes the WCS object created earlier
#plt.subplot(projection=wcs)

#plt.grid(color='white', ls='solid')
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/526983045.py:7: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/526983045.py:7: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',

# %%
counts_tot_814w_z067 = 0

#for i in range(len(seg_map_gal_x_814w_z067)):
#    x = seg_map_gal_x_814w_z067[i]
#    y = seg_map_gal_y_814w_z067[i]
#    counts_tot_814w_z067 += img_fits_814w[0].data[y,x]

#for i in range(len(seg_map_gal_x_814w_z067)):
#    x = seg_map_gal_x_814w_z067[i]
#    y = seg_map_gal_y_814w_z067[i]
#    if idx_bright_814w_z067[i]==True:
#        counts_tot_814w_z067 += img_fits_814w[0].data[y,x]

for idx in list(idx_814w_z067[0]):
    x = seg_map_gal_x_814w_z067[idx]
    y = seg_map_gal_y_814w_z067[idx]
    counts_tot_814w_z067 += img_fits_814w[0].data[y,x]

flux_tot_814w_z067 = counts_tot_814w_z067*3.34e+4*img_fits_814w[0].header['PHOTPLAM']**2*img_fits_814w[0].header['PHOTFLAM']
mag_814w_z067 = -2.5*np.log10(flux_tot_814w_z067/3631)

# %%
np.round(mag_814w_z067,3)
# Out:
# 23.634

# %% [markdown]
# ### z=1.09

# %%
idx_814w_z109=np.where((seg_map_gal_x_814w_z109-x_814w_z109)**2+(seg_map_gal_y_814w_z109-y_814w_z109)**2<25**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

# img[0].header['PHOTFLAM'] is the flux calibration
# We plot in log-scale to see features distinctly
# Notice also that the coordinate system is rotated
plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-16.5, cmap='hot')

ax.scatter(seg_map_gal_x_814w_z109[idx_814w_z109], seg_map_gal_y_814w_z109[idx_814w_z109],  
           color='red', s=20, alpha=.5)

ax.set_xlim(x_814w_z109-40,x_814w_z109+40)
ax.set_ylim(y_814w_z109-40,y_814w_z109+40)
ax.invert_yaxis()
ax.invert_xaxis()
# Projection utilizes the WCS object created earlier
#plt.subplot(projection=wcs)

#plt.grid(color='white', ls='solid')
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2297925267.py:6: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2297925267.py:6: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',

# %%
counts_tot_814w_z109 = 0

for idx in list(idx_814w_z109[0]):
    x = seg_map_gal_x_814w_z109[idx]
    y = seg_map_gal_y_814w_z109[idx]
    counts_tot_814w_z109 += img_fits_814w[0].data[y,x]

flux_tot_814w_z109 = counts_tot_814w_z109*3.34e+4*img_fits_814w[0].header['PHOTPLAM']**2*img_fits_814w[0].header['PHOTFLAM']
mag_814w_z109 = -2.5*np.log10(flux_tot_814w_z109/3631)

# %%
np.round(mag_814w_z109,3)
# Out:
# 25.533

# %% [markdown]
# ### z=1.22

# %%
idx_814w_z122=np.where((seg_map_gal_x_814w_z122-x_814w_z122)**2+(seg_map_gal_y_814w_z122-y_814w_z122)**2<25**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
          vmin=-23, vmax=-16.5, cmap='gray')

ax.scatter(seg_map_gal_x_814w_z122[idx_814w_z122], seg_map_gal_y_814w_z122[idx_814w_z122],  
           color='red', s=10, alpha=.3)

ax.set_xlim(x_814w_z122-75,x_814w_z122+75)
ax.set_ylim(y_814w_z122-75,y_814w_z122+75)
ax.invert_yaxis()
ax.invert_xaxis()
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/119163640.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/119163640.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',

# %%
counts_tot_814w_z122 = 0

for idx in list(idx_814w_z122[0]):
    x = seg_map_gal_x_814w_z122[idx]
    y = seg_map_gal_y_814w_z122[idx]
    counts_tot_814w_z122 += img_fits_814w[0].data[y,x]

flux_tot_814w_z122 = counts_tot_814w_z122*3.34e+4*img_fits_814w[0].header['PHOTPLAM']**2*img_fits_814w[0].header['PHOTFLAM']
mag_814w_z122 = -2.5*np.log10(flux_tot_814w_z122/3631)

# %%
np.round(mag_814w_z122,3)
# Out:
# 24.765

# %% [markdown]
# ### z=1.27

# %%
idx_814w_z127=np.where((seg_map_gal_x_814w_z127-x_814w_z127)**2+(seg_map_gal_y_814w_z127-y_814w_z127)**2<30**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
          vmin=-23, vmax=-16.5, cmap='gray')

ax.scatter(seg_map_gal_x_814w_z127[idx_814w_z127], seg_map_gal_y_814w_z127[idx_814w_z127],  
           color='red', s=10, alpha=.3)

ax.set_xlim(x_814w_z127-75,x_814w_z127+75)
ax.set_ylim(y_814w_z127-75,y_814w_z127+75)
ax.invert_yaxis()
ax.invert_xaxis()
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2153123878.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2153123878.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_814w[0].data*img_fits_814w[0].header['PHOTFLAM']), origin='lower',

# %%
counts_tot_814w_z127 = 0

for idx in list(idx_814w_z127[0]):
    x = seg_map_gal_x_814w_z127[idx]
    y = seg_map_gal_y_814w_z127[idx]
    counts_tot_814w_z127 += img_fits_814w[0].data[y,x]

flux_tot_814w_z127 = counts_tot_814w_z127*3.34e+4*img_fits_814w[0].header['PHOTPLAM']**2*img_fits_814w[0].header['PHOTFLAM']
mag_814w_z127 = -2.5*np.log10(flux_tot_814w_z127/3631)

# %%
np.round(mag_814w_z127,3)
# Out:
# 24.031

# %% [markdown]
# ## F140W

# %%
#wcs_140w = WCS(header=img_fits_140w[0].header)

# %%
seg_map_gal_y_140w_z067, seg_map_gal_x_140w_z067 = np.where(seg_fits_140w[0].data==681)
x_140w_z067, y_140w_z067 = np.mean(seg_map_gal_x_140w_z067), np.mean(seg_map_gal_y_140w_z067)

seg_map_gal_y_140w_z109, seg_map_gal_x_140w_z109 = np.where(seg_fits_140w[0].data==281)
x_140w_z109, y_140w_z109 = np.mean(seg_map_gal_x_140w_z109), np.mean(seg_map_gal_y_140w_z109)

seg_map_gal_y_140w_z122, seg_map_gal_x_140w_z122 = np.where(seg_fits_140w[0].data==452)
x_140w_z122, y_140w_z122 = np.mean(seg_map_gal_x_140w_z122), np.mean(seg_map_gal_y_140w_z122)

seg_map_gal_y_140w_z127, seg_map_gal_x_140w_z127 = np.where(seg_fits_140w[0].data==563)
x_140w_z127, y_140w_z127 = np.mean(seg_map_gal_x_140w_z127), np.mean(seg_map_gal_y_140w_z127)

# %%
[np.nanmin(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM'])),
np.nanmax(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']))]
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3456420234.py:1: RuntimeWarning: divide by zero encountered in log10
#   [np.nanmin(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM'])),
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3456420234.py:1: RuntimeWarning: invalid value encountered in log10
#   [np.nanmin(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM'])),
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3456420234.py:2: RuntimeWarning: divide by zero encountered in log10
#   np.nanmax(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']))]
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3456420234.py:2: RuntimeWarning: invalid value encountered in log10
#   np.nanmax(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']))]
# [-inf, -16.46889]

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

#plt.subplot(projection=wcs_140w)

# img[0].header['PHOTFLAM'] is the flux calibration
# We plot in log-scale to see features distinctly
# Notice also that the coordinate system is rotated
plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-17, cmap='gray')

ax.scatter(seg_map_gal_x_140w_z067, seg_map_gal_y_140w_z067,  color='red', s=20, alpha=.05)
ax.scatter(seg_map_gal_x_140w_z109, seg_map_gal_y_140w_z109,  color='yellow', s=20, alpha=.05)
ax.scatter(seg_map_gal_x_140w_z122, seg_map_gal_y_140w_z122,  color='green', s=20, alpha=.05)
ax.scatter(seg_map_gal_x_140w_z127, seg_map_gal_y_140w_z127,  color='blue', s=20, alpha=.05)

#plt.imshow(seg_fits_814w[0].data == 7246, origin='lower')

#ax.set_xlim(50,1000)
#ax.set_ylim(50,1000)
#ax.invert_yaxis()
#ax.invert_xaxis()
# Projection utilizes the WCS object created earlier

#plt.grid(color='white', ls='solid')
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/1904675833.py:8: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/1904675833.py:8: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',

# %% [markdown]
# ### z=0.67

# %%
idx_140w_z067=np.where((seg_map_gal_x_140w_z067-x_140w_z067)**2+(seg_map_gal_y_140w_z067-y_140w_z067)**2<4**2)

counts_140w_z067 = np.zeros(len(seg_map_gal_x_140w_z067))

for i in range(len(seg_map_gal_x_140w_z067)):
    x = seg_map_gal_x_140w_z067[i]
    y = seg_map_gal_y_140w_z067[i]
    counts_140w_z067[i] = img_fits_140w[0].data[y,x]
    
min_count_140w_z067 = np.nanpercentile(counts_140w_z067, 75)
max_count_140w_z067 = np.nanpercentile(counts_140w_z067, 100)
        
idx_bright_140w_z067 = (counts_140w_z067>=min_count_140w_z067)&(counts_140w_z067<=max_count_140w_z067)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-19., cmap='hot')

ax.scatter(seg_map_gal_x_140w_z067[idx_140w_z067], seg_map_gal_y_140w_z067[idx_140w_z067],  
           color='cyan', s=10, alpha=.2)

#ax.scatter(seg_map_gal_x_140w_z067[idx_bright_140w_z067], seg_map_gal_y_140w_z067[idx_bright_140w_z067],  
#           color='yellow', s=10, alpha=.5)

ax.set_xlim(x_140w_z067-50,x_140w_z067+50)
ax.set_ylim(y_140w_z067-50,y_140w_z067+50)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/585947611.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/585947611.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# (327.27685950413223, 427.27685950413223)

# %%
counts_tot_140w_z067 = 0

#for i in range(len(seg_map_gal_x_140w_z067)):
#    x = seg_map_gal_x_140w_z067[i]
#    y = seg_map_gal_y_140w_z067[i]
#    counts_tot_140w_z067 += img_fits_140w[0].data[y,x]

#for i in range(len(seg_map_gal_x_140w_z067)):
#    x = seg_map_gal_x_140w_z067[i]
#    y = seg_map_gal_y_140w_z067[i]
#    if idx_bright_140w_z067[i]==True:
#        counts_tot_140w_z067 += img_fits_140w[0].data[y,x]

for idx in list(idx_140w_z067[0]):
    x = seg_map_gal_x_140w_z067[idx]
    y = seg_map_gal_y_140w_z067[idx]
    counts_tot_140w_z067 += img_fits_140w[0].data[y,x]

flux_tot_140w_z067 = counts_tot_140w_z067*img_fits_140w[0].header['PHOTFNU']
mag_140w_z067 = -2.5*np.log10(flux_tot_140w_z067/3631)

# %%
np.round(mag_140w_z067,3)
# Out:
# 22.137

# %% [markdown]
# ### z=1.09

# %%
idx_140w_z109=np.where((seg_map_gal_x_140w_z109-x_140w_z109)**2+(seg_map_gal_y_140w_z109-y_140w_z109)**2<2.5**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20.5, vmax=-19.5, cmap='hot')

ax.scatter(seg_map_gal_x_140w_z109[idx_140w_z109], seg_map_gal_y_140w_z109[idx_140w_z109],  
           color='cyan', s=10, alpha=.3)

ax.set_xlim(x_140w_z109-50,x_140w_z109+50)
ax.set_ylim(y_140w_z109-50,y_140w_z109+50)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/679237847.py:2: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/679237847.py:2: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# (660.3555555555556, 760.3555555555556)

# %%
counts_tot_140w_z109 = 0

for idx in list(idx_140w_z109[0]):
    x = seg_map_gal_x_140w_z109[idx]
    y = seg_map_gal_y_140w_z109[idx]
    counts_tot_140w_z109 += img_fits_140w[0].data[y,x]

flux_tot_140w_z109 = counts_tot_140w_z109*img_fits_140w[0].header['PHOTFNU']
mag_140w_z109 = -2.5*np.log10(flux_tot_140w_z109/3631)

# %%
np.round(mag_140w_z109,3)
# Out:
# 23.341

# %% [markdown]
# ### z=1.22

# %%
idx_140w_z122=np.where((seg_map_gal_x_140w_z122-x_140w_z122-1)**2+(seg_map_gal_y_140w_z122-y_140w_z122+3)**2<3**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20.5, vmax=-19.5, cmap='hot')

ax.scatter(seg_map_gal_x_140w_z122[idx_140w_z122], seg_map_gal_y_140w_z122[idx_140w_z122],  
           color='cyan', s=10, alpha=.3)

ax.set_xlim(x_140w_z122-75,x_140w_z122+75)
ax.set_ylim(y_140w_z122-75,y_140w_z122+75)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/881628039.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/881628039.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# (517.196261682243, 667.196261682243)

# %%
counts_tot_140w_z122 = 0

for idx in list(idx_140w_z122[0]):
    x = seg_map_gal_x_140w_z122[idx]
    y = seg_map_gal_y_140w_z122[idx]
    counts_tot_140w_z122 += img_fits_140w[0].data[y,x]

flux_tot_140w_z122 = counts_tot_140w_z122*3.34e+4*img_fits_140w[0].header['PHOTPLAM']**2*img_fits_140w[0].header['PHOTFLAM']
mag_140w_z122 = -2.5*np.log10(flux_tot_140w_z122/3631)

# %%
np.round(mag_140w_z122,3)
# Out:
# 22.894

# %% [markdown]
# ### z=1.27

# %%
idx_140w_z127=np.where((seg_map_gal_x_140w_z127-x_140w_z127)**2+(seg_map_gal_y_140w_z127-y_140w_z127+1)**2<3**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-18.5, cmap='hot')

ax.scatter(seg_map_gal_x_140w_z127[idx_140w_z127], seg_map_gal_y_140w_z127[idx_140w_z127],  
           color='cyan', s=10, alpha=.3)

ax.set_xlim(x_140w_z127-50,x_140w_z127+50)
ax.set_ylim(y_140w_z127-50,y_140w_z127+50)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2898791687.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2898791687.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_140w[0].data*img_fits_140w[0].header['PHOTFLAM']), origin='lower',
# (389.2758620689655, 489.2758620689655)

# %%
counts_tot_140w_z127 = 0

for idx in list(idx_140w_z127[0]):
    x = seg_map_gal_x_140w_z127[idx]
    y = seg_map_gal_y_140w_z127[idx]
    counts_tot_140w_z127 += img_fits_140w[0].data[y,x]

flux_tot_140w_z127 = counts_tot_140w_z127*3.34e+4*img_fits_140w[0].header['PHOTPLAM']**2*img_fits_140w[0].header['PHOTFLAM']
mag_140w_z127 = -2.5*np.log10(flux_tot_140w_z127/3631)

# %%
np.round(mag_140w_z127,3)
# Out:
# 22.134

# %% [markdown]
# ## F160W

# %%
seg_map_gal_y_160w_z067, seg_map_gal_x_160w_z067 = np.where(seg_fits_160w[0].data==642)
x_160w_z067, y_160w_z067 = np.mean(seg_map_gal_x_160w_z067), np.mean(seg_map_gal_y_160w_z067)

seg_map_gal_y_160w_z109, seg_map_gal_x_160w_z109 = np.where(seg_fits_160w[0].data==301)
x_160w_z109, y_160w_z109 = np.mean(seg_map_gal_x_160w_z109), np.mean(seg_map_gal_y_160w_z109)

seg_map_gal_y_160w_z122, seg_map_gal_x_160w_z122 = np.where(seg_fits_160w[0].data==465)
x_160w_z122, y_160w_z122 = np.mean(seg_map_gal_x_160w_z122), np.mean(seg_map_gal_y_160w_z122)

seg_map_gal_y_160w_z127, seg_map_gal_x_160w_z127 = np.where(seg_fits_160w[0].data==570)
x_160w_z127, y_160w_z127 = np.mean(seg_map_gal_x_160w_z127), np.mean(seg_map_gal_y_160w_z127)

# %%
[np.nanmin(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM'])),
np.nanmax(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']))]
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/1578795380.py:1: RuntimeWarning: divide by zero encountered in log10
#   [np.nanmin(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM'])),
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/1578795380.py:1: RuntimeWarning: invalid value encountered in log10
#   [np.nanmin(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM'])),
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/1578795380.py:2: RuntimeWarning: divide by zero encountered in log10
#   np.nanmax(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']))]
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/1578795380.py:2: RuntimeWarning: invalid value encountered in log10
#   np.nanmax(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']))]
# [-inf, -16.455936]

# %%
fig, ax = plt.subplots(1, figsize=(10,10))


# img[0].header['PHOTFLAM'] is the flux calibration
# We plot in log-scale to see features distinctly
# Notice also that the coordinate system is rotated
plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-17, cmap='gray')
#plt.imshow(seg_fits_814w[0].data == 7246, origin='lower')

ax.scatter(seg_map_gal_x_160w_z067, seg_map_gal_y_160w_z067,  color='red', s=100, alpha=.05)
ax.scatter(seg_map_gal_x_160w_z109, seg_map_gal_y_160w_z109,  color='yellow', s=100, alpha=.05)
ax.scatter(seg_map_gal_x_160w_z122, seg_map_gal_y_160w_z122,  color='green', s=100, alpha=.05)
ax.scatter(seg_map_gal_x_160w_z127, seg_map_gal_y_160w_z127,  color='blue', s=100, alpha=.05)


ax.set_xlim(200,800)
ax.set_ylim(200,800)
#ax.invert_yaxis()
#ax.invert_xaxis()
# Projection utilizes the WCS object created earlier
#plt.subplot(projection=wcs)

#plt.grid(color='white', ls='solid')
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3290723778.py:7: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3290723778.py:7: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# (200.0, 800.0)

# %% [markdown]
# ### z=0.67

# %%
idx_160w_z067=np.where((seg_map_gal_x_160w_z067-x_160w_z067+1)**2+(seg_map_gal_y_160w_z067-y_160w_z067)**2<4**2)

counts_160w_z067 = np.zeros(len(seg_map_gal_x_160w_z067))

for i in range(len(seg_map_gal_x_160w_z067)):
    x = seg_map_gal_x_160w_z067[i]
    y = seg_map_gal_y_160w_z067[i]
    counts_160w_z067[i] = img_fits_160w[0].data[y,x]
    
min_count_160w_z067 = np.nanpercentile(counts_160w_z067, 75)
max_count_160w_z067 = np.nanpercentile(counts_160w_z067, 100)
        
idx_bright_160w_z067 = (counts_160w_z067>=min_count_160w_z067)&(counts_160w_z067<=max_count_160w_z067)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-19.5, cmap='hot')

ax.scatter(seg_map_gal_x_160w_z067[idx_160w_z067], seg_map_gal_y_160w_z067[idx_160w_z067],  
           color='cyan', s=10, alpha=.2)

#ax.scatter(seg_map_gal_x_160w_z067[idx_bright_160w_z067], seg_map_gal_y_160w_z067[idx_bright_160w_z067],  
#           color='yellow', s=10, alpha=.5)

ax.set_xlim(x_160w_z067-50,x_160w_z067+50)
ax.set_ylim(y_160w_z067-50,y_160w_z067+50)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2030607593.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2030607593.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# (330.8563829787234, 430.8563829787234)

# %%
counts_tot_160w_z067 = 0

#for i in range(len(seg_map_gal_x_160w_z067)):
#    x = seg_map_gal_x_160w_z067[i]
#    y = seg_map_gal_y_160w_z067[i]
#    counts_tot_160w_z067 += img_fits_160w[0].data[y,x]

#for i in range(len(seg_map_gal_x_160w_z067)):
#    x = seg_map_gal_x_160w_z067[i]
#    y = seg_map_gal_y_160w_z067[i]
#    if idx_bright_160w_z067[i]==True:
#        counts_tot_160w_z067 += img_fits_160w[0].data[y,x]

for idx in list(idx_160w_z067[0]):
    x = seg_map_gal_x_160w_z067[idx]
    y = seg_map_gal_y_160w_z067[idx]
    counts_tot_160w_z067 += img_fits_160w[0].data[y,x]

flux_tot_160w_z067 = counts_tot_160w_z067*img_fits_160w[0].header['PHOTFNU']
mag_160w_z067 = -2.5*np.log10(flux_tot_160w_z067/3631)

# %%
np.round(mag_160w_z067,4)
# Out:
# 21.9878

# %% [markdown]
# ### z=1.09

# %%
idx_160w_z109=np.where((seg_map_gal_x_160w_z109-x_160w_z109+1)**2+(seg_map_gal_y_160w_z109-y_160w_z109+1)**2<3**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20., vmax=-19.6, cmap='hot')

ax.scatter(seg_map_gal_x_160w_z109[idx_160w_z109], seg_map_gal_y_160w_z109[idx_160w_z109],  
           color='cyan', s=10, alpha=.3)

ax.set_xlim(x_160w_z109-30,x_160w_z109+30)
ax.set_ylim(y_160w_z109-30,y_160w_z109+30)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3779846330.py:2: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3779846330.py:2: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# (684.3666666666667, 744.3666666666667)

# %%
counts_tot_160w_z109 = 0

for idx in list(idx_160w_z109[0]):
    x = seg_map_gal_x_160w_z109[idx]
    y = seg_map_gal_y_160w_z109[idx]
    counts_tot_160w_z109 += img_fits_160w[0].data[y,x]

flux_tot_160w_z109 = counts_tot_160w_z109*img_fits_160w[0].header['PHOTFNU']
mag_160w_z109 = -2.5*np.log10(flux_tot_160w_z109/3631)

# %%
np.round(mag_160w_z109,3)
# Out:
# 23.178

# %% [markdown]
# ### z=1.22

# %%
idx_160w_z122=np.where((seg_map_gal_x_160w_z122-x_160w_z122-1)**2+(seg_map_gal_y_160w_z122-y_160w_z122)**2<3**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20.5, vmax=-19.5, cmap='hot')

ax.scatter(seg_map_gal_x_160w_z122[idx_160w_z122], seg_map_gal_y_160w_z122[idx_160w_z122],  
           color='cyan', s=10, alpha=.3)

ax.set_xlim(x_160w_z122-75,x_160w_z122+75)
ax.set_ylim(y_160w_z122-75,y_160w_z122+75)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3248725074.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/3248725074.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# (517.4090909090909, 667.4090909090909)

# %%
counts_tot_160w_z122 = 0

for idx in list(idx_160w_z122[0]):
    x = seg_map_gal_x_160w_z122[idx]
    y = seg_map_gal_y_160w_z122[idx]
    counts_tot_160w_z122 += img_fits_160w[0].data[y,x]

flux_tot_160w_z122 = counts_tot_160w_z122*3.34e+4*img_fits_160w[0].header['PHOTPLAM']**2*img_fits_160w[0].header['PHOTFLAM']
mag_160w_z122 = -2.5*np.log10(flux_tot_160w_z122/3631)

# %%
np.round(mag_160w_z122,3)
# Out:
# 22.693

# %% [markdown]
# ### z=1.27

# %%
idx_160w_z127=np.where((seg_map_gal_x_160w_z127-x_160w_z127)**2+(seg_map_gal_y_160w_z127-y_160w_z127+1)**2<3**2)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))

plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
          vmin=-20, vmax=-18.5, cmap='hot')

ax.scatter(seg_map_gal_x_160w_z127[idx_160w_z127], seg_map_gal_y_160w_z127[idx_160w_z127],  
           color='cyan', s=10, alpha=.3)

ax.set_xlim(x_160w_z127-50,x_160w_z127+50)
ax.set_ylim(y_160w_z127-50,y_160w_z127+50)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2379441629.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_79251/2379441629.py:3: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(img_fits_160w[0].data*img_fits_160w[0].header['PHOTFLAM']), origin='lower',
# (393.0285714285714, 493.0285714285714)

# %%
counts_tot_160w_z127 = 0

for idx in list(idx_160w_z127[0]):
    x = seg_map_gal_x_160w_z127[idx]
    y = seg_map_gal_y_160w_z127[idx]
    counts_tot_160w_z127 += img_fits_160w[0].data[y,x]

flux_tot_160w_z127 = counts_tot_160w_z127*3.34e+4*img_fits_160w[0].header['PHOTPLAM']**2*img_fits_160w[0].header['PHOTFLAM']
mag_160w_z127 = -2.5*np.log10(flux_tot_160w_z127/3631)

# %%
np.round(mag_160w_z127,3)
# Out:
# 22.049

# %% [markdown]
# # Extinction calculations

# %%
Rv = 3.1
ebv_z067 = 0.0404
ebv_z109 = 0.0397
ebv_z122 = 0.0397
ebv_z127 = 0.0404

# %% [markdown]
# ## For z=0.67

# %%
wave = np.arange(1250.,33000.,1)

ex_z067 = extinction.ccm89(wave,Rv*1,Rv,unit='aa',out=None)

# %%
fig, ax = plt.subplots(1, figsize=(5,3))
ax.plot(wave, ex_z067)

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel(r'$A_\lambda$ (mag)')

ax.axvspan(4800,5800,color='yellow',alpha=.2)
ax.axvspan(6800,10000,color='yellow',alpha=.2)
ax.axvspan(11370,16450,color='yellow',alpha=.2)

# %%
np.round(np.mean(ex_z067[(wave>=4800)&(wave<=5800)]),3)
# Out:
# 3.255

# %%
np.round(np.mean(ex_z067[(wave>=6000)&(wave<=7500)]),3)
# Out:
# 2.446

# %%
np.round(np.mean(ex_z067[(wave>=7500)&(wave<=9000)]),3)
# Out:
# 1.758

# %%
np.round(np.mean(ex_z067[(wave>=6800)&(wave<=10000)]),3)
# Out:
# 1.743

# %%
np.round(np.mean(ex_z067[(wave>=11370)&(wave<=16450)]),3)
# Out:
# 0.754

# %%
np.round(np.mean(ex_z067[(wave>=14210)&(wave<=19240)]),3)
# Out:
# 0.556

# %% [markdown]
# ## For z=1.09

# %%
wave = np.arange(1250.,33000.,1)

ex_z109 = extinction.ccm89(wave,Rv*ebv_z109,Rv,unit='aa',out=None)

# %%
fig, ax = plt.subplots(1, figsize=(5,3))
ax.plot(wave, ex_z109)

ax.set_xlabel('Wavelength (Å)')
ax.set_ylabel(r'$A_\lambda$ (mag)')

ax.axvspan(4800,5800,color='yellow',alpha=.2)
ax.axvspan(6800,10000,color='yellow',alpha=.2)
ax.axvspan(11370,16450,color='yellow',alpha=.2)

# %%
np.round(np.mean(ex_z109[(wave>=4800)&(wave<=5800)]),3)
# Out:
# 0.129

# %%
np.round(np.mean(ex_z109[(wave>=6000)&(wave<=7500)]),3)
# Out:
# 0.097

# %%
np.round(np.mean(ex_z109[(wave>=7500)&(wave<=9000)]),3)
# Out:
# 0.07

# %%
np.round(np.mean(ex_z109[(wave>=6800)&(wave<=10000)]),3)
# Out:
# 0.069

# %%
np.round(np.mean(ex_z109[(wave>=11370)&(wave<=16450)]),3)
# Out:
# 0.03

# %%
np.round(np.mean(ex_z109[(wave>=14210)&(wave<=19240)]),3)
# Out:
# 0.022
