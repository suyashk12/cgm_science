# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import constants, units
from astropy.coordinates import Angle
from scipy.optimize import curve_fit
import pandas as pd
import os

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/'

# %% [markdown]
# Load in the catalogs, first the subset containing all MUSE objects

# %%
ldss_photo_df = pd.read_csv(rootdir+'ldss_photometry_final_subset.dat')

# %%
ldss_photo_df
# Out:
#             RA       Dec  f160w_mag  f140w_mag  pseudo_g_mag  pseudo_r_mag  \
# 0   231.098500  9.983185      20.67      20.60         24.48         23.64
# 1   231.097411  9.982920      21.41      21.42         24.54         24.20
# 2   231.094330  9.981459      21.40      21.42         25.75         25.44
# 3   231.097686  9.982070      21.27      21.17         26.15         25.71
# 4   231.097092  9.982013      20.65      20.82         27.11         26.62
# ..         ...       ...        ...        ...           ...           ...
# 74  231.106633  9.969961      19.80      19.84         28.88         27.78
# 75  231.105125  9.967151      20.50      20.40         23.43         22.76
# 76  231.104042  9.966671      21.00      20.99         25.63         24.67
# 77  231.107361  9.967401      18.99      19.13         23.22         21.99
# 78  231.109252  9.967202      21.84      21.75         27.75         27.10
#
#     pseudo_i_mag       z
# 0          23.08  0.4784
# 1          23.80  0.1393
# 2          25.28 -1.0000
# 3          25.25 -1.0000
# 4          25.78 -1.0000
# ..           ...     ...
# 74         26.77 -1.0000
# 75         22.62  0.4581
# 76         24.01  0.8217
# 77         21.41  0.5356
# 78         26.66 -1.0000
#
# [79 rows x 8 columns]

# %%
query_ra = Angle("15h24m26.3329s").rad
query_dec = Angle("+9d58m21.179s").rad

# %%
def calc_phi(alpha_1, delta_1, alpha_2, delta_2):
    
    cos_phi = np.dot([np.cos(delta_1)*np.cos(alpha_1), np.cos(delta_1)*np.sin(alpha_1), np.sin(delta_1)],
                      [np.cos(delta_2)*np.cos(alpha_2), np.cos(delta_2)*np.sin(alpha_2), np.sin(delta_2)])
    
    phi = np.arccos(cos_phi)
    
    return phi

# %%
phi_arr = []

for i in range(len(ldss_photo_df)):
    
    ra = Angle(ldss_photo_df.loc[i]['RA'], units.deg).rad
    dec = Angle(ldss_photo_df.loc[i]['Dec'], units.deg).rad
    
    phi_arr.append((calc_phi(ra, dec, query_ra, query_dec)*units.rad).to(units.arcsecond).value)
    
phi_arr = np.array(phi_arr)

# %%
ldss_photo_df.iloc[np.argmin(phi_arr)], np.min(phi_arr)
# Out:
# (RA              231.109683
#  Dec               9.972539
#  f160w_mag        16.900000
#  f140w_mag        16.970000
#  pseudo_g_mag     17.910000
#  pseudo_r_mag     17.490000
#  pseudo_i_mag     17.300000
#  z                 0.000000
#  Name: 58, dtype: float64,
#  0.14014334867062242)
