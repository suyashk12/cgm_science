# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import constants, units
from astropy.coordinates import Angle
from scipy.optimize import curve_fit
import pandas as pd
import os
from redshift_fit_lib import *

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/MUSE/'

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
gal_dict = {0.67: 105, 
            0.72: 61, 
            1.09: 27,
            1.16: -1,
            1.27: 87,
           1.04: -1}

# %% [markdown]
# Load in the segmentation map for galaxy IDs

# %%
cat_file = np.loadtxt(rootdir + 'test_new_updated.cat')

# %%
gal_ids_arr = np.int_(cat_file[:,0])

# %%
z_ids_arr = cat_file[:,12]

# %% [markdown]
# Plot $\chi^2$ versus $z$

# %%
gal_id = 61

# %%
gal_model_arr = np.loadtxt(rootdir+'gal{}/gal{}_model.dat'.format(gal_id, gal_id), delimiter='\t')

# %%
z_arr = gal_model_arr[:,0]
chi_sq_arr = gal_model_arr[:,5]

# %%
z_best = z_arr[np.argmin(chi_sq_arr)]

# %%
fig, ax = plt.subplots(1, figsize=(5,3))

ax.plot(z_arr, chi_sq_arr)
ax.axvline(z_best, color='orange', linestyle=':', lw=2, label=r'$z_{\mathrm{gal}}$' +'={}'.format(np.round(z_best, 3)))

ax.set_xlabel(r'$z$')
ax.set_ylabel(r'$\chi^2$')
#ax.set_title('Galaxy {}'.format(gal_id))

ax.legend()

# %% [markdown]
# Plot galaxy spectrum with atomic lines

# %%
gal_id = 105

# %%
idx = np.where(gal_ids_arr==gal_id)[0][0]

# %%
z_best = z_ids_arr[idx]

# %%
z_best
# Out:
# 0.678

# %%
gal_spec_arr = np.loadtxt(rootdir+'gal{}/gal{}_spec.dat'.format(gal_id, gal_id), delimiter='\t')

# %%
wav_arr = gal_spec_arr[:,0]
gal_spec_raw = gal_spec_arr[:,1]
gal_spec_err = gal_spec_arr[:,2]
gal_spec_fit = gal_spec_arr[:,3]

# %%
z_abs = 0.6753127

# %%
d_proj = 241

# %%
fig, ax = plt.subplots(1, figsize=(15,4))

ax.step(wav_arr, gal_spec_raw, where='mid')
ax.step(wav_arr, gal_spec_err, where='mid')
ax.axhline(0, linestyle=':', color='red')

plot_gal_lines(ax, z_best, plot_list=['[OII]'], 
               y_pos=6.5, lw=0.8, wav_min = 6100, wav_max=7000)

ax.set_xlabel(r'Wavelength (Å)')
ax.set_ylabel(r'Flux (1e-20 erg/s/cm${}^2$/Å)')

ax.text(x=6620, y=7, s=r'$z_{\mathrm{gal}}=$'+' {:.3f}'.format(z_best))
#ax.text(x=6620, y=7, s=r'$\Delta v_{\mathrm{abs}}=$'+' {:.3f}'.format(z_best))
ax.text(x=6620, y=6, s=r'$d_{\mathrm{proj}}=$'+' {} kpc'.format(d_proj))

ax.set_xlim(6150,6700)
ax.set_ylim(-1, 8)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z={}/z={}_gal_spec.pdf'.format(str(z_abs), 
                                                                                                         str(z_abs).replace('.', '_')), 
            dpi=300)

# %%
1472.5*1e+3*33.8*4.84814e-6
# Out:
# 241.29435186999996

# %%
np.round(3e+5*(z_abs-z_best)/(1+z_best))
# Out:
# -480.0

# %% [markdown]
# Next system

# %%
gal_id = 61

# %%
idx = np.where(gal_ids_arr==gal_id)[0][0]

# %%
z_best = z_ids_arr[idx]

# %%
gal_spec_arr = np.loadtxt(rootdir+'gal{}/gal{}_spec.dat'.format(gal_id, gal_id), delimiter='\t')

# %%
wav_arr = gal_spec_arr[:,0]
gal_spec_raw = gal_spec_arr[:,1]
gal_spec_err = gal_spec_arr[:,2]
gal_spec_fit = gal_spec_arr[:,3]

# %%
z_abs = 0.72882357

# %%
d_proj = 179

# %%
fig, ax = plt.subplots(1, figsize=(15,4))

ax.step(wav_arr, gal_spec_raw, where='mid')
ax.step(wav_arr, gal_spec_err, where='mid')
ax.axhline(0, linestyle=':', color='red')

#plot_gal_lines(ax, z_best, plot_list=['[OII]', 'CaIIH', 'CaIIK', 
#                                      'Hb', 'Hd', 'Hg', '[OIII]', 'G-band'], 
#               y_pos=15, wav_min=6000, wav_max=9000, lw=0.8)

ax.set_xlabel(r'Wavelength (Å)')
ax.set_ylabel(r'Flux (1e-20 erg/s/cm${}^2$/Å)')

#ax.text(x=8400, y=28, s=r'$z=$'+' {:.3f}'.format(z_best))
#ax.text(x=8400, y=25, s=r'$d_{\mathrm{proj}}=$'+' {} kpc'.format(d_proj))

ax.set_xlim(6300,8800)
ax.set_ylim(-2.5, 35)
# Out:
# (-2.5, 35.0)

# %%
fig, ax = plt.subplots(1, figsize=(15,4))

ax.step(wav_arr, gal_spec_raw, where='mid')
ax.step(wav_arr, gal_spec_err, where='mid')
ax.axhline(0, linestyle=':', color='red')

plot_gal_lines(ax, z_best, plot_list=['[OII]', 'CaIIH', 'CaIIK', 
                                      'Hb', 'Hd', 'Hg', '[OIII]', 'G-band'], 
               y_pos=15, wav_min=6000, wav_max=9000, lw=0.8)

ax.set_xlabel(r'Wavelength (Å)')
ax.set_ylabel(r'Flux (1e-20 erg/s/cm${}^2$/Å)')

ax.text(x=8400, y=28, s=r'$z_{\mathrm{gal}}=$'+' {:.3f}'.format(z_best))
ax.text(x=8400, y=25, s=r'$d_{\mathrm{proj}}=$'+' {} kpc'.format(d_proj))
ax.set_ylim(-2.5, 35)

ax.set_xlim(6300,8800)
ax.set_ylim(-2.5, 35)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z={}/z={}_gal_spec.pdf'.format(str(z_abs), 
                                                                                                         str(z_abs).replace('.', '_')), 
            dpi=300)

# %%
1516.1*1e+3*24.3*4.84814e-6
# Out:
# 178.6114408122

# %%
3e+5*(z_abs-z_best)/(1+z_best)
# Out:
# -82.65136182269801

# %% [markdown]
# Next system

# %%
gal_id = 27

# %%
idx = np.where(gal_ids_arr==gal_id)[0][0]

# %%
z_best = z_ids_arr[idx]

# %%
gal_spec_arr = np.loadtxt(rootdir+'gal{}/gal{}_spec.dat'.format(gal_id, gal_id), delimiter='\t')

# %%
wav_arr = gal_spec_arr[:,0]
gal_spec_raw = gal_spec_arr[:,1]
gal_spec_err = gal_spec_arr[:,2]
gal_spec_fit = gal_spec_arr[:,3]

# %%
z_abs = 1.09456367

# %%
d_proj = 202

# %%
fig, ax = plt.subplots(1, figsize=(15,4))

ax.step(wav_arr, gal_spec_raw, where='mid')
#ax.plot(wav_arr, gal_spec_fit, label='Fit')
ax.step(wav_arr, gal_spec_err, where='mid')

plot_gal_lines(ax, z_best, plot_list=['[OII]'], 
               y_pos=10, wav_min=7750, wav_max=9000, lw=0.8)

ax.set_xlabel(r'Wavelength (Å)')
ax.set_ylabel(r'Flux (1e-20 erg/s/cm${}^2$/Å)')

ax.text(x=8600, y=15, s=r'$z=$'+' {:.3f}'.format(z_best))
ax.text(x=8600, y=12, s=r'$d_{\mathrm{proj}}=$'+' {} kpc'.format(d_proj))

ax.set_ylim(-5.5, 32)

ax.set_xlim(7750,8800)
ax.set_ylim(-5.5, 20)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z={}/z={}_gal_spec.pdf'.format(str(z_abs), 
                                                                                                         str(z_abs).replace('.', '_')), 
            dpi=300)

# %%
1709.4*1e+3*24.4*4.84814e-6
# Out:
# 202.2128165904

# %%
3e+5*(z_abs-z_best)/(1+z_best)
# Out:
# -191.27773271625503

# %% [markdown]
# Next system

# %%
gal_id = 87

# %%
idx = np.where(gal_ids_arr==gal_id)[0][0]

# %%
z_best = z_ids_arr[idx]

# %%
gal_spec_arr = np.loadtxt(rootdir+'gal{}/gal{}_spec.dat'.format(gal_id, gal_id), delimiter='\t')

# %%
wav_arr = gal_spec_arr[:,0]
gal_spec_raw = gal_spec_arr[:,1]
gal_spec_err = gal_spec_arr[:,2]
gal_spec_fit = gal_spec_arr[:,3]

# %%
z_abs = 1.27767328

# %%
fig, ax = plt.subplots(1, figsize=(15,4))

ax.plot(wav_arr, gal_spec_raw)
ax.plot(wav_arr, gal_spec_err)

plot_gal_lines(ax, z_best, plot_list=['OII', 'CaIIH', 'CaIIK'], pos_y=10)

ax.set_xlabel(r'Wavelength (Å)')
ax.set_ylabel(r'Flux (1e-20 erg/s/cm${}^2$/Å)')

ax.text(x=8750, y=28, s=r'$z=$'+'{:.3f}'.format(z_best))
ax.set_ylim(-5.5, 32)

ax.set_xlim(4750,9300)
ax.set_ylim(-5.5, 35)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z={}/z={}_gal_spec.pdf'.format(str(z_abs), 
                                                                                                         str(z_abs).replace('.', '_')), 
            dpi=300)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.plot(wav_arr, gal_spec_raw)
ax.plot(wav_arr, gal_spec_err)

plot_gal_lines(ax, z_best, plot_list=['OII'], pos_y=12)

ax.set_xlabel(r'Wavelength (Å)')
ax.set_ylabel(r'Flux (1e-20 erg/s/cm${}^2$/Å)')

ax.set_xlim(8400,8600)
ax.set_ylim(-2, 16)
# Out:
# (-2.0, 16.0)

# %%
3e+5*(z_abs-z_best)/(1+z_best)
# Out:
# -135.1718084873002
