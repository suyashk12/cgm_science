# %%
from astropy.io import fits
from astropy import units, constants
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import corner
from voigt_fit_lib import *
import os
import pickle

# %% [markdown]
# Load in the files

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/'

# %% [markdown]
# First, the FUV files

# %%
spec_fits_fuv = fits.open(rootdir + 'FUV/PG1522+101_FUV_wavecal_new.fits')
lsf_fits_fuv = fits.open(rootdir + 'FUV/PG1522_COS_FUV_wavcal2022_lsf_ZQ.fits')

# %% [markdown]
# Then, the NUV files

# %%
spec_fits_nuv = fits.open(rootdir + 'G185M/PG1522+101_NUV_wavecal_new.fits')
lsf_fits_nuv = fits.open(rootdir + 'G185M/PG1522_COS_NUV_wavcal2022_lsf.fits')

# %% [markdown]
# Then, the STIS files

# %%
spec_fits_stis = fits.open(rootdir + 'STIS/PG1522+101_E230M_new.fits')
lsf_fits_stis = fits.open(rootdir + 'STIS/PG1522_STIS_NUV_wavcal2022_lsf.fits')

# %% [markdown]
# Then, the HIRES files

# %%
spec_fits_hires = fits.open(rootdir + 'HIRES/PG1522+101_HIRES.fits')
lsf_fits_hires = fits.open(rootdir + 'HIRES/PG1522_HIRES_wavcal2023_lsf.fits')

# %% [markdown]
# Compile a list of the spectra, continuum nodes, and IDs for all detectors

# %%
spec_fits_list = [spec_fits_fuv, spec_fits_nuv, spec_fits_stis, spec_fits_hires]
lsf_fits_list = [lsf_fits_fuv, lsf_fits_nuv, lsf_fits_stis, lsf_fits_hires]

# %% [markdown]
# # z=0.0966

# %%
z_sys = 0.0966

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'FUV')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -3, 15
# EW-3sig: 44

# %% [markdown]
# # z=0.1203

# %%
z_sys = 0.1203

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'FUV')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -12, 17
# EW-3sig: 50

# %% [markdown]
# # z=0.1204

# %%
z_sys = 0.1204

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'FUV')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -37, 16
# EW-3sig: 49

# %% [markdown]
# # z=0.1393

# %%
z_sys = 0.1393

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'FUV')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-20,-10]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -18, 16
# EW-3sig: 49

# %% [markdown]
# # z=0.2791

# %%
z_sys = 0.2791

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'NUV')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 77, 35
# EW-3sig: 105

# %% [markdown]
# # z=0.2915

# %%
z_sys = 0.2915

# %% [markdown]
# ## CIV 1548

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'NUV')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-400,-100],[160,500]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1548.plot_ion_transition_spec()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 227, 32
# EW-3sig: 97

# %% [markdown]
# ## CIV 1550

# %%
civ_1550 = ion_transition('CIV', 1550, 'C', z_sys, 'NUV')

# %%
civ_1550.grab_ion_transition_info()

# %%
civ_1550.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-440], [-350,-150], [400,500]])

# %%
civ_1550.cont_norm_flux(v_abs_range=[-140,50], degree=1)

# %%
fig, ax = civ_1550.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1550.plot_ion_transition_spec()

# %%
civ_1550.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 308, 31
# EW-3sig: 94

# %% [markdown]
# ## NV 1242

# %%
nv_1242 = ion_transition('NV', 1242, 'N', z_sys, 'FUV')

# %%
nv_1242.grab_ion_transition_info()

# %%
nv_1242.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-440], [-250,-50]])

# %%
nv_1242.cont_norm_flux(v_abs_range=[-140,50], degree=1)

# %%
fig, ax = nv_1242.plot_ion_transition_spec_cont()

# %%
fig, ax = nv_1242.plot_ion_transition_spec()

# %%
nv_1242.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 150, 10
# EW-3sig: 30

# %% [markdown]
# ## FeII 1608

# %%
feii_1608 = ion_transition('FeII', 1608, 'Fe', z_sys, 'NUV')

# %%
feii_1608.grab_ion_transition_info()

# %%
feii_1608.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-440], [-250,-50]])

# %%
feii_1608.cont_norm_flux(v_abs_range=[-140,50], degree=1)

# %%
fig, ax = feii_1608.plot_ion_transition_spec_cont()

# %%
fig, ax = feii_1608.plot_ion_transition_spec()

# %%
feii_1608.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 6, 34
# EW-3sig: 103

# %% [markdown]
# # z=0.3198

# %%
z_sys = 0.3198

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[350,500]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -23, 52
# EW-3sig: 157

# %% [markdown]
# # z=0.3286

# %%
z_sys = 0.3286

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-60,150], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 423, 41
# EW-3sig: 123

# %% [markdown]
# # z=0.3752

# %%
z_sys = 0.3752

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-120],[350,500]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 41, 31
# EW-3sig: 93

# %% [markdown]
# # z=0.3759

# %%
z_sys = 0.3759

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-260],[150,500]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-200,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 53, 32
# EW-3sig: 95

# %% [markdown]
# # z=0.4395

# %%
z_sys = 0.4395

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-120],[50,440]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 42, 24
# EW-3sig: 73

# %% [markdown]
# # z=0.4581

# %%
z_sys = 0.4581

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-160],[390,450]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 78, 23
# EW-3sig: 69

# %% [markdown]
# # z=0.4784

# %%
z_sys = 0.4784

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-350,-120],[390,470]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -24, 20
# EW-3sig: 59

# %% [markdown]
# # z=0.5191

# %%
z_sys = 0.5191

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-230,-110],[100,270]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -1, 20
# EW-3sig: 60

# %% [markdown]
# # z=0.5205

# %%
z_sys = 0.5205

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-350],[-220,50]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 84, 21
# EW-3sig: 62

# %% [markdown]
# # z=0.5356

# %%
z_sys = 0.5356

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-350]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 16, 16
# EW-3sig: 47

# %% [markdown]
# # z=0.5723

# %%
z_sys = 0.5723

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 50, 16
# EW-3sig: 48

# %% [markdown]
# # z=0.6164

# %%
z_sys = 0.6164

# %% [markdown]
# ## CIV 1548

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[0,200]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-200,200], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1548.plot_ion_transition_spec()

# %%
civ_1548.get_EW_total(-150,0)
# Out:
# Integration window: [-150, 0]
# EW, 1sig: 254, 22
# EW-3sig: 67

# %% [markdown]
# ## CIV 1550

# %%
civ_1550 = ion_transition('CIV', 1550, 'C', z_sys, 'STIS')

# %%
civ_1550.grab_ion_transition_info()

# %%
civ_1550.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-300]])

# %%
civ_1550.cont_norm_flux(v_abs_range=[-200,200], degree=1)

# %%
fig, ax = civ_1550.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1550.plot_ion_transition_spec()

# %%
civ_1550.get_EW_total(-150,0)
# Out:
# Integration window: [-150, 0]
# EW, 1sig: 72, 22
# EW-3sig: 65

# %% [markdown]
# # z=0.6174

# %%
z_sys = 0.6174

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[150,290]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-300,290], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-400,-175)
# Out:
# Integration window: [-400, -175]
# EW, 1sig: 246, 29
# EW-3sig: 86

# %% [markdown]
# # z=0.6178

# %%
z_sys = 0.6178

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-400,200], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -44, 19
# EW-3sig: 58

# %% [markdown]
# # z=0.6183

# %%
z_sys = 0.6183

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-100]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 3, 19
# EW-3sig: 58

# %% [markdown]
# # z=0.6469

# %%
z_sys = 0.6469

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,0]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 49, 15
# EW-3sig: 46

# %% [markdown]
# # z=0.6518

# %%
z_sys = 0.6518

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -33, 17
# EW-3sig: 52

# %% [markdown]
# # z=0.6531

# %%
z_sys = 0.6531

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 8, 17
# EW-3sig: 52

# %% [markdown]
# # z=0.6780

# %%
z_sys = 0.6780

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-350],[150,300]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 26, 18
# EW-3sig: 55

# %% [markdown]
# # z=0.7010

# %%
z_sys = 0.7010

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-200,10]])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 291, 16
# EW-3sig: 49

# %% [markdown]
# # z=0.7293

# %%
z_sys = 0.7293

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -31, 17
# EW-3sig: 51

# %% [markdown]
# # z=0.8217

# %%
z_sys = 0.8217

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'STIS')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
#civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
#fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
#civ_1548.get_EW_total(-50,50)

# %% [markdown]
# # z=0.8415

# %%
z_sys = 0.8415

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
#civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
#fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
#civ_1548.get_EW_total(-50,50)

# %% [markdown]
# # z=1.0959

# %%
z_sys = 1.0959

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-400,400], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -16, 4
# EW-3sig: 11

# %% [markdown]
# # z=1.1935

# %%
z_sys = 1.1935

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: -10, 4
# EW-3sig: 12

# %% [markdown]
# # z=1.2256

# %%
z_sys = 1.2256

# %% [markdown]
# ## CIV 1548

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-60,10], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1548.plot_ion_transition_spec()

# %%
civ_1548.get_EW_total(-60,10)
# Out:
# Integration window: [-60, 10]
# EW, 1sig: 16, 3
# EW-3sig: 8

# %% [markdown]
# ## CIV 1550

# %%
civ_1550 = ion_transition('CIV', 1550, 'C', z_sys, 'HIRES')

# %%
civ_1550.grab_ion_transition_info()

# %%
civ_1550.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[0,110]])

# %%
civ_1550.cont_norm_flux(v_abs_range=[-100,110], degree=1)

# %%
fig, ax = civ_1550.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1550.plot_ion_transition_spec()

# %%
civ_1550.get_EW_total(-60,10)
# Out:
# Integration window: [-60, 10]
# EW, 1sig: 11, 3
# EW-3sig: 8

# %% [markdown]
# # z=1.2787

# %%
z_sys = 1.2787

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-250,450], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-60,10)
# Out:
# Integration window: [-60, 10]
# EW, 1sig: 5, 3
# EW-3sig: 8

# %% [markdown]
# # z=1.2988

# %%
z_sys = 1.2988

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 1, 3
# EW-3sig: 8

# %% [markdown]
# # z=1.25938

# %%
z_sys=1.25938

# %% [markdown]
# ## CIV 1548

# %%
civ_1548 = ion_transition('CIV', 1548, 'C', z_sys, 'HIRES')

# %%
civ_1548.grab_ion_transition_info()

# %%
civ_1548.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500])

# %%
civ_1548.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1548.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1548.plot_ion_transition_spec()

# %%
civ_1548.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 13, 3
# EW-3sig: 10

# %% [markdown]
# ## CIV 1550

# %%
civ_1550 = ion_transition('CIV', 1550, 'C', z_sys, 'HIRES')

# %%
civ_1550.grab_ion_transition_info()

# %%
civ_1550.grab_ion_transition_spec(spec_fits_list, v_range=[-500,500], masks=[[-500,-480]])

# %%
civ_1550.cont_norm_flux(v_abs_range=[-50,50], degree=1)

# %%
fig, ax = civ_1550.plot_ion_transition_spec_cont()

# %%
fig, ax = civ_1550.plot_ion_transition_spec()

# %%
civ_1550.get_EW_total(-50,50)
# Out:
# Integration window: [-50, 50]
# EW, 1sig: 12, 3
# EW-3sig: 9
