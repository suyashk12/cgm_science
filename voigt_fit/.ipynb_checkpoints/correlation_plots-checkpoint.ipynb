# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %% [markdown]
# Get fitting results - first absorber redshifts

# %%
z_list = [0.67, 0.72, 1.09, 1.09, 1.16, 1.16, 1.27, 1.27, 1.04, 1.04, 1.04, 1.04, 1.04]

# %%
z_markers_list = ['o', 'o', 'o', '^', 'o', '^', 'o', '^', 'o', '^', 'v', 's', '*']

# %%
z_markers_names = ['z=0.67, c1', 'z=0.72, c2', 
                   'z=1.09, c1', 'z=1.09, c2', 
                   'z=1.16, c1', 'z=1.16, c2', 
                   'z=1.27, c1', 'z=1.27, c2',
                   'z=1.04, c1', 'z=1.04, c2', 'z=1.04, c3', 'z=1.04, c4', 'z=1.04, c5']

# %%
z_color_dict = {0.67: 'salmon', 
                0.72: 'olivedrab', 
                1.09: 'mediumslateblue', 
                1.16: 'slategray', 
                1.27: 'tan',
                1.04: 'brown'}

# %% [markdown]
# Temperature and non-thermal turbulence

# %%
v_c_list = ['27.4, -0.6, 0.6', # z=0.67, c2
            '0.0, -0.3, +0.3', # z=0.72
            '0.0, -0.8, +0.8', # z=1.09, c1
            '20, -2, +2', # z=1.09, c2
            '0.0, -0.3, +0.3', # z=1.16, c1
            '-24, -3, +3', # z=1.16, c2
            '0.0, -0.1, +0.1', # z=1.27, c1
            '39.8, -0.2, +0.2', # z=1.27, c2
            '0.0, -0.2, +0.2', # z=1.04, c1
            '39.7, -0.3, +0.3', # z=1.04, c2
            '80.8, -0.7, +0.7', # z=1.04, c3
            '101.1, -0.5, +0.5', # z=1.04, c4
            '55, -6, +6'] # z=1.04, c5

# %%
logT_list = ['<4.9', # z=0.67, c2
              '4.5, -0.1, +0.1', # z=0.72
              '4.5, -0.1, +0.1', # z=1.09, c1
              '<6.0', # z=1.09, c2
              '4.3, -0.1, +0.1', # z=1.16, c1
              '<4.9', # z=1.16, c2
              '4.4, -0.1, +0.1', # z=1.27, c1
              '4.5, -0.2, +0.2', # z=1.27, c2
              '4.4, -0.1, +0.1', # z=1.04, c1
              '4.2, -0.1, +0.1', # z=1.04, c2
              '<5.4', # z=1.04, c3
              '4.6, -0.1, +0.1', # z=1.04, c4
              '<6.0', # z=1.04, c5
        ]

# %%
b_NT_list = ['32, -1, +1',
           '12, -2, +2',
           '14.2, -0.9, +0.9',
           '<42',
           '10.0, -0.5, +0.5',
           '26, -2, +2',
           '9.5, -0.5, +0.5',
           '8, -2, +1',
           '<6',
           '<5',
           '<50',
           '<7',
           '<49']

# %% [markdown]
# Ion specific measurements

# %%
z_0_67 = {'HI': ['15.40, -0.06, +0.06', '36, -1, +2',  '<32'],
        'CII': ['<13.5', '32',  '<9'],
        'CIII': ['13.97, -0.03, +0.03', '32, -1, +1',  '<9'],
        'CIV': ['13.73, -0.05, +0.05', '32, -1, +1',  '<9'],
        'NII': ['<13.3', '32',  '<9'],
        'NIII': ['<13.5', '32',  '<9'],
        'NV': ['<13.8', '32',  '<9'],
        'OII': ['<13.3', '32',  '<8'],
        'OIII': ['14.42, -0.02, +0.02', '32, -1, +1',  '<8'],
        'OIV': ['14.95, -0.03, +0.03', '32, -1, +1',  '<8'],
        'NeVIII': ['<13.4', '32',  '<7'],
        'MgII': ['<11.5', '32',  '<7'],
        'AlIII': ['<12.3', '32',  '<6'],
        'SiII': ['<13.3', '32',  '<6'],
        'SiIII': ['<12.9', '32',  '<6'],
        'SVI': ['<12.8', '32',  '<6'],
        'FeII': ['<11.9', '32',  '<4']}

# %%
z_0_72 = {'HI' : ['16.64, -0.01, +0.01', '25, -3, +3', '22, -1, +1'],
        'CII' : ['<12.8', '14', '6.3'],
        'CIII' : ['13.37, -0.07, +0.07', '14, -2, +2', '6.3, -0.4, +0.3'],
        'CIV' : ['<13.0', '14', '6.3'],
        'NII' : ['<13.7', '14', '5.8'],
        'NIII' : ['<13.0', '14', '5.8'],
        'NIV' : ['<12.7', '14', '5.8'],
        'OII' : ['<13.0', '14', '5.5'],
        'OIII' : ['13.97, -0.03, +0.03', '14, -2, +2', '5.5, -0.3, +0.3'],
        'NeVIII' : ['<13.6', '13', '4.9'],
        'MgII' : ['<11.3', '13', '4.4'],
        'AlIII' : ['<11.8', '13', '4.2'],
        'SiII' : ['<12.5', '13', '4.1'],
        'SiIII' : ['<12.6', '13', '4.1'],
        'SiIV' : ['<12.5', '13', '4.1'],
        'SIV' : ['<12.7', '13', '3.9'],
        'SV' : ['<12.2', '13', '3.9'],
        'SVI' : ['<13.0', '13', '3.9'],
        'FeII' : ['<11.7', '13', '2.9']}

# %%
z_1_09_c1 = {'HI': ['14.53, -0.08, +0.08', '26, -2, +2', '22, -2, +2'],
            'HeI': ['<13.10', '18.1', '11'],
            'CII': ['<13.4', '15.6', '6.4'],
            'CIII': ['>13.3', '15.6, -0.7, +0.7', '6.4, -0.5, +0.6'],
            'CIV': ['13.90, -0.03, +0.03', '15.6, -0.7, +0.7', '6.4, -0.5, +0.6'],
            'NII': ['<13.4', '15.4', '5.9'],
            'NIV': ['13.0,  -0.1, +0.1', '15.4, -0.7, +0.7', '5.9, -0.5, +0.5'],
            'NV': ['<13.5', '15.4', '5.9'],
            'OII': ['<13.5', '15.3', '5.5'],
            'OIII': ['14.17, -0.05, +0.05', '15.3, -0.8, +0.8', '5.5, -0.5, +0.5'],
            'OIV': ['14.7, -0.1, +0.1', '15.3, -0.8, +0.8', '5.5, -0.5, +0.5'],
            'NeVI': ['<13.8', '15.1', '4.9'],
            'NeVIII': ['<13.8', '15.1', '4.9'],
            'MgII': ['<11.4', '14.9', '4.5'],
            'MgX': ['<13.9', '14.9', '4.5'],
            'AlII': ['<11.2', '14.9', '4.3'],
            'AlIII': ['<11.5', '14.9', '4.3'],
            'SiII': ['<12.3', '14.8', '4.2'],
            'SiIII': ['<12.1', '14.8', '4.2'],
            'SIV': ['<12.8', '14.8', '3.9'],
            'SV': ['<12.4', '14.8', '3.9'],
            'SVI': ['<13.6', '14.8', '3.9'],
            'FeII': ['<11.8', '14.5', '3']}

# %%
z_1_09_c2 = {'HI' : ['<13.5', '24, -6, +10', '<119'],
            'HeI' : ['<13.0', '15', '<60'],
            'CII' : ['<13.3', '11', '<34'],
            'CIII' : ['<13.2', '11', '<34'],
            'CIV' : ['13.1, -0.2, +0.2', '11, -2, +2', '<34'],
            'NII' : ['<13.4', '11', '<32'],
            'NIV' : ['<12.7', '11', '<32'],
            'NV' : ['<13.4', '11', '<32'],
            'OII' : ['<13.4', '10', '<30'],
            'OIII' : ['13.7, -0.1, +0.1', '10, -2, +2', '<30'],
            'OIV' : ['14.2, -0.2, +0.2', '10, -2, +2', '<30'],
            'NeVI' : ['<13.7', '10', '<27'],
            'NeVIII' : ['<13.7', '10', '<27'],
            'MgII' : ['<11.3', '10', '<24'],
            'MgX' : ['<13.8', '10', '<24'],
            'AlII' : ['<11.1', '10', '<23'],
            'AlIII' : ['<11.5', '10', '<23'],
            'SiII' : ['<12.2', '10', '<22'],
            'SiIII' : ['<12.0', '10', '<22'],
            'SIV' : ['<12.7', '9', '<21'],
            'SV' : ['<12.3', '9', '<21'],
            'SVI' : ['<13.6', '9', '<21'],
            'FeII' : ['<11.7', '9', '<16']}

# %%
z_1_16_c1 = {'HI' : ['16.4, -0.1, +0.1', '21.1, -0.8, +0.8', '19, -1, +1'],
            'HeI' : ['14.49, -0.05, +0.05', '13.7, -0.4, +0.4', '9.4, -0.5, +0.5'],
            'CIII' : ['>12.8', '11.3, -0.4, +0.4', '5.4, -0.3, +0.3'],
            'CIV' : ['13.49, -0.02, +0.02', '11.3, -0.4, +0.4', '5.4, -0.3, +0.3'],
            'OII' : ['<13.8', '11', '4.7'],
            'OIII' : ['14.22, -0.07, +0.07', '11.0, -0.4, +0.4', '4.7, -0.3, +0.3'],
            'OIV' : ['14.41, -0.05, +0.05', '11.0, -0.4, +0.4', '4.7, -0.3, +0.3'],
            'OV' : ['13.6, -0.1, +0.1', '11.0, -0.4, +0.4', '4.7, -0.3, +0.3'],
            'OVI' : ['<13.4', '11', '4.7'],
            'NeVIII' : ['<13.5', '10.8', '4.2'],
            'MgII' : ['<15.4', '10.7', '3.8'],
            'MgX' : ['<13.6', '10.7', '3.8'],
            'AlII' : ['<11.0', '10.6', '3.6'],
            'AlIII' : ['<11.5', '10.6', '3.6'],
            'SiII' : ['<12.1', '10.6', '3.5'],
            'FeII' : ['<11.7', '10.3', '2.5']}

# %%
z_1_16_c2 = {'HI' : ['14.6, -0.2, +0.2',  '32, -2, +3', '<35'],
            'HeI' : ['<13.0',  '28', '<18'],
            'CIII' : ['<13.1',  '27', '<10'],
            'CIV' : ['13.03, -0.06, +0.06',  '27, -2, +2', '<10'],
            'OII' : ['<13.9',  '27', '<9'],
            'OIII' : ['<13.5',  '27', '<9'],
            'OIV' : ['13.85, -0.09, +0.09',  '27, -2, +2', '<9'],
            'OV' : ['13.83, -0.05, +0.05',  '27, -2, +2', '<9'],
            'OVI' : ['13.8, -0.1, +0.1',  '27, -2, +2', '<9'],
            'NeVIII' : ['<13.6',  '27', '<8'],
            'MgII' : ['<15.6',  '27', '<7'],
            'MgX' : ['<13.7',  '27', '<7'],
            'AlII' : ['<11.2',  '27', '<7'],
            'AlIII' : ['<11.7',  '27', '<7'],
            'SiII' : ['<12.3',  '27', '<7'],
            'FeII' : ['<11.9',  '26', '<5']}

# %%
z_1_27_c1 = {'HI' : ['14.11, -0.07, +0.07', '23, -2, +2', '21, -2, +2'],
            'HeI' : ['<13.0', '14.2', '10'],
            'CII' : ['<13.4', '11.3', '6.1'],
            'CIII' : ['12.8, -0.2, +0.2', '11.3, -0.2, +0.2', '6.1, -0.6, +0.7'],
            'CIV' : ['13.65, -0.01, +0.01', '11.3, -0.2, +0.2', '6.1, -0.6, +0.7'],
            'NII' : ['<13.4', '11', '5.6'],
            'NIII' : ['<13.0', '11', '5.6'],
            'NIV' : ['13.0, -0.1, +0.1', '11.0, -0.2, +0.2', '5.6, -0.6, +0.6'],
            'OIII' : ['13.79, -0.09, +0.09', '10.9, -0.2, +0.2', '5.3, -0.6, +0.6'],
            'OIV' : ['14.49, -0.04, +0.04', '10.9, -0.2, +0.2', '5.3, -0.6, +0.6'],
            'NeV' : ['14.16, -0.05, +0.05', '10.6, -0.3, +0.3', '4.7, -0.5, +0.5'],
            'NeVI' : ['14.18, -0.05, +0.05', '10.6, -0.3, +0.3', '4.7, -0.5, +0.5'],
            'NeVIII' : ['<13.5', '10.6', '4.7'],
            'MgX' : ['<13.5', '10.4', '4.3'],
            'AlII' : ['<11.0', '10.3', '4.1'],
            'AlIII' : ['<11.5', '10.3', '4.1'],
            'SiII' : ['<14.3', '10.3', '4'],
            'SiIII' : ['<12.0', '10.3', '4'],
            'SiIV' : ['<12.0', '10.3', '4'],
            'SIV' : ['<12.9', '10.2', '3.7'],
            'SV' : ['<12.6', '10.2', '3.7'],
            'SVI' : ['<13.1', '10.2', '3.7'],
            'FeII' : ['<11.7', '9.9', '2.8']}

# %%
z_1_27_c2 = {'HI': ['14.0, -0.1, +0.1', '23, -5, +6', '22, -6, +7'],
            'HeI': ['<13.0', '14', '11'],
            'CII': ['<13.4', '10', '6'],
            'CIII': ['<12.8', '10', '6'],
            'CIV': ['13.41, -0.01, +0.01', '10.0, -0.3, +0.3', '6, -2, +2'],
            'NII': ['<13.4', '9.7', '6'],
            'NIII': ['<13.0', '9.7', '6'],
            'NIV': ['<12.7', '9.7', '6'],
            'OIII': ['<13.4', '9.4', '6'],
            'OIV': ['14.25, -0.04, +0.04', '9.4, -0.4, +0.4', '6, -1, +2'],
            'NeV': ['13.7, -0.1, +0.1', '9.1, -0.7, +0.5', '5, -1, +2'],
            'NeVI': ['13.94, -0.06, +0.06', '9.1, -0.7, +0.5', '5, -1, +2'],
            'NeVIII': ['<13.5', '9.1', '5'],
            'MgX': ['<13.5', '9', '4'],
            'AlII': ['<11.0', '9', '4'],
            'AlIII': ['<11.4', '9', '4'],
            'SiII': ['<14.2', '9', '4'],
            'SiIII': ['<12.0', '9', '4'],
            'SiIV': ['<12.0', '9', '4'],
            'SIV': ['<12.9', '9', '4'],
            'SV': ['<12.6', '9', '4'],
            'SVI': ['<13.1', '9', '4'],
            'FeII': ['<11.7', '8', '3']}

# %%
z_1_04_c1 = {'HI' : ['14.6, -0.2, +0.2', '21, -2, +2', '20, -2, +2'],
            'HeI' : ['13.2, -0.2, +0.2', '10.7, -0.7, +0.7', '10, -1, +1'],
            'CII' : ['<13.8', '6.7', '5.9'],
            'CIV' : ['13.64, -0.02, +0.02', '6.7, -0.3, +0.3', '5.9, -0.6, +0.5'],
            'NIV' : ['13.0, -0.1, +0.1', '6.3, -0.3, +0.3', '5.5, -0.6, +0.5'],
            'OIV' : ['14.5, -0.1, +0.1', '6.0, -0.3, +0.4', '5.1, -0.5, +0.5'],
            'MgII' : ['<11.2', '5.2', '4.1'],
            'MgX' : ['<13.5', '5.2', '4.1'],
            'AlII' : ['<11.0', '5', '3.9'],
            'AlIII' : ['<11.4', '5', '3.9'],
            'SiII' : ['<12.5', '5', '3.9'],
            'SIV' : ['<13.8', '4.8', '3.6'],
            'SVI' : ['<13.2', '4.8', '3.6'],
            'FeII' : ['<11.4', '4.2', '2.7']}

# %%
z_1_04_c2 = {'HI' : ['13.8, -0.2, +0.2', '16, -2, +2', '15, -2, +2'],
            'HeI' : ['13.2, -0.2, +0.2', '7.9, -0.7, +0.9', '7.7, -0.8, +0.9'],
            'CII' : ['<13.8', '4.8', '4.5'],
            'CIV' : ['13.29, -0.04, +0.04', '4.8, -0.5, +0.5', '4.5, -0.5, +0.5'],
            'NIV' : ['12.9, -0.1, +0.1', '4.5, -0.5, +0.5', '4.1, -0.4, +0.5'],
            'OIV' : ['14.2, -0.2, +0.2', '4.2, -0.4, +0.4', '3.9, -0.4, +0.5'],
            'MgII' : ['<11.1', '3.6', '3.1'],
            'MgX' : ['<13.5', '3.6', '3.1'],
            'AlII' : ['<10.8', '3.4', '3'],
            'AlIII' : ['<11.3', '3.4', '3'],
            'SiII' : ['<12.5', '3.4', '2.9'],
            'SIV' : ['<14.0', '3.2', '2.7'],
            'SVI' : ['<13.6', '3.2', '2.7'],
            'FeII' : ['<11.3', '2.5', '2.5']}

# %%
z_1_04_c3 = {'HI' : ['<15.3' , '27, -8, +10', '<59'],
            'HeI' : ['<13.1' , '15', '<30'],
            'CII' : ['<13.7' , '11', '<17'],
            'CIV' : ['13.41, -0.07, +0.07' , '11, -2, +2', '<17'],
            'NIV' : ['13.0, -0.2, +0.2' , '10, -2, +2', '<16'],
            'OIV' : ['14.2, -0.1, +0.1' , '10, -2, +2', '<15'],
            'MgII' : ['<11.3' , '9', '<12'],
            'MgX' : ['<13.5' , '9', '<12'],
            'AlII' : ['<11.2' , '9', '<11'],
            'AlIII' : ['<11.5' , '9', '<11'],
            'SiII' : ['<12.6' , '9', '<11'],
            'SIV' : ['<13.9' , '8', '<10'],
            'SVI' : ['<13.3' , '8', '<10'],
            'FeII' : ['<11.6' , '8', '<8']}

# %% [markdown]
# Column densities

# %%
logN_dict = {'HI': ['15.40, -0.06, +0.06', # z=0.67
                   '16.64, -0.01, +0.01', # z=0.78
                   '14.53, -0.08, +0.08', # z=1.09, c1
                   '<13.5', # z=1.09, c2
                   '16.4, -0.1, +0.1', # z=1.16, c1
                   '14.6, -0.2, +0.2', # z=1.16, c2
                   '14.11, -0.07, +0.07', # z=1.27, c1
                   '14.0, -0.1, +0.1', # z=1.27, c2
                   '14.6, -0.2, +0.2', # z=1.04, c1
                   '13.8, -0.2, +0.2', # z=1.04, c2
                   '<15.3', # z=1.04, c3
                   '14.5, -0.2, +0.2', # z=1.04, c4
                   '<15.0'], # z=1.04, c5 
           'CIII': ['13.97, -0.03, +0.03',
                   '13.37, -0.07, +0.07',
                   '>13.3',
                   '<13.2',
                   '>12.8',
                   '<13.1',
                   '12.8, -0.2, +0.2',
                   '<12.8',
                   '', # Contaminated
                   '', # Contaminated
                   '', # Contaminated
                   '', # Contaminated
                   ''], # Contaminated
           'CIV': ['13.73, -0.05, +0.05',
                  '<13.0',
                  '13.90, -0.03, +0.03',
                  '13.1, -0.2, +0.2',
                  '13.49, -0.02, +0.02',
                  '13.03, -0.06, +0.06',
                  '13.65, -0.01, +0.01',
                  '13.41, -0.01, +0.01',
                  '13.64, -0.02, +0.02',
                  '13.29, -0.04, +0.04',
                  '13.41, -0.07, +0.07',
                  '13.50, -0.04, +0.04',
                  '13.23, -0.07, +0.07',],
           'NIV': ['', # Not within wavelength coverage
                  '<12.7',
                  '13.0,  -0.1, +0.1',
                  '<12.7',
                  '', # Not mentioned in Sankar?
                  '', # Not mentioned in Sankar?
                  '13.0, -0.1, +0.1',
                  '<12.7',
                  '13.0, -0.1, +0.1',
                  '12.9, -0.1, +0.1',
                  '13.0, -0.2, +0.2',
                  '13.0, -0.1, +0.1',
                  '12.7, -0.2, +0.1',],
           'OIII': ['14.42, -0.02, +0.02',
                   '13.97, -0.03, +0.03',
                   '14.17, -0.05, +0.05',
                   '13.7, -0.1, +0.1',
                   '14.22, -0.07, +0.07',
                   '<13.5',
                   '13.79, -0.09, +0.09',
                   '<13.4', 
                   '', # Contaminated
                   '', # Contaminated
                   '', # Contaminated
                   '', # Contaminated
                   '',], # Contaminated
           'OIV': ['14.95, -0.03, +0.03',
                  '', # This is identified, but has a broader linewidth so not including as detection
                  '14.7, -0.1, +0.1',
                  '14.2, -0.2, +0.2',
                  '14.41, -0.05, +0.05',
                  '13.85, -0.09, +0.09',
                  '14.49, -0.04, +0.04',
                  '14.25, -0.04, +0.04',
                   '14.5, -0.1, +0.1',
                   '14.2, -0.2, +0.2',
                   '14.2, -0.1, +0.1',
                   '14.1, -0.1, +0.1',
                   '<14.4']
           }

# %%
b_dict = {'HI': ['36, -1, +2', # z=0.67
                   '25, -3, +3', # z=0.78
                   '26, -2, +2', # z=1.09, c1
                   '24', # z=1.09, c2
                   '21.1, -0.8, +0.8', # z=1.16, c1
                   '32, -2, +3', # z=1.16, c2
                   '23, -2, +2', # z=1.27, c1
                   '23, -5, +6', # z=1.27, c2
                   '21, -2, +2', # z=1.04, c1
                   '16, -2, +2', # z=1.04, c2
                   '27, -8, +10', # z=1.04, c3
                   '26, -2, +2', # z=1.04, c4
                   '47, -16, +31'], # z=1.04, c5 
           'CIII': ['32, -1, +1',
                   '14, -2, +2',
                   '15.6, -0.7, +0.7',
                   '11',
                   '11.3, -0.4, +0.4',
                   '27',
                   '11.3, -0.2, +0.2',
                   '10.0',
                   '', # Have to calculate the upper limit here
                   '', # Have to calculate the upper limit here
                   '', # Have to calculate the upper limit here
                   '', # Have to calculate the upper limit here
                   ''], # Have to calculate the upper limit here
           'CIV': ['32, -1, +1',
                  '14',
                  '15.6, -0.7, +0.7',
                  '11, -2, +2',
                  '11.3, -0.4, +0.4',
                  '27, -2, +2',
                  '11.3, -0.2, +0.2',
                  '10.0, -0.3, +0.3',
                  '6.7, -0.3, +0.3',
                  '4.8, -0.5, +0.5',
                  '11, -2, +2',
                  '8.1, -0.6, +0.6',
                  '26, -5, +6',],
           'NIV': ['', # Not within wavelength coverage
                  '14',
                  '15.4, -0.7, +0.7',
                  '11',
                  '', # Not mentioned in Sankar?
                  '', # Not mentioned in Sankar?                  
                  '11.0, -0.2, +0.2',
                  '9.7', 
                  '6.3, -0.3, +0.3',
                  '4.5, -0.4, +0.4',
                  '10, -2, +2',
                  '7.5,  -0.6, +0.6',
                  '26, -5, +6'],
           'OIII': ['32, -1, +1',
                   '14, -2, +2',
                   '15.3, -0.8, +0.8',
                   '10, -2, +2',
                   '11.0, -0.4, +0.4',
                   '27',
                   '10.9, -0.2, +0.2',
                   '9.4',
                   '', # Have to calculate the upper limit here
                   '', # Have to calculate the upper limit here
                   '', # Have to calculate the upper limit here
                   '', # Have to calculate the upper limit here
                   '',], # Have to calculate the upper limit here
           'OIV': ['32, -1, +1',
                  '', # This is identified, but has a broader linewidth so not including as detection
                  '15.3, -0.8, +0.8',
                  '10, -2, +2',
                  '11.0, -0.4, +0.4',
                  '27, -2, +2',
                  '10.9, -0.2, +0.2',
                  '9.4, -0.4, +0.4',
                  '6.0, -0.3, +0.4',
                  '4.2, -0.4, +0.4',
                  '10, -2, +2',
                  '7.1, -0.6, +0.6',
                  '25, -5, +6']
           }

# %% [markdown]
# Write some functions to process data strings

# %%
def process_data_str(s, non_det_err):
    
    # Check if the point should be plotted or not
    bool_plot = False
    # Coordinate value
    coord_value = np.nan
    # Lower error
    err_lo = 0
    # Upper error
    err_hi = 0
    # Boolean for upper limit
    uplim = False
    # Boolean for lower limit
    lolim = False
    
    # If we don't have an empty string 
    if len(s)!=0:
        
        # Then it needs to be plotted
        bool_plot = True
        
        # Now, check for a non-detection first
        
        # Upper limit
        if s[0] == '<':
            # Set coordinate value
            coord_value = float(s[1:])
            # Only lower error
            uplim = True
            err_lo = non_det_err
            
        # Lower limit
        elif s[0] == '>':
            # Set coordinate value
            coord_value = float(s[1:])
            # Only upper error
            lolim = True
            err_hi = non_det_err
            
        # Detection
        else:
            s_arr = np.array(s.split(','), dtype=float)
            
            # Errors not provided
            if len(s_arr) == 1:
                coord_value = s_arr[0]
                err_lo = 0
                err_hi = 0
                
            # Errors provided
            else:
                coord_value = s_arr[0]
                err_lo = -s_arr[1] # Negative sign to flip the already present negative sign
                err_hi = s_arr[2]
        
    return bool_plot, coord_value, err_lo, err_hi, uplim, lolim

# %%
def plot_data_strings(ax, s_x, s_y, c, m, non_det_err=0.3, alpha=1):
    
    # First process each data string
    bool_plot_x, coord_value_x, err_lo_x, err_hi_x, uplim_x, lolim_x = process_data_str(s_x, non_det_err)
    bool_plot_y, coord_value_y, err_lo_y, err_hi_y, uplim_y, lolim_y = process_data_str(s_y, non_det_err)

    ax.errorbar(x=coord_value_x, y=coord_value_y,
                xerr=[[err_lo_x], [err_hi_x]],
                yerr=[[err_lo_y], [err_hi_y]], 
                color=c, alpha=alpha,
                marker=m, markersize=8, capsize=4, elinewidth=0.7,
                xuplims = uplim_x, xlolims= lolim_x,
                uplims = uplim_y, lolims= lolim_y)

# %% [markdown]
# $\log N$ versus $b$

# %%
def logN_b_plot(ax, ion, logN_dict, b_dict, z_list, z_color_dict):
    
    for i in range(len(b_NT_list)):
        
        logN_str = logN_dict[ion][i]
        b_str = b_dict[ion][i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_str, b_str, c, m)

# %%
fig, axes = plt.subplots(2, 3, figsize=(12,8))

for i in range(len(logN_dict)):
    
    ion = list(logN_dict.keys())[i]
    ax = axes[i//3, i%3]
    logN_b_plot(ax, ion, logN_dict, b_dict, z_list, z_color_dict)
    ax.set_title(ion)
    
ax_label = fig.add_subplot(111, frameon=False)
## hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_xlabel(r'$\log (N_{\mathrm{ion}}/\mathrm{cm}^{-2})$')
ax_label.set_ylabel(r'$b_{\mathrm{ion}}$ (km/s)') # Use argument `labelpad` to move label downwards.

plt.tight_layout()
plt.subplots_adjust(wspace=0.1, hspace=0.2)

# Specify handles ONLY for this plot

handles = []

for i in range(len(z_list)):
    
    handles.append(mlines.Line2D([], [], color=z_color_dict[z_list[i]], marker=z_markers_list[i],
                  linestyle='None', markersize=8, label=z_markers_names[i]))
    
plt.legend(handles=handles, loc='upper center', bbox_to_anchor=(0.5, -0.08),
          fancybox=True, shadow=True, ncol=7)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/b_vs_logN.pdf', dpi=300)
        
#ax.set_xlabel(r'$b_{\mathrm{NT}}$ (km/s)')
#ax.set_ylabel(r'$\log (N_{\mathrm{HI}}/\mathrm{cm}^{-2})$')

# %% [markdown]
# $b_{\mathrm{NT}}$ versus $\log T$

# %%
logT_list_1sig = ['<4.5', # z=0.67
              '4.5, -0.1, +0.1', # z=0.78
              '4.5, -0.1, +0.1', # z=1.09, c1
              '<5.1', # z=1.09, c2
              '4.3, -0.1, +0.1', # z=1.16, c1
              '<4.6', # z=1.16, c2
              '4.4, -0.1, +0.1', # z=1.27, c1
              '4.5, -0.2, +0.2', # z=1.27, c2
              '4.4, -0.1, +0.1', # z=1.04, c1
              '4.2, -0.1, +0.1', # z=1.04, c2
              '<5.0', # z=1.04, c3
              '4.6, -0.1, +0.1', # z=1.04, c4
              '<5.8', # z=1.04, c5
        ]

# %%
b_NT_list_1sig = ['32, -1, +1',
           '12, -2, +2',
           '14.2, -0.9, +0.9',
           '<12',
           '10.0, -0.5, +0.5',
           '26, -2, +2',
           '9.5, -0.5, +0.5',
           '8, -2, +1',
           '<4',
           '<3',
           '<10',
           '<4',
           '<29']

# %%
CUBS_logT_list = ['4.41, -0.20, +0.13',
'<4.6',
'<5.2',
'4.34, -0.26, +0.24',
'<5.1',
'4.72, -0.29, +0.24',
'4.00, -0.15, +0.10',
'<4.5',
'4.57, -0.11, +0.11',
'<5.1',
'<5.0',
'<5.4',
'<5.2',
'4.42, -0.23, +0.18',
'4.03, -0.32, +0.24',
'4.60, -0.43, +0.26',
'<5.5',
'4.65, -0.19, +0.09',
'<5.4',
'<5.1',
'<5.0',
'<5.4',
'<5.3',
'<4.9',
'4.23, -0.27, +0.16',
'4.49, -0.03, +0.03',
'4.25, -0.03, +0.02',
'<3.6',
'<3.7',
'3.92, -0.23, +0.16',
'4.25, -0.05, +0.04',
'4.18, -0.31, +0.14',
'<5.8',
'<3.8',
'4.38, -0.31, +0.21',
'4.01, -0.32, +0.18',
'4.38, -0.13, +0.09',
'4.19, -0.02, +0.02',
'4.34, -0.17, +0.15',
'3.88, -0.06, +0.06',
'5.28, -0.16, +0.07',
'3.93, -0.06, +0.06',
'4.10, -0.06, +0.06',
'4.28, -0.05, +0.04',
'4.15, -0.09, +0.08',
'4.31, -0.12, +0.09',
'<5.4',
'4.48, -0.10, +0.09',
'4.68, -0.12, +0.11',
'4.07, -0.04, +0.04',
'<5.2',
'3.91, -0.03, +0.03',
'5.37, -0.14, +0.15',
'<4.3',
'<3.8',
'<3.6',
'4.48, -0.20, +0.14',
'<5.0',
'4.22, -0.22, +0.14',
'3.62, -0.32, +0.18',
'4.01, -0.41, +0.22',
'4.00, -0.44, +0.24',
'<3.5',
'4.97, -0.10, +0.10',
'4.93, -0.21, +0.19',
'<4.2',
'<3.9',
'4.41, -0.06, +0.05',
'<4.1',
'4.64, -0.06, +0.06',
'4.22, -0.22, +0.11',
'4.68, -0.14, +0.10',
'4.62, -0.18, +0.16',
'3.68, -0.31, +0.17',
'<5.3',
'4.24, -0.03, +0.03',
'4.15, -0.09, +0.04',
'4.15, -0.09, +0.06',
'<4.4',
'4.04, -0.10, +0.08',
'<4.6',
'4.49, -0.38, +0.19',
'<4.5',
'4.81, -0.12, +0.11',
'4.18, -0.13, +0.12',
'4.53, -1.04, +0.35',
'4.11, -0.40, +0.29',
'4.43, -0.17, +0.16']

# %%
CUBS_b_NT_list = ['<6.9',
'22.4, -4.8, +4.6',
'<10.6',
'<3.2',
'<7.7',
'19.8, -4.7, +5.1',
'7.5, -0.4, +0.5',
'34.8, -1.6, +1.2',
'6.3, -0.7, +0.7',
'9.8, -4.3, +2.7',
'25.7, -3.0, +3.0',
'<24.0',
'<21.0',
'6.6, -0.7, +0.5',
'2.4, -1.4, +1.0',
'14.4, -1.2, +1.0',
'<19.1',
'<4.8',
'<14.0',
'<13.2',
'<12.2',
'<25.0',
'<12.4',
'<7.8',
'26.6, -2.0, +2.0',
'7.3, -0.9, +0.8',
'10.5, -0.4, +0.3',
'8.9, -3.0, +2.8',
'19.2, -1.7, +2.3',
'19.1, -1.6, +1.3',
'7.5, -1.3, +1.3',
'11.2, -6.1, +4.7',
'22.2, -9.0, +3.6',
'12.9, -0.8, +0.8',
'21.2, -2.4, +2.3',
'8.8, -1.8, +1.7',
'17.8, -2.6, +2.6',
'9.8, -0.4, +0.4',
'4.1, -0.9, +0.7',
'5.2, -0.2, +0.2',
'<26.3',
'3.6, -0.3, +0.3',
'4.9, -0.2, +0.2',
'<2.2',
'5.5, -0.4, +0.4',
'9.9, -2.5, +2.5',
'29.5, -5.3, +1.9',
'<3.8',
'19.1, -1.5, +1.4',
'3.7, -1.3, +1.1',
'20.7, -4.3, +2.6',
'5.6, -0.5, +0.5',
'12.7, -6.2, +6.9',
'18.2, -1.7, +1.7',
'10.6, -0.6, +0.7',
'10.8, -0.9, +1.0',
'16.5, -4.1, +4.0',
'63.7, -8.3, +5.6',
'13.7, -2.9, +2.9',
'7.8, -1.7, +1.8',
'15.6, -3.6, +2.9',
'20.2, -2.2, +2.2',
'11.8, -1.8, +2.1',
'<14.2',
'<10.4',
'25.8, -2.4, +5.1',
'12.9, -0.9, +1.4',
'13.2, -0.5, +0.4',
'14.4, -1.6, +4.1',
'<4.2',
'7.8, -4.8, +5.3',
'17.6, -4.6, +4.2',
'18.5, -1.9, +2.0',
'9.2, -1.7, +1.7',
'<50.0',
'4.2, -1.3, +1.1',
'<8.0',
'4.7, -3.0, +3.4',
'23.4, -4.5, +1.2',
'5.9, -0.8, +0.8',
'20.8, -2.5, +2.5',
'15.2, -8.6, +8.1',
'16.3, -5.0, +5.0',
'5.5, -2.8, +2.2',
'2.1, -1.3, +1.1',
'9.5, -3.7, +5.0',
'6.4, -2.0, +1.8',
'5.6, -1.4, +1.1']

# %%
def b_NT_logT_plot(ax, logT_list, b_NT_list, z_list, z_color_dict):
    
    for i in range(len(b_NT_list)):
        
        logT_str = logT_list[i]
        b_NT_str = b_NT_list[i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logT_str, b_NT_str, c, m)

# %%
def b_NT_logT_CUBS_plot(ax, logT_list, b_NT_list, c='gray', alpha=.1):
    
    print(len(b_NT_list))
    for i in range(len(b_NT_list)):
                
        logT_str = logT_list[i]
        b_NT_str = b_NT_list[i]

        plot_data_strings(ax, logT_str, b_NT_str, c, 'o', alpha=alpha)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

b_NT_logT_plot(ax, logT_list_1sig, b_NT_list_1sig, z_list, z_color_dict)
    
b_NT_logT_CUBS_plot(ax, CUBS_logT_list, CUBS_b_NT_list)
    
ax.set_xlabel(r'$\log (T/\mathrm{K})$')
ax.set_ylabel(r'$b_{\mathrm{NT}}$')

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/b_NT_vs_logT.pdf', dpi=300)
# Out:
# 88

# %% [markdown]
# $\log N$ versus $b_{\mathrm{NT}}$
#
#
# $$b_{\mathrm{NT}} \propto l^\alpha$$

# %%
def logN_b_NT_plot(ax, ion, logN_dict, b_NT_list, z_list, z_color_dict):
    
    for i in range(len(b_NT_list)):
        
        logN_str = logN_dict[ion][i]
        b_NT_str = b_NT_list[i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_str, b_NT_str, c, m)

# %%
fig, axes = plt.subplots(2, 3, figsize=(12,8))

for i in range(len(logN_dict)):
    
    ion = list(logN_dict.keys())[i]
    ax = axes[i//3, i%3]
    logN_b_NT_plot(ax, ion, logN_dict, b_NT_list, z_list, z_color_dict)
    ax.set_title(ion)
    #ax.set_xlim(0, 20)
    #ax.set_ylim(12, 14.5)

ax_label = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_xlabel(r'$\log (N_{\mathrm{ion}}/\mathrm{cm}^{-2})$')
ax_label.set_ylabel(r'$b_{\mathrm{NT}}$ (km/s)') # Use argument `labelpad` to move label downwards.

plt.tight_layout()
plt.subplots_adjust(wspace=0.1, hspace=0.2)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/b_NT_vs_logN.pdf', dpi=300)

# %% [markdown]
# $\log T$ versus $\log N$

# %%
def logN_logT_plot(ax, ion, logN_dict, logT_list, z_list, z_color_dict):
    
    for i in range(len(b_NT_list)):
        
        logN_str = logN_dict[ion][i]
        logT_str = logT_list[i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_str, logT_str, c, m)

# %%
fig, axes = plt.subplots(2, 3, figsize=(12,8))

for i in range(len(logN_dict)):
    
    ion = list(logN_dict.keys())[i]
    ax = axes[i//3, i%3]
    logN_logT_plot(ax, ion, logN_dict, logT_list, z_list, z_color_dict)
    ax.set_title(ion)
    #ax.set_xlim(0, 20)
    #ax.set_ylim(12, 14.5)

ax_label = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_xlabel(r'$\log (N_{\mathrm{ion}}/\mathrm{cm}^{-2})$')
ax_label.set_ylabel(r'$\log (T/\mathrm{K})$') # Use argument `labelpad` to move label downwards.

plt.tight_layout()
plt.subplots_adjust(wspace=0.12, hspace=0.2)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/logT_vs_logN.pdf', dpi=300)

# %% [markdown]
# Generate column density ratios

# %%
def gen_logN_ratio_str(logN_str_1, logN_str_2, non_det_err=0.3):
    
    # First process each data string
    bool_plot_logN1, coord_value_logN1, err_lo_logN1, err_hi_logN1, uplim_logN1, lolim_logN1 = process_data_str(logN_str_1, non_det_err)
    bool_plot_logN2, coord_value_logN2, err_lo_logN2, err_hi_logN2, uplim_logN2, lolim_logN2 = process_data_str(logN_str_2, non_det_err)
    
    # Classify detection
    det_logN1 = bool_plot_logN1 and (not uplim_logN1) and (not lolim_logN1)
    det_logN2 = bool_plot_logN2 and (not uplim_logN2) and (not lolim_logN2)
    
    # Relevant quantities
    logN_ratio = coord_value_logN1-coord_value_logN2
    err_lo_logN_ratio = -np.sqrt(err_lo_logN1**2 + err_lo_logN2**2) # Put negative sign for consistency w/ plotting functions
    err_hi_logN_ratio = np.sqrt(err_hi_logN1**2 + err_hi_logN2**2)  
    
    # Classify cases as booleans
    
    # Variables to store 
    logN_ratio_str = ''
    
    # Cases that create upper limits
    
    # N1 upper limit and N2 lower limit
    # N1 upper limit and N2 detection
    # N1 detection and N2 lower limit - WHAT is the probabilistic meaning of this?
    if (uplim_logN1 == True and lolim_logN2 == True) or (uplim_logN1 == True and det_logN2 == True) or (det_logN1 == True and lolim_logN2 == True):
        logN_ratio_str = '<{:.2f}'.format(logN_ratio)
    
    # Cases that create lower limits
    
    # N1 lower limit and N2 upper limit
    # N1 lower limit and N2 detection
    # N1 detection and N2 upper limit - WHAT is the probabilistic meaning of this?
    elif (lolim_logN1 == True and uplim_logN2 == True) or (lolim_logN1 == True and det_logN2 == True) or (det_logN1 == True and uplim_logN2 == True):
        logN_ratio_str = '>{:.2f}'.format(logN_ratio)  
        
    # Both are detections
    elif det_logN1 == True and det_logN2 == True:
        logN_ratio_str = '{:.2f}, {:.2f}, {:.2f}'.format(logN_ratio,
                                            err_lo_logN_ratio, # Errors add in quadrature
                                            err_hi_logN_ratio)
        
    return logN_ratio_str

# %%
logN_ratio_dict = {'CIV_CIII': [], 
                   'OIV_OIII': [],
                   'CIV_OIV': [],
                   'CIII_OIII': [],
                   'CIV_NIV': []}

# %%
for i in range(len(z_list)):
    
    logN_CIV_str = logN_dict['CIV'][i]
    logN_CIII_str = logN_dict['CIII'][i]
    logN_OIV_str = logN_dict['OIV'][i]
    logN_OIII_str = logN_dict['OIII'][i]
    logN_NIV_str = logN_dict['NIV'][i]
    
    logN_ratio_dict['CIV_CIII'].append(gen_logN_ratio_str(logN_CIV_str, logN_CIII_str))
    logN_ratio_dict['OIV_OIII'].append(gen_logN_ratio_str(logN_OIV_str, logN_OIII_str))
    logN_ratio_dict['CIV_OIV'].append(gen_logN_ratio_str(logN_CIV_str, logN_OIV_str))
    logN_ratio_dict['CIII_OIII'].append(gen_logN_ratio_str(logN_CIII_str, logN_OIII_str))
    logN_ratio_dict['CIV_NIV'].append(gen_logN_ratio_str(logN_CIV_str, logN_NIV_str))

# %% [markdown]
# Plot column density ratios versus temperature

# %%
def logN_ratio_logT_plot(ax, ion_pair, logN_ratio_dict, logT_list, z_list, z_color_dict):
    
    for i in range(len(logT_list)):
        
        logN_ratio_str = logN_ratio_dict[ion_pair][i]
        logT_str = logT_list[i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_ratio_str, logT_str, c, m)

# %%
ion_pair_labels = {'CIV_CIII': r'$\log (N_{\mathrm{CIV}}/ N_{\mathrm{CIII}})$',
                   'OIV_OIII': r'$\log (N_{\mathrm{OIV}}/ N_{\mathrm{OIII}})$',
                   'CIV_OIV': r'$\log (N_{\mathrm{CIV}}/ N_{\mathrm{OIV}})$',
                   'CIII_OIII': r'$\log (N_{\mathrm{CIII}}/ N_{\mathrm{OIII}})$',
                   'CIV_NIV': r'$\log (N_{\mathrm{CIV}}/ N_{\mathrm{NIV}})$',}

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,4), sharey=True)

plot_ion_pairs = ['CIV_CIII', 'OIV_OIII']
    
for i in range(len(plot_ion_pairs)):
    
    ion_pair = plot_ion_pairs[i]
    ax = axes[i]
    logN_ratio_logT_plot(ax, ion_pair, logN_ratio_dict, logT_list, z_list, z_color_dict)
    ax.set_xlabel(ion_pair_labels[ion_pair])
    
ax_label = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_ylabel(r'$\log (T/\mathrm{K})$') # Use argument `labelpad` to move label downwards.
    
plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0.2)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/logT_vs_logN_ratio.pdf', dpi=300)

# %% [markdown]
# Plot column density ratios versus $b_{\mathrm{NT}}$

# %%
def logN_ratio_b_NT_plot(ax, ion_pair, logN_ratio_dict, b_NT_list, z_list, z_color_dict):
    
    for i in range(len(logT_list)):
        
        logN_ratio_str = logN_ratio_dict[ion_pair][i]
        b_NT_str = b_NT_list[i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_ratio_str, b_NT_str, c, m)

# %%
ion_pair_labels = {'CIV_CIII': r'$\log (N_{\mathrm{CIV}}/ N_{\mathrm{CIII}})$',
                   'OIV_OIII': r'$\log (N_{\mathrm{OIV}}/ N_{\mathrm{OIII}})$',
                   'CIV_OIV': r'$\log (N_{\mathrm{CIV}}/ N_{\mathrm{OIV}})$',
                   'CIII_OIII': r'$\log (N_{\mathrm{CIII}}/ N_{\mathrm{OIII}})$',
                   'CIV_NIV': r'$\log (N_{\mathrm{CIV}}/ N_{\mathrm{NIV}})$',}

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,4), sharey=True)

plot_ion_pairs = ['CIV_CIII', 'OIV_OIII']
    
for i in range(len(plot_ion_pairs)):
    
    ion_pair = plot_ion_pairs[i]
    ax = axes[i]
    logN_ratio_b_NT_plot(ax, ion_pair, logN_ratio_dict, b_NT_list, z_list, z_color_dict)
    ax.set_xlabel(ion_pair_labels[ion_pair])
    
ax_label = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_ylabel(r'$b_{\mathrm{NT}}$ (km/s)') # Use argument `labelpad` to move label downwards.
    
plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0.2)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/b_NT_vs_logN_ratio.pdf', dpi=300)

# %% [markdown]
# Plot column density ratios versus $\log N_{\mathrm{HI}}$

# %%
def logN_ratio_logN_plot(ax, ion_pair, logN_ratio_dict, logN_list, z_list, z_color_dict):
    
    for i in range(len(logN_list)):
        
        logN_ratio_str = logN_ratio_dict[ion_pair][i]
        logN_str = logN_list[i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_ratio_str, logN_str, c, m)

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,4), sharey=True)

plot_ion_pairs = ['CIV_CIII', 'OIV_OIII']
    
for i in range(len(plot_ion_pairs)):
    
    ion_pair = plot_ion_pairs[i]
    ax = axes[i]
    logN_ratio_logN_plot(ax, ion_pair, logN_ratio_dict, logN_dict['HI'], z_list, z_color_dict)
    ax.set_xlabel(ion_pair_labels[ion_pair])

ax_label = fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

ax_label.set_ylabel(r'$\log (N_{\mathrm{HI}}/\mathrm{cm}^{-2})$') # Use argument `labelpad` to move label downwards.
    
plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0.2)

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/logN_HI_vs_logN_ratio.pdf', dpi=300)

# %% [markdown]
# Plot column density ratios across different elements

# %%
def logN_logN_ratio_plot(ax, ion_pair, logN_list, logN_ratio_dict, z_list, z_color_dict):
    
    for i in range(len(logN_list)):
        
        logN_str = logN_list[i]
        logN_ratio_str = logN_ratio_dict[ion_pair][i]
        z = z_list[i]
        c = z_color_dict[z]
        m = z_markers_list[i]

        plot_data_strings(ax, logN_str, logN_ratio_str, c, m)

# %%
ion_labels = {'OIII': r'$\log (N_{\mathrm{OIII}}/\mathrm{cm}^{-2})$',
             'OIV': r'$\log (N_{\mathrm{OIV}}/\mathrm{cm}^{-2})$',}

# %%
n_C_H_solar = 0.000245
n_O_H_solar = 0.00049
n_N_H_solar = 8.51e-05

f_CIII = 0.0382

C_O_solar = np.log10(n_C_H_solar/n_O_H_solar)

# %%
fig, axes = plt.subplots(1, 2, figsize=(9,4), sharey=True)

plot_ion_pairs = ['CIII_OIII', 'CIV_OIV']
plot_ions = ['OIII', 'OIV']
    
for i in range(len(plot_ion_pairs)):
    
    ion_pair = plot_ion_pairs[i]
    ion = plot_ions[i]
    ax = axes[i]
    #ax.axhline(C_O_solar, linestyle=':', color='black')
    logN_logN_ratio_plot(ax, ion_pair, logN_dict[ion], logN_ratio_dict, z_list, z_color_dict)
    ax.set_ylabel(ion_pair_labels[ion_pair])
    ax.set_xlabel(ion_labels[ion])
    #ax.set_xlim(0, 20)
    #ax.set_ylim(12, 14.5)
