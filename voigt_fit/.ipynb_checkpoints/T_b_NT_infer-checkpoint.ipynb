# %%
import numpy as np
import matplotlib.pyplot as plt
import emcee
import corner
import pandas as pd
from scipy import interpolate

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %% [markdown]
# # Constants

# %%
# List of atmoic numbers
A_dict = {'H' : 1.00797 ,
'He' : 4.00260 ,
'Li' : 6.941 ,
'Be' : 9.01218 ,
'B' : 10.81 ,
'C' : 12.011 ,
'N' : 14.0067 ,
'O' : 15.994 ,
'F' : 18.9994 ,
'Ne' : 20.179 ,
'Na' : 22.98977 ,
'Mg' : 24.305 ,
'Al' : 26.98154 ,
'Si' : 28.0855 ,
'P' : 30.97376 ,
'S' : 32.06 ,
'Cl' : 35.453 ,
'A' : 39.948 ,
'K' : 39.0983 ,
'Ca' : 40.08 ,
'Sc' : 44.9559 ,
'Ti' : 47.90 ,
'V' : 50.9415 ,
'Te' : 51.996 ,
'Mn' : 54.9380 ,
'Fe' : 55.847 ,
'Co' : 58.70 ,
'Ni' : 58.9332 ,
'Cu' : 63.546 ,
'Zn' : 65.38,
}

# %%
# Significance levels
# Sigma values taken from Gehrels 1986
cdf_1sig = 0.8413
cdf_2sig = 0.9772
cdf_3sig = 0.9987

# %%
# Boltzmann constant, adjusted to use km instead of m
k_B = 1.380649e-29
# Mass of hydrogen atom
amu = 1.66054e-27

# %% [markdown]
# # Functions

# %%
def gen_b(logT, b_NT, A):
    
    return np.sqrt((2*k_B*10**logT/(A*amu)) + b_NT**2)

# %%
def log_prior(params):

    # Grid parameters being varied
    logT, b_NT = params
    
    # Avoid edges?
    if 4<logT<6 and 0<b_NT<50:
        # Convert to linear T, then take natural log
        return np.log(10**logT)
    return -np.inf

# %%
def log_likelihood(params, b_list):
    
    logT, b_NT = params

    #print(logT, b_NT)
    
    ll = 0
    
    for i in range(len(b_list)):
        
        ybar = gen_b(logT, b_NT, A_dict[b_list[i][1]])
        y = b_list[i][2]
        dy = b_list[i][3]
        
        ll += -.5*(y-ybar)**2/dy**2
            
    return ll

# %%
def log_probability(params, b_list):
        
    lp = log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(params, b_list)

# %%
gen_b(4., 0, A_dict['H'])
# Out:
# 12.844232700646511

# %%
gen_b(4, 0, A_dict['C'])
# Out:
# 3.7208519053703197

# %%
gen_b(4., 0, A_dict['Si'])
# Out:
# 2.433273287255247

# %%
gen_b(5, 0, A_dict['Mg'])
# Out:
# 8.271497744829851

# %%
gen_b(4, 0, A_dict['N'])
# Out:
# 3.445593622658098

# %%
gen_b(4.8, 16, A_dict['O'])
# Out:
# 17.933222075561797

# %%
gen_b(4, 0, A_dict['Si'])
# Out:
# 2.433273287255247

# %% [markdown]
# # z=0.67

# %% [markdown]
# ## c1

# %% [markdown]
# ### c1H

# %%
b_list = [[['HI', 'H', 36, 2],
          ['OIII', 'O', 34, 2],
          ['CIII', 'C', 31, 2],
          ['CIV', 'C', 33, 5]
          ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*(1-cdf_3sig)), np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# (4.001245407193947, 4.712425940695306)

# %% [markdown]
# ### c1L

# %%
b_list = [[
          ['OIV', 'O', 30, 2],
          ['OVI', 'O', 32, 3]
          ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
sampler.run_mcmc(pos, 5000, progress=True)
# Out:
# 100%|██████████████████████████████████████| 5000/5000 [00:09<00:00, 504.02it/s]
# State([[5.98249168e+00 4.64407697e+00]
#  [5.93090759e+00 9.44362567e+00]
#  [5.91485710e+00 1.43059815e+01]
#  [5.75986802e+00 8.94979290e+00]
#  [5.18584324e+00 2.68357467e+01]
#  [5.43933491e+00 2.16356845e+01]
#  [5.57873350e+00 2.16403277e+01]
#  [5.94424788e+00 1.44131535e+01]
#  [5.91638296e+00 7.38738817e+00]
#  [5.68151879e+00 2.24254545e+01]
#  [5.68271302e+00 1.90486155e+01]
#  [5.48875941e+00 2.45324303e+01]
#  [5.73521999e+00 1.82276394e+01]
#  [5.92556782e+00 4.69496783e+00]
#  [5.64463381e+00 2.00020473e+01]
#  [5.55083263e+00 2.18295258e+01]
#  [5.67520468e+00 2.33172051e+01]
#  [5.96017842e+00 9.81507294e+00]
#  [5.02559047e+00 2.77832944e+01]
#  [5.97493003e+00 8.63783450e+00]
#  [5.92996847e+00 4.90588637e-01]
#  [5.93066349e+00 6.08915115e+00]
#  [5.87724942e+00 9.86956616e+00]
#  [5.94026470e+00 1.00490741e+01]
#  [5.62250122e+00 2.08973218e+01]
#  [5.80070917e+00 1.47520174e+01]
#  [5.88981064e+00 9.32969905e+00]
#  [5.94277308e+00 6.01168291e+00]
#  [5.30006141e+00 2.82619028e+01]
#  [4.80937834e+00 2.80078220e+01]
#  [5.84483456e+00 6.92195687e+00]
#  [5.92816580e+00 1.12591568e+01]
#  [5.30876554e+00 2.61065776e+01]
#  [5.89824714e+00 5.04605375e+00]
#  [5.74224304e+00 1.79859402e+01]
#  [5.79198570e+00 1.30592897e+01]
#  [5.82665114e+00 8.57513023e+00]
#  [5.82001135e+00 1.71042318e+01]
#  [5.49987811e+00 2.47239789e+01]
#  [5.97673788e+00 2.68474668e+00]
#  [5.89540323e+00 1.36672001e+01]
#  [5.66376240e+00 1.76458586e+01]
#  [5.74803354e+00 2.13808650e+01]
#  [5.84913393e+00 1.63647602e+01]
#  [5.50613056e+00 2.19792065e+01]
#  [5.93813527e+00 5.10191008e+00]
#  [5.66117148e+00 1.96623499e+01]
#  [5.89953338e+00 1.52073406e+01]
#  [5.68457993e+00 2.11808054e+01]
#  [5.93857799e+00 1.43967183e+01]
#  [5.98730105e+00 1.64613689e+00]
#  [5.86752772e+00 1.05247252e+01]
#  [5.73886659e+00 2.36679786e+01]
#  [5.47072462e+00 2.52638420e+01]
#  [5.94683750e+00 9.86433097e+00]
#        2255943152, 2581594878, 3393575292, 3268095616,  148041115,
#        2026155296, 4001000709, 4191681832,  510629973,  732701650,
#         248412956, 4178069517, 3287256853, 2985036726,  459251485,
#        1732973313, 4252655216,  492038103, 2158257137,  594513677,
#        1615174554, 3467729347, 3326529705, 2452806020,  190059725,
#        2680314916, 2682889986,  411822102, 2682888759,  929588515,
#         342076789,  349535974,  691525402,  231597578, 1314061288,
#        3394985517, 1856914654, 1226779729, 4047510062, 3653829715,
#         258253305, 3350297325, 2327985744, 3136799416, 4120434166,
#        1762924373, 4060396075, 3221786285, 1648877823,  716823535,
#        4077750716, 4226154730, 2350759431, 2892473450, 1105292204,
#        1964573710, 2855925098, 3107720427,  265741485, 1947830409,
#        3978719010,  475862231, 2938919589, 3342692364, 1874074138,
#        3763659800, 3013370021, 2444065691, 3287374493, 3115240476,
#        2820588247, 2356530677, 3233429454, 1460355630, 2521416436,
#         212269795,  210133667, 3086399326, 2400115901, 1994025028,
#        1255151891,  822420294, 3848670214, 3638979750,   10528869,
#         599307170,  821301949,  390456663, 2402371043,  520505742,
#        2417406925,  351574308,  844846806, 2210678349, 1280746968,
#        1909183440, 2065717452, 1929230309, 1431439952], dtype=uint32), 50, 0, 0.0))

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
plt.hist(10**flat_samples['logT'])
# Out:
# (array([ 54792.,  58266.,  61814.,  66320.,  74355.,  85032., 105743.,
#         141333., 153539.,  98806.]),
#  array([ 10003.2299565 , 109002.7615557 , 208002.2931549 , 307001.82475411,
#         406001.35635331, 505000.88795251, 604000.41955172, 702999.95115092,
#         801999.48275012, 900999.01434932, 999998.54594853]),
#  <BarContainer object of 10 artists>)

# %%
np.percentile(flat_samples['logT'], 100*(1-cdf_3sig)), np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# (4.069670293484817, 5.999182865357982)

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 33.235700031194284

# %% [markdown]
# # z=1.04

# %% [markdown]
# ## c1

# %% [markdown]
# ### c1H

# %%
b_list = [[['HI', 'H', 19, 1],
           ['CIV', 'C', 6.7, 0.3],
           ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.percentile(flat_samples['logT'],100*(1-cdf_3sig)), np.percentile(flat_samples['logT'],100*cdf_3sig)
# Out:
# (4.1541669568563035, 4.473937007145371)

# %% [markdown]
# ### c1L

# %%
b_list = [[['OV', 'O', 23, 2],
           ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.percentile(flat_samples['logT'],100*cdf_3sig), np.percentile(flat_samples['b_NT'],100*cdf_3sig)
# Out:
# (5.885385147345337, 26.500169230689387)

# %% [markdown]
# ## c2

# %%
b_list = [[['HI', 'H', 10, 2],
           ['CIV', 'C', 6.3, 0.4],
           ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.289568397277587

# %% [markdown]
# ## c3

# %% [markdown]
# ### c3H

# %%
b_list = [[['HI', 'H', 14, 3],
          ['CIV', 'C', 10, 1]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.532791134023759

# %% [markdown]
# ### c3L

# %%
b_list = [[['OV', 'O', 26, 3]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 5.994272529247227

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 31.75264001425646

# %% [markdown]
# ## c4

# %% [markdown]
# ### c4H

# %%
b_list = [[['HI', 'H', 22, 5],
          ['OIII', 'O', 8.2, 0.6]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 8.835238449137595

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.882710092337469

# %% [markdown]
# ### c4L

# %%
b_list = [[['OIV', 'O', 8.2, 0.6],
           ['NIV', 'N', 8.2, 0.6],
           ['CIV', 'C', 8.2, 0.6],
           ['CIII', 'C', 8.2, 0.6]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 7.9963619865624

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.797905288626772

# %% [markdown]
# # z=1.09

# %% [markdown]
# ## c1

# %% [markdown]
# ### c1H

# %%
b_list = [[['HI', 'H', 21, 3],
           ['CIII', 'C', 18.3, 0.3],
          ['CIV', 'C', 18.3, 0.3],
          ['NIV', 'N', 13, 6]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(400, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 8000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.627379423110129

# %% [markdown]
# ### c1L

# %%
b_list = [[['OIV', 'O', 23, 1],
          ['OV', 'O', 26, 2]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*(1-cdf_3sig)), np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# (4.068017676673675, 5.8048376209588035)

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 24.695267905005345

# %% [markdown]
# # z=1.16

# %% [markdown]
# ## c1

# %%
b_list = [[['HI', 'H', 19, 3],
          ['HeI', 'He', 12, 1],
          ['CIII', 'C', 11.0, 0.4],
          ['CIV', 'C', 11.0, 0.4],
          ['OIII', 'O', 14, 3],
          ['OIV', 'O', 16, 2],
          ['OV', 'O', 10, 3],
          ['SiIII', 'Si', 11, 2]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.median(flat_samples['b_NT'])-np.percentile(flat_samples['b_NT'], 100*(1-cdf_1sig))
# Out:
# 0.4565450714296322

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.507069358227368

# %% [markdown]
# ## c2

# %% [markdown]
# ### Single phase

# %%
b_list = [[['HI', 'H', 32, 3],
           ['CIV', 'C', 27, 3],
          ['OIV', 'O', 27, 7],
          ['OV', 'O', 28, 3]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (4.830366794109147, 32.10015972071997)

# %% [markdown]
# ### c2H

# %%
b_list = [[['HI', 'H', 32, 3]]]
          #['OVI', 'O', 45, 22]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (4.985141296167284, 35.67853910647879)

# %% [markdown]
# ### c2L

# %%
b_list = [[['CIV', 'C', 27, 3],
          ['OIV', 'O', 27, 7],
          ['OV', 'O', 28, 3]]]
          #['OVI', 'O', 45, 22]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (5.94175085047585, 31.17296641573264)

# %% [markdown]
# # z=1.22

# %% [markdown]
# ## c1

# %% [markdown]
# ### Single phase

# %%
b_list = [[['HI', 'H', 26, 5],
           ['CIV', 'C', 16, 3],
          ['OIV', 'O', 21, 2],
          ['OV', 'O', 21, 2],
          ['OVI', 'O', 21, 2]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (4.944070346230868, 22.983617631470345)

# %% [markdown]
# ### c1H

# %%
b_list = [[['HI', 'H', 26, 5]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.median(flat_samples['logT'])-np.percentile(flat_samples['logT'], 100*(1-cdf_1sig))
# Out:
# 0.26189054786220023

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (4.999202509075811, 35.034118533551485)

# %% [markdown]
# ### c1L

# %%
b_list = [[['CIV', 'C', 16, 3],
           ['OIV', 'O', 21, 2],
          ['OV', 'O', 21, 2],
          ['OVI', 'O', 21, 2]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (5.674468956972161, 22.323347845807184)

# %% [markdown]
# # z=1.26

# %% [markdown]
# ## c1

# %%
b_list = [[['HI', 'H', 22, 2],
           ['CIII', 'C', 6.6, 0.6],
          ['CIV', 'C', 6.6, 0.6],
           ['OIV', 'O', 6.6, 0.6]
          ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*(1-cdf_3sig)), np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# (4.162396886782367, 4.60979870904304)

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 5.565885820874075

# %% [markdown]
# # z=1.27

# %% [markdown]
# ## c1

# %% [markdown]
# ### c1H

# %%
b_list = [[['HI', 'H', 24, 3],
          ['OIII', 'O', 11.9, 0.9]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.median(flat_samples['logT'])-np.percentile(flat_samples['logT'], 100*(1-cdf_1sig))
# Out:
# 0.15327703863173525

# %%
np.percentile(flat_samples['logT'], 100*(1-cdf_3sig)), np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# (4.016416648676425, 4.8065845944085055)

# %% [markdown]
# ### c1H

# %%
b_list = [[['CIII', 'C', 11.1, 0.2],
           ['CIV', 'C', 11.1, 0.2],
           ['NIV', 'N', 12, 6],
          ['OIV', 'O', 12, 1],
          ['OV', 'O', 17, 1],
          ['NeV', 'Ne', 21, 4]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*(1-cdf_3sig)), np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# (4.000489466539204, 4.939198507984573)

# %%
np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# 10.935018015489195

# %% [markdown]
# ## c2

# %% [markdown]
# ### Single phase

# %%
b_list = [[['HI', 'H', 36, 10],
          ['CIV', 'C', 9.8, 0.3],
          ['OIV', 'O', 11, 2],
          ['OV', 'O', 15, 2],
          ['OVI', 'O', 15, 2],
          ['NeV', 'Ne', 17, 3]
          ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.906320359846462

# %% [markdown]
# ### c2H

# %%
b_list = [[['HI', 'H', 36, 10]
          ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig), np.percentile(flat_samples['b_NT'], 100*cdf_3sig)
# Out:
# (5.417755410038449, 49.474726158822264)

# %% [markdown]
# ### c2L

# %%
b_list = [[['CIV', 'C', 9.8, 0.3],
          ['OIV', 'O', 11, 2],
          ['OV', 'O', 15, 2],
          ['OVI', 'O', 15, 2],
          ['NeV', 'Ne', 17, 3]
          ]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
#sampler.run_mcmc(pos, 5000, progress=True)

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
np.percentile(flat_samples['logT'], 100*cdf_3sig)
# Out:
# 4.892768089941283

# %% [markdown]
# # DRAFT

# %% [markdown]
# ## z=0.72

# %%
b_list = [[['HI', 'H', 25.6, 0.4],
          ['CIII', 'C', 15, 4],
          ['OIII', 'O', 12, 2]]]

# %%
pos = np.array([4.2, 32]) + 1e-4 * np.random.randn(200, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(b_list)
)

# %%
sampler.run_mcmc(pos, 5000, progress=True)
# Out:
# 100%|██████████████████████████████████████| 5000/5000 [00:13<00:00, 378.65it/s]
# State([[ 4.5384403   8.09929585]
#  [ 4.47312911 12.56506458]
#  [ 4.51935019  9.9915456 ]
#  [ 4.43163142 15.65060414]
#  [ 4.52375086  9.37540148]
#  [ 4.54954478  6.62458899]
#  [ 4.52685679 10.13970275]
#  [ 4.42873199 14.08212653]
#  [ 4.50605638 12.29829318]
#  [ 4.50825934 10.95642096]
#  [ 4.52653629 10.0437353 ]
#  [ 4.43088461 14.06331714]
#  [ 4.52991303 10.05491318]
#  [ 4.5366154   8.2728032 ]
#  [ 4.57220497  8.25733952]
#  [ 4.47898707 12.46445221]
#  [ 4.57009848  8.66609242]
#  [ 4.50306259 11.53717785]
#  [ 4.36597978 15.86877089]
#  [ 4.56793488  9.68422604]
#  [ 4.45187513 13.86462879]
#  [ 4.56351901  5.3446461 ]
#  [ 4.59466794  3.46409942]
#  [ 4.53785633  9.65510504]
#  [ 4.55211141  8.05027689]
#  [ 4.49100075 11.93868292]
#  [ 4.54138785 10.3322841 ]
#  [ 4.54959999  9.2107803 ]
#  [ 4.42833962 14.57471485]
#  [ 4.51295023 12.04145711]
#  [ 4.59385652  7.83400509]
#  [ 4.46092935 12.78548227]
#  [ 4.5263072  12.37414796]
#  [ 4.48133168 13.77105522]
#  [ 4.49751563 10.66109777]
#  [ 4.53237196  9.36835803]
#  [ 4.53007861 10.24665585]
#  [ 4.50661102 10.98938445]
#  [ 4.57828135  8.43078466]
#  [ 4.50910705 10.02456875]
#  [ 4.49746746 11.5018401 ]
#  [ 4.5935886   7.98051695]
#  [ 4.45825857 13.00953798]
#  [ 4.51217334 10.92085818]
#  [ 4.55051737  9.55981349]
#  [ 4.44807555 13.18633514]
#  [ 4.50183824 10.87849408]
#  [ 4.52965718 10.20790073]
#  [ 4.49831845  9.5420254 ]
#  [ 4.50462588  9.69819292]
#  [ 4.52291058  8.61485199]
#  [ 4.50266159 10.80046921]
#  [ 4.50791544 11.90323679]
#  [ 4.56676408  8.85838834]
#  [ 4.45187508 11.92154952]
#  [ 4.49174421 12.55350775]
#  [ 4.50645991 11.03868549]
#  [ 4.45061132 12.72085143]
#  [ 4.55380495  8.46932771]
#  [ 4.509589   10.6956739 ]
#  [ 4.53467516  8.79946173]
#  [ 4.47958016 13.4946875 ]
#  [ 4.54784787  9.49940312]
#  [ 4.50852571 10.89766653]
#  [ 4.48075677 12.07702564]
#  [ 4.58710578  4.08971003]
#  [ 4.53576783  7.69234185]
#  [ 4.45642741 12.47873165]
#  [ 4.5124093  10.30532894]
#  [ 4.51201203 11.80645388]
#  [ 4.53705097  8.37226566]
#  [ 4.47070673 11.60266705]
#  [ 4.4574379  12.51928751]
#  [ 4.49688791 12.2091118 ]
#  [ 4.39558843 15.34784264]
#  [ 4.58023258  6.49594896]
#  [ 4.53004428 10.61098127]
#  [ 4.48976276 11.74448908]
#  [ 4.43136676 13.33396602]
#  [ 4.53725535 10.61588776]
#  [ 4.52077697 10.88285662]
#  [ 4.51584615 11.17932907]
#  [ 4.51318581 11.5543078 ]
#  [ 4.4836389  11.78831563]
#  [ 4.51465454 10.02524634]
#  [ 4.46359451 10.85412594]
#  [ 4.54152328  8.59352944]
#  [ 4.51755807 11.62878296]
#  [ 4.49632622 13.26565635]
#  [ 4.57963225  8.87960872]
#  [ 4.54170542  9.79766063]
#  [ 4.55886392  7.78602792]
#  [ 4.53820663  8.6398282 ]
#  [ 4.51988103 10.26868747]
#  [ 4.51835257 11.5773361 ]
#  [ 4.50143149 11.61923683]
#  [ 4.4596972  14.05013496]
#        3626262569, 1664448295,  622227082, 4141813346, 3180341061,
#        2974575296,  944676454,  972052652, 3562857025, 3639740658,
#        3856001711, 3354983910, 2619559403,  999809191, 1215524146,
#        3809218913, 3712701972,  383587525, 1417941717, 2862827361,
#        3447949985,  216315974, 2439686182, 3557832566, 3703855585,
#        1382785278, 3557363575, 1101924325, 2980019258, 2744540963,
#        4268559264,  802834885, 3053799412, 3812597438,  592051897,
#        3917022707, 1081964497, 1672455179, 1652632856, 3025634796,
#        1523738810, 2874400548, 3375658085,  743025802, 1871134602,
#        1837973597, 3577263283, 1984118724, 2430160365, 1509583454,
#        1754144402,   88861237, 2535473974, 3654876124, 3239557538,
#         280886350, 3608036692, 1017111185, 3153864337, 2854544556,
#        1189509817, 3404931525, 1538537054, 2486167737, 1346180478,
#        3940072415,  933689854, 3923465879,  285605062, 2730267121,
#        3972569906,  851571859, 2677003374,  587509794,  371397555,
#        1214972433, 1802600891, 3674060439,  693089442, 1427138239,
#        2800171834, 3528653209,  163615651, 4052555260, 3339002442,
#        2758422421, 2758357209, 2159814569, 1190829947,  209562523,
#        1813651216,  511070998, 1939112888, 1695732192, 1999277267,
#        4229098524, 3401674046, 3954125214,  263199187, 4029424326,
#        1964449517, 1050144040,  479007756,  634901360,  544168790,
#         198642631, 1485261545,  294123397, 3363756104, 3424591964,
#        1596762941, 2626261380, 1849015491, 3455773222, 3064335708,
#         736068788, 3833851882, 2071547059, 3927160314, 1916834214,
#        1436820392, 1844925139, 2002351263,  919699428, 1299587479,
#        2174574355, 1036430701, 4150117654, 2069426525, 2148747943,
#        3383952313, 3995343277, 1115973333, 2295305439, 1631988913,
#          50916893, 1882003326,  465000830, 3412262812], dtype=uint32), 476, 0, 0.0))

# %%
flat_samples = pd.DataFrame(sampler.get_chain(discard=500, flat=True), 
                                columns=['logT', 'b_NT'])

# %%
fig = corner.corner(
    flat_samples, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log T$', r'$b_{\mathrm{NT}}$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Predicted linewidths

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['C']))
# Out:
# 12.821218751413966

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['N']))
# Out:
# 12.567972555170432

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['O']))
# Out:
# 12.375375197197565

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['Ne']))
# Out:
# 12.088713599866455

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['Mg']))
# Out:
# 11.898696060874855

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['Al']))
# Out:
# 11.805498059645785

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['Si']))
# Out:
# 11.77212289470581

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['S']))
# Out:
# 11.670068905881259

# %%
np.median(gen_b(flat_samples['logT'], flat_samples['b_NT'], A_dict['Fe']))
# Out:
# 11.358898777000608
