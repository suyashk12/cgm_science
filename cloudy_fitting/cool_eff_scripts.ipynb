# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy import constants, units
import os
import os.path
import pandas as pd

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/cloudy_grids/non_eqm_models/'

# %% [markdown]
# # Grid parameters for cooling efficiencies

# %%
C_list = ['CI', 'CII', 'CIII', 'CIV', 'CV', 'CVI', 'CVII']
O_list = ['OI', 'OII', 'OIII', 'OIV', 'OV', 'OVI', 'OVII', 'OVIII', 'OIX']

# %%
C_species = [r'$\mathrm{C}^0$', r'$\mathrm{C}^+$', r'$\mathrm{C}^{2+}$', r'$\mathrm{C}^{3+}$',
            r'$\mathrm{C}^{4+}$', r'$\mathrm{C}^{5+}$', r'$\mathrm{C}^{6+}$', r'$\mathrm{C}^{6+}$']

O_species = [r'$\mathrm{O}^0$', r'$\mathrm{O}^+$', r'$\mathrm{O}^{2+}$', r'$\mathrm{O}^{3+}$',
            r'$\mathrm{O}^{4+}$', r'$\mathrm{O}^{5+}$', r'$\mathrm{O}^{6+}$', r'$\mathrm{O}^{6+}$',
            r'$\mathrm{O}^{7+}$', r'$\mathrm{O}^{8+}$']

# %%
key_C_list = []

for i in range(len(C_list)):
    s = '0 '*i
    s = s + '1 '
    s = s + '0 '*(len(C_list)-i-1)
    s = s[:-1]
    key_C_list.append(s)

# %%
#key_C_list

# %%
key_O_list = []

for i in range(len(O_list)):
    s = '0 '*i
    s = s + '1 '
    s = s + '0 '*(len(O_list)-i-1)
    s = s[:-1]
    key_O_list.append(s)

# %%
#key_O_list

# %% [markdown]
# # Write log(hdens) = -10 files

# %%
for i in range(len(O_list)):
    
    s = '''title coronal equilibrium at 1e6 K
coronal 6 vary
grid 4 8 0.02
set dr 0
hden -10 log
set eden 0
no molecules
no photoionization
cosmic ray background
element abundance oxygen 10
stop zone 1
init "honly.ini"
element oxygen on
element oxygen ionization {}
save overview "coll t6.ovr" separate
save cooling each "coll t6.cool" last no hash
save recombination coefficients "recomb t6.cool" last no hash
'''.format(key_O_list[i])
    
    with open(rootdir+'cooling_eff/{}/cool.in'.format(O_list[i]), 'w') as f:
        f.write(s)
    
    print('cd cooling_eff/{}; ./run.sh cool; cd ../..'.format(O_list[i]))

print('')
# Out:
# cd cooling_eff/OI; ./run.sh cool; cd ../..
# cd cooling_eff/OII; ./run.sh cool; cd ../..
# cd cooling_eff/OIII; ./run.sh cool; cd ../..
# cd cooling_eff/OIV; ./run.sh cool; cd ../..
# cd cooling_eff/OV; ./run.sh cool; cd ../..
# cd cooling_eff/OVI; ./run.sh cool; cd ../..
# cd cooling_eff/OVII; ./run.sh cool; cd ../..
# cd cooling_eff/OVIII; ./run.sh cool; cd ../..
# cd cooling_eff/OIX; ./run.sh cool; cd ../..

# %%
for i in range(len(C_list)):
    
    s = '''title coronal equilibrium at 1e6 K
coronal 6 vary
grid 4 8 0.2
set dr 0
hden -10 log
set eden 0
no molecules
no photoionization
cosmic ray background
element abundance carbon 10
stop zone 1
iterate to convergence
init "honly.ini"
element carbon on
element carbon ionization {}
save overview "coll t6.ovr" separate
save cooling each "coll t6.cool" last no hash
save recombination coefficients "recomb t6.cool" last no hash
'''.format(key_C_list[i])
    
    with open(rootdir+'cooling_eff/{}/cool.in'.format(C_list[i]), 'w') as f:
        f.write(s)
    
    print('cd cooling_eff/{}; ./run.sh cool; cd ../..'.format(C_list[i]))

print('')
# Out:
# cd cooling_eff/CI; ./run.sh cool; cd ../..
# cd cooling_eff/CII; ./run.sh cool; cd ../..
# cd cooling_eff/CIII; ./run.sh cool; cd ../..
# cd cooling_eff/CIV; ./run.sh cool; cd ../..
# cd cooling_eff/CV; ./run.sh cool; cd ../..
# cd cooling_eff/CVI; ./run.sh cool; cd ../..
# cd cooling_eff/CVII; ./run.sh cool; cd ../..

# %% [markdown]
# $$C (T) = n_e n_\mathrm{H} \Lambda_\mathrm{net} (T) \ (\mathrm{erg} \ \mathrm{cm}^{-3} \mathrm{s}^{-1})$$

# %% [markdown]
# $$\Lambda_\mathrm{net} (T) \ (\mathrm{erg} \ \mathrm{cm}^3 \mathrm{s}^{-1}) = \sum_{X} \frac{n_X}{n_\mathrm{H}} \left( \sum_{i} \frac{n_{X_i}}{n_X} (T) \cdot \Lambda_{X_i} (T) \right) , \ X = \mathrm{C, N, O, Si, ...}$$

# %% [markdown]
# $$\Lambda_{E_i}(T) = C(T) \times (1 \ \mathrm{cm}^{-3})^2$$

# %% [markdown]
# $$10^{10} n_\mathrm{H} =n_\mathrm{O} = n_e = 1 \ \mathrm{cm}^{-3}$$

# %% [markdown]
# $$n_{\mathrm{O}, \odot}/n_{\mathrm{H}, \odot} = 4.57 \ \times 10^{-4}$$

# %% [markdown]
# $$t_\mathrm{c} \sim t_\mathrm{r, i}$$

# %% [markdown]
# $$t_\mathrm{c} \ll t_{\mathrm{r},i}$$
