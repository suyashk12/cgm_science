# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd
from cloudy_fit_lib import *
from scipy.interpolate import RegularGridInterpolator
import pickle
import corner
from scipy import integrate, interpolate
import emcee

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/cloudy_grids/'

# %%
savedir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z=0.6753127/cloudy_fits/'

# %% [markdown]
# Obtain the UVB grid from FG20

# %%
fg20_z_grid, fg20_wav_grid, fg20_J_nu_grid = read_uvb('', 'fg20_galaxy.ascii')

# %% [markdown]
# Fetch the SED at $z=1$

# %%
z_test = 1

# %%
fg20_J_nu_test = fetch_sed(z_test, fg20_z_grid, fg20_J_nu_grid)

# %% [markdown]
# Specify $N_{\mathrm{HI}}$ grid points and get corresponding filenames

# %%
logN_HI_min = 12
logN_HI_max = 17
logN_HI_step = 0.25

logN_HI_arr = np.arange(logN_HI_min, logN_HI_max+logN_HI_step, logN_HI_step)

# %%
file_list = create_grid_file_list(logN_HI_arr)

# %% [markdown]
# Specify grid points for densities and metallicities

# %%
log_hdens_min = -5
log_hdens_max = 1
log_hdens_step = 0.25

log_hdens_arr = np.arange(log_hdens_min, log_hdens_max+log_hdens_step, log_hdens_step)
logU_arr = np.log10(calc_U(fg20_wav_grid, fg20_J_nu_test, 10**log_hdens_arr))

# %%
log_metals_min = -3
log_metals_max = 1
log_metals_step = 0.25

log_metals_arr = np.arange(log_metals_min, log_metals_max+log_metals_step, log_metals_step)

# %% [markdown]
# Load the final grid

# %%
pkl_file = open(rootdir+'final_grid.pkl', 'rb')
species_logN_samples = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# Interpolate this grid

# %%
species_logN_interp = {}

for s in list(species_logN_samples.keys()):
    
    species_logN_samples[s][species_logN_samples[s]==-np.inf] = -99
    
    species_logN_interp[s] = RegularGridInterpolator((logN_HI_arr, log_hdens_arr, log_metals_arr), 
                                                     species_logN_samples[s])

# %% [markdown]
# Enter measurements for species

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            'NII':'<13.0',
            'NIII':'<13.2',
            'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            'AlIII':'<12.3',
            'SiII':'<13.0',
            'SiIII':'<12.6',
            'SVI':'<12.6',
            'FeII':'<11.6'}

# %% [markdown]
# To predict the column density of the $i$-th ion of an element $X$ within a single gas phase (characterized by $n_{\mathrm{H}}$,) we first need to find the total hydrogen column density, as follows -
#
# $$N_{\mathrm{H}} = N_{\mathrm{HI}} \times \frac{n_{\mathrm{H}}}{n_{\mathrm{HI}}} = \frac{N_{\mathrm{HI}}}{f_{\mathrm{HI}}}$$
#
# Then, we can obtain the total column density of $X$ using the abundance [X/H] -
#
# $$N_{\mathrm{X}} = N_{\mathrm{H}} \times 10^{\mathrm{[X/H]}}$$
#
# Finally, we can get the column density of the ion $X_i$ using the ionization fraction $f_{X_i} = n_{\mathrm{X_i}}/n_{\mathrm{X}}$ -
#
# $$N_{\mathrm{X_i}} = f_{X_i} \times N_{\mathrm{X}}$$
#
# Putting all of this together -
#
# $$N_{\mathrm{X_i}} = N_{\mathrm{HI}} \times \frac{f_{X_i}}{f_{\mathrm{HI}}} \times 10^{[\mathrm{X/H}]}$$
#
# It is helpful to remember that ionizing fractions (at least in the low metallicity regime) only depend on the ionization parameter $U = n_{\gamma}/ n_{\mathrm{H}}$, so that -
#
# $$\boxed{N_{\mathrm{X_i}} (N_{\mathrm{HI}}, U, [\mathrm{X/H}]) = N_{\mathrm{HI}} \times \frac{f_{X_i}}{f_{\mathrm{HI}}} (U) \times 10^{[\mathrm{X/H}]}}$$

# %%
logN_HI_test = 15.44
log_hdens_test = -3.4
log_metals_test = -0.6

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, log_metals_test, species_logN_interp)

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['CIII'], logN_dict['CIV'])
# Out:
# '0.29, -0.08, 0.08'

# %%
logN_ratio_dict = {'OIV/SVI': '>2.4, 0.2',
                   'OII/OIII': '<-1.4, 0.1',
                   'OIV/OIII': '0.57, -0.04, 0.06',  
                   'CII/CIII': '<-0.8, 0.2',
                   'CIV/CIII': '-0.29, -0.08, 0.08'
                  }

# %% [markdown]
# We had the expression -
#
# $$N_{\mathrm{X_i}} = N_{\mathrm{HI}} \times \frac{f_{X_i}}{f_{\mathrm{HI}}} \times 10^{[\mathrm{X/H}]}$$
#
# So the column density ratio of two ions $X_i$ and $Y_j$ will be given by -
#
# $$\boxed{\frac{N_{\mathrm{X_i}}}{N_{\mathrm{Y_j}}} = \frac{f_{X_i}}{f_{Y_j}} \times 10^{[\mathrm{X/Y}]}}$$
#
# If we assume [X/Y]=0 (as we can for $\alpha$ elements usually, or at least for oxygen and sulphur), then the column density ratio will just be governed by the gas density.
#
# We can test the hypothesis of the observed column density distribution of ions being explainable by a single gas phase by plotting observed column density ratios and inferring correpsonding gas density ranges. If we can get a consistent range of gas densities, then a single phase solution is feasible. If this test fails, then there are two possibilities -
#
# 1. If the ion pair used to infer gas density involves different elements, then their abundance pattern may not be similar (i.e. [X/Y] is not zero)
#
# 2. A single gas phase is not sufficient to explain the observed column densities of ions

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict)

ax.set_xlim(-5, -1.5)
ax.set_ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# # Fit gas density

# %%
def log_probability(params, logN_ratio_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    log_hdens = params[0]
    
    lp = log_prior_hdens(log_hdens)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_hdens(log_hdens, logN_ratio_dict, species_logN_interp)

# %%
logN_ratio_dict
# Out:
# {'OIV/SVI': '>2.4, 0.2',
#  'OII/OIII': '<-1.4, 0.1',
#  'OIV/OIII': '0.57, -0.04, 0.06',
#  'CII/CIII': '<-0.8, 0.2',
#  'CIV/CIII': '-0.29, -0.08, 0.08'}

# %%
#pos = np.array(-3.35) + 1e-4 * np.random.randn(500, 1)
#nwalkers, ndim = pos.shape

# %%
#sampler = emcee.EnsembleSampler(
#    nwalkers, ndim, log_probability, args=(logN_ratio_dict, species_logN_interp)
#)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_hdens = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens'])
#
#flat_samples_hdens.to_csv(savedir+'hdens_op.csv', index=False)

flat_samples_hdens = pd.read_csv(savedir+'hdens_op.csv')

# %%
fig = corner.corner(
    flat_samples_hdens, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
grid_points_hdens = np.array([[12, log_hdens, -3] for log_hdens in flat_samples_hdens['log_hdens']])

# %%
logN_offset = 14.42-np.mean(species_logN_interp['O+2'](grid_points_hdens))

# %%
logN_offset
# Out:
# 5.655109385672585

# %% [markdown]
# Calculate the C/O ratio

# %%
logN_CIII_obs = np.random.normal(loc=13.97, scale=0.05, size=len(flat_samples_hdens))
logN_CIV_obs = np.random.normal(loc=13.68, scale=0.05, size=len(flat_samples_hdens))

# %%
C_O_dist_CIII = logN_CIII_obs-(logN_offset+species_logN_interp['C+2'](grid_points_hdens))
C_O_dist_CIV = logN_CIV_obs-(logN_offset+species_logN_interp['C+3'](grid_points_hdens))
C_O_dist = np.concatenate((C_O_dist_CIII, C_O_dist_CIV))

# %%
get_quantiles(C_O_dist)
# Out:
# -0.56 -0.06 0.07

# %% [markdown]
# Plot models

# %%
logN_dict = {#'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            #'NII':'<13.0',
            #'NIII':'<13.2',
            #'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            #'NeVIII':'<13.1',
            'MgII':'<11.2',
            #'AlIII':'<12.3',
            #'SiII':'<13.0',
            #'SiIII':'<12.6',
            'SVI':'<12.6',}
            #'FeII':'<11.6'}

# %%
sample_indices_hdens = np.random.randint(low=0, high=len(flat_samples_hdens), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(len(sample_indices_hdens)):
    
    idx = sample_indices_hdens[i]
    flat_samples_row = flat_samples_hdens.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    
    logN_species_test = predict_col_dens(logN_dict, 12, log_hdens, 
                                         -3, species_logN_interp, {'C': np.median(C_O_dist)})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), 
            np.array(logN_species_test)+logN_offset,
            color='lightcoral', lw=.2, alpha=.1)

# %% [markdown]
# Plot cloud sizes

# %%
l_dist = np.array([get_cloud_size(15.44, log_hdens, species_logN_interp) for log_hdens in flat_samples_hdens['log_hdens']])

# %%
plt.hist(l_dist)
# Out:
# (array([1.3064e+04, 8.6291e+04, 7.1239e+04, 2.3391e+04, 4.9510e+03,
#         8.8100e+02, 1.4100e+02, 3.1000e+01, 7.0000e+00, 4.0000e+00]),
#  array([ 4.8219083 ,  9.08962676, 13.35734522, 17.62506368, 21.89278215,
#         26.16050061, 30.42821907, 34.69593753, 38.96365599, 43.23137445,
#         47.49909291]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Low density phase

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'<13.97',
            'CIV':'13.68, -0.06, +0.06',
            'NII':'<13.0',
            'NIII':'<13.2',
            'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'<14.42',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            'AlIII':'<12.3',
            'SiII':'<13.0',
            'SiIII':'<12.6',
            'SVI':'<12.6',
            'FeII':'<11.6'}

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['NV'], logN_dict['OIV'])
# Out:
# '<-1.49, 0.15'

# %%
logN_ratio_dict = {'OIII/OIV': '<-0.6, 0.2',
                   'SVI/OIV' : '<-2.4, 0.2',
                   'NeVIII/OIV': '<-1.9, 0.2',
                   'CIII/CIV': '<0.3, 0.2',
                   #'NV/OIV': '<-1.5, 0.2'
                  }

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict)

ax.set_xlim(-5, -1.5)
ax.set_ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# Fit the density

# %%
def lambda_log_prior_hdens(log_hdens):
    
    '''
    Priors for an MCMC search. 
    '''
   
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if -4<log_hdens<-3:
        return 0.0
    return -np.inf

# %%
def log_probability(params, logN_ratio_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    log_hdens = params[0]
    
    lp = log_prior_hdens(log_hdens)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_hdens(log_hdens, logN_ratio_dict, species_logN_interp)

# %%
#pos = np.array(-3.4) + 1e-6 * np.random.randn(500, 1)
#nwalkers, ndim = pos.shape

# %%
#sampler = emcee.EnsembleSampler(
#    nwalkers, ndim, log_probability, args=(logN_ratio_dict, species_logN_interp)
#)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_hdens = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens'])

#flat_samples_hdens.to_csv(savedir+'hdens_lo.csv', index=False)

flat_samples_hdens = pd.read_csv(savedir+'hdens_lo.csv')

# %%
fig = corner.corner(
    flat_samples_hdens, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
grid_points_hdens = np.array([[12, log_hdens, -3] for log_hdens in flat_samples_hdens['log_hdens']])

# %%
hist, bins = np.histogram(species_logN_interp['O+3'](grid_points_hdens), bins=1000)
centers = .5*(bins[1:]+bins[:-1])

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(species_logN_interp['O+3'](grid_points_hdens), bins=20)
ax.axvline(np.median(species_logN_interp['O+3'](grid_points_hdens)), linestyle=':')
ax.set_xlabel(r'$\log N_{\mathrm{OIV, ref}}$')

#ax.set_xlim(9.8, 9.9)
# Out:
# Text(0.5, 0, '$\\log N_{\\mathrm{OIV, ref}}$')

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(species_logN_interp['C+3'](grid_points_hdens), bins=200)
ax.axvline(np.median(species_logN_interp['C+3'](grid_points_hdens)), linestyle=':')
ax.set_xlabel(r'$\log N_{\mathrm{CIV, ref}}$')

#ax.set_xlim(9.8, 9.9)
# Out:
# Text(0.5, 0, '$\\log N_{\\mathrm{CIV, ref}}$')

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(species_logN_interp['O+2'](grid_points_hdens), bins=200)
ax.axvline(np.median(species_logN_interp['O+2'](grid_points_hdens)), linestyle=':')
ax.set_xlabel(r'$\log N_{\mathrm{OIII, ref}}$')

#ax.set_xlim(9.8, 9.9)
# Out:
# Text(0.5, 0, '$\\log N_{\\mathrm{OIII, ref}}$')

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(species_logN_interp['C+2'](grid_points_hdens), bins=200)
ax.axvline(np.median(species_logN_interp['C+2'](grid_points_hdens)), linestyle=':')
ax.set_xlabel(r'$\log N_{\mathrm{CIII, ref}}$')

#ax.set_xlim(9.8, 9.9)
# Out:
# Text(0.5, 0, '$\\log N_{\\mathrm{CIII, ref}}$')

# %% [markdown]
# Get the offset

# %%
logN_offset = 14.99-np.median(species_logN_interp['O+3'](grid_points_hdens))

# %%
logN_offset
# Out:
# 5.210591937216021

# %% [markdown]
# Calculate the C/O ratio

# %%
logN_CIV_obs = np.random.normal(loc=13.68, scale=0.05, size=len(flat_samples_hdens))

# %%
C_O_dist_CIV = logN_CIV_obs-(logN_offset+species_logN_interp['C+3'](grid_points_hdens))
C_O_dist = C_O_dist_CIV

# %%
get_quantiles(C_O_dist)
# Out:
# -0.45 -0.08 0.2

# %% [markdown]
# Get yields

# %%
get_quantiles(logN_offset+species_logN_interp['O+3'](grid_points_hdens))
# Out:
# 14.99 -0.28 0.1

# %%
get_quantiles(logN_offset-0.5+species_logN_interp['C+3'](grid_points_hdens))
# Out:
# 13.65 -0.22 0.03

# %%
get_quantiles(logN_offset+species_logN_interp['O+2'](grid_points_hdens))
# Out:
# 13.98 -0.08 0.02

# %%
get_quantiles(logN_offset-0.5+species_logN_interp['C+2'](grid_points_hdens))
# Out:
# 13.55 -0.21 0.08

# %% [markdown]
# Plot models

# %%
logN_dict = {#'HI':'15.44, -0.06, +0.06',
            #'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            #'NII':'<13.0',
            #'NIII':'<13.2',
            #'NV':'<13.5',
            #'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            #'MgII':'<11.2',
            #'AlIII':'<12.3',
            #'SiII':'<13.0',
            #'SiIII':'<12.6',
            'SVI':'<12.6',}
            #'FeII':'<11.6'}

# %%
sample_indices_hdens = np.random.randint(low=0, high=len(flat_samples_hdens), size=200)

# %%
log_hdens_lo = []

# %%
fig, ax = plot_column_densities_obs(logN_dict)

ax.errorbar(x=0, y=13.6, yerr=0.2, color='black', linestyle='None', mfc='white',
        fmt='o', markersize=3, capsize=4)

ax.errorbar(x=1, y=13.98, yerr=0.08, color='black', linestyle='None', mfc='white',
        fmt='o', markersize=3, capsize=4)

for i in range(len(sample_indices_hdens)):
    
    idx = sample_indices_hdens[i]
    flat_samples_row = flat_samples_hdens.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_hdens_lo.append(log_hdens)
    
    logN_species_test = predict_col_dens(logN_dict, 12, log_hdens, 
                                         -3, species_logN_interp, {'C': np.median(C_O_dist)})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), 
            np.array(logN_species_test)+logN_offset,
            color='skyblue', lw=.2, alpha=.2)

# %% [markdown]
# Calculate residual for CIII

# %%
logN_CIII_tot = np.random.normal(loc=13.97, scale=0.05, size=1000)
logN_CIII_lo_dens = np.random.normal(loc=13.6, scale=0.2, size=1000)
logN_CIII_hi_dens = np.log10(10**logN_CIII_tot - 10**logN_CIII_lo_dens)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_69723/285293535.py:3: RuntimeWarning: invalid value encountered in log10
#   logN_CIII_hi_dens = np.log10(10**logN_CIII_tot - 10**logN_CIII_lo_dens)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(logN_CIII_tot, label='total (obs)', alpha=0.5)
ax.hist(logN_CIII_lo_dens, label='lo-dens (model)', alpha=0.5)
ax.hist(logN_CIII_hi_dens, label='hi-dens (res)', alpha=0.5)

ax.set_xlabel(r'$\log N_{\mathrm{CIII}}$')
ax.set_ylabel('Counts')

#ax.set_xlim(13.81,14.39)
ax.legend(loc='upper left')

# %%
logN_CIII_hi_dens_clean = logN_CIII_hi_dens[~np.isnan(logN_CIII_hi_dens)]

# %%
get_quantiles(logN_CIII_hi_dens_clean)
# Out:
# 13.73 -0.24 0.12

# %% [markdown]
# Calculate residual for OIII

# %%
logN_OIII_tot = np.random.normal(loc=14.42, scale=0.02, size=1000)
logN_OIII_hi_dens = np.random.normal(loc=13.98, scale=0.08, size=1000)
logN_OIII_lo_dens = np.log10(10**logN_OIII_tot - 10**logN_OIII_hi_dens)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(logN_OIII_tot, label='total (obs)', alpha=0.5)
ax.hist(logN_OIII_lo_dens, label='lo-dens (model)', alpha=0.5)
ax.hist(logN_OIII_hi_dens, label='hi-dens (res)', alpha=0.5)

ax.set_xlabel(r'$\log N_{\mathrm{OIII}}$')
ax.set_ylabel('Counts')

#ax.set_xlim(13.81,14.39)
ax.legend(loc='upper left')

# %%
logN_OIII_hi_dens_clean = logN_OIII_hi_dens[~np.isnan(logN_OIII_hi_dens)]

# %%
get_quantiles(logN_OIII_hi_dens_clean)
# Out:
# 13.98 -0.08 0.08

# %% [markdown]
# # Fit high density phase

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.7, -0.2, +0.1',
            'CIV':'<13.68',
            'NII':'<13.0',
            'NIII':'<13.2',
            'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'13.98, -0.08, +0.08',
            'OIV':'<14.99',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            'AlIII':'<12.3',
            'SiII':'<13.0',
            'SiIII':'<12.6',
            'SVI':'<12.6',
            'FeII':'<11.6'}

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['MgII'], logN_dict['OIII'])
# Out:
# '<-2.78, 0.16'

# %%
logN_ratio_dict = {'CII/CIII': '<-0.5, 0.2',
                   'CIV/CIII': '<-0.0, 0.2',
                   'OII/OIII': '<-1.0, 0.2',
                   'OIV/OIII': '<0.9, 0.2',
                   'MgII/OIII':  '<-2.9, 0.2'
                  }

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict)

ax.set_xlim(-5, -1.5)
ax.set_ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %%
#pos = np.array(-3) + 1e-6 * np.random.randn(500, 1)
#nwalkers, ndim = pos.shape

# %%
#sampler = emcee.EnsembleSampler(
#    nwalkers, ndim, log_probability, args=(logN_ratio_dict, species_logN_interp)
#)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_hdens = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens'])

#flat_samples_hdens.to_csv(savedir+'hdens_hi.csv', index=False)

flat_samples_hdens = pd.read_csv(savedir+'hdens_hi.csv')

# %%
fig = corner.corner(
    flat_samples_hdens, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
grid_points_hdens = np.array([[12, log_hdens, -3] for log_hdens in flat_samples_hdens['log_hdens']])

# %%
logN_offset = 14.06-np.median(species_logN_interp['O+2'](grid_points_hdens))

# %%
logN_offset
# Out:
# 5.35594675403159

# %% [markdown]
# Calculate the C/O ratio

# %%
logN_CIII_obs = np.random.normal(loc=13.7, scale=0.2, size=len(flat_samples_hdens))

# %%
C_O_dist_CIII = logN_CIII_obs-(logN_offset+species_logN_interp['C+2'](grid_points_hdens))
C_O_dist = C_O_dist_CIII

# %%
get_quantiles(C_O_dist)
# Out:
# -0.35 -0.28 0.34

# %% [markdown]
# Plot models

# %%
logN_dict = {#'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.7, -0.2, +0.1',
            'CIV':'<13.68',
            #'NII':'<13.0',
            #'NIII':'<13.2',
            #'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'13.98, -0.08, +0.08',
            'OIV':'<14.99',
            #'NeVIII':'<13.1',
            'MgII':'<11.2',}
            #'AlIII':'<12.3',
            #'SiII':'<13.0',
            #'SiIII':'<12.6',
            #'SVI':'<12.6',
            #'FeII':'<11.6'}

# %%
sample_indices_hdens = np.random.randint(low=0, high=len(flat_samples_hdens), size=200)

# %%
log_hdens_hi = []

# %%
fig, ax = plot_column_densities_obs(logN_dict)

#ax.errorbar(x=0, y=13.6, yerr=0.2, color='black', linestyle='None', mfc='white',
#        fmt='o', markersize=3, capsize=4)

#ax.errorbar(x=1, y=14.06, yerr=0.08, color='black', linestyle='None', mfc='white',
#        fmt='o', markersize=3, capsize=4)

for i in range(len(sample_indices_hdens)):
    
    idx = sample_indices_hdens[i]
    flat_samples_row = flat_samples_hdens.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_hdens_hi.append(log_hdens)
    
    logN_species_test = predict_col_dens(logN_dict, 12, log_hdens, 
                                         -3, species_logN_interp, {'C': np.median(C_O_dist)})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), 
            np.array(logN_species_test)+logN_offset,
            color='orangered', lw=.2, alpha=.1)

# %% [markdown]
# # Multiphase solution

# %%
logN_dict = {#'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            #'NII':'<13.0',
            #'NIII':'<13.2',
            #'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            #'AlIII':'<12.3',
            #'SiII':'<13.0',
            #'SiIII':'<12.6',
            'SVI':'<12.6',}
            #'FeII':'<11.6'}

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(400):
    
    log_hdens_hi = np.random.normal(loc=-3.0, scale=0.4)
    log_hdens_lo = np.random.normal(loc=-3.8, scale=0.4)
    
    if log_hdens_min<log_hdens_hi<log_hdens_max and log_hdens_min<log_hdens_lo<log_hdens_max:
        
        logN_species_test_hi = np.array(predict_col_dens(logN_dict, 12, log_hdens_hi, 
                                             -3, species_logN_interp, {'C': -0.4}))+5.36

        logN_species_test_lo = np.array(predict_col_dens(logN_dict, 12, log_hdens_lo, 
                                             -3, species_logN_interp, {'C': -0.5}))+5.21

        logN_species_test = np.log10(10**logN_species_test_hi + 10**logN_species_test_lo)

        # Plot
        ax.plot(np.arange(len(logN_species_test_hi)), 
                np.array(logN_species_test_hi),
                color='gold', lw=.2, alpha=.1)

        # Plot
        ax.plot(np.arange(len(logN_species_test_lo)), 
                np.array(logN_species_test_lo),
                color='skyblue', lw=.2, alpha=.1)    

        #ax.plot(np.arange(len(logN_species_test)), 
        #        np.array(logN_species_test),
        #        color='lightcoral', lw=.2, alpha=.1)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(400):
    
    log_hdens_hi = np.random.normal(loc=-3.0, scale=0.4)
    log_hdens_lo = np.random.normal(loc=-3.8, scale=0.4)
    
    if log_hdens_min<log_hdens_hi<log_hdens_max and log_hdens_min<log_hdens_lo<log_hdens_max and log_hdens_lo<log_hdens_hi:
        
        logN_species_test_hi = np.array(predict_col_dens(logN_dict, 12, log_hdens_hi, 
                                             -3, species_logN_interp, {'C': -0.4}))+5.36

        logN_species_test_lo = np.array(predict_col_dens(logN_dict, 12, log_hdens_lo, 
                                             -3, species_logN_interp, {'C': -0.5}))+5.21

        logN_species_test = np.log10(10**logN_species_test_hi + 10**logN_species_test_lo)

        # Plot
        #ax.plot(np.arange(len(logN_species_test_hi)), 
        #        np.array(logN_species_test_hi),
        #        color='gold', lw=.2, alpha=.1)

        # Plot
        #ax.plot(np.arange(len(logN_species_test_lo)), 
        #        np.array(logN_species_test_lo),
        #        color='skyblue', lw=.2, alpha=.1)    

        ax.plot(np.arange(len(logN_species_test)), 
                np.array(logN_species_test),
                color='lightcoral', lw=.2, alpha=.1)

# %% [markdown]
# # Constrain column densities and metallicities

# %%
np.log10(10**15.20 + 10**14.80)
# Out:
# 15.345540463109293

# %%
-3+(5.36-(15.20-12)), -3+(5.21-(14.80-12))
# Out:
# (-0.839999999999999, -0.5900000000000007)

# %% [markdown]
# Plot some solutions

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            #'NII':'<13.0',
            #'NIII':'<13.2',
            #'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            #'AlIII':'<12.3',
            #'SiII':'<13.0',
            #'SiIII':'<12.6',
            'SVI':'<12.6',}
            #'FeII':'<11.6'}

# %%
logN_HI_p1_test = 15.4
log_hdens_p1_test = -3.0
log_metals_p1_test = -0.8

logN_HI_p2_test = 14.8
log_hdens_p2_test = -3.8
log_metals_p2_test = -0.6

# %%
logN_species_test_p1 = (logN_HI_p1_test-12) + (log_metals_p1_test+3) + np.array(predict_col_dens(logN_dict, 
                                                                                                 12, 
                                                                                                 log_hdens_p1_test,
                                                                                                 -3, 
                                                                                 species_logN_interp, {'C':-0.4}))

logN_species_test_p2 = (logN_HI_p2_test-12) + (log_metals_p2_test+3) + np.array(predict_col_dens(logN_dict, 
                                                                                                 12, 
                                                                                                 log_hdens_p2_test,
                                                                                                 -3, 
                                                                                 species_logN_interp, {'C':-0.5}))

logN_species_test_p1[0] = logN_HI_p1_test
logN_species_test_p2[0] = logN_HI_p2_test

logN_species_test = np.log10(10**logN_species_test_p1 + 10**logN_species_test_p2)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

ax.plot(np.arange(len(logN_species_test)), logN_species_test_p1, color='gold', label='p1')
ax.plot(np.arange(len(logN_species_test)), logN_species_test_p2, color='skyblue', label='p2')
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='red', label='Total')

ax.legend()

# %% [markdown]
# Constrain stuff

# %%
def get_cloud_size(logN_HI, log_hdens, species_logN_interp):

    logN_HII = species_logN_interp['H+']([logN_HI, log_hdens, -3])[0]
    N_H = 10**logN_HI + 10**logN_HII

    l = (N_H/10**log_hdens)*3.24078e-19*1e-3

    return l

# %%
def log_prior_N_HI_metals(params, log_hdens_p1, log_hdens_p2, species_logN_interp):
    
    '''
    Priors for an MCMC search. 
    '''
   
    # Grid parameters being varied
    logN_HI_p1, log_metals_p1, logN_HI_p2, log_metals_p2 = params

    # Get cloud sizes
    l_p1 = get_cloud_size(logN_HI_p1, log_hdens_p1, species_logN_interp)
    l_p2 = get_cloud_size(logN_HI_p2, log_hdens_p2, species_logN_interp)
        
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if logN_HI_min<logN_HI_p1<logN_HI_max: 
        if log_metals_min<log_metals_p1<log_metals_max:
            if logN_HI_min<logN_HI_p2<logN_HI_max: 
                if log_metals_min<log_metals_p2<log_metals_max:
                        if l_p1 < l_p2:
                            if l_p2 < 100:
                                return 0.0
                            else:
                                return -np.inf
                        else:
                            return -np.inf
                else:
                    return -np.inf
            else:
                return -np.inf
        else:
            return -np.inf
    else: 
        return -np.inf

# %%
def log_likelihood_N_HI_metals(params, logN_dict, log_hdens_p1, C_O_p1, log_hdens_p2, C_O_p2, species_logN_interp):
    
    '''
    Likelihood function for comparing CLOUDY predicted column densities to the observed values from VP fit.
    If only some of the parameters need to be fit, the log_likelihood function can be overridden with a lambda function
    which calls this likelihood function with only some parameters being varied.

    params: parameters needed to generate CLOUDY predicted column densities
    logN_dict: dictionary of measured column densities from VP fit
    species_logN_interp: interpolated CLOUDY grid
    '''
    
    # Grid parameters being varied
    logN_HI_p1, log_metals_p1, logN_HI_p2, log_metals_p2 = params

    # Likelihood function
    ll = 0
    
    ions = list(logN_dict.keys())
    
    # Ignore first entry since it's HI
    for i in range(len(ions)):
        
        # This is from VP fit
        ion = ions[i]
        logN_str = logN_dict[ion]
        
        # This is from CLOUDY
        s = ion_species_dict[ion]
        
        # Get interpolated column density from CLOUDY grid
        if ion != 'HI':
            
            y_bar_1 = species_logN_interp[s]([logN_HI_p1, log_hdens_p1, log_metals_p1])[0]
            y_bar_2 = species_logN_interp[s]([logN_HI_p2, log_hdens_p2, log_metals_p2])[0]
            
            if ion[0] == 'C':
                y_bar_1 += C_O_p1
                y_bar_2 += C_O_p2
        else:
            y_bar_1 = logN_HI_p1
            y_bar_2 = logN_HI_p2

        y_bar = np.log10(10**y_bar_1 + 10**y_bar_2)

        # Based on detection or non-detection, compute the likelihood term
        
        # Detection
        if logN_str[0] != '<' and logN_str[0] != '>':
            
            logN_arr = np.array(logN_str.split(','), dtype=float)
            
            # Observed column density
            y = logN_arr[0]

            # Use max of lower and upper error for defining Gaussian distribution of column density
            sig_y = max(-logN_arr[1], logN_arr[2])

            # Gaussian likelihood
            ll += -.5*(y-y_bar)**2/sig_y**2

        # Upper limit
        elif logN_str[0] == '<':
            
            logN_arr = np.array(logN_str[1:].split(','), dtype=float)

            # Isolate the lower limit and sigma
            y = logN_arr[0]
            sig_y = 0.14

            y_range_min = -10 # Should extend to infinity, ideally
            y_range_step = 0.05

            y_range = np.arange(y_range_min, y+y_range_step, y_range_step)

            # CDF, marginalize over reported values
            ll += np.log(integrate.simpson(x=y_range, y=np.exp(-.5*(y_range-y_bar)**2/sig_y**2)))
            
        # Lower limit
        # NOTE: not implemented yet
        elif logN_str[0] == '>':

            logN_arr = np.array(logN_str[1:].split(','), dtype=float)

            # Isolate the lower limit and sigma
            y = logN_arr[0]
            sig_y = 0.14

            y_range_max = 21.5 # Should extend to infinity, ideally
            y_range_step = 0.05

            y_range = np.arange(y, y_range_max+y_range_step, y_range_step)

            # "Q"-function, marginalize over reported values
            ll += np.log(integrate.simpson(x=y_range, y=np.exp(-.5*(y_range-y_bar)**2/sig_y**2)))

    # Return log likelihood for MCMC
    return ll

# %%
def log_probability(params, logN_dict, log_hdens_p1, C_O_p1, log_hdens_p2, C_O_p2, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = log_prior_N_HI_metals(params, log_hdens_p1, log_hdens_p2, species_logN_interp)
    
    if not np.isfinite(lp):
        #print('woah')
        return -np.inf
    return lp + log_likelihood_N_HI_metals(params, logN_dict,
                                  log_hdens_p1, C_O_p1, log_hdens_p2, C_O_p2, 
                                  species_logN_interp)

# %%
#pos = np.array([logN_HI_p1_test, log_metals_p1_test,
#                logN_HI_p2_test, log_metals_p2_test]) + 1e-3 * np.random.randn(500, 4)
#nwalkers, ndim = pos.shape

# %%
#sampler = emcee.EnsembleSampler(
#    nwalkers, ndim, log_probability, args=(logN_dict, log_hdens_p1_test, -0.4, log_hdens_p2_test, -0.5, 
#                                          species_logN_interp)
#)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_metals = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['logN_HI_p1', 'log_metals_p1',
#                                         'logN_HI_p2', 'log_metals_p2'])
#flat_samples_metals.to_csv(savedir+'N_HI_metals.csv', index=False)

flat_samples_metals = pd.read_csv(savedir+'N_HI_metals.csv')

# %%
fig = corner.corner(
    flat_samples_metals, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_\mathrm{HI, p1})$', r'$[\mathrm{O/H}]_{\mathrm{p1}}$',
            r'$\log(N_\mathrm{HI, p2})$', r'$[\mathrm{O/H}]_{\mathrm{p2}}$',], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
get_cloud_size(15.24, -3.0, species_logN_interp)
# Out:
# 1.690030520631817

# %% [markdown]
# Get cloud sizes

# %%
l_hi_dist = np.array([get_cloud_size(logN_HI, 
                                  -3.0, 
                                  species_logN_interp) for logN_HI in flat_samples_metals['logN_HI_p1']])

# %%
l_lo_dist = np.array([get_cloud_size(logN_HI, 
                                  -3.8, 
                                  species_logN_interp) for logN_HI in flat_samples_metals['logN_HI_p2']])

# %%
fig, ax = plt.subplots(1, figsize=(5,5))

ax.hist(l_hi_dist, bins=25)

ax.set_xlabel(r'$l_{\mathrm{p1}}$')
ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
fig, ax = plt.subplots(1, figsize=(5,5))

ax.hist(l_lo_dist, bins=25)

ax.set_xlabel(r'$l_{\mathrm{p2}}$')
ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
fig, ax = plt.subplots(1, figsize=(5,5))
ax.scatter(l_hi_dist, l_lo_dist, s=)

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, linestyle=':')

ax.set_xlim(0, 10)

ax.set_xlabel(r'$l_{\mathrm{p1}}$')
ax.set_ylabel(r'$l_{\mathrm{p2}}$')
# Out:
# Text(0, 0.5, '$l_{\\mathrm{p2}}$')

# %% [markdown]
# Overplot models

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            #'NII':'<13.0',
            #'NIII':'<13.2',
            #'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            #'AlIII':'<12.3',
            #'SiII':'<13.0',
            #'SiIII':'<12.6',
            'SVI':'<12.6',}
            #'FeII':'<11.6'}

# %%
sample_indices_metals = np.random.randint(low=0, high=len(flat_samples_metals), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(len(sample_indices_metals)):
    
    idx = sample_indices_hdens[i]
    flat_samples_row = flat_samples_metals.iloc[i]
    
    logN_HI_p1 = flat_samples_row['logN_HI_p1']
    logN_HI_p2 = flat_samples_row['logN_HI_p2']
    
    log_metals_p1 = flat_samples_row['log_metals_p1']
    log_metals_p2 = flat_samples_row['log_metals_p2']
    
    logN_species_test_hi = (logN_HI_p1-12)+(log_metals_p1+3)+np.array(predict_col_dens(logN_dict, 
                                                                                       12, -3.0, -3, 
                                                                                       species_logN_interp, 
                                                                                       {'C': -0.4}))
    
    logN_species_test_lo = (logN_HI_p2-12)+(log_metals_p2+3)+np.array(predict_col_dens(logN_dict, 
                                                                                       12, -3.8, -3, 
                                                                                       species_logN_interp, 
                                                                                       {'C': -0.5}))

    
    logN_species_test_hi[0] = logN_HI_p1
    logN_species_test_lo[0] = logN_HI_p2
    
    logN_species_test = np.log10(10**logN_species_test_hi + 10**logN_species_test_lo)
    
    # Plot
    ax.plot(np.arange(len(logN_species_test_hi)), 
            np.array(logN_species_test_hi),
            color='gold', lw=.2, alpha=.1)

    # Plot
    ax.plot(np.arange(len(logN_species_test_lo)), 
            np.array(logN_species_test_lo),
            color='skyblue', lw=.2, alpha=.1)    

    ax.plot(np.arange(len(logN_species_test)), 
            np.array(logN_species_test),
            color='lightcoral', lw=.2, alpha=.1)

# %% [markdown]
# # Oxygen + Sulphur fit

# %%
# Assume solar abundance patterns throughout

def lambda_log_prior(params):
    
    # Only parameters being varied
    log_hdens, log_metals = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, log_metals, {}])
    
    # Call the original prior function on the full set of parameters
    return log_prior(params_full)

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    log_hdens, log_metals = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, log_metals, {}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Isolate the ions

# %%
ions_oxy_sul = ['OII', 'OIII', 'OIV', 'SVI']

# %%
logN_dict_oxy_sul = {ion: logN_dict[ion] for ion in ions_oxy_sul}

# %%
logN_dict_oxy_sul
# Out:
# {'OII': '<13.0',
#  'OIII': '14.42, -0.02, +0.02',
#  'OIV': '14.99, -0.04, +0.06',
#  'SVI': '<12.6'}

# %%
pos = np.array([log_hdens_test, log_metals_test]) + 1e-4 * np.random.randn(500, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_oxy_sul, species_logN_interp)
)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_oxy_sul = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens', 'log_metals'])
#flat_samples_oxy_sul.to_csv(savedir+'oxy_sul_solar_flat.csv', index=False)

flat_samples_oxy_sul = pd.read_csv(savedir+'oxy_sul_solar_flat.csv')

# %%
fig = corner.corner(
    flat_samples_oxy_sul.loc[:, ['log_hdens', 'log_metals']], quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Plot expected column density ratios for derived metallicity

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict, 
                logN_HI_ref=logN_HI_test, log_metals_ref=-0.7)

ax.set_xlim(-5, -1.5)
ax.set_ylim(-5, 1.5)
# Out:
# (-5.0, 1.5)

# %% [markdown]
# We'd expect the CIV to be slightly overproduced at the best fit density; worth allowing non-solar C/O for a single phase and seeing if affects the best density/ metallicity. Now plot the best models.

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            'NII':'<13.0',
            'NIII':'<13.2',
            'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            'AlIII':'<12.3',
            'SiII':'<13.0',
            'SiIII':'<12.6',
            'SVI':'<12.6',
            'FeII':'<11.6'}

# %%
sample_indices_oxy_sul = np.random.randint(low=0, high=len(flat_samples_oxy_sul), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'CII', 'CIII', 
                                                         'CIV', 'NII', 'NIII', 
                                                         'NV', 
                                                         'NeVIII', 'MgII', 
                                                         'AlIII', 'SiII', 'SiIII', 
                                                         'FeII', 'OVI'])

for i in range(len(sample_indices_oxy_sul)):
    
    idx = sample_indices_oxy_sul[i]
    flat_samples_row = flat_samples_oxy_sul.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens, 
                                         log_metals, species_logN_interp)

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.33 \pm 0.03$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -0.66 \pm 0.02$')

#plt.savefig(savedir+'z=0_67532051_cloudy_oxy_sul.pdf', dpi=300)

# %% [markdown]
# Plot the posterior for cloud size

# %%
#flat_samples_oxy_sul['logN_HII'] = [species_logN_interp['H+']([logN_HI_test,
#                                                            flat_samples_oxy_sul.iloc[i]['log_hdens'],
#                                                            flat_samples_oxy_sul.iloc[i]['log_metals']])[0]
#                                               for i in range(len(flat_samples_oxy_sul))]

# %%
#flat_samples_oxy_sul['cloud_size_kpc'] = ((10**logN_HI_test+10**flat_samples_oxy_sul['logN_HII'])/10**flat_samples_oxy_sul['log_hdens'])*3.24078e-19*1e-3

# %%
#flat_samples_oxy_sul.to_csv(savedir+'oxy_sul_solar_flat.csv', index=False)

# %%
l_med = np.median(flat_samples_oxy_sul['cloud_size_kpc'])
l_perc_16 = np.percentile(flat_samples_oxy_sul['cloud_size_kpc'],16)
l_perc_84 = np.percentile(flat_samples_oxy_sul['cloud_size_kpc'],84)

# %%
l_med, l_med-l_perc_16, l_perc_84-l_med
# Out:
# (9.36314085414645, 1.9061283323764773, 2.3758813960689817)

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.hist(flat_samples_oxy_sul['cloud_size_kpc'], bins=150, density=True, color='coral', alpha=.8)
#ax.axvline(l_med, linestyle=':', lw=2)
#ax.axvline(l_perc_16, linestyle=':', lw=2)
#ax.axvline(l_perc_84, linestyle=':', lw=2)

#ax.text(12, 0.26, s=r'$\log N_{\mathrm{HI}} = 15.40 \pm 0.06$')
#ax.text(12, 0.22, s=r'$l = 9 \pm 1 \ \mathrm{kpc}$')

ax.set_xlabel('Cloud size (kpc)')
ax.set_ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# # Oxygen + Sulphur + Carbon

# %%
# Assume solar abundance patterns throughout

def lambda_log_prior(params):
    
    # Only parameters being varied
    log_hdens, log_metals, C_O = params
    
    # Get abundance for carbon
    C_H = log_metals + C_O
    
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if log_hdens_min<log_hdens<log_hdens_max and log_metals_min<log_metals<log_metals_max and log_metals_min<C_H<log_metals_max:
        return 0.0
    return -np.inf

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    log_hdens, log_metals, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, log_metals, {'C': C_O}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Isolate the ions

# %%
ions_oxy_sul_carb = ['OII', 'OIII', 'OIV', 'SVI', 'CIII', 'CIV']

# %%
logN_dict_oxy_sul_carb = {ion: logN_dict[ion] for ion in ions_oxy_sul_carb}

# %%
logN_dict_oxy_sul_carb
# Out:
# {'OII': '<13.0',
#  'OIII': '14.42, -0.02, +0.02',
#  'OIV': '14.99, -0.04, +0.06',
#  'SVI': '<12.6',
#  'CIII': '13.97, -0.05, +0.05',
#  'CIV': '13.68, -0.06, +0.06'}

# %%
pos = np.array([log_hdens_test, log_metals_test, -0.4]) + 1e-4 * np.random.randn(500, 3)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_oxy_sul_carb, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 500, progress=True)
# Out:
# 100%|███████████████████████████████████| 500/500 [05:21<00:00,  1.56it/s]
# State([[-3.28855759 -0.74069656 -0.50129678]
#  [-3.32693156 -0.68363822 -0.56890643]
#  [-3.25654211 -0.71521076 -0.48942145]
#  ...
#  [-3.30488692 -0.70680771 -0.53097802]
#  [-3.37796538 -0.72565968 -0.56599576]
#  [-3.27326879 -0.698146   -0.45446109]], log_prob=[ -7.1809752   -6.96260372  -5.80414147  -6.54131999  -8.37914132
#   -6.14884821  -6.8821715   -8.10151071  -8.46191894  -7.22841786
#   -6.73567348  -6.14191895  -7.06596     -6.34953795  -7.96080937
#   -6.63476846  -5.66676451  -5.90526027  -6.1712271   -7.61312833
#   -6.6421767   -6.49514722  -6.01895035  -5.97995399  -5.99158687
#  -10.14890049  -9.87180302  -5.98383347  -6.7720334   -6.88449135
#   -8.93485396  -8.21024706  -5.87682275  -6.17646641  -9.0315355
#   -7.10747439  -5.7781125   -6.28390123  -6.01129126  -9.31713895
#   -7.75658759  -6.98621577  -7.96545466  -6.65726841  -6.74214594
#   -7.28265355  -7.35914784  -6.65972305  -7.33662496  -8.84221545
#   -7.49918759 -11.52799236  -6.53911535 -10.25452373  -6.85924641
#   -6.22168402  -7.50541653  -5.67815492  -7.82187552  -6.11017592
#   -6.47041886  -7.66348651  -5.7668428   -6.06166861  -7.96749631
#   -7.52622701  -8.50096786  -6.52070963  -6.16511213  -5.61747975
#   -6.26404984  -7.08021126  -6.37906586  -6.95956082  -7.82729308
#   -7.55008983  -6.19898995  -7.1492866   -6.95217082  -8.06103577
#   -6.6319662   -5.77232662  -6.89825928  -5.6389153   -5.51627928
#   -9.46478421  -6.54126351  -5.7499999   -8.76238768  -6.1577021
#   -7.22957459  -7.27360204  -8.13643555  -6.69750331  -7.10965089
#        1011190606,  104459828, 4228855269,  859204678, 3344171997,
#        2778570462, 2437553197, 2239603734, 3512241918, 3731205043,
#        2833730195, 3454793772,  905320824, 1759840703, 2377002734,
#         960112559, 1852013834, 2069354404, 3073426489,  325890401,
#         236176612, 3383709972, 1854085554, 3278521977, 1930996802,
#          31641185, 1487070761, 2375399882, 2576862937, 3643667870,
#        2398995566, 1751541598, 2399348703, 2770985288, 1715187964,
#        3417699564, 1115032949, 1111399199,  178127903, 2167264461,
#        2760641131, 2009630845,  746299515,  915599674,  693465385,
#        3527143493, 3732166734, 1867096576,  582106683, 1391446582,
#        4119152905, 1898105336, 2423006068, 3867497418, 2097211365,
#         451348020,  770917585, 1682963415,  639593415,  553865682,
#         311618751, 1118545962, 2973393449, 3293195965, 4022107656,
#        1414168141, 2876415922,  461977195, 4186303539, 1660969139,
#        2460124210, 1269357990, 1385097234, 1927595147, 4223431880,
#        2909317776, 4190538035,  686680620, 1037534274, 1267912584,
#         733772177,  807811808, 1500676644, 3596889333, 2981914121,
#        2728230379, 4124834074, 1244678638, 2182650892, 3018922997,
#        1182318495, 1266001268,   48642217, 1627644236,  748374089,
#        1666454646, 3502987692,  686433909,  394674426, 2674804079,
#        2883018045, 1163590681,  836991768, 2679248899,  139696401,
#        1801046644, 3485745809, 3838800155, 4047528760, 4001241565,
#         652164052, 1636794398, 3213565332,  159441216,  760806434,
#         825234966, 3101932204, 3495077378, 1851809331, 1822099751,
#        3454036961, 1935082402, 2533627481, 1690255057, 2241594401,
#        3123812385, 4029414602, 1806848449, 3098451797,  172279212,
#        2095050365, 2331844490,  379485553, 2924543975], dtype=uint32), 397, 0, 0.0))

# %%
flat_samples_oxy_sul_carb = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
                                columns=['log_hdens', 'log_metals', 'C_O'])
flat_samples_oxy_sul_carb.to_csv(savedir+'oxy_sul_carb_subsolar_flat.csv', index=False)

#flat_samples_oxy_sul_carb = pd.read_csv(savedir+'oxy_sul_carb_subsolar_flat.csv')

# %%
fig = corner.corner(
    flat_samples_oxy_sul_carb, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$', r'$[\mathrm{C/O}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            'NII':'<13.0',
            'NIII':'<13.2',
            'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            'AlIII':'<12.3',
            'SiII':'<13.0',
            'SiIII':'<12.6',
            'SVI':'<12.6',
            'FeII':'<11.6'}

# %%
sample_indices_oxy_sul_carb = np.random.randint(low=0, high=len(flat_samples_oxy_sul_carb), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'CII',
                                                         'NII', 'NIII', 
                                                         'NV', 
                                                         'NeVIII', 'MgII', 
                                                         'AlIII', 'SiII', 'SiIII', 
                                                         'FeII', 'OVI'])

for i in range(len(sample_indices_oxy_sul_carb)):
    
    idx = sample_indices_oxy_sul_carb[i]
    flat_samples_row = flat_samples_oxy_sul_carb.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    C_O = flat_samples_row['C_O']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens, 
                                         log_metals, species_logN_interp, {'C': C_O})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.33 \pm 0.03$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -0.66 \pm 0.02$')

#plt.savefig(savedir+'z=0_67532051_cloudy_oxy_sul.pdf', dpi=300)

# %% [markdown]
# # Hydrogen + Oxygen + Sulphur + Carbon

# %%
# Assume solar abundance patterns throughout

def lambda_log_prior(params):
    
    # Only parameters being varied
    logN_HI, log_hdens, log_metals, C_O = params
    
    # Get abundance for carbon
    C_H = log_metals + C_O
    
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if log_hdens_min<log_hdens<log_hdens_max and log_metals_min<log_metals<log_metals_max and log_metals_min<C_H<log_metals_max:
        return 0.0
    return -np.inf

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    logN_HI, log_hdens, log_metals, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, log_metals, {'C': C_O}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Isolate the ions

# %%
ions_hyd_oxy_sul_carb = ['HI','OII', 'OIII', 'OIV', 'SVI', 'CIII', 'CIV']

# %%
logN_dict_hyd_oxy_sul_carb = {ion: logN_dict[ion] for ion in ions_hyd_oxy_sul_carb}

# %%
logN_dict_hyd_oxy_sul_carb
# Out:
# {'HI': '15.44, -0.06, +0.06',
#  'OII': '<13.0',
#  'OIII': '14.42, -0.02, +0.02',
#  'OIV': '14.99, -0.04, +0.06',
#  'SVI': '<12.6',
#  'CIII': '13.97, -0.05, +0.05',
#  'CIV': '13.68, -0.06, +0.06'}

# %%
pos = np.array([logN_HI_test, log_hdens_test, log_metals_test, -0.4]) + 1e-4 * np.random.randn(500, 4)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=
#        1071209270, 1373391374, 3085462620, 1598856628, 3680826832,
#        2215441993,  895017156, 3883975738, 2989909435,  542315350,
#         546335840, 1008430811, 2331294024, 3122720761,  143685305,
#        3233782727, 3982968814, 1199918927, 2738608247, 2797572115,
#        1853580207, 2581958435,  894042872, 3822288854, 3618071464,
#        2606264558, 2453813362, 3821042376, 2285038806, 1067761136,
#        1693392365, 3249198426,   11958745,   66670615, 3828171546,
#        1443717787, 3119827328,   19992430,  628945964], dtype=uint32), 417, 0, 0.0))

# %%
flat_samples_hyd_oxy_sul_carb = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
                                columns=['logN_HI', 'log_hdens', 'log_metals', 'C_O'])
flat_samples_hyd_oxy_sul_carb.to_csv(savedir+'hyd_oxy_sul_carb_subsolar_flat.csv', index=False)

#flat_samples_hyd_oxy_sul_carb = pd.read_csv(savedir+'hyd_oxy_sul_carb_subsolar_flat.csv')

# %%
fig = corner.corner(
    flat_samples_hyd_oxy_sul_carb, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_\mathrm{HI})$', r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$', r'$[\mathrm{C/O}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI':'15.44, -0.06, +0.06',
            'CII':'<13.2',
            'CIII':'13.97, -0.05, +0.05',
            'CIV':'13.68, -0.06, +0.06',
            'NII':'<13.0',
            'NIII':'<13.2',
            'NV':'<13.5',
            'OII':'<13.0',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.99, -0.04, +0.06',
            'NeVIII':'<13.1',
            'MgII':'<11.2',
            'AlIII':'<12.3',
            'SiII':'<13.0',
            'SiIII':'<12.6',
            'SVI':'<12.6',
            'FeII':'<11.6'}

# %%
sample_indices_hyd_oxy_sul_carb = np.random.randint(low=0, high=len(flat_samples_hyd_oxy_sul_carb), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['CII',
                                                         'NII', 'NIII', 
                                                         'NV', 
                                                         'NeVIII', 'MgII', 
                                                         'AlIII', 'SiII', 'SiIII', 
                                                         'FeII', 'OVI'])

for i in range(len(sample_indices_hyd_oxy_sul_carb)):
    
    idx = sample_indices_hyd_oxy_sul_carb[i]
    flat_samples_row = flat_samples_hyd_oxy_sul_carb.iloc[i]
    logN_HI = flat_samples_row['logN_HI']
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    C_O = flat_samples_row['C_O']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI, log_hdens, 
                                         log_metals, species_logN_interp, {'C': C_O})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.33 \pm 0.03$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -0.66 \pm 0.02$')

#plt.savefig(savedir+'z=0_67532051_cloudy_oxy_sul.pdf', dpi=300)
