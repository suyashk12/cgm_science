# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd
from cloudy_fit_lib import *
from scipy.interpolate import RegularGridInterpolator
import pickle
import corner
from scipy import integrate, interpolate
import emcee

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/cloudy_grids/'

# %%
savedir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z=1.1659134/cloudy_fits/'

# %% [markdown]
# Obtain the UVB grid from FG20

# %%
fg20_z_grid, fg20_wav_grid, fg20_J_nu_grid = read_uvb('', 'fg20_galaxy.ascii')

# %% [markdown]
# Fetch the SED at $z=1$

# %%
z_test = 1

# %%
fg20_J_nu_test = fetch_sed(z_test, fg20_z_grid, fg20_J_nu_grid)

# %% [markdown]
# Specify $N_{\mathrm{HI}}$ grid points and get corresponding filenames

# %%
logN_HI_min = 12
logN_HI_max = 17
logN_HI_step = 0.25

logN_HI_arr = np.arange(logN_HI_min, logN_HI_max+logN_HI_step, logN_HI_step)

# %%
file_list = create_grid_file_list(logN_HI_arr)

# %% [markdown]
# Specify grid points for densities and metallicities

# %%
log_hdens_min = -5
log_hdens_max = 1
log_hdens_step = 0.25

log_hdens_arr = np.arange(log_hdens_min, log_hdens_max+log_hdens_step, log_hdens_step)
logU_arr = np.log10(calc_U(fg20_wav_grid, fg20_J_nu_test, 10**log_hdens_arr))

# %%
log_metals_min = -3
log_metals_max = 1
log_metals_step = 0.25

log_metals_arr = np.arange(log_metals_min, log_metals_max+log_metals_step, log_metals_step)

# %% [markdown]
# Load the final grid

# %%
pkl_file = open(rootdir+'final_grid.pkl', 'rb')
species_logN_samples = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# Interpolate this grid

# %%
species_logN_interp = {}

for s in list(species_logN_samples.keys()):
    
    species_logN_samples[s][species_logN_samples[s]==-np.inf] = -99
    
    species_logN_interp[s] = RegularGridInterpolator((logN_HI_arr, log_hdens_arr, log_metals_arr), 
                                                     species_logN_samples[s])

# %% [markdown]
# # Component 1

# %% [markdown]
# Enter measurements for species

# %%
logN_dict = {'HI':'16.42, -0.14, +0.14',
            #'HeI':'14.49, -0.05, +0.05',
            'CIII':'>12.78, 0.36',
            'CIV':'13.49, -0.02, +0.02',
            'OII':'<13.59',
            'OIII':'14.22, -0.07, +0.07',
            'OIV':'14.41, -0.05, +0.05',
            'OV':'13.64, -0.13, +0.13',
            'OVI':'<13.31',
            'NeVIII':'<13.35',
            'MgII':'<15.29',
            'MgX':'<13.46',
            'AlII':'<11.00',
            'AlIII':'<11.50',
            'SiII':'<12.03',
            'FeII':'<11.64'}

# %% [markdown]
# Try out a solution including sub-solar [C/O], [N/O], [S/O]

# %%
logN_HI_test = 16.42
log_hdens_test = -3.25 #-4.7 
O_H_test = -2.24 #-2.99
C_O_test = -0.1
log_metals_test = get_metal_abundance(O_H_test, {'C': C_O_test})

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp, {'C': C_O_test})

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Define overridden priors, likelihood, and posterior

# %%
def lambda_log_prior(params):
    
    # Only parameters being varied
    logN_HI_test, log_hdens, O_H, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, O_H, {'C': C_O}])
    
    # Call the original prior function on the full set of parameters
    return log_prior(params_full)

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    logN_HI_test, log_hdens, O_H, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, O_H, {'C': C_O}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Time to fit!

# %%
pos = np.array([logN_HI_test, log_hdens_test, O_H_test, C_O_test]) + 1e-6*np.random.randn(500, 4)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 500, progress=True);
# Out:
# 100%|█████████████████████████████████████████| 500/500 [13:24<00:00,  1.61s/it]

# %%
flat_samples_subsolar = pd.DataFrame(sampler.get_chain(discard=100, flat=True), columns=['logN_HI', 'log_hdens', '[O/H]', '[C/O]'])
flat_samples_subsolar.to_csv(savedir+'c1_subsolar_flat.csv', index=False)

#flat_samples_subsolar = pd.read_csv(savedir+'c1_subsolar_flat.csv')

# %%
flat_samples_subsolar['[M/H]'] = [get_metal_abundance(flat_samples_subsolar.iloc[i]['[O/H]'], 
                                                   {'C': flat_samples_subsolar.iloc[i]['[C/O]']}) for 
                               i in range(len(flat_samples_subsolar))]

# %%
fig = corner.corner(
    flat_samples_subsolar.loc[:, ['logN_HI', 'log_hdens', '[O/H]', '[C/O]']], 
    quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_{\mathrm{HI}})$', r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$', 
            r'$[\mathrm{C/O}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
plt.hist(flat_samples_subsolar['[M/H]'])
# Out:
# (array([  498.,  3862., 14036., 33096., 54065., 50679., 32303.,  9818.,
#          1519.,   124.]),
#  array([-2.9886399 , -2.81669961, -2.64475932, -2.47281903, -2.30087874,
#         -2.12893845, -1.95699816, -1.78505787, -1.61311758, -1.44117729,
#         -1.269237  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Overplot fit samples

# %%
logN_dict = {'HI':'16.42, -0.14, +0.14',
            'HeI':'14.49, -0.05, +0.05',
            'CIII':'>12.78, 0.36',
            'CIV':'13.49, -0.02, +0.02',
            'OII':'<13.59',
            'OIII':'14.22, -0.07, +0.07',
            'OIV':'14.41, -0.05, +0.05',
            'OV':'13.64, -0.13, +0.13',
            'OVI':'<13.31',
            'NeVIII':'<13.35',
            'MgII':'<15.29',
            'MgX':'<13.46',
            'AlII':'<11.00',
            'AlIII':'<11.50',
            'SiII':'<12.03',
            'FeII':'<11.64',
            'SiIII':'12.63, -0.07, +0.07'}

# %%
sample_indices_subsolar = np.random.randint(low=0, high=len(flat_samples_subsolar), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HeI', 'SiIII'])

for i in range(len(sample_indices_subsolar)):
    
    idx = sample_indices_subsolar[i]
    flat_samples_row = flat_samples_subsolar.iloc[i]
    logN_HI = flat_samples_row['logN_HI']
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['[M/H]']
    C_O = flat_samples_row['[C/O]']
    
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI, log_hdens, 
                                         log_metals, species_logN_interp, {'C': C_O})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

logN_species_alt = predict_col_dens(logN_dict, logN_HI_test, -4.7, 
                                         -2.99, species_logN_interp)
    
ax.plot(np.arange(len(logN_species_alt)), logN_species_alt, color='darkolivegreen', lw=2, alpha=.5,
       label=r'$\log(n_\mathrm{H})=-4.7, \ [\mathrm{O}/\mathrm{H}]=-2.99$')
    
ax.text(x=0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.25 \pm 0.13$')
ax.text(x=0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -2.11 \pm 0.24$,')
ax.text(x=3.5, y=16.5, s=r'$[\mathrm{C}/\mathrm{O}] = -0.19 \pm 0.05$')

ax.legend()

plt.savefig(savedir+'z=1_1659134_c1_cloudy.pdf', dpi=300)

# %% [markdown]
# Plot the posterior for cloud size

# %%
flat_samples_subsolar['cloud_size_pc'] = (10**flat_samples_subsolar['logN_HI']/10**flat_samples_subsolar['log_hdens'])*3.24078e-19

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.hist(flat_samples_subsolar['cloud_size_pc'], bins=200, density=True, color='peachpuff')

ax.set_xlabel('Cloud size (pc)')
ax.set_ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# Finally save dataframe again

# %%
flat_samples_subsolar.to_csv(savedir+'c1_subsolar_flat.csv', index=False)

# %% [markdown]
# # Component 2

# %%
logN_dict = {'HI':'14.64, -0.15, +0.15',
            'HeI':'<12.93',
            'CIII':'<13.00',
            'CIV':'13.03, -0.06, 0.06',
            'OII':'<13.79',
            'OIII':'<13.38',
            'OIV':'13.85, -0.09, +0.09',
            'OV':'13.83, -0.05, +0.05',
            'OVI':'13.75, -0.12, +0.12',
            'NeVIII':'<13.56',
            'MgII':'<15.55',
            'MgX':'<13.67',
            'AlII':'<11.20',
            'AlIII':'<11.71',
            'SiII':'<12.29',
            'FeII':'<11.85'}

# %% [markdown]
# Try out a solution including sub-solar [C/O], [N/O], [S/O]

# %%
logN_HI_test = 14.64
log_hdens_test = -3.7 #-1.7  
O_H_test = -1.2 #-1.0  
C_O_test = -0.2
log_metals_test = get_metal_abundance(O_H_test, {'C': C_O_test})

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp, {'C': C_O_test})

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Define overridden priors, likelihood, and posterior

# %%
def lambda_log_prior(params):
    
    # Only parameters being varied
    logN_HI, log_hdens, O_H, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, O_H, {'C': C_O}])
    
    # Call the original prior function on the full set of parameters
    return log_prior(params_full)

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    logN_HI, log_hdens, O_H, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, O_H, {'C': C_O}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Time to fit!

# %%
pos = np.array([logN_HI_test, log_hdens_test, O_H_test, C_O_test]) + 1e-6 * np.random.randn(250, 4)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 250, progress=True);
# Out:
# 100%|█████████████████████████████████████████| 250/250 [03:36<00:00,  1.15it/s]

# %%
flat_samples_subsolar = pd.DataFrame(sampler.get_chain(discard=100, flat=True), columns=['logN_HI', 'log_hdens', '[O/H]', '[C/O]'])
flat_samples_subsolar.to_csv(savedir+'c2_subsolar_flat.csv', index=False)

#flat_samples_subsolar = pd.read_csv(savedir+'c2_subsolar_flat.csv')

# %%
flat_samples_subsolar['[M/H]'] = [get_metal_abundance(flat_samples_subsolar.iloc[i]['[O/H]'], 
                                                   {'C': flat_samples_subsolar.iloc[i]['[C/O]']}) for 
                               i in range(len(flat_samples_subsolar))]

# %%
fig = corner.corner(
    flat_samples_subsolar.loc[:, ['logN_HI', 'log_hdens', '[O/H]', '[C/O]']], 
    quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_{\mathrm{HI}})$', r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$', 
            r'$[\mathrm{C/O}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Overplot fit samples

# %%
sample_indices_subsolar = np.random.randint(low=0, high=len(flat_samples_subsolar), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(len(sample_indices_subsolar)):
    
    idx = sample_indices_subsolar[i]
    flat_samples_row = flat_samples_subsolar.iloc[i]
    logN_HI = flat_samples_row['logN_HI']
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['[M/H]']
    C_O = flat_samples_row['[C/O]']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI, log_hdens, 
                                         log_metals, species_logN_interp, {'C': C_O})

    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)
    
ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -4.08 \pm 0.09$')
ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -1.71 \pm 0.25$')

ax.text(x=len(logN_species_test)-4.0, y=17.3, s=r'$[\mathrm{C}/\mathrm{O}] = 0.12 \pm 0.13$')

plt.savefig(savedir+'z=1_1659134_c2_cloudy.pdf', dpi=300)

# %% [markdown]
# Plot the posterior for cloud size

# %%
flat_samples_subsolar['cloud_size_pc'] = (10**flat_samples_subsolar['logN_HI']/10**flat_samples_subsolar['log_hdens'])*3.24078e-19

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.hist(flat_samples_subsolar['cloud_size_pc'], bins=200, density=True, color='peachpuff')

ax.set_xlabel('Cloud size (pc)')
ax.set_ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# Finally save the dataframe again

# %%
flat_samples_subsolar.to_csv(savedir+'c2_subsolar_flat.csv', index=False)
