# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd
from cloudy_fit_lib import *
from scipy.interpolate import RegularGridInterpolator
import pickle
import corner
from scipy import integrate, interpolate
import emcee

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/cloudy_grids/'

# %%
savedir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z=1.27767328/cloudy_fits/'

# %% [markdown]
# Obtain the UVB grid from FG20

# %%
fg20_z_grid, fg20_wav_grid, fg20_J_nu_grid = read_uvb('', 'fg20_galaxy.ascii')

# %% [markdown]
# Fetch the SED at $z=1$

# %%
z_test = 1

# %%
fg20_J_nu_test = fetch_sed(z_test, fg20_z_grid, fg20_J_nu_grid)

# %% [markdown]
# Specify $N_{\mathrm{HI}}$ grid points and get corresponding filenames

# %%
logN_HI_min = 12
logN_HI_max = 17
logN_HI_step = 0.25

logN_HI_arr = np.arange(logN_HI_min, logN_HI_max+logN_HI_step, logN_HI_step)

# %%
file_list = create_grid_file_list(logN_HI_arr)

# %% [markdown]
# Specify grid points for densities and metallicities

# %%
log_hdens_min = -5
log_hdens_max = 1
log_hdens_step = 0.25

log_hdens_arr = np.arange(log_hdens_min, log_hdens_max+log_hdens_step, log_hdens_step)
logU_arr = np.log10(calc_U(fg20_wav_grid, fg20_J_nu_test, 10**log_hdens_arr))

# %%
log_metals_min = -3
log_metals_max = 1
log_metals_step = 0.25

log_metals_arr = np.arange(log_metals_min, log_metals_max+log_metals_step, log_metals_step)

# %% [markdown]
# Load the final grid

# %%
pkl_file = open(rootdir+'final_grid.pkl', 'rb')
species_logN_samples = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# Interpolate this grid

# %%
species_logN_interp = {}

for s in list(species_logN_samples.keys()):
    
    species_logN_samples[s][species_logN_samples[s]==-np.inf] = -99
    
    species_logN_interp[s] = RegularGridInterpolator((logN_HI_arr, log_hdens_arr, log_metals_arr), 
                                                     species_logN_samples[s])

# %% [markdown]
# # Component 1

# %% [markdown]
# Enter measurements for species

# %%
logN_dict = {'HI':'14.08, -0.06, +0.06',
            'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'13.0, -0.2, +0.1',
            'CIV':'13.65, -0.01, +0.01',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'13.0, -0.1, +0.1',
            'OIII':'13.82, -0.09, +0.09',
            'OIV':'14.43, -0.04, +0.04',
            'NeV':'14.21, -0.05, +0.05',
            'NeVI':'14.20, -0.05, +0.05',
            'NeVIII':'<13.3',
            'MgX':'<13.3',
            'AlII':'<10.7',
            'AlIII':'<11.2',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            'SVI':'<12.8',
            'FeII':'<11.8',}

# %% [markdown]
# Try out a solution

# %%
logN_HI_test = 14.08
log_hdens_test = -3.67
log_metals_test = -0.29

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp)

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['CII'], logN_dict['CIII'])
# Out:
# '<0.10, 0.17'

# %%
logN_ratio_dict = {#'SV/OIII': '<-1.5, 0.2',
                   #'SIV/OIII': '<-1.2, 0.2',
                   #'SiIV/OIII': '<-2.1, 0.2',
                   #'SiII/OIII': '<0.0, 0.2',
                   #'CII/CIII': '<0.1, 0.2'}
                   #'NeV/OIV': '-0.22, -0.06, 0.06'}
                   #'CII/CIII': '<0.1, 0.2'}
                   #'NeV/OIV': '-0.22, -0.06, 0.06',
                   #'NeVI/OIV': '-0.23, -0.06, 0.06'}
                   #'SVI/OIV': '<-1.6, 0.2',
                   #'SV/OIV': '<-2.1, 0.2'}
                   #'OIII/CIII': '0.8, -0.2, 0.1',
                   #'OIV/CIV': '0.78, -0.04, 0.04',}
                   #'OIV/NIV': '1.4, -0.1, 0.1'}
                   'OIV/OIII': '0.6, -0.1, 0.1',
                   'CIV/CIII': '0.6, -0.2, 0.1'}
                   #'NII/NIV': '<0.1, 0.2',
                   #'NIII/NIV': '<-0.2, 0.2'}

# %% [markdown]
# Generate predicted column density ratios

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict)

ax.set_xlim(-5, -1)
ax.set_ylim(-5, 2)
# Out:
# (-5.0, 2.0)

# %% [markdown]
# # Fit gas density (low ion phase)

# %%
logN_dict = {'HI':'14.08, -0.06, +0.06',
            'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'13.0, -0.2, +0.1',
            'CIV':'<13.68',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'<13.3',
            'OIII':'13.82, -0.09, +0.09',
            'OIV':'<14.55',
            'NeV':'14.21, -0.05, +0.05',
            'NeVI':'14.20, -0.05, +0.05',
            'NeVIII':'<13.3',
            'MgX':'<13.3',
            'AlII':'<10.7',
            'AlIII':'<11.2',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            'SVI':'<12.8',
            'FeII':'<11.8',}

# %% [markdown]
# Try out a solution

# %%
logN_HI_test = 14.08
log_hdens_test = -3.67
log_metals_test = -0.29

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp)

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['SiII'], logN_dict['OIII'])
# Out:
# '<0.08, 0.17'

# %%
logN_ratio_dict = {'SV/OIII': '<-1.5, 0.2',
                   'SIV/OIII': '<-1.2, 0.2',
                   'CII/CIII': '<0.1, 0.2',
                   'OIV/OIII': '<0.7, 0.2',
                   'CIV/CIII': '<0.7, 0.2',}
                   #'SiIV/OIII': '<-2.1, 0.2',
                   #'SiII/OIII': '<0.1, 0.2'}

# %% [markdown]
# Generate predicted column density ratios

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict)

ax.set_xlim(-5, -1)
ax.set_ylim(-5, 2)
# Out:
# (-5.0, 2.0)

# %%
def lambda_log_prior_hdens(log_hdens):
    
    '''
    Priors for an MCMC search. 
    '''
   
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if -4<log_hdens<log_hdens_max:
        return 0.0
    return -np.inf

# %%
def log_probability(params, logN_ratio_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    log_hdens = params[0]
    
    lp = lambda_log_prior_hdens(log_hdens)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_hdens(log_hdens, logN_ratio_dict, species_logN_interp)

# %%
logN_ratio_dict
# Out:
# {'SV/OIII': '<-1.5, 0.2',
#  'SIV/OIII': '<-1.2, 0.2',
#  'CII/CIII': '<0.1, 0.2',
#  'OIV/OIII': '<0.7, 0.2',
#  'CIV/CIII': '<0.7, 0.2'}

# %%
pos = np.array(-2) + 1e-4 * np.random.randn(500, 1)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_ratio_dict, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 500, progress=True);
# Out:
#   6%|██▎                                       | 28/500 [00:32<09:05,  1.16s/it]/Users/thepoetoftwilight/Documents/CUBS/Code/cloudy_fitting/cloudy_fit_lib.py:760: RuntimeWarning: divide by zero encountered in log
#   ll += np.log(integrate.simpson(x=y_range, y=np.exp(-.5*(y_range-y_bar)**2/sig_y**2)))
# 100%|█████████████████████████████████████████| 500/500 [09:39<00:00,  1.16s/it]

# %%
flat_samples_hdens = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
                                columns=['log_hdens'])

# %%
fig = corner.corner(
    flat_samples_hdens, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
grid_points_hdens = np.array([[12, log_hdens, -3] for log_hdens in flat_samples_hdens['log_hdens']])

# %%
logN_offset = 13.82-np.median(species_logN_interp['O+2'](grid_points_hdens))

# %% [markdown]
# Calculate C/O ratio

# %%
logN_CIII_obs = np.random.normal(loc=13.0, scale=0.2, size=len(flat_samples_hdens))

# %%
C_O_dist_CIII = logN_CIII_obs-(logN_offset+species_logN_interp['C+2'](grid_points_hdens))
C_O_dist = C_O_dist_CIII

# %%
(np.round(np.median(C_O_dist), 2), 
np.round(np.percentile(C_O_dist, 100*(1-cdf_1sig))-np.median(C_O_dist), 2),
np.round(np.percentile(C_O_dist, 100*cdf_1sig)-np.median(C_O_dist), 2))
# Out:
# (-0.56, -0.7, 0.85)

# %% [markdown]
# Calculate NIV yield

# %%
logN_NIV_samples = species_logN_interp['N+3'](grid_points_hdens)+logN_offset

# %%
logN_NIV_med = np.median(logN_NIV_samples)
logN_NIV_sig = logN_NIV_med-np.percentile(logN_NIV_samples, 100*(1-cdf_1sig))

# %%
np.round(logN_NIV_med, 2), np.round(logN_NIV_sig, 2)
# Out:
# (11.97, 2.06)

# %% [markdown]
# Calculate CIV yield

# %%
logN_CIV_samples = species_logN_interp['C+3'](grid_points_hdens)+logN_offset

# %%
logN_CIV_med = np.median(logN_CIV_samples)
logN_CIV_sig = logN_CIV_med-np.percentile(logN_CIV_samples, 100*(1-cdf_1sig))

# %%
np.round(logN_CIV_med, 2), np.round(logN_CIV_sig, 2)
# Out:
# (12.23, 1.79)

# %% [markdown]
# Calculate OIV yield

# %%
logN_OIV_samples = species_logN_interp['O+3'](grid_points_hdens)+logN_offset

# %%
logN_OIV_med = np.median(logN_OIV_samples)
logN_OIV_sig = logN_OIV_med-np.percentile(logN_OIV_samples, 100*(1-cdf_1sig))

# %%
np.round(logN_OIV_med, 2), np.round(logN_OIV_sig, 2)
# Out:
# (12.91, 2.26)

# %% [markdown]
# Plot models

# %%
logN_dict = {#'HI':'14.08, -0.06, +0.06',
            #'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'13.0, -0.2, +0.1',
            'CIV':'13.65, -0.01, +0.01',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'13.0, -0.1, +0.1',
            'OIII':'13.82, -0.09, +0.09',
            'OIV':'14.43, -0.04, +0.04',
            #'NeV':'14.21, -0.05, +0.05',
            #'NeVI':'14.20, -0.05, +0.05',
            #'NeVIII':'<13.3',
            #'MgX':'<13.3',
            #'AlII':'<10.7',
            #'AlIII':'<11.2',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            #'SVI':'<12.8',
            'FeII':'<11.8',}

# %%
sample_indices_hdens = np.random.randint(low=0, high=len(flat_samples_hdens), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

ax.errorbar(x=11, y=12, yerr=2, color='black', linestyle='None', mfc='white',
        fmt='o', markersize=3, capsize=4)

ax.errorbar(x=12, y=12, yerr=2, color='black', linestyle='None', mfc='white',
        fmt='o', markersize=3, capsize=4)

ax.errorbar(x=13, y=13, yerr=2, color='black', linestyle='None', mfc='white',
        fmt='o', markersize=3, capsize=4)

for i in range(len(sample_indices_hdens)):
    
    idx = sample_indices_hdens[i]
    flat_samples_row = flat_samples_hdens.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    
    logN_species_test = predict_col_dens(logN_dict, 12, log_hdens, 
                                         -3, species_logN_interp, {'C': np.median(C_O_dist)})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), 
            np.array(logN_species_test)+logN_offset,
            color='darkorange', lw=.2, alpha=.3)

# %% [markdown]
# Calculate residual for NIV

# %%
logN_NIV_tot = np.random.normal(loc=13.0, scale=0.1, size=1000)
logN_NIV_hi_dens = np.random.normal(loc=12, scale=2, size=1000)
logN_NIV_lo_dens = np.log10(10**logN_NIV_tot - 10**logN_NIV_hi_dens)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_52917/1311929848.py:3: RuntimeWarning: invalid value encountered in log10
#   logN_NIV_lo_dens = np.log10(10**logN_NIV_tot - 10**logN_NIV_hi_dens)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(logN_NIV_tot, label='total (obs)', alpha=0.5)
ax.hist(logN_NIV_hi_dens, label='hi-dens (model)', alpha=0.5)
ax.hist(logN_NIV_lo_dens, label='lo-dens (res)', alpha=0.5)

ax.set_xlabel(r'$\log N_{\mathrm{NIV}}$')
ax.set_ylabel('Counts')

#ax.set_xlim(13.81,14.39)
ax.legend(loc='upper left')

# %%
logN_NIV_lo_dens_clean = logN_NIV_lo_dens[~np.isnan(logN_NIV_lo_dens)]

# %%
logN_NIV_lo_dens_med = np.median(logN_NIV_lo_dens_clean)
logN_NIV_lo_dens_1sig_lo = logN_NIV_lo_dens_med-np.percentile(logN_NIV_lo_dens_clean, 100*(1-cdf_1sig))
logN_NIV_lo_dens_1sig_hi = np.percentile(logN_NIV_lo_dens_clean, 100*cdf_1sig)-logN_NIV_lo_dens_med

# %%
np.round(logN_NIV_lo_dens_med, 2), np.round(logN_NIV_lo_dens_1sig_lo, 2), np.round(logN_NIV_lo_dens_1sig_hi, 2)
# Out:
# (12.96, 0.15, 0.11)

# %% [markdown]
# Calculate residual for CIV

# %%
logN_CIV_tot = np.random.normal(loc=13.65, scale=0.01, size=1000)
logN_CIV_hi_dens = np.random.normal(loc=12, scale=2, size=1000)
logN_CIV_lo_dens = np.log10(10**logN_CIV_tot - 10**logN_CIV_hi_dens)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_52917/598202148.py:3: RuntimeWarning: invalid value encountered in log10
#   logN_CIV_lo_dens = np.log10(10**logN_CIV_tot - 10**logN_CIV_hi_dens)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(logN_CIV_tot, label='total (obs)', alpha=0.5)
ax.hist(logN_CIV_hi_dens, label='hi-dens (model)', alpha=0.5)
ax.hist(logN_CIV_lo_dens, label='lo-dens (res)', alpha=0.5)

ax.set_xlabel(r'$\log N_{\mathrm{CIV}}$')
ax.set_ylabel('Counts')

#ax.set_xlim(13.81,14.39)
ax.legend(loc='upper left')

# %%
logN_CIV_lo_dens_clean = logN_CIV_lo_dens[~np.isnan(logN_CIV_lo_dens)]

# %%
logN_CIV_lo_dens_med = np.median(logN_CIV_lo_dens_clean)
logN_CIV_lo_dens_1sig_lo = logN_CIV_lo_dens_med-np.percentile(logN_CIV_lo_dens_clean, 100*(1-cdf_1sig))
logN_CIV_lo_dens_1sig_hi = np.percentile(logN_CIV_lo_dens_clean, 100*cdf_1sig)-logN_CIV_lo_dens_med

# %%
np.round(logN_CIV_lo_dens_med, 2), np.round(logN_CIV_lo_dens_1sig_lo, 2), np.round(logN_CIV_lo_dens_1sig_hi, 2)
# Out:
# (13.64, 0.09, 0.01)

# %% [markdown]
# Calculate residual for OIV

# %%
logN_OIV_tot = np.random.normal(loc=14.43, scale=0.04, size=1000)
logN_OIV_hi_dens = np.random.normal(loc=12, scale=2, size=1000)
logN_OIV_lo_dens = np.log10(10**logN_OIV_tot - 10**logN_OIV_hi_dens)
# Out:
# /var/folders/tj/vc_wjrpj36sf3zws4s7s770c0000gn/T/ipykernel_52917/3628844815.py:3: RuntimeWarning: invalid value encountered in log10
#   logN_OIV_lo_dens = np.log10(10**logN_OIV_tot - 10**logN_OIV_hi_dens)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

ax.hist(logN_OIV_tot, label='total (obs)', alpha=0.5)
ax.hist(logN_OIV_hi_dens, label='hi-dens (model)', alpha=0.5)
ax.hist(logN_OIV_lo_dens, label='lo-dens (res)', alpha=0.5)

ax.set_xlabel(r'$\log N_{\mathrm{OIV}}$')
ax.set_ylabel('Counts')

#ax.set_xlim(13.81,14.39)
ax.legend(loc='upper left')

# %%
logN_OIV_lo_dens_clean = logN_OIV_lo_dens[~np.isnan(logN_OIV_lo_dens)]

# %%
logN_OIV_lo_dens_med = np.median(logN_OIV_lo_dens_clean)
logN_OIV_lo_dens_1sig_lo = logN_OIV_lo_dens_med-np.percentile(logN_OIV_lo_dens_clean, 100*(1-cdf_1sig))
logN_OIV_lo_dens_1sig_hi = np.percentile(logN_OIV_lo_dens_clean, 100*cdf_1sig)-logN_OIV_lo_dens_med

# %%
np.round(logN_OIV_lo_dens_med, 2), np.round(logN_OIV_lo_dens_1sig_lo, 2), np.round(logN_OIV_lo_dens_1sig_hi, 2)
# Out:
# (14.42, 0.06, 0.04)

# %% [markdown]
# # Fit gas density (high ion phase)

# %%
logN_dict = {'HI':'14.08, -0.06, +0.06',
            'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'<13.3',
            'CIV':'13.64, -0.09, +0.01',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'13.0, -0.2, +0.1',
            'OIII':'<14.09',
            'OIV':'14.42, -0.06, +0.04',
            'NeV':'<14.36',
            'NeVI':'<14.35',
            'NeVIII':'<13.3',
            'MgX':'<13.3',
            'AlII':'<10.7',
            'AlIII':'<11.2',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            'SVI':'<12.8',
            'FeII':'<11.8',}

# %% [markdown]
# Plot column density ratios

# %%
logN_HI_test = 14.08
log_hdens_test = -3.67
log_metals_test = -0.29

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp)

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['NIII'], logN_dict['NIV'])
# Out:
# '<-0.20, 0.17'

# %%
logN_ratio_dict = {'NeV/OIV': '<-0.1, 0.2',
                   'NeVI/OIV': '<-0.1, 0.2',
                   'OIII/OIV': '<-0.3, 0.2',
                   'CIII/CIV': '<-0.3, 0.1',
                   'NIII/NIV': '<-0.2, 0.2'}

# %% [markdown]
# Generate predicted column density ratios

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict)

ax.set_xlim(-5, -1)
ax.set_ylim(-5, 2)
# Out:
# (-5.0, 2.0)

# %%
def lambda_log_prior_hdens(log_hdens):
    
    '''
    Priors for an MCMC search. 
    '''
   
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if log_hdens_min<log_hdens<log_hdens_max:
        return 0.0
    return -np.inf

# %%
def log_probability(params, logN_ratio_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    log_hdens = params[0]
    
    lp = lambda_log_prior_hdens(log_hdens)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_hdens(log_hdens, logN_ratio_dict, species_logN_interp)

# %%
logN_ratio_dict
# Out:
# {'NeV/OIV': '<-0.1, 0.2',
#  'NeVI/OIV': '<-0.1, 0.2',
#  'OIII/OIV': '<-0.3, 0.2',
#  'CIII/CIV': '<-0.3, 0.1',
#  'NIII/NIV': '<-0.2, 0.2'}

# %%
pos = np.array(-3.8) + 1e-4 * np.random.randn(500, 1)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_ratio_dict, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 500, progress=True);
# Out:
# 100%|█████████████████████████████████████████| 500/500 [09:47<00:00,  1.18s/it]

# %%
flat_samples_hdens = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
                                columns=['log_hdens'])

# %%
fig = corner.corner(
    flat_samples_hdens, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
grid_points_hdens = np.array([[12, log_hdens, -3] for log_hdens in flat_samples_hdens['log_hdens']])

# %%
logN_offset = 14.42-np.median(species_logN_interp['O+3'](grid_points_hdens))

# %% [markdown]
# Calculate the C/O ratio

# %%
logN_CIV_obs = np.random.normal(loc=13.64, scale=0.07, size=len(flat_samples_hdens))

# %%
C_O_dist_CIV = logN_CIV_obs-(logN_offset+species_logN_interp['C+3'](grid_points_hdens))
C_O_dist = C_O_dist_CIV

# %%
(np.round(np.median(C_O_dist), 2), 
np.round(np.percentile(C_O_dist, 100*(1-cdf_1sig))-np.median(C_O_dist), 2),
np.round(np.percentile(C_O_dist, 100*cdf_1sig)-np.median(C_O_dist), 2))
# Out:
# (0.15, -0.08, 0.08)

# %% [markdown]
# Compute N/O ratio

# %%
logN_NIV_obs = np.random.normal(loc=13.0, scale=0.1, size=len(flat_samples_hdens))

# %%
N_O_dist_NIV = logN_NIV_obs-(logN_offset+species_logN_interp['N+3'](grid_points_hdens))
N_O_dist = N_O_dist_NIV

# %%
(np.round(np.median(N_O_dist), 2), 
np.round(np.percentile(N_O_dist, 100*(1-cdf_1sig))-np.median(N_O_dist), 2),
np.round(np.percentile(N_O_dist, 100*cdf_1sig)-np.median(N_O_dist), 2))
# Out:
# (-0.6, -0.11, 0.11)

# %% [markdown]
# Plot models

# %%
logN_dict = {#'HI':'14.08, -0.06, +0.06',
            #'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'13.0, -0.2, +0.1',
            'CIV':'13.64, -0.07, +0.02',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'13.0, -0.1, +0.1',
            'OIII':'13.82, -0.09, +0.09',
            'OIV':'14.42, -0.05, +0.05',
            'NeV':'14.21, -0.05, +0.05',
            'NeVI':'14.20, -0.05, +0.05',
            'NeVIII':'<13.3',
            'MgX':'<13.3',
            'AlII':'<10.7',
            'AlIII':'<11.2',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            'SVI':'<12.8',
            'FeII':'<11.8',}

# %%
sample_indices_hdens = np.random.randint(low=0, high=len(flat_samples_hdens), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(200):
    
    log_hdens_2 = np.random.normal()
    log_hdens_1 = np.random.normal(loc=-4.2, scale=0.1)
    
    logN_species_test = predict_col_dens(logN_dict, 12, log_hdens_1, 
                                         -3, species_logN_interp, {'C': np.median(0.15),
                                                                   'N': np.median(-0.6)})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), 
            np.array(logN_species_test)+logN_offset,
            color='skyblue', lw=.2, alpha=.3)

# %% [markdown]
# # Oxygen + Sulphur fit

# %%
# Assume solar abundance patterns throughout

def lambda_log_prior(params):
    
    # Only parameters being varied
    log_hdens, log_metals = params
    
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if log_hdens_min<log_hdens<log_hdens_max and log_metals_min<log_metals<log_metals_max:
        return 0.0
    return -np.inf

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    log_hdens, log_metals = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, log_metals, {}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Isolate the ions

# %%
ions_oxy_sul = ['OIII', 'OIV', 'SIV', 'SV', 'SVI']

# %%
logN_dict_oxy_sul = {ion: logN_dict[ion] for ion in ions_oxy_sul}

# %%
logN_dict_oxy_sul
# Out:
# {'OIII': '13.82, -0.09, +0.09',
#  'OIV': '14.43, -0.04, +0.04',
#  'SIV': '<12.6',
#  'SV': '<12.3',
#  'SVI': '<12.8'}

# %%
pos = np.array([log_hdens_test, log_metals_test]) + 1e-4 * np.random.randn(500, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_oxy_sul, species_logN_interp)
)

# %%
#sampler.run_mcmc(pos, 500, progress=True)

# %%
#flat_samples_oxy_sul = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens', 'log_metals'])
#flat_samples_oxy_sul.to_csv(savedir+'oxy_sul_solar_flat_c1.csv', index=False)

flat_samples_oxy_sul = pd.read_csv(savedir+'oxy_sul_solar_flat_c1.csv')

# %%
fig = corner.corner(
    flat_samples_oxy_sul.loc[:, ['log_hdens', 'log_metals']], quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI' : '14.11, -0.07, +0.07',
            'HeI' : '<13.0',
            'CII' : '<13.4',
            'CIII' : '12.8, -0.2, +0.2',
            'CIV' : '13.65, -0.01, +0.01',
            'NII' : '<13.4',
            'NIII' : '<13.0',
            'NIV' : '13.0, -0.1, +0.1',
            'OIII' : '13.79, -0.09, +0.09',
            'OIV' : '14.49, -0.04, +0.04',
            'NeV' : '14.16, -0.05, +0.05',
            'NeVI' : '14.18, -0.05, +0.05',
            'NeVIII' : '<13.5',
            'MgX' : '<13.5',
            'AlII' : '<11.0',
            'AlIII' : '<11.5',
            'SiII' : '<14.3',
            'SiIII' : '<12.0',
            'SiIV' : '<12.0',
            'SIV' : '<12.9',
            'SV' : '<12.6',
            'SVI' : '<13.1',
            'FeII' : '<11.7'}

# %%
sample_indices_oxy_sul = np.random.randint(low=0, high=len(flat_samples_oxy_sul), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'HeI', 'CII', 'CIII',  'CIV', 
                                                         'NII', 'NIII', 'NIV', 'NeV',
                                                         'NeVI', 'NeVIII', 'MgX', 'AlII', 'AlIII',
                                                         'SiII', 'SiIII', 'SiIV', 'FeII'])

for i in range(len(sample_indices_oxy_sul)):
    
    idx = sample_indices_oxy_sul[i]
    flat_samples_row = flat_samples_oxy_sul.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens, 
                                         log_metals, species_logN_interp)

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.44 \pm 0.11$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = 0.06_{-0.06}^{+0.07}$')

#plt.savefig(savedir+'z=0_72882224_cloudy_oxy.pdf', dpi=300)

# %% [markdown]
# Plot the posterior for cloud size

# %%
flat_samples_oxy_sul['logN_HII'] = [species_logN_interp['H+']([logN_HI_test,
                                                            flat_samples_oxy_sul.iloc[i]['log_hdens'],
                                                            flat_samples_oxy_sul.iloc[i]['log_metals']])[0]
                                               for i in range(len(flat_samples_oxy_sul))]

# %%
flat_samples_oxy_sul['cloud_size_kpc'] = ((10**logN_HI_test+10**flat_samples_oxy_sul['logN_HII'])/10**flat_samples_oxy_sul['log_hdens'])*3.24078e-19*1e-3

# %%
l_med = np.median(flat_samples_oxy_sul['cloud_size_kpc'])
l_perc_16 = np.percentile(flat_samples_oxy_sul['cloud_size_kpc'],16)
l_perc_84 = np.percentile(flat_samples_oxy_sul['cloud_size_kpc'],84)

# %%
l_med, l_med-l_perc_16, l_perc_84-l_med
# Out:
# (0.9196330689321923, 0.3518700674986034, 0.48023247062922225)

# %%
#np.percentile(flat_samples_oxy['cloud_size_kpc'],100*cdf_3sig)

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.hist(flat_samples_oxy_sul['cloud_size_kpc'], bins=150, density=True, color='coral', alpha=.8)
#ax.axvline(l_med, linestyle=':', lw=2)
#ax.axvline(l_perc_16, linestyle=':', lw=2)
#ax.axvline(l_perc_84, linestyle=':', lw=2)

#ax.text(140, 0.03, s=r'$\log N_{\mathrm{HI}} = 16.64 \pm 0.01$')
#ax.text(140, 0.022, s=r'$l < 200 \ \mathrm{kpc}$')

ax.set_xlabel('Cloud size (kpc)')
ax.set_ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# # Oxygen + Sulphur + Carbon

# %%
# Assume solar abundance patterns throughout

def lambda_log_prior(params):
    
    # Only parameters being varied
    log_hdens, log_metals, C_O = params
    
    # Get abundance for carbon
    C_H = log_metals + C_O
    
    # If the sampled density is within the CLOUDY limits
    # Avoid edges?
    if log_hdens_min<log_hdens<log_hdens_max and log_metals_min<log_metals<log_metals_max and log_metals_min<C_H<log_metals_max:
        return 0.0
    return -np.inf

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    log_hdens, log_metals, C_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI_test, log_hdens, log_metals, {'C': C_O}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Isolate the ions

# %%
ions_oxy_sul_carb = ['OIII', 'OIV', 'SIV', 'SV', 'SVI', 'CIII', 'CIV']

# %%
logN_dict_oxy_sul_carb = {ion: logN_dict[ion] for ion in ions_oxy_sul_carb}

# %%
logN_dict_oxy_sul_carb
# Out:
# {'OIII': '13.79, -0.09, +0.09',
#  'OIV': '14.49, -0.04, +0.04',
#  'SIV': '<12.9',
#  'SV': '<12.6',
#  'SVI': '<13.1',
#  'CIII': '12.8, -0.2, +0.2',
#  'CIV': '13.65, -0.01, +0.01'}

# %%
pos = np.array([log_hdens_test, log_metals_test, -0.8]) + 1e-4 * np.random.randn(500, 3)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_oxy_sul_carb, species_logN_interp)
)

# %%
#sampler.run_mcmc(pos, 500, progress=True)

# %%
#flat_samples_oxy_sul_carb = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens', 'log_metals', 'C_O'])
#flat_samples_oxy_sul_carb.to_csv(savedir+'oxy_sul_carb_subsolar_flat_c1.csv', index=False)

flat_samples_oxy_sul_carb = pd.read_csv(savedir+'oxy_sul_carb_subsolar_flat_c1.csv')

# %%
fig = corner.corner(
    flat_samples_oxy_sul_carb, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$', r'$[\mathrm{C/O}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI' : '14.11, -0.07, +0.07',
            'HeI' : '<13.0',
            'CII' : '<13.4',
            'CIII' : '12.8, -0.2, +0.2',
            'CIV' : '13.65, -0.01, +0.01',
            'NII' : '<13.4',
            'NIII' : '<13.0',
            'NIV' : '13.0, -0.1, +0.1',
            'OIII' : '13.79, -0.09, +0.09',
            'OIV' : '14.49, -0.04, +0.04',
            'NeV' : '14.16, -0.05, +0.05',
            'NeVI' : '14.18, -0.05, +0.05',
            'NeVIII' : '<13.5',
            'MgX' : '<13.5',
            'AlII' : '<11.0',
            'AlIII' : '<11.5',
            'SiII' : '<14.3',
            'SiIII' : '<12.0',
            'SiIV' : '<12.0',
            'SIV' : '<12.9',
            'SV' : '<12.6',
            'SVI' : '<13.1',
            'FeII' : '<11.7'}

# %%
sample_indices_oxy_sul_carb = np.random.randint(low=0, high=len(flat_samples_oxy_sul_carb), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'HeI', 'CII',
                                                         'NII', 'NIII', 'NIV', 'NeV',
                                                         'NeVI', 'NeVIII', 'MgX', 'AlII', 'AlIII',
                                                         'SiII', 'SiIII', 'SiIV', 'FeII'])

for i in range(len(sample_indices_oxy_sul_carb)):
    
    idx = sample_indices_oxy_sul_carb[i]
    flat_samples_row = flat_samples_oxy_sul_carb.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    C_O = flat_samples_row['C_O']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens, 
                                         log_metals, species_logN_interp, {'C':C_O})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.44 \pm 0.11$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = 0.06_{-0.06}^{+0.07}$')

#plt.savefig(savedir+'z=0_72882224_cloudy_oxy.pdf', dpi=300)

# %% [markdown]
# # Two phase solution
#
# If a gas cloud is composed of two phases ($n_{\mathrm{H,1}}$ and $n_{\mathrm{H,2}}$) of corresponding elemental abundances ($\mathrm{[X/H]}_{1}$ and $\mathrm{[X/H]}_{2}$) and HI column densities ($N_{\mathrm{HI, 1}}$ and $N_{\mathrm{HI, 2}}$), then the total ionic column density of $X_i$ can be written as -
#
# $$N_{\mathrm{X_i}} = N_{\mathrm{HI,1}} \times \frac{f_{X_i,1}}{f_{\mathrm{HI,1}}} (n_{\mathrm{H,1}}) \times 10^{[\mathrm{X/H}]_1} + N_{\mathrm{HI, 2}} \times \frac{f_{X_i, 2}}{f_{\mathrm{HI, 2}}} (n_{\mathrm{H,2}}) \times 10^{[\mathrm{X/H}]_2}$$
#
# The other constraining condition is -
#
# $$N_{\mathrm{HI}} = N_{\mathrm{HI, 1}} + N_{\mathrm{HI, 2}}$$
#
# We expect several degeneracies and consequently weaker constraints on each of these parameters.

# %%
logN_HI_p1_test = 14.0
log_hdens_p1_test = -2.5
log_metals_p1_test = 0.5

logN_HI_p2_test = 13.5
log_hdens_p2_test = -4.5
log_metals_p2_test = 0.5

# %%
logN_species_test_p1 = np.array(predict_col_dens(logN_dict, logN_HI_p1_test, log_hdens_p1_test, 
                                     log_metals_p1_test, species_logN_interp))

logN_species_test_p2 = np.array(predict_col_dens(logN_dict, logN_HI_p2_test, log_hdens_p2_test, 
                                     log_metals_p2_test, species_logN_interp))

logN_species_test = np.log10(10**logN_species_test_p1 + 10**logN_species_test_p2)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

ax.plot(np.arange(len(logN_species_test)), logN_species_test_p1, color='gold', label='p1')
ax.plot(np.arange(len(logN_species_test)), logN_species_test_p2, color='skyblue', label='p2')
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='red', label='Total')

ax.legend()

# %% [markdown]
# # Hydrogen + Oxygen + Sulphur fit

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = log_prior_tp(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_tp(params, logN_dict, species_logN_interp)

# %%
ions_hyd_oxy_sul = ['HI', 'OIII', 'OIV', 'SIV', 'SV', 'SVI']

# %%
logN_dict_hyd_oxy_sul = {ion: logN_dict[ion] for ion in ions_hyd_oxy_sul}

# %%
pos = np.array([logN_HI_p1_test, log_hdens_p1_test, log_metals_p1_test,
                logN_HI_p2_test, log_hdens_p2_test, log_metals_p2_test]) + 1e-4 * np.random.randn(500, 6)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_hyd_oxy_sul, species_logN_interp)
)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_hyd_oxy_sul = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['logN_HI_p1', 'log_hdens_p1', 'log_metals_p1',
#                                         'logN_HI_p2', 'log_hdens_p2', 'log_metals_p2'])
#flat_samples_hyd_oxy_sul.to_csv(savedir+'hyd_oxy_sul_solar_flat_c1.csv', index=False)

flat_samples_hyd_oxy_sul = pd.read_csv(savedir+'hyd_oxy_sul_solar_flat_c1.csv')

# %%
fig = corner.corner(
    flat_samples_hyd_oxy_sul, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_\mathrm{HI, p1})$', r'$\log(n_\mathrm{H, p1})$', r'$[\mathrm{O/H}]_{\mathrm{p1}}$',
            r'$\log(N_\mathrm{HI, p2})$', r'$\log(n_\mathrm{H, p2})$', r'$[\mathrm{O/H}]_{\mathrm{p2}}$',], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
n_H, pdf, cdf, cdf_inv_interp = log_to_linear_PDF(flat_samples_hyd_oxy_sul['log_hdens_p1'], bins=300)

# %%
np.min(n_H)
# Out:
# 0.0001446844951964193

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.plot(n_H, cdf)
ax.set_xlabel('n_H')
ax.set_ylabel('CDF')

#ax.set_xscale('log')
# Out:
# Text(0, 0.5, 'CDF')

# %%
np.log10(cdf_inv_interp(1-cdf_3sig))
# Out:
# -3.5433112810327434

# %%
N, pdf, cdf, cdf_inv_interp = log_to_linear_PDF(flat_samples_hyd_oxy_sul['logN_HI_p2'])

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.plot(N, cdf)
ax.set_xlabel('n_H')
ax.set_ylabel('CDF')

#ax.set_xscale('log')
# Out:
# Text(0, 0.5, 'CDF')

# %%
np.log10(cdf_inv_interp(cdf_3sig))
# Out:
# 13.982240555702303

# %%
n_H, pdf, cdf, cdf_inv_interp = log_to_linear_PDF(flat_samples_hyd_oxy_sul['log_hdens_p2'])

# %%
np.max(n_H)
# Out:
# 0.0005259276691956239

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.plot(n_H, cdf)
ax.set_xlabel('n_H')
ax.set_ylabel('CDF')

#ax.set_xscale('log')
# Out:
# Text(0, 0.5, 'CDF')

# %%
np.log10(cdf_inv_interp(cdf_3sig))
# Out:
# -3.3865074142125353

# %%
np.percentile(flat_samples_hyd_oxy_sul['log_metals_p2'], 100*(1-cdf_3sig))
# Out:
# -2.3915159429582533

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI' : '14.11, -0.07, +0.07',
            'HeI' : '<13.0',
            'CII' : '<13.4',
            'CIII' : '12.8, -0.2, +0.2',
            'CIV' : '13.65, -0.01, +0.01',
            'NII' : '<13.4',
            'NIII' : '<13.0',
            'NIV' : '13.0, -0.1, +0.1',
            'OIII' : '13.79, -0.09, +0.09',
            'OIV' : '14.49, -0.04, +0.04',
            'NeV' : '14.16, -0.05, +0.05',
            'NeVI' : '14.18, -0.05, +0.05',
            'NeVIII' : '<13.5',
            'MgX' : '<13.5',
            'AlII' : '<11.0',
            'AlIII' : '<11.5',
            'SiII' : '<14.3',
            'SiIII' : '<12.0',
            'SiIV' : '<12.0',
            'SIV' : '<12.9',
            'SV' : '<12.6',
            'SVI' : '<13.1',
            'FeII' : '<11.3'}

# %%
sample_indices_hyd_oxy_sul = np.random.randint(low=0, high=len(flat_samples_hyd_oxy_sul), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'HeI', 'CII', 'CIII',  'CIV', 
                                                         'NII', 'NIII', 'NIV', 'NeV', 'NeVI', 'NeVIII', 
                                                         'MgX', 'AlII', 'AlIII',
                                                         'SiII', 'SiIII', 'SiIV', 'FeII'])

for i in range(len(sample_indices_hyd_oxy_sul)):
    
    idx = sample_indices_hyd_oxy_sul[i]
    flat_samples_row = flat_samples_hyd_oxy_sul.iloc[i]
    
    logN_HI_p1 = flat_samples_row['logN_HI_p1']
    log_hdens_p1 = flat_samples_row['log_hdens_p1']
    log_metals_p1 = flat_samples_row['log_metals_p1']

    logN_species_test_p1 = np.array(predict_col_dens(logN_dict, logN_HI_p1, log_hdens_p1, 
                                         log_metals_p1, species_logN_interp))
    
    logN_HI_p2 = flat_samples_row['logN_HI_p2']
    log_hdens_p2 = flat_samples_row['log_hdens_p2']
    log_metals_p2 = flat_samples_row['log_metals_p2']
    
    logN_species_test_p2 = np.array(predict_col_dens(logN_dict, logN_HI_p2, log_hdens_p2, 
                                         log_metals_p2, species_logN_interp))
    
    logN_species_test = np.log10(10**logN_species_test_p1 + 10**logN_species_test_p2)
        
    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test_p1, color='gold', lw=.2, alpha=.15)
    ax.plot(np.arange(len(logN_species_test)), logN_species_test_p2, color='skyblue', lw=.2, alpha=.15)

    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.15)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.34 \pm 0.03$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -0.66 \pm 0.02$')

#plt.savefig(savedir+'z=1_1659134_cloudy_hyd_oxy_c1.pdf', dpi=300)

# %% [markdown]
# # Component 2

# %% [markdown]
# Enter measurements for species

# %%
logN_dict = {'HI':'13.98, -0.07, +0.07',
            'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'<12.4',
            'CIV':'13.41, -0.01, +0.01',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'<12.4',
            'OIII':'<13.1',
            'OIV':'14.21, -0.05, +0.05',
            'NeV':'<13.1',
            'NeVI':'13.9, -0.1, +0.1',
            'NeVIII':'<13.3',
            'MgX':'<13.3',
            'AlII':'<10.7',
            'AlIII':'<11.1',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            'SVI':'<12.8',
            'FeII':'<11.7'}

# %% [markdown]
# Try out a solution

# %%
logN_HI_test = 13.98
log_hdens_test = -3.67
log_metals_test = -0.29

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp)

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Get column density ratios

# %%
gen_logN_ratio_str(logN_dict['OIII'], logN_dict['OIV'])
# Out:
# '<-1.11, 0.15'

# %%
logN_ratio_dict = {'OIII/OIV': '<-1.1, 0.2',
                  'CIII/CIV': '<-1.0, 0.1'}

# %% [markdown]
# Generate predicted column density ratios

# %%
fig, ax = plt.subplots(1, figsize=(5,4))

plot_logN_ratio(ax, species_logN_interp, logN_ratio_dict, logN_HI_ref=12.5, log_metals_ref=-2.5)

ax.set_xlim(-5, -1.8)
ax.set_ylim(-3.2, 2)
# Out:
# (-3.2, 2.0)

# %% [markdown]
# # Oxygen + Sulphur fit

# %% [markdown]
# Isolate the ions

# %%
ions_oxy_sul = ['OIII', 'OIV', 'SIV', 'SV', 'SVI', 'NeV']

# %%
logN_dict_oxy_sul = {ion: logN_dict[ion] for ion in ions_oxy_sul}

# %%
logN_dict_oxy_sul
# Out:
# {'OIII': '<13.1',
#  'OIV': '14.21, -0.05, +0.05',
#  'SIV': '<12.6',
#  'SV': '<12.3',
#  'SVI': '<12.8',
#  'NeV': '<13.1'}

# %%
pos = np.array([log_hdens_test, log_metals_test]) + 1e-4 * np.random.randn(500, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=
'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI':'13.98, -0.07, +0.07',
            'HeI':'<12.8',
            'CII':'<13.1',
            'CIII':'<12.4',
            'CIV':'13.41, -0.01, +0.01',
            'NII':'<13.1',
            'NIII':'<12.8',
            'NIV':'<12.4',
            'OIII':'<13.1',
            'OIV':'14.21, -0.05, +0.05',
            'NeV':'<13.1',
            'NeVI':'13.90, -0.10, +0.08',
            'NeVIII':'<13.3',
            'MgX':'<13.3',
            'AlII':'<10.7',
            'AlIII':'<11.1',
            'SiII':'<13.9',
            'SiIII':'<11.7',
            'SiIV':'<11.7',
            'SIV':'<12.6',
            'SV':'<12.3',
            'SVI':'<12.8',
            'FeII':'<11.7'}

# %%
sample_indices_oxy_sul = np.random.randint(low=0, high=len(flat_samples_oxy_sul), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'HeI', 'CII', 'CIII', 'CIV',
                                                         'NII', 'NIII', 'NIV', 
                                                         'NeVI', 'NeVIII', 'MgX', 'AlII', 'AlIII',
                                                         'SiII', 'SiIII', 'SiIV', 'FeII'])

for i in range(len(sample_indices_oxy_sul)):
    
    idx = sample_indices_oxy_sul[i]
    flat_samples_row = flat_samples_oxy_sul.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    #C_O = flat_samples_row['C_O']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens, 
                                         log_metals, species_logN_interp) #, {'C':C_O})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.44 \pm 0.11$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = 0.06_{-0.06}^{+0.07}$')

#plt.savefig(savedir+'z=0_72882224_cloudy_oxy.pdf', dpi=300)

# %% [markdown]
# Plot posterior for cloud size

# %%
flat_samples_oxy_sul['logN_HII'] = [species_logN_interp['H+']([logN_HI_test,
                                                            flat_samples_oxy_sul.iloc[i]['log_hdens'],
                                                            flat_samples_oxy_sul.iloc[i]['log_metals']])[0]
                                               for i in range(len(flat_samples_oxy_sul))]

# %%
flat_samples_oxy_sul['cloud_size_kpc'] = ((10**logN_HI_test+10**flat_samples_oxy_sul['logN_HII'])/10**flat_samples_oxy_sul['log_hdens'])*3.24078e-19*1e-3

# %%
#flat_samples_oxy_sul.to_csv(savedir+'oxy_sul_solar_flat.csv', index=False)

# %%
l_med = np.median(flat_samples_oxy_sul['cloud_size_kpc'])
l_perc_16 = np.percentile(flat_samples_oxy_sul['cloud_size_kpc'],16)
l_perc_84 = np.percentile(flat_samples_oxy_sul['cloud_size_kpc'],84)

# %%
l_med, l_med-l_perc_16, l_perc_84-l_med
# Out:
# (1.49062560973213, 0.5975704608796798, 1.0761930634284342)

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.hist(flat_samples_oxy_sul['cloud_size_kpc'], bins=150, density=True, color='coral', alpha=.8)
#ax.axvline(l_med, linestyle=':', lw=2)
#ax.axvline(l_perc_16, linestyle=':', lw=2)
#ax.axvline(l_perc_84, linestyle=':', lw=2)

#ax.text(12, 0.26, s=r'$\log N_{\mathrm{HI}} = 15.40 \pm 0.06$')
#ax.text(12, 0.22, s=r'$l = 9 \pm 1 \ \mathrm{kpc}$')

ax.set_xlabel('Cloud size (kpc)')
ax.set_ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# # Oxygen + Sulphur + Neon fit

# %% [markdown]
# Isolate the ions

# %%
ions_oxy_sul_ne = ['OIII', 'OIV', 'SIV', 'SV', 'SVI', 'NeV', 'NeVI']

# %%
logN_dict_oxy_sul_ne = {ion: logN_dict[ion] for ion in ions_oxy_sul_ne}

# %%
logN_dict_oxy_sul_ne
# Out:
# {'OIII': '<13.4',
#  'OIV': '14.25, -0.04, +0.04',
#  'SIV': '<12.9',
#  'SV': '<12.6',
#  'SVI': '<13.1',
#  'NeV': '13.7, -0.1, +0.1',
#  'NeVI': '13.94, -0.06, +0.06'}

# %%
pos = np.array([log_hdens_test, log_metals_test]) + 1e-4 * np.random.randn(500, 2)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_oxy_sul_ne, species_logN_interp)
)

# %%
#sampler.run_mcmc(pos, 500, progress=True)

# %%
#flat_samples_oxy_sul_ne = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
#                                columns=['log_hdens', 'log_metals'])
#flat_samples_oxy_sul_ne.to_csv(savedir+'oxy_sul_ne_solar_flat_c2.csv', index=False)

flat_samples_oxy_sul_ne = pd.read_csv(savedir+'oxy_sul_ne_solar_flat_c2.csv')

# %%
fig = corner.corner(
    flat_samples_oxy_sul_ne.loc[:, ['log_hdens', 'log_metals']], quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI' : '14.0, -0.1, +0.1',
            'HeI' : '<13.0',
            'CII' : '<13.4',
            'CIII' : '<12.8',
            'CIV' : '13.41, -0.01, +0.01',
            'NII' : '<13.4',
            'NIII' : '<13.0',
            'NIV' : '<12.7',
            'OIII' : '<13.4',
            'OIV' : '14.25, -0.04, +0.04',
            'NeV' : '13.7, -0.1, +0.1',
            'NeVI' : '13.94, -0.06, +0.06',
            'NeVIII' : '<13.5',
            'MgX' : '<13.5',
            'AlII' : '<11.0',
            'AlIII' : '<11.4',
            'SiII' : '<14.2',
            'SiIII' : '<12.0',
            'SiIV' : '<12.0',
            'SIV' : '<12.9',
            'SV' : '<12.6',
            'SVI' : '<13.1',
            'FeII' : '<11.7'}

# %%
sample_indices_oxy_sul_ne = np.random.randint(low=0, high=len(flat_samples_oxy_sul_ne), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'HeI', 'CII', 'CIII',  'CIV', 
                                                         'NII', 'NIII', 'NIV', 
                                                         'NeVIII', 'MgX', 'AlII', 'AlIII',
                                                         'SiII', 'SiIII', 'SiIV', 'FeII'])

for i in range(len(sample_indices_oxy_sul_ne)):
    
    idx = sample_indices_oxy_sul_ne[i]
    flat_samples_row = flat_samples_oxy_sul_ne.iloc[i]
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['log_metals']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens, 
                                         log_metals, species_logN_interp)

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.05)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.44 \pm 0.11$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = 0.06_{-0.06}^{+0.07}$')

#plt.savefig(savedir+'z=0_72882224_cloudy_oxy.pdf', dpi=300)

# %% [markdown]
# # Two phase solution

# %%
logN_HI_p1_test = 13.9
log_hdens_p1_test = -3.7
log_metals_p1_test = 0.2

logN_HI_p2_test = 13.8
log_hdens_p2_test = -4.7
log_metals_p2_test = -0.5

# %%
logN_species_test_p1 = np.array(predict_col_dens(logN_dict, logN_HI_p1_test, log_hdens_p1_test, 
                                     log_metals_p1_test, species_logN_interp))

logN_species_test_p2 = np.array(predict_col_dens(logN_dict, logN_HI_p2_test, log_hdens_p2_test, 
                                     log_metals_p2_test, species_logN_interp))

logN_species_test = np.log10(10**logN_species_test_p1 + 10**logN_species_test_p2)

# %%
fig, ax = plot_column_densities_obs(logN_dict)

ax.plot(np.arange(len(logN_species_test)), logN_species_test_p1, color='salmon', label='p1')
ax.plot(np.arange(len(logN_species_test)), logN_species_test_p2, color='gold', label='p2')
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue', label='Total')

ax.legend()

# %% [markdown]
# # Hydrogen + Oxygen + Sulphur + Neon fit

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = log_prior_tp(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_tp(params, logN_dict, species_logN_interp)

# %%
ions_hyd_oxy_sul_ne = ['HI', 'OIII', 'OIV', 'SIV', 'SV', 'SVI', 'NeV', 'NeVI']

# %%
logN_dict_hyd_oxy_sul_ne = {ion: logN_dict[ion] for ion in ions_hyd_oxy_sul_ne}

# %%
pos = np.array([logN_HI_p1_test, log_hdens_p1_test, log_metals_p1_test,
                logN_HI_p2_test, log_hdens_p2_test, log_metals_p2_test]) + 1e-4 * np.random.randn(500, 6)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_hyd_oxy_sul_ne, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 500, progress=True);
# Out:
# 100%|█████████████████████████████████████████| 500/500 [10:14<00:00,  1.23s/it]

# %%
flat_samples_hyd_oxy_sul_ne = pd.DataFrame(sampler.get_chain(discard=100, flat=True), 
                                columns=['logN_HI_p1', 'log_hdens_p1', 'log_metals_p1',
                                         'logN_HI_p2', 'log_hdens_p2', 'log_metals_p2'])
flat_samples_hyd_oxy_sul_ne.to_csv(savedir+'hyd_oxy_sul_ne_solar_flat_c2.csv', index=False)

#flat_samples_hyd_oxy_sul_ne = pd.read_csv(savedir+'hyd_oxy_sul_ne_solar_flat_c2.csv')

# %%
fig = corner.corner(
    flat_samples_hyd_oxy_sul_ne, quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_\mathrm{HI, p1})$', r'$\log(n_\mathrm{H, p1})$', r'$[\mathrm{O/H}]_{\mathrm{p1}}$',
            r'$\log(N_\mathrm{HI, p2})$', r'$\log(n_\mathrm{H, p2})$', r'$[\mathrm{O/H}]_{\mathrm{p2}}$',], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Now plot the best models

# %%
logN_dict = {'HI' : '14.0, -0.1, +0.1',
            'HeI' : '<13.0',
            'CII' : '<13.4',
            'CIII' : '<12.8',
            'CIV' : '13.41, -0.01, +0.01',
            'NII' : '<13.4',
            'NIII' : '<13.0',
            'NIV' : '<12.7',
            'OIII' : '<13.4',
            'OIV' : '14.25, -0.04, +0.04',
            'NeV' : '13.7, -0.1, +0.1',
            'NeVI' : '13.94, -0.06, +0.06',
            'NeVIII' : '<13.5',
            'MgX' : '<13.5',
            'AlII' : '<11.0',
            'AlIII' : '<11.4',
            'SiII' : '<14.2',
            'SiIII' : '<12.0',
            'SiIV' : '<12.0',
            'SIV' : '<12.9',
            'SV' : '<12.6',
            'SVI' : '<13.1',
            'FeII' : '<11.7'}

# %%
sample_indices_hyd_oxy_sul_ne = np.random.randint(low=0, high=len(flat_samples_hyd_oxy_sul_ne), size=200)

# %%
fig, ax = plot_column_densities_obs(logN_dict, gray_out=['HI', 'HeI', 'CII', 'CIII',  'CIV', 
                                                         'NII', 'NIII', 'NIV', 'NeVIII', 'MgX', 
                                                         'AlII', 'AlIII',
                                                         'SiII', 'SiIII', 'SiIV', 'FeII'])

for i in range(len(sample_indices_hyd_oxy_sul_ne)):
    
    idx = sample_indices_hyd_oxy_sul_ne[i]
    flat_samples_row = flat_samples_hyd_oxy_sul_ne.iloc[i]
    
    logN_HI_p1 = flat_samples_row['logN_HI_p1']
    log_hdens_p1 = flat_samples_row['log_hdens_p1']
    log_metals_p1 = flat_samples_row['log_metals_p1']

    logN_species_test_p1 = np.array(predict_col_dens(logN_dict, logN_HI_p1, log_hdens_p1, 
                                         log_metals_p1, species_logN_interp))
    
    logN_HI_p2 = flat_samples_row['logN_HI_p2']
    log_hdens_p2 = flat_samples_row['log_hdens_p2']
    log_metals_p2 = flat_samples_row['log_metals_p2']
    
    logN_species_test_p2 = np.array(predict_col_dens(logN_dict, logN_HI_p2, log_hdens_p2, 
                                         log_metals_p2, species_logN_interp))
    
    logN_species_test = np.log10(10**logN_species_test_p1 + 10**logN_species_test_p2)
        
    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test_p1, color='gold', lw=.2, alpha=.15)
    ax.plot(np.arange(len(logN_species_test)), logN_species_test_p2, color='skyblue', lw=.2, alpha=.15)

    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='lightcoral', lw=.2, alpha=.15)

#ax.text(x=-0.5, y=17.3, s=r'$\log(n_\mathrm{H}) = -3.34 \pm 0.03$')
#ax.text(x=-0.5, y=16.5, s=r'$[\mathrm{O}/\mathrm{H}] = -0.66 \pm 0.02$')

#plt.savefig(savedir+'z=1_1659134_cloudy_hyd_oxy_c1.pdf', dpi=300)
