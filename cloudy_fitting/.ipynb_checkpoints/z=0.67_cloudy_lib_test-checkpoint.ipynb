# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd
from cloudy_fit_lib import *
from scipy.interpolate import RegularGridInterpolator
import pickle
import corner
from scipy import integrate, interpolate
import emcee

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/cloudy_grids/'

# %%
savedir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/Ions/z=0.67532051/cloudy_fits/'

# %% [markdown]
# Obtain the UVB grid from FG20

# %%
fg20_z_grid, fg20_wav_grid, fg20_J_nu_grid = read_uvb('', 'fg20_galaxy.ascii')

# %% [markdown]
# Fetch the SED at $z=1$

# %%
z_test = 1

# %%
fg20_J_nu_test = fetch_sed(z_test, fg20_z_grid, fg20_J_nu_grid)

# %% [markdown]
# Specify $N_{\mathrm{HI}}$ grid points and get corresponding filenames

# %%
logN_HI_min = 12
logN_HI_max = 17
logN_HI_step = 0.25

logN_HI_arr = np.arange(logN_HI_min, logN_HI_max+logN_HI_step, logN_HI_step)

# %%
file_list = create_grid_file_list(logN_HI_arr)

# %% [markdown]
# Specify grid points for densities and metallicities

# %%
log_hdens_min = -5
log_hdens_max = 1
log_hdens_step = 0.25

log_hdens_arr = np.arange(log_hdens_min, log_hdens_max+log_hdens_step, log_hdens_step)
logU_arr = np.log10(calc_U(fg20_wav_grid, fg20_J_nu_test, 10**log_hdens_arr))

# %%
log_metals_min = -3
log_metals_max = 1
log_metals_step = 0.25

log_metals_arr = np.arange(log_metals_min, log_metals_max+log_metals_step, log_metals_step)

# %% [markdown]
# Load the final grid

# %%
pkl_file = open(rootdir+'final_grid.pkl', 'rb')
species_logN_samples = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# Interpolate this grid

# %%
species_logN_interp = {}

for s in list(species_logN_samples.keys()):
    
    species_logN_samples[s][species_logN_samples[s]==-np.inf] = -99
    
    species_logN_interp[s] = RegularGridInterpolator((logN_HI_arr, log_hdens_arr, log_metals_arr), 
                                                     species_logN_samples[s])

# %% [markdown]
# Enter measurements for species

# %%
logN_dict = {'HI':'15.40, -0.06, +0.06',
            'CII':'<13.46',
            'CIII':'13.97, -0.03, +0.03',
            'CIV':'13.73, -0.05, +0.05',
            'NII':'<13.23',
            'NIII':'<13.42',
            'NV':'<13.72',
            'OII':'<13.29',
            'OIII':'14.42, -0.02, +0.02',
            'OIV':'14.95, -0.03, +0.03',
            'NeVIII':'<13.35',
            'MgII':'<11.52',
            'AlIII':'<12.29',
            'SiII':'<13.27',
            'SiIII':'<12.77',
            'SVI':'<12.79',
            'FeII':'<11.90'}

# %% [markdown]
# Plot column densities

# %%
logN_HI_test = 15.40
log_hdens_test = -3.3
O_H_test = -0.6
log_metals_test = get_metal_abundance(O_H_test)

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, log_metals_test, species_logN_interp)

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Define overridden prior and likelihood functions

# %%
# Assume solar abundance patterns throughout

def lambda_log_prior(params):
    
    # Only parameters being varied
    logN_HI, log_hdens, O_H = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, O_H, {}])
    
    # Call the original prior function on the full set of parameters
    return log_prior(params_full)

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    logN_HI, log_hdens, O_H = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, O_H, {}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    # Params here will only contain n_H and [O/H]
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# $\alpha$-element only, solar abundance pattern fit

# %%
ions_alpha = ['HI', 'MgII', 'SiII', 'OII', 'SiIII', 'OIII', 'OIV', 'SVI', 'NeVIII']
#ions_alpha = ['HI', 'OIII', 'OIV']

# %%
logN_dict_alpha = {ion: logN_dict[ion] for ion in ions_alpha}

# %%
pos = np.array([logN_HI_test, log_hdens_test, O_H_test]) + 1e-4 * np.random.randn(500, 3)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict_alpha, species_logN_interp)
)

# %%
#sampler.run_mcmc(pos, 500, progress=True);

# %%
#flat_samples_alpha = pd.DataFrame(sampler.get_chain(discard=100, flat=True), columns=['logN_HI', 'log_hdens', '[O/H]'])
#flat_samples_alpha.to_csv(savedir+'alpha_solar_flat.csv', index=False)

flat_samples_alpha = pd.read_csv(savedir+'alpha_solar_flat.csv')

# %%
flat_samples_alpha['[M/H]'] = [get_metal_abundance(O_H) for O_H in flat_samples_alpha['[O/H]']]

# %%
fig = corner.corner(
    flat_samples_alpha.loc[:, ['logN_HI', 'log_hdens', '[O/H]']], quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_{\mathrm{HI}})$', r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# Plot the samples over the measured column densities

# %%
sample_indices_alpha = np.random.randint(low=0, high=len(flat_samples_alpha), size=100)

# %%
ions_ordered = [s for s in list(IP_dict.keys()) if s in list(logN_dict.keys())]

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(len(sample_indices_alpha)):
    
    idx = sample_indices_alpha[i]
    flat_samples_row = flat_samples_alpha.iloc[i]
    logN_HI = flat_samples_row['logN_HI']
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['[M/H]']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI, log_hdens, 
                                         log_metals, species_logN_interp)

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue', lw=.2, alpha=.1)

# %% [markdown]
# Now vary [C/O], [N/O]

# %%
def lambda_log_prior(params):
    
    # Only parameters being varied
    logN_HI, log_hdens, O_H, C_O, N_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, O_H, {'C': C_O, 'N': N_O}])
    
    if N_O < -3:
        return -np.inf
    
    # Call the original prior function on the full set of parameters
    return log_prior(params_full)

# %%
def lambda_log_likelihood(params, logN_dict, species_logN_interp):

    # Only parameters being varied
    logN_HI, log_hdens, O_H, C_O, N_O = params
    
    # Construct the full range of parameters
    # Empty dictionary means solar abundance patterns
    params_full = np.array([logN_HI, log_hdens, O_H, {'C': C_O, 'N': N_O}])
    
    # Call the original likelihood function on the full set of parameters
    return log_likelihood(params_full, logN_dict, species_logN_interp)

# %%
def log_probability(params, logN_dict, species_logN_interp):
    
    # Create the probability function using overridden prior and likelihood functions
    
    lp = lambda_log_prior(params)
    
    if not np.isfinite(lp):
        return -np.inf
    return lp + lambda_log_likelihood(params, logN_dict, species_logN_interp)

# %% [markdown]
# Try out a new solution including sub-solar [C/O], [N/O]

# %%
logN_HI_test = 15.40
log_hdens_test = -3.3
O_H_test = -0.6
C_O_test = -0.5
N_O_test = -0.6
log_metals_test = get_metal_abundance(O_H_test, {'C': C_O_test, 'N': N_O_test})

# %%
logN_species_test = predict_col_dens(logN_dict, logN_HI_test, log_hdens_test, 
                                     log_metals_test, species_logN_interp, {'C': C_O_test, 'N': N_O_test})

# %%
fig, ax = plot_column_densities_obs(logN_dict)
ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue')

# %% [markdown]
# Time to fit!

# %%
pos = np.array([logN_HI_test, log_hdens_test, O_H_test, C_O_test, N_O_test]) + 1e-4 * np.random.randn(500, 5)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(logN_dict, species_logN_interp)
)

# %%
sampler.run_mcmc(pos, 500, progress=True);
# Out:
#  10%|████                                      | 48/500 [01:40<15:45,  2.09s/it]/Users/thepoetoftwilight/Documents/CUBS/Code/cloudy_fitting/cloudy_fit_lib.py:686: RuntimeWarning: divide by zero encountered in log
#   ll += np.log(integrate.simpson(x=lin_y_range, y=np.exp(-.5*(lin_y_range-10**y_bar)**2/sig_lin_y**2)))
# 100%|█████████████████████████████████████████| 500/500 [16:32<00:00,  1.99s/it]

# %%
#flat_samples_subsolar = pd.DataFrame(sampler.get_chain(discard=100, flat=True), columns=['logN_HI', 'log_hdens', '[O/H]', '[C/O]', '[N/O]'])
#flat_samples_subsolar.to_csv(savedir+'subsolar_flat.csv', index=False)

flat_samples_subsolar = pd.read_csv(savedir+'subsolar_flat.csv')

# %%
flat_samples_subsolar['[M/H]'] = [get_metal_abundance(flat_samples_subsolar.iloc[i]['[O/H]'], 
                                                   {'C': flat_samples_subsolar.iloc[i]['[C/O]'],
                                                    'N': flat_samples_subsolar.iloc[i]['[N/O]']}) for 
                               i in range(len(flat_samples_subsolar))]

# %% [markdown]
# The likelihood function for constraining the gas density and chemical abundances is expressed as -
#
# $$\mathcal{L} \propto \left(\prod_{i=1}^n \exp \left(- \frac{1}{2} \left( \frac{\log N_i - \log \bar{N_i}}{\sigma_{i}} \right)^2 \right)\right) \times \left(\prod_{i=1}^l \int_{\log N_i}^{\infty} \mathrm{d}\log N_i' \exp \left(- \frac{1}{2} \left( \frac{\log N_i' - \bar{\log N_i}}{\sigma_{i}} \right)^2 \right) \right) \times \left(\prod_{i=1}^m \int_{0}^{N_i} \mathrm{d}N_i' \exp \left(- \frac{1}{2} \left( \frac{N_i' - \bar{N_i}}{N_i/3} \right)^2 \right) \right)$$
#
# The above likelihood constrains the gas density and chemical abundances primarily by means of $n$ detected ionic species that belong to the same kinematic component identified and fit using Voigt profiles. To do so, we compare the CLOUDY predicted logarithmic column density $\log \bar{N_i}(N_{\mathrm{HI}}, n_{\mathrm{H}}, [\mathrm{O}/\mathrm{H}], [\mathrm{X}/\mathrm{O}])$ to the observed column densities $\log N_i$ with uncertainty $\sigma_i$. For detections, $\sigma_i$ can be read off directly using the inferred Gaussian PDF from Voigt Profile fitting.
#
# The Voigt profile fitting may also include partially saturated features, for which the uncertainty $\sigma_i$ is large (>0.3 dex, typically). The second term of the likelihood function deals with such $l$ such lower limits by marginalizing the reported value from the $3 \sigma$ (or 99%) lower limit to infinity. Similar to detections, $\sigma_i$ is just the uncertainty read off the inferred PDF for the logarithmic column density of the ion.
#
# The joint fitting procedure does not include non-detections, for which we quote the $3\sigma$ upper limits. The last term of the likelihood function deals with $m$ such upper limits by marginalizing the reported observed value $N_i'$ running from 0 to the upper limit $N_i$. Note that the PDF within the integral is in fact comparing $N$, not $\log N$, because PDF is Gaussian in linear space, not log space. This is why the Gaussian likelihood within the integral for upper limits has an uncertainty equal to one-third of the upper limit itself.

# %%
fig = corner.corner(
    flat_samples_subsolar.loc[:, ['logN_HI', 'log_hdens', '[O/H]', '[C/O]', '[N/O]']], 
    quantiles = [0.16, 0.5, 0.84], show_titles=True, 
    labels=[r'$\log(N_{\mathrm{HI}})$', r'$\log(n_\mathrm{H})$', r'$[\mathrm{O/H}]$', 
            r'$[\mathrm{C/O}]$', r'$[\mathrm{N/O}]$'], 
    plot_density=True, levels=[0.68, 0.95], contour_kwargs={'colors':'red'}
);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
hist, bins = np.histogram(flat_samples_subsolar['[N/O]'], bins=150, density=True)
centers = 10**(.5*(bins[1:]+bins[:-1]))

# %%
PDF = hist/integrate.trapz(x=centers, y=hist)

# %%
fig, ax = plt.subplots(1, figsize=(7, 4))

ax.plot(centers, PDF)
ax.set_xlabel(r'$10^{[\mathrm{N}/\mathrm{O}]}=(n_{\mathrm{N}}/n_{\mathrm{O}})/(n_{\mathrm{N}}/n_{\mathrm{O}})_{\odot}$')
ax.set_ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')

# %%
CDF = integrate.cumtrapz(x=centers, y=PDF, initial=0)/integrate.trapz(x=centers, y=PDF)

# %%
CDF_inv_interp = interpolate.interp1d(x=CDF, y=centers)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(centers, PDF)
axes[0].set_xlabel(r'$10^{[\mathrm{N}/\mathrm{O}]}=(n_{\mathrm{N}}/n_{\mathrm{O}})/(n_{\mathrm{N}}/n_{\mathrm{O}})_{\odot}$')
axes[0].set_ylabel('PDF')

axes[1].plot(centers, CDF)
axes[1].axhline(0.995, linestyle=':')
axes[1].axvline(CDF_inv_interp(0.995), linestyle=':')
axes[1].set_xlabel(r'$10^{[\mathrm{N}/\mathrm{O}]}=(n_{\mathrm{N}}/n_{\mathrm{O}})/(n_{\mathrm{N}}/n_{\mathrm{O}})_{\odot}$')
axes[1].set_ylabel('CDF')
# Out:
# Text(0, 0.5, 'CDF')

# %%
np.log10(CDF_inv_interp(0.995))
# Out:
# -0.2129365961972115

# %% [markdown]
# Overplot fit samples

# %%
sample_indices_subsolar = np.random.randint(low=0, high=len(flat_samples_subsolar), size=200)

# %%
ions_ordered = [s for s in list(IP_dict.keys()) if s in list(logN_dict.keys())]

# %%
fig, ax = plot_column_densities_obs(logN_dict)

for i in range(len(sample_indices_subsolar)):
    
    idx = sample_indices_subsolar[i]
    flat_samples_row = flat_samples_subsolar.iloc[i]
    logN_HI = flat_samples_row['logN_HI']
    log_hdens = flat_samples_row['log_hdens']
    log_metals = flat_samples_row['[M/H]']
    C_O = flat_samples_row['[C/O]']
    N_O = flat_samples_row['[N/O]']
    
    logN_species_test = predict_col_dens(logN_dict, logN_HI, log_hdens, 
                                         log_metals, species_logN_interp, {'C': C_O, 'N': N_O})

    # Plot
    ax.plot(np.arange(len(logN_species_test)), logN_species_test, color='skyblue', lw=.2, alpha=.1)

# %% [markdown]
# Plot the posterior for cloud size

# %%
flat_samples_subsolar['cloud_size_pc'] = (10**flat_samples_subsolar['logN_HI']/10**flat_samples_subsolar['log_hdens'])*3.24078e-19

# %%
fig, ax = plt.subplots(1, figsize=(7,4))

ax.hist(flat_samples_subsolar['cloud_size_pc'], bins=200, density=True, color='peachpuff')

ax.set_xlabel('Cloud size (pc)')
ax.set_ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')
