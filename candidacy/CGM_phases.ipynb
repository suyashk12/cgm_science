# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import pandas as pd
from scipy import interpolate
from scipy.stats import linregress
from voigt_fit_lib import *

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %% [markdown]
# Bar chart

# %%
disk_lo = 4e10
disk_hi = 7e10

# %%
cool_lo = 1e9
cool_hi = 1e10

# %%
warm_lo = 1e10
warm_hi = 1e11

# %%
hot_lo = 2e10
hot_hi = 5e10

# %%
mb = 0.17*(10**12.2)

# %%
(cool_lo+warm_lo+hot_lo)/mb, (cool_hi+warm_hi+hot_hi)/mb
# Out:
# (0.11505692752285895, 0.5938422065695946)

# %%
fig, ax = plt.subplots(1, figsize=(4.2,4.2))

ax.bar(0, disk_lo/mb, color='teal')
ax.bar(0, disk_hi/mb, alpha=.1, color='teal')

ax.text(-0.4, 0.8, r'$M_\mathrm{halo} = 10^{12.2} M_\odot$', fontsize=14)

ax.bar(1, cool_lo/mb, color='green')
ax.bar(1, cool_hi/mb, alpha=.1, color='green')

ax.bar(2, warm_lo/mb, color='orange')
ax.bar(2, warm_hi/mb, alpha=.1, color='orange')

ax.bar(3, hot_lo/mb, color='red')
ax.bar(3, hot_hi/mb, alpha=.1, color='red')

ax.bar(4, (disk_lo+cool_lo+warm_lo+hot_lo)/mb, color='brown')
ax.bar(4, (disk_hi+cool_hi+warm_hi+hot_hi)/mb, alpha=.1, color='brown')

ax.set_ylabel('Fraction of baryon budget (0.17 $M_\mathrm{halo}$)', fontsize=13)

ax.set_xticks([0,1,2,3,4], ['Disk', 'Cool \n CGM', 'Warm-Hot\n CGM', 'Hot \n CGM', 'Total'], 
              fontsize=12, minor=False)
ax.xaxis.set_ticks_position('none') 

plt.savefig('/Users/thepoetoftwilight/Documents/CUBS/Baryon_budget.pdf', dpi=300)
