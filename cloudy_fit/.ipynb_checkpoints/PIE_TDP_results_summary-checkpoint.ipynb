# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd
from cloudy_fit_lib import *
from scipy.interpolate import RegularGridInterpolator
import pickle
from astropy import constants, units
import matplotlib.lines as mlines

# %%
rootdir = '/Users/thepoetoftwilight/Documents/CUBS/Data/PG1522+101/'

# %%
plt.style.use('/Users/thepoetoftwilight/Documents/CUBS/Code/science.mplstyle')

# %% [markdown]
# Plot densities versus metallicities

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

# z=0.67
ax.errorbar(-2.7, -0.8, xerr = [[0.3],[0.2]], yerr=0.1, marker='o',
           linestyle='none', capsize=5, color='black')

ax.errorbar(-3.8, -0.7, xerr = [[0.08],[0.06]], yerr=[[0.2],[0.4]], marker='o',
           linestyle='none', capsize=5, color='black', markerfacecolor='none')

# z=1.04
ax.errorbar(-3.08, 0.0, xerr = [0.06], yerr=[0.1], marker='o',
           linestyle='none', capsize=5, color='slateblue')

ax.errorbar(-3.38, 0.1, xerr = [0.06], yerr=[0.1], marker='s',
           linestyle='none', capsize=5, color='slateblue')

ax.errorbar(-3.49, -0.33, xerr = [0.08], yerr=[0.06], marker='v',
           linestyle='none', capsize=5, color='slateblue')

ax.errorbar(-3.1, -0.5, xerr = [[0.2],[0.1]], yerr=[0.1], marker='*',
           linestyle='none', capsize=5, color='slateblue')


# z=1.09
ax.errorbar(-2.6, 0.4, xerr = [0.2], yerr=[0.1], marker='o',
           linestyle='none', capsize=5, color='orangered')

ax.errorbar(-3.67, 0.4, xerr = [[0.07],[0.09]], yerr=[0.3], marker='o', lolims=True,
           linestyle='none', capsize=5, color='orangered', markerfacecolor='none')

# z=1.16
ax.errorbar(-3.18, -1.85, xerr = [0.03], yerr=[0.05], marker='o',
           linestyle='none', capsize=5, color='grey')

ax.errorbar(-3.9, -1.6, xerr = [0.1], yerr=[[0.1],[0.2]], marker='s',
           linestyle='none', capsize=5, color='grey')


# z=1.22
ax.errorbar(-4.24, -0.77, xerr = [0.04], yerr=[0.04], marker='o',
           linestyle='none', capsize=5, color='navy')

# z=1.26
ax.errorbar(-3.3, 0.6, xerr = [[0.2],[0.1]], yerr=[[0.1],[0.2]], marker='o',
           linestyle='none', capsize=5, color='orchid')

# z=1.27

ax.errorbar(-2.4, -0.1, xerr = [[0.6],[0.3]], yerr=[0.3], marker='o', lolims=True,
           linestyle='none', capsize=5, color='firebrick')

ax.errorbar(-4.29, 0., xerr = [0.08], yerr=[[0.2],[0.4]], marker='o',
           linestyle='none', capsize=5, color='firebrick', markerfacecolor='none')

ax.errorbar(-4.07, -0.40, xerr = [0.06], yerr=[0.07], marker='s',
           linestyle='none', capsize=5, color='firebrick')

ax.set_xlabel(r'$\log(n_\mathrm{H}/\mathrm{cm}^{-3})$')
ax.set_ylabel(r'$\mathrm{[O/H]}$')

plt.savefig(rootdir+'Figures/n_H_metals.pdf', dpi=300)
plt.savefig(rootdir+'Figures/n_H_metals.png', dpi=300)

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

# z=0.67
ax.errorbar(-0.8, -0.2, xerr = [0.1], yerr=[[0.1],[0.2]], marker='o',
           linestyle='none', capsize=5, color='black')

ax.errorbar(-0.7, -0.8, xerr = [[0.2],[0.4]], yerr=[0.2], marker='o',
           linestyle='none', capsize=5, color='black', markerfacecolor='none')


# z=1.04
ax.errorbar(0.0, -0.24, xerr = [0.1], yerr=[0.09], marker='o',
           linestyle='none', capsize=5, color='slateblue')

ax.errorbar(0.1, -0.32, xerr = [0.1], yerr=[0.08], marker='s',
           linestyle='none', capsize=5, color='slateblue')

ax.errorbar(-0.33, -0.25, xerr = [0.06], yerr=[0.08], marker='v',
           linestyle='none', capsize=5, color='slateblue')

ax.errorbar(-0.5, 0.3, xerr = [0.1], yerr=[0.2], marker='*',
           linestyle='none', capsize=5, color='slateblue')

# z=1.09

ax.errorbar(0.4, 0.7, xerr = [0.1], yerr=[0.3], marker='o', uplims=True,
           linestyle='none', capsize=5, color='orangered')

ax.errorbar(0.4, -0.15, xerr = [0.3], yerr=[0.05], marker='o', xlolims=True,
           linestyle='none', capsize=5, color='orangered', markerfacecolor='none')

# z=1.16

ax.errorbar(-1.85, -0.17, xerr = [0.05], yerr=[0.04], marker='o',
           linestyle='none', capsize=5, color='grey')

ax.errorbar(-1.6, 0.0, xerr = [[0.1],[0.2]], yerr=[0.1], marker='s',
           linestyle='none', capsize=5, color='grey')

# z=1.22
ax.errorbar(-0.77, -0.49, xerr = [0.04], yerr=[0.08], marker='o',
           linestyle='none', capsize=5, color='navy')

# z=1.26
ax.errorbar(0.6, 0.00, xerr = [[0.1],[0.2]], yerr=[0.09], marker='o',
           linestyle='none', capsize=5, color='orchid')

# z=1.27
ax.errorbar(0.1, 0.2, xerr = [0.3], yerr=[0.3], marker='o', xlolims=True, uplims=True,
           linestyle='none', capsize=5, color='firebrick')

ax.errorbar(0.0, -0.20, xerr = [[0.2],[0.4]], yerr=[0.08], marker='o',
           linestyle='none', capsize=5, color='firebrick', markerfacecolor='none')

ax.errorbar(-0.40, -0.15, xerr = [0.07], yerr=[0.07], marker='s',
           linestyle='none', capsize=5, color='firebrick')

ax.set_xlabel(r'$\mathrm{[O/H]}$')
ax.set_ylabel(r'$\mathrm{[C/O]}$')

ax.axhline(0, linestyle='--')
ax.axvline(0, linestyle='--')

plt.savefig(rootdir+'Figures/C_O_metals.pdf', dpi=300)
plt.savefig(rootdir+'Figures/C_O_metals.png', dpi=300)

# %%
x = [510.19,287.42,116.62,65.60,36.76,20.72,11.66,4.75,2.67,1.50,0.85]
y = [8.39,5.74,8.80,7.78,6.97,6.35,5.90,7.73,7.56,7.51,7.53]

x1 = [367.59,207.25,84.61,47.53,26.71,10.96,6.15,3.45,0.62,1.10,0.62]
y1 = [2.97,2.72,3.37,2.96,2.62,3.29,3.18,3.55,11.44,6.33,3.64]

x2 = [367.59,150.21,84.61,34.54,19.49,10.96,6.15,3.45,0.62,1.10,0.62]
y2 = [1.15,1.46,1.18,1.18,1.11,1.10,1.12,1.15,3.71,1.19,1.18]

# %%
fig, ax = plt.subplots(1, figsize=(4,4))

# z=0.67
ax.scatter(4, 32/4, marker='o', color='black')
ax.scatter(74, 411/74, marker='o', color='black', facecolor='none')

# z=1.04
ax.scatter(8, 19/8, marker='o', color='slateblue')
ax.scatter(21, 70/21, marker='s', color='slateblue')
ax.scatter(27, 111/27, marker='v', color='slateblue')
ax.scatter(11, 45/11, marker='*', color='slateblue')

# z=1.09
ax.scatter(2.5, 2.3/2.5, marker='o', color='orangered')
ax.scatter(31, 23/31, marker='o', color='orangered', facecolor='none')

# z=1.16
ax.scatter(18, 201/18, marker='o', color='grey')
ax.scatter(128, 1521/128, marker='s', color='grey')

# z=1.16
ax.scatter(18, 201/18, marker='o', color='grey')
ax.scatter(128, 1521/128, marker='s', color='grey')

# z=1.22
ax.scatter(185, 1607/185, marker='o', color='navy')

# z=1.26
ax.scatter(12.3, 12.0/12.3, marker='o', color='orchid')

# z=1.27
ax.scatter(1.5, 2.3/1.5, marker='o', color='firebrick')
ax.scatter(233, 564/233, marker='o', color='firebrick', facecolor='none')
ax.scatter(147, 1033/147, marker='s', color='firebrick')

ax.axhline(1, linestyle=':')

ax.set_xlabel(r'$t_\mathrm{rec,CIV} \ (\mathrm{Myr})$')
ax.set_ylabel(r'$t_\mathrm{cool}/t_\mathrm{rec,CIV}$')

ax.set_xscale('log')
ax.set_yscale('log')

ax.plot(x,y, linestyle='--', label=r'$Z=0.1Z_\odot$')
ax.plot(x1,y1, linestyle='-.', label=r'$Z=Z_\odot$', color='black')
ax.plot(x2,y2, linestyle=':', lw=1.5, label=r'$Z=3Z_\odot$', color='black')

ax.set_xlim(1.1e0,3e2)
ax.legend(fontsize=8, loc='center left')
plt.savefig(rootdir+'Figures/t_rec_t_cool.pdf', dpi=300)
plt.savefig(rootdir+'Figures/t_rec_t_cool.png', dpi=300)

# %%
fig, axes = plt.subplots(1, 3, figsize=(4*3, 3))

# n_H vs. metals
# z=0.67
axes[0].errorbar(-2.7, -0.8, xerr = [[0.3],[0.2]], yerr=0.1, marker='o',
           linestyle='none', capsize=5, color='black')

axes[0].errorbar(-3.8, -0.7, xerr = [[0.08],[0.06]], yerr=[[0.2],[0.4]], marker='o',
           linestyle='none', capsize=5, color='black', markerfacecolor='none')

# z=1.04
axes[0].errorbar(-3.08, 0.0, xerr = [0.06], yerr=[0.1], marker='o',
           linestyle='none', capsize=5, color='slateblue')

axes[0].errorbar(-3.38, 0.1, xerr = [0.06], yerr=[0.1], marker='s',
           linestyle='none', capsize=5, color='slateblue')

axes[0].errorbar(-3.49, -0.33, xerr = [0.08], yerr=[0.06], marker='v',
           linestyle='none', capsize=5, color='slateblue')

axes[0].errorbar(-3.1, -0.5, xerr = [[0.2],[0.1]], yerr=[0.1], marker='*',
           linestyle='none', capsize=5, color='slateblue')


# z=1.09
axes[0].errorbar(-2.6, 0.4, xerr = [0.2], yerr=[0.1], marker='o',
           linestyle='none', capsize=5, color='orangered')

axes[0].errorbar(-3.67, 0.4, xerr = [[0.07],[0.09]], yerr=[0.3], marker='o', lolims=True,
           linestyle='none', capsize=5, color='orangered', markerfacecolor='none')

# z=1.16
axes[0].errorbar(-3.18, -1.85, xerr = [0.03], yerr=[0.05], marker='o',
           linestyle='none', capsize=5, color='grey')

axes[0].errorbar(-3.9, -1.6, xerr = [0.1], yerr=[[0.1],[0.2]], marker='s',
           linestyle='none', capsize=5, color='grey')


# z=1.22
axes[0].errorbar(-4.24, -0.77, xerr = [0.04], yerr=[0.04], marker='o',
           linestyle='none', capsize=5, color='navy')

# z=1.26
axes[0].errorbar(-3.3, 0.6, xerr = [[0.2],[0.1]], yerr=[[0.1],[0.2]], marker='o',
           linestyle='none', capsize=5, color='orchid')

# z=1.27

axes[0].errorbar(-2.4, -0.1, xerr = [[0.6],[0.3]], yerr=[0.3], marker='o', lolims=True,
           linestyle='none', capsize=5, color='firebrick')

axes[0].errorbar(-4.29, 0., xerr = [0.08], yerr=[[0.2],[0.4]], marker='o',
           linestyle='none', capsize=5, color='firebrick', markerfacecolor='none')

axes[0].errorbar(-4.07, -0.40, xerr = [0.06], yerr=[0.07], marker='s',
           linestyle='none', capsize=5, color='firebrick')

axes[0].axhline(0, linestyle=':')
axes[0].set_xlabel(r'$\log(n_\mathrm{H}/\mathrm{cm}^{-3})$')
axes[0].set_ylabel(r'$\mathrm{[O/H]}$')

# metals vs. C_O
# z=0.67
axes[1].errorbar(-0.8, -0.2, xerr = [0.1], yerr=[[0.1],[0.2]], marker='o',
           linestyle='none', capsize=5, color='black')

axes[1].errorbar(-0.7, -0.8, xerr = [[0.2],[0.4]], yerr=[0.2], marker='o',
           linestyle='none', capsize=5, color='black', markerfacecolor='none')

axes[1].axvline(0, linestyle=':')
axes[1].axhline(0, linestyle=':')


# z=1.04
axes[1].errorbar(0.0, -0.24, xerr = [0.1], yerr=[0.09], marker='o',
           linestyle='none', capsize=5, color='slateblue')

axes[1].errorbar(0.1, -0.32, xerr = [0.1], yerr=[0.08], marker='s',
           linestyle='none', capsize=5, color='slateblue')

axes[1].errorbar(-0.33, -0.25, xerr = [0.06], yerr=[0.08], marker='v',
           linestyle='none', capsize=5, color='slateblue')

axes[1].errorbar(-0.5, 0.3, xerr = [0.1], yerr=[0.2], marker='*',
           linestyle='none', capsize=5, color='slateblue')

# z=1.09

axes[1].errorbar(0.4, 0.7, xerr = [0.1], yerr=[0.3], marker='o', uplims=True,
           linestyle='none', capsize=5, color='orangered')

axes[1].errorbar(0.4, -0.15, xerr = [0.3], yerr=[0.05], marker='o', xlolims=True,
           linestyle='none', capsize=5, color='orangered', markerfacecolor='none')

# z=1.16

axes[1].errorbar(-1.85, -0.17, xerr = [0.05], yerr=[0.04], marker='o',
           linestyle='none', capsize=5, color='grey')

axes[1].errorbar(-1.6, 0.0, xerr = [[0.1],[0.2]], yerr=[0.1], marker='s',
           linestyle='none', capsize=5, color='grey')

# z=1.22
axes[1].errorbar(-0.77, -0.49, xerr = [0.04], yerr=[0.08], marker='o',
           linestyle='none', capsize=5, color='navy')

# z=1.26
axes[1].errorbar(0.6, 0.00, xerr = [[0.1],[0.2]], yerr=[0.09], marker='o',
           linestyle='none', capsize=5, color='orchid')

# z=1.27
axes[1].errorbar(0.1, 0.2, xerr = [0.3], yerr=[0.3], marker='o', xlolims=True, uplims=True,
           linestyle='none', capsize=5, color='firebrick')

axes[1].errorbar(0.0, -0.20, xerr = [[0.2],[0.4]], yerr=[0.08], marker='o',
           linestyle='none', capsize=5, color='firebrick', markerfacecolor='none')

axes[1].errorbar(-0.40, -0.15, xerr = [0.07], yerr=[0.07], marker='s',
           linestyle='none', capsize=5, color='firebrick')

axes[1].set_xlabel(r'$\mathrm{[O/H]}$')
axes[1].set_ylabel(r'$\mathrm{[C/O]}$')

# t_rec, t_cool
# z=0.67
axes[2].scatter(4, 32/4, marker='o', color='black')
axes[2].scatter(74, 411/74, marker='o', color='black', facecolor='none')

# z=1.04
axes[2].scatter(8, 19/8, marker='o', color='slateblue')
axes[2].scatter(21, 70/21, marker='s', color='slateblue')
axes[2].scatter(27, 111/27, marker='v', color='slateblue')
axes[2].scatter(11, 45/11, marker='*', color='slateblue')

# z=1.09
axes[2].scatter(2.5, 2.3/2.5, marker='o', color='orangered')
axes[2].scatter(31, 23/31, marker='o', color='orangered', facecolor='none')

# z=1.16
axes[2].scatter(18, 201/18, marker='o', color='grey')
axes[2].scatter(128, 1521/128, marker='s', color='grey')

# z=1.16
axes[2].scatter(18, 201/18, marker='o', color='grey')
axes[2].scatter(128, 1521/128, marker='s', color='grey')

# z=1.22
axes[2].scatter(185, 1607/185, marker='o', color='navy')

# z=1.26
axes[2].scatter(12.3, 12.0/12.3, marker='o', color='orchid')

# z=1.27
axes[2].scatter(1.5, 2.3/1.5, marker='o', color='firebrick')
axes[2].scatter(233, 564/233, marker='o', facecolor='none', color='firebrick')
axes[2].scatter(147, 1033/147, marker='s', color='firebrick')

axes[2].axhline(1, linestyle=':')

axes[2].set_xlabel(r'$t_\mathrm{rec,CIV} \ (\mathrm{Myr})$')
axes[2].set_ylabel(r'$t_\mathrm{cool}/t_\mathrm{rec,CIV}$')

axes[2].set_xscale('log')
axes[2].set_yscale('log')

#axes[2].text(10,7.8,r'$Z=0.1Z_\odot$', fontsize=10)
#axes[2].plot(x,y, linestyle='--')

#axes[2].text(80,3.6,r'$Z=Z_\odot$', fontsize=10)
#axes[2].plot(x1,y1, linestyle='-.', label=r'$Z=Z_\odot$', color='black')

#axes[2].text(80,1.5,r'$Z=3Z_\odot$', fontsize=10)
#axes[2].plot(x2,y2, linestyle='-.', label=r'$Z=Z_\odot$', color='black')

axes[2].set_xlim(1.1e0,3e2)

plt.subplots_adjust(wspace=0.4, hspace=0.0)

# Specify handles ONLY for this plot

handles = []
z_list = [r'$z=0.67,\ \mathrm{c1L}$', r'$z=0.67,\ \mathrm{c1H}$',
          r'$z=1.04,\ \mathrm{c1}$', r'$z=1.04,\ \mathrm{c2}$',
          r'$z=1.04,\ \mathrm{c3}$', r'$z=1.04,\ \mathrm{c4}$',
          r'$z=1.09,\ \mathrm{c1L}$', r'$z=1.09,\ \mathrm{c1H}$',
          r'$z=1.16,\ \mathrm{c1}$', r'$z=1.16,\ \mathrm{c2}$',
          r'$z=1.22,\ \mathrm{c1}$', r'$z=1.26,\ \mathrm{c1}$',
          r'$z=1.27,\ \mathrm{c1L}$', r'$z=1.27,\ \mathrm{c1H}$',
          r'$z=1.27,\ \mathrm{c2}$'
         ]

colors_list = ['black', 'black',
                 'slateblue', 'slateblue','slateblue','slateblue',
                 'orangered', 'orangered', 'grey', 'grey',
                 'navy', 'orchid',
                 'firebrick', 'firebrick', 'firebrick']

markers_list = ['o', 'o', 'o', 's', 'v', '*', 'o', 'o', 'o', 's', 'o', 'o', 'o' ,'o', 's']

fc_list = ['black', 'none',
                 'slateblue', 'slateblue','slateblue','slateblue',
                 'orangered', 'none', 'grey', 'grey',
                 'navy', 'orchid',
                 'firebrick', 'none', 'firebrick']

for i in range(len(z_list)):
    
    handles.append(mlines.Line2D([], [], color=colors_list[i], marker=markers_list[i],
                  markerfacecolor = fc_list[i],
                  linestyle='None', markersize=8, label=z_list[i]))
    
#plt.legend(handles=handles, loc='upper center', bbox_to_anchor=(-0.93, 1.5),
#          fancybox=True, shadow=True, ncol=5)

#plt.savefig(rootdir+'Figures/PIE_summary.pdf', dpi=300)
plt.savefig(rootdir+'Figures/PIE_summary.png', dpi=300)

# %%
x = np.arange(0,1,0.1)
f = (1-x)**4/4 + x**4/12 + x*(1-x)**3/3 - np.pi

# %%
plt.plot(x,f)
